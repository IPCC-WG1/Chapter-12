# %% [markdown]
# ## Calculate the snow index (SWE100) for global warming levels for CMIP6

# %% [markdown]
# This script calculates results for the snow index (SWE100) for the 20 year periods in which certain global warming levels (1.5, 2, 3 and 4 degrees above pre-industrial (1850-1900)) are reached for each CMIP6 model.
#
# Inputs:
# - The Atlas' table of when each CMIP6 model reaches each global warming level- available in this repository, or a since updated version here https://github.com/SantanderMetGroup/ATLAS/tree/master/warming-levels. This page also describes the global warming level methodology in more detail.
# - Yearly netcdf files of SWE100 output by the script snow_CMIP6.sh
#
# Created by Carley Iles (carley.iles@cicero.oslo.no) and Jerome Servonnat (jerome.servonnat@lsce.ipsl.fr)

# %% [markdown]
# ### 1. Get the periods for the GWL

# %%
# Specify the path to the Global warming levels csv file.
GWL_csv = '/path/CMIP6_Atlas_WarmingLevels.csv'

# %%
import csv

# %%
GWL_dict = dict()
i = 0
with open(GWL_csv) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
    for row in spamreader:
        #print(i)
        print(row)
        model = row[0].split('_')[0]
        print(model)
        GWL_dict[model] = dict()
        if i==0:
            colnames = row
        j = 1
        for elt in row[1:17]:
            #print(j)
            print (elt)
            GWL_dict[model][colnames[j]] = row[j]
            j = j + 1
        i = i + 1
# Out:
# ['', '1.5_ssp126', '2_ssp126', '3_ssp126', '4_ssp126', '1.5_ssp245', '2_ssp245', '3_ssp245', '4_ssp245', '1.5_ssp370', '2_ssp370', '3_ssp370', '4_ssp370', '1.5_ssp585', '2_ssp585', '3_ssp585', '4_ssp585']
#
# 1.5_ssp126
# 2_ssp126
# 3_ssp126
# 4_ssp126
# 1.5_ssp245
# 2_ssp245
# 3_ssp245
# 4_ssp245
# 1.5_ssp370
# 2_ssp370
# 3_ssp370
# 4_ssp370
# 1.5_ssp585
# 2_ssp585
# 3_ssp585
# 4_ssp585
# ['ACCESS-CM2_r1i1p1f1', '2027', '2042', 'NA', 'NA', '2028', '2040', '2070', 'NA', '2027', '2039', '2062', '2082', '2025', '2038', '2055', '2070']
# ACCESS-CM2
# 2027
# 2042
# NA
# NA
# 2028
# 2040
# 2070
# NA
# 2027
# 2039
# 2062
# 2082
# 2025
# 2038
# 2055
# 2070
# ['ACCESS-ESM1-5_r1i1p1f1', '2030', '2072', 'NA', 'NA', '2029', '2045', 'NA', 'NA', '2033', '2048', '2069', 'NA', '2027', '2038', '2060', '2078']
# ACCESS-ESM1-5
# 2030
# 2072
# NA
# NA
# 2029
# 2045
# NA
# NA
# 2033
# 2048
# 2069
# NA
# 2027
# 2038
# 2060
# 2078
# ['AWI-CM-1-1-MR_r1i1p1f1', '2022', '2050', 'NA', 'NA', '2020', '2039', 'NA', 'NA', '2021', '2037', '2064', 'NA', '2019', '2036', '2059', '2079']
# AWI-CM-1-1-MR
# 2022
# 2050
# NA
# NA
# 2020
# 2039
# NA
# NA
# 2021
# 2037
# 2064
# NA
# 2019
# 2036
# 2059
# 2079
# ['BCC-CSM2-MR_r1i1p1f1', '2041', 'NA', 'NA', 'NA', '2035', '2057', 'NA', 'NA', '2032', '2046', '2074', 'NA', '2031', '2043', '2065', 'NA']
# BCC-CSM2-MR
# 2041
# NA
# NA
# NA
# 2035
# 2057
# NA
# NA
# 2032
# 2046
# 2074
# NA
# 2031
# 2043
# 2065
# NA
# ['CESM2-WACCM_r1i1p1f1', '2021', '2038', 'NA', 'NA', '2024', '2039', '2075', 'NA', '2027', '2041', '2063', '2085', '2020', '2033', '2053', '2068']
# CESM2-WACCM
# 2021
# 2038
# NA
# NA
# 2024
# 2039
# 2075
# NA
# 2027
# 2041
# 2063
# 2085
# 2020
# 2033
# 2053
# 2068
# ['CNRM-CM6-1-HR_r1i1p1f2', '2017', '2030', 'NA', 'NA', '2019', '2033', '2061', 'NA', '2019', '2032', '2057', '2076', '2018', '2029', '2051', '2066']
# CNRM-CM6-1-HR
# 2017
# 2030
# NA
# NA
# 2019
# 2033
# 2061
# NA
# 2019
# 2032
# 2057
# 2076
# 2018
# 2029
# 2051
# 2066
# ['CNRM-CM6-1_r1i1p1f2', '2027', '2058', 'NA', 'NA', '2030', '2047', '2084', 'NA', '2032', '2045', '2066', '2083', '2027', '2040', '2058', '2072']
# CNRM-CM6-1
# 2027
# 2058
# NA
# NA
# 2030
# 2047
# 2084
# NA
# 2032
# 2045
# 2066
# 2083
# 2027
# 2040
# 2058
# 2072
# ['CNRM-ESM2-1_r1i1p1f2', '2047', 'NA', 'NA', 'NA', '2037', '2055', '2088', 'NA', '2037', '2052', '2072', '2089', '2032', '2045', '2064', '2079']
# CNRM-ESM2-1
# 2047
# NA
# NA
# NA
# 2037
# 2055
# 2088
# NA
# 2037
# 2052
# 2072
# 2089
# 2032
# 2045
# 2064
# 2079
# ['CanESM5_r1i1p1f1', '2013', '2025', 'NA', 'NA', '2012', '2023', '2049', '2082', '2012', '2023', '2042', '2059', '2011', '2022', '2040', '2054']
# CanESM5
# 2013
# 2025
# NA
# NA
# 2012
# 2023
# 2049
# 2082
# 2012
# 2023
# 2042
# 2059
# 2011
# 2022
# 2040
# 2054
# ['EC-Earth3-Veg_r1i1p1f1', '2012', '2029', 'NA', 'NA', '2010', '2032', '2067', 'NA', '2011', '2031', '2057', '2075', '2011', '2027', '2050', '2067']
# EC-Earth3-Veg
# 2012
# 2029
# NA
# NA
# 2010
# 2032
# 2067
# NA
# 2011
# 2031
# 2057
# 2075
# 2011
# 2027
# 2050
# 2067
# ['EC-Earth3_r1i1p1f1', '2022', '2042', 'NA', 'NA', '2022', '2044', '2085', 'NA', '2022', '2038', '2062', '2084', '2024', '2035', '2057', '2073']
# EC-Earth3
# 2022
# 2042
# NA
# NA
# 2022
# 2044
# 2085
# NA
# 2022
# 2038
# 2062
# 2084
# 2024
# 2035
# 2057
# 2073
# ['FGOALS-g3_r1i1p1f1', '2076', 'NA', 'NA', 'NA', '2030', '2063', 'NA', 'NA', '2026', '2044', '2082', 'NA', '2027', '2046', '2072', 'NA']
# FGOALS-g3
# 2076
# NA
# NA
# NA
# 2030
# 2063
# NA
# NA
# 2026
# 2044
# 2082
# NA
# 2027
# 2046
# 2072
# NA
# ['GFDL-CM4_r1i1p1f1', '9999', '9999', '9999', '9999', '2031', '2050', 'NA', 'NA', '9999', '9999', '9999', '9999', '2029', '2041', '2059', '2079']
# GFDL-CM4
# 9999
# 9999
# 9999
# 9999
# 2031
# 2050
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 2029
# 2041
# 2059
# 2079
# ['GFDL-ESM4_r1i1p1f1', 'NA', 'NA', 'NA', 'NA', '2046', '2072', 'NA', 'NA', '2041', '2057', '2083', 'NA', '2039', '2052', '2075', 'NA']
# GFDL-ESM4
# NA
# NA
# NA
# NA
# 2046
# 2072
# NA
# NA
# 2041
# 2057
# 2083
# NA
# 2039
# 2052
# 2075
# NA
# ['HadGEM3-GC31-LL_r1i1p1f3', '2021', '2037', 'NA', 'NA', '2019', '2033', '2061', 'NA', '9999', '9999', '9999', '9999', '2020', '2030', '2047', '2063']
# HadGEM3-GC31-LL
# 2021
# 2037
# NA
# NA
# 2019
# 2033
# 2061
# NA
# 9999
# 9999
# 9999
# 9999
# 2020
# 2030
# 2047
# 2063
# ['INM-CM4-8_r1i1p1f1', '2050', 'NA', 'NA', 'NA', '2035', '2063', 'NA', 'NA', '2035', '2052', '2083', 'NA', '2030', '2046', '2069', 'NA']
# INM-CM4-8
# 2050
# NA
# NA
# NA
# 2035
# 2063
# NA
# NA
# 2035
# 2052
# 2083
# NA
# 2030
# 2046
# 2069
# NA
# ['INM-CM5-0_r1i1p1f1', '2036', 'NA', 'NA', 'NA', '2036', '2072', 'NA', 'NA', '2032', '2050', '2083', 'NA', '2030', '2045', '2074', 'NA']
# INM-CM5-0
# 2036
# NA
# NA
# NA
# 2036
# 2072
# NA
# NA
# 2032
# 2050
# 2083
# NA
# 2030
# 2045
# 2074
# NA
# ['IPSL-CM6A-LR_r1i1p1f1', '2019', '2038', 'NA', 'NA', '2018', '2033', '2064', 'NA', '2019', '2034', '2055', '2076', '2018', '2034', '2050', '2066']
# IPSL-CM6A-LR
# 2019
# 2038
# NA
# NA
# 2018
# 2033
# 2064
# NA
# 2019
# 2034
# 2055
# 2076
# 2018
# 2034
# 2050
# 2066
# ['KACE-1-0-G_r2i1p1f1', '2009', '2022', 'NA', 'NA', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '2009', '2021', '2042', '2063']
# KACE-1-0-G
# 2009
# 2022
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 2009
# 2021
# 2042
# 2063
# ['MIROC-ES2L_r1i1p1f2', '2041', 'NA', 'NA', 'NA', '2041', '2063', 'NA', 'NA', '2039', '2055', '2084', 'NA', '2034', '2047', '2070', 'NA']
# MIROC-ES2L
# 2041
# NA
# NA
# NA
# 2041
# 2063
# NA
# NA
# 2039
# 2055
# 2084
# NA
# 2034
# 2047
# 2070
# NA
# ['MIROC6_r1i1p1f1', '2063', 'NA', 'NA', 'NA', '2046', '2073', 'NA', 'NA', '2042', '2059', 'NA', 'NA', '2040', '2052', '2076', 'NA']
# MIROC6
# 2063
# NA
# NA
# NA
# 2046
# 2073
# NA
# NA
# 2042
# 2059
# NA
# NA
# 2040
# 2052
# 2076
# NA
# ['MPI-ESM-1-2-HAM_r1i1p1f1', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999']
# MPI-ESM-1-2-HAM
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# ['MPI-ESM1-2-LR_r1i1p1f1', '2042', 'NA', 'NA', 'NA', '2036', '2057', 'NA', 'NA', '2035', '2052', '2078', 'NA', '2034', '2048', '2071', 'NA']
# MPI-ESM1-2-LR
# 2042
# NA
# NA
# NA
# 2036
# 2057
# NA
# NA
# 2035
# 2052
# 2078
# NA
# 2034
# 2048
# 2071
# NA
# ['MRI-ESM2-0_r1i1p1f1', '2029', 'NA', 'NA', 'NA', '2030', '2049', 'NA', 'NA', '2031', '2045', '2073', 'NA', '2026', '2038', '2064', '2083']
# MRI-ESM2-0
# 2029
# NA
# NA
# NA
# 2030
# 2049
# NA
# NA
# 2031
# 2045
# 2073
# NA
# 2026
# 2038
# 2064
# 2083
# ['NESM3_r1i1p1f1', '2021', '2049', 'NA', 'NA', '2024', '2042', 'NA', 'NA', '9999', '9999', '9999', '9999', '2020', '2033', '2054', '2072']
# NESM3
# 2021
# 2049
# NA
# NA
# 2024
# 2042
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 2020
# 2033
# 2054
# 2072
# ['NorESM2-LM_r1i1p1f1', 'NA', 'NA', 'NA', 'NA', '2055', '2085', 'NA', 'NA', '2051', '2069', 'NA', 'NA', '2042', '2056', '2077', 'NA']
# NorESM2-LM
# NA
# NA
# NA
# NA
# 2055
# 2085
# NA
# NA
# 2051
# 2069
# NA
# NA
# 2042
# 2056
# 2077
# NA
# ['NorESM2-MM_r1i1p1f1', 'NA', 'NA', 'NA', 'NA', '2046', '2077', 'NA', 'NA', '2046', '2062', 'NA', 'NA', '2039', '2054', '2076', 'NA']
# NorESM2-MM
# NA
# NA
# NA
# NA
# 2046
# 2077
# NA
# NA
# 2046
# 2062
# NA
# NA
# 2039
# 2054
# 2076
# NA
# ['UKESM1-0-LL_r1i1p1f2', '2023', '2036', 'NA', 'NA', '2023', '2034', '2059', 'NA', '2022', '2031', '2050', '2069', '2023', '2031', '2046', '2060']
# UKESM1-0-LL
# 2023
# 2036
# NA
# NA
# 2023
# 2034
# 2059
# NA
# 2022
# 2031
# 2050
# 2069
# 2023
# 2031
# 2046
# 2060

# %% [markdown]
# ### 2. Apply on the files

# %%
import glob

# %%
list_of_files = glob.glob('[insert the path to the yearly files output by snow_CMIP6.sh]') # File name will be of the form AWI-CM-1-1-MR_85_snw100seas_1980-2100.1deg.nc
list_of_files
# Out:
# ['/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MRI-ESM2-0_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/AWI-CM-1-1-MR_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/NESM3_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/AWI-CM-1-1-MR_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/BCC-CSM2-MR_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/BCC-CSM2-MR_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/CanESM5_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/CanESM5_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/EC-Earth3_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/EC-Earth3_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/GFDL-CM4_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/GFDL-ESM4_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/GFDL-ESM4_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MRI-ESM2-0_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/HadGEM3-GC31-LL_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/NESM3_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/HadGEM3-GC31-LL_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/UKESM1-0-LL_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/HadGEM3-GC31-MM_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/UKESM1-0-LL_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/HadGEM3-GC31-MM_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/INM-CM4-8_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/INM-CM4-8_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/INM-CM5-0_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/INM-CM5-0_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/IPSL-CM6A-LR_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/IPSL-CM6A-LR_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MIROC6_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MIROC6_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MIROC-ES2L_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MIROC-ES2L_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MPI-ESM1-2-HR_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MPI-ESM1-2-HR_85_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MPI-ESM1-2-LR_26_snw100seas_1980-2100.1deg.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip6/yearly/MPI-ESM1-2-LR_85_snw100seas_1980-2100.1deg.nc']

# %%
import os

# %%
GWL_dict.keys()
# Out:
# dict_keys(['', 'ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-CM-1-1-MR', 'BCC-CSM2-MR', 'CESM2-WACCM', 'CNRM-CM6-1-HR', 'CNRM-CM6-1', 'CNRM-ESM2-1', 'CanESM5', 'EC-Earth3-Veg', 'EC-Earth3', 'FGOALS-g3', 'GFDL-CM4', 'GFDL-ESM4', 'HadGEM3-GC31-LL', 'INM-CM4-8', 'INM-CM5-0', 'IPSL-CM6A-LR', 'KACE-1-0-G', 'MIROC-ES2L', 'MIROC6', 'MPI-ESM-1-2-HAM', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NESM3', 'NorESM2-LM', 'NorESM2-MM', 'UKESM1-0-LL'])

# %%
output_rootdir = '[insert path to directory in which to output the data]'
files_per_GWL = dict()
for GWL in ['1.5','2','3','4']:
    files_per_GWL[GWL] = list()

for wfile in list_of_files:
    #print os.path.basename(wfile)
    filename = os.path.basename(wfile)
    wmodel = filename.split('_')[0]
    scenario = filename.split('_')[1]
    if wmodel in GWL_dict:
        print ('We have : ', wmodel)
        #print (GWL_dict[wmodel])
        for GWL in ['1.5','2','3','4']:
            if scenario=='26': GWL_scenario = GWL+'_ssp126'
            if scenario=='85': GWL_scenario = GWL+'_ssp585'
            
            # --> file nc
            # --> period
            central_year = GWL_dict[wmodel][GWL_scenario]
            if central_year not in ['NA','9999']:
                outfilename = output_rootdir +'/'+ wmodel+'_'+scenario+'_'+GWL+'.nc'
                start_year = str( int(central_year)-9 )
                end_year = str( int(central_year)+10 )
                cmd = 'cdo timavg -selyear,'+start_year+'/'+end_year+' '+wfile+' '+outfilename
                #print (cmd)
                os.system(cmd)
                files_per_GWL[GWL].append(outfilename) 
    else:
        print ('We dont have GWL info for ',wmodel)
# Out:
# We have :  MRI-ESM2-0
# We have :  AWI-CM-1-1-MR
# We have :  NESM3
# We have :  AWI-CM-1-1-MR
# We have :  BCC-CSM2-MR
# We have :  BCC-CSM2-MR
# We have :  CanESM5
# We have :  CanESM5
# We have :  EC-Earth3
# We have :  EC-Earth3
# We have :  GFDL-CM4
# We have :  GFDL-ESM4
# We have :  GFDL-ESM4
# We have :  MRI-ESM2-0
# We have :  HadGEM3-GC31-LL
# We have :  NESM3
# We have :  HadGEM3-GC31-LL
# We have :  UKESM1-0-LL
# We dont have GWL info for  HadGEM3-GC31-MM
# We have :  UKESM1-0-LL
# We dont have GWL info for  HadGEM3-GC31-MM
# We have :  INM-CM4-8
# We have :  INM-CM4-8
# We have :  INM-CM5-0
# We have :  INM-CM5-0
# We have :  IPSL-CM6A-LR
# We have :  IPSL-CM6A-LR
# We have :  MIROC6
# We have :  MIROC6
# We have :  MIROC-ES2L
# We have :  MIROC-ES2L
# We dont have GWL info for  MPI-ESM1-2-HR
# We dont have GWL info for  MPI-ESM1-2-HR
# We have :  MPI-ESM1-2-LR
# We have :  MPI-ESM1-2-LR

# %%
#testing
files_per_GWL['1.5']
# Out:
# ['/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMPI-ESM-MR_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsbcc-csm1-1-m_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMPI-ESM-LR_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsbcc-csm1-1-m_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsbcc-csm1-1_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsbcc-csm1-1_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCanESM2_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCanESM2_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCNRM-CM5_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCNRM-CM5_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMPI-ESM-MR_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCSIRO-Mk3-6-0_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsCSIRO-Mk3-6-0_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsGFDL-CM3_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsGFDL-ESM2G_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsGFDL-ESM2M_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsHadGEM2-CC_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsHadGEM2-ES_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsHadGEM2-ES_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsinmcm4_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC-ESM-CHEM_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMRI-CGCM3_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC-ESM-CHEM_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC-ESM_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC-ESM_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC5_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMIROC5_85_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsMPI-ESM-LR_26_1.5.nc',
#  '/div/amoc/archive/ciles/IPCC_FGD/snow/cmip5/GWLsNorESM1-M_85_1.5.nc']
