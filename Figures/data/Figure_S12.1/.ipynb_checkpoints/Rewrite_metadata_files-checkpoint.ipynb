# %% [markdown]
# ## CMIP5

# %%
import csv


metadata_input_filename = 'CMIP5_tasmax.csv'

output_metadata_filename = 'CMIP5_day_tx35isimip_md.csv'

rows = []
with open(metadata_input_filename) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        #newrow = row[0].split(',')[1:]
        #.replace('"','')
        #finalrow = newrow.split(',')[1:]
        newrow = row[1:4]+['day']+row[5:]
        finalrow = []
        for elt in newrow:
            finalrow.append(elt.replace('"',''))
        print finalrow
        rows.append(finalrow)
        #rows.append(finalrow)
        #if 'DATA_REF_SYNTAX' in newrow:
        #    finalrow.append('panels')
        #    rows.append(finalrow)
# Out:
# ['DATA_REF_SYNTAX', 'FREQUENCY', 'MODELING_REALM', 'day', 'ENS_MEMBER', 'VERSION_NO', 'VAR_NAME']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'tasmax']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1-m.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BNU.BNU-ESM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CCCma.CanESM2.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCAR.CCSM4.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CMS.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'tasmax']
# ['CMIP5.output.ICHEC.EC-EARTH.historical', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'tasmax']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-CC.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-ES.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.INM.inmcm4.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC5.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MRI.MRI-CGCM3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCC.NorESM1-M.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BNU.BNU-ESM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CCCma.CanESM2.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCAR.CCSM4.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'tasmax']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp26', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'tasmax']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC5.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCC.NorESM1-M.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'tasmax']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BNU.BNU-ESM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CCCma.CanESM2.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCAR.CCSM4.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CMS.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'tasmax']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp45', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'tasmax']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-CC.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.INM.inmcm4.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC5.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCC.NorESM1-M.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'tasmax']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.BNU.BNU-ESM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CCCma.CanESM2.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCAR.CCSM4.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CMCC.CMCC-CMS.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'tasmax']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp85', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'tasmax']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-CC.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.INM.inmcm4.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MIROC.MIROC5.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']
# ['CMIP5.output.NCC.NorESM1-M.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'tasmax']

# %%
with open(output_metadata_filename, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in rows:
        spamwriter.writerow(row)

# %% [markdown]
# ## CORDEX

# %%
AR6regions_by_CORDEX_domain = dict(
    AUS = ['NAU','CAU','EAU','SAU','NZ'],
    SEA = ['SEA'],
    WAS = ['ARP','SAS','WCA'],#,'TIB'],
    EAS = ['TIB','ECA','EAS'],#'SAS'
    CAM = ['NSA','SCA','CAR'],
    SAM = ['NWS','NSA','SAM','NES','SWS','SES','SSA'],
    NAM = ['NWN','NEN','WNA','CNA','ENA','NCA'],#,'GAP'],
    EUR = ['MED','WCE','NEU'],
    AFR = ['WAF','SAH','CAF','WSAF','ESAF','MDG','SEAF','NEAF','ARP']
)


for CORDEX_domain in AR6regions_by_CORDEX_domain:
    metadata_input_filename = 'CORDEX-'+CORDEX_domain+'_tx35isimip.csv'
    output_metadata_filename = 'CORDEX-'+CORDEX_domain+'_day_tx35isimip_md.csv'

    rows = []
    with open(metadata_input_filename) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            newrow = row[1:]
            #.replace('"','')
            #finalrow = newrow.split(',')[1:]
            finalrow = []
            for elt in newrow:
                finalrow.append(elt.replace('"',''))
            if 'DATA_REF_SYNTAX' in finalrow:
                finalrow.append('PANELS')
            else:
                finalrow = finalrow + AR6regions_by_CORDEX_domain[CORDEX_domain]
            print finalrow
            rows.append(finalrow)
            
    with open(output_metadata_filename, 'w') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=',',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        for row in rows:
            spamwriter.writerow(row)
# Out:
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CCCma-CanESM2.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CCCma-CanESM2.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20191130', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20191130', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'tasmax', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'tasmax', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'tasmax', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'tasmax', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160818', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160902', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160902', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20140225', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20140225', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'tasmax', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.UCAN.CCCma-CanESM2.historical.r1i1p1', 'UCAN-WRF341I', 'v2', 'day', 'tasmax', 'v20161020', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.UCAN.CCCma-CanESM2.rcp85.r1i1p1', 'UCAN-WRF341I', 'v2', 'day', 'tasmax', 'v20191223', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.historical.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CCCma-CanESM2.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20180221', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CCCma-CanESM2.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20180417', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20181203', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20181211', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20181017', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20181107', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20180626', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'tasmax', 'v20181008', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'tasmax', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'tasmax', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'tasmax', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'tasmax', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'tasmax', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'tasmax', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.ECMWF-ERAINT.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'tasmax', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360L', 'v1', 'day', 'tasmax', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360L', 'v1', 'day', 'tasmax', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'tasmax', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'tasmax', 'v202006', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'tasmax', 'v20171212', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'tasmax', 'v20171212', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'tasmax', 'v20170912', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'tasmax', 'v20170912', 'SEA']
# ['CORDEX.output.SEA-22.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20180528', 'SEA']
# ['CORDEX.output.SEA-22.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20180528', 'SEA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'tasmax', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'tasmax', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'tasmax', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'tasmax', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20191219', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20200211', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20200106', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20200304', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'tasmax', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20160824', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20160825', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20161130', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20161201', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'tasmax', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'tasmax', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'tasmax', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'tasmax', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'tasmax', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'tasmax', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'tasmax', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'tasmax', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'tasmax', 'v20140804', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'tasmax', 'v20140915', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.NOAA-GFDL-GFDL-ESM2G.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.NOAA-GFDL-GFDL-ESM2G.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'tasmax', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.historical.r12i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'tasmax', 'v20170403', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'tasmax', 'v20170403', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'tasmax', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'tasmax', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'tasmax', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.historical.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp26.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp85.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'tasmax', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'tasmax', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.CCCma-CanESM2.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'tasmax', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-32-ba5f8422f900> in <module>()
#      17
#      18     rows = []
# ---> 19     with open(metadata_input_filename) as csvfile:
#      20         spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
#      21         for row in spamreader:
#
# IOError: [Errno 2] No such file or directory: 'CORDEX-EUR_tx35isimip.csv'
