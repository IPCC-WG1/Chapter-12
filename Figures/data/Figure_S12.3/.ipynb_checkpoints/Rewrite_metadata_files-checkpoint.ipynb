# %% [markdown]
# ## CMIP5

# %%
import csv


metadata_input_filename = 'CMIP5_pr.csv'

output_metadata_filename = 'CMIP5_day_pr_md.csv'

rows = []
with open(metadata_input_filename) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        #newrow = row[0].split(',')[1:]
        #.replace('"','')
        #finalrow = newrow.split(',')[1:]
        newrow = row[1:4]+['day']+row[5:]
        finalrow = []
        for elt in newrow:
            finalrow.append(elt.replace('"',''))
        print finalrow
        rows.append(finalrow)
        #rows.append(finalrow)
        #if 'DATA_REF_SYNTAX' in newrow:
        #    finalrow.append('panels')
        #    rows.append(finalrow)
# Out:
# ['DATA_REF_SYNTAX', 'FREQUENCY', 'MODELING_REALM', 'day', 'ENS_MEMBER', 'VERSION_NO', 'VAR_NAME']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'pr']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1-m.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BNU.BNU-ESM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CCCma.CanESM2.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCAR.CCSM4.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CMS.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.historical', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'pr']
# ['CMIP5.output.ICHEC.EC-EARTH.historical', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'pr']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-CC.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-ES.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.INM.inmcm4.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC5.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MRI.MRI-CGCM3.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCC.NorESM1-M.historical', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BNU.BNU-ESM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CCCma.CanESM2.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCAR.CCSM4.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'pr']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp26', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'pr']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC5.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCC.NorESM1-M.rcp26', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'pr']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BNU.BNU-ESM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CCCma.CanESM2.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCAR.CCSM4.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CMS.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'pr']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp45', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'pr']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-CC.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.INM.inmcm4.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC5.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCC.NorESM1-M.rcp45', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20120115', 'pr']
# ['CMIP5.output.CSIRO-BOM.ACCESS1.3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20120413', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1-m.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BCC.bcc-csm1-1.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.BNU.BNU-ESM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CCCma.CanESM2.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCAR.CCSM4.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CMCC.CMCC-CMS.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'v20110518', 'pr']
# ['CMIP5.output.ICHEC.EC-EARTH.rcp85', 'day', 'atmos', 'day', 'r12i1p1', 'NA', 'pr']
# ['CMIP5.output.LASG-CESS.FGOALS_g2.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-CM3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2G.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output1.NOAA GFDL.GFDL-ESM2M.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-CC.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.INM.inmcm4.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC-ESM.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MIROC.MIROC5.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.MRI.MRI-CGCM3.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']
# ['CMIP5.output.NCC.NorESM1-M.rcp85', 'day', 'atmos', 'day', 'r1i1p1', 'NA', 'pr']

# %%
with open(output_metadata_filename, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in rows:
        spamwriter.writerow(row)

# %% [markdown]
# ## CMIP6

# %%
import csv


metadata_input_filename = 'SPI6_md_CMIP6.csv'

output_metadata_filename = 'CMIP6_day_pr_md.csv'

rows = []
with open(metadata_input_filename) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        #newrow = row[0].split(',')[1:]
        #.replace('"','')
        #finalrow = newrow.split(',')[1:]
        newrow = row[1:4]+['day']+row[5:]
        finalrow = []
        for elt in newrow:
            finalrow.append(elt.replace('"',''))
        print finalrow
        rows.append(finalrow)
# Out:
# ['DATA_REF_SYNTAX', 'SUB_EX_ID', 'ENS_MEMBER', 'day', 'VAR_NAME', 'GRID_LABEL', 'VERSION_NO']
# ['CMIP6.CMIP.AS-RCEC.TaiESM1.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200626']
# ['CMIP6.CMIP.BCC.BCC-CSM2-MR.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20181126']
# ['CMIP6.CMIP.CAMS.CAMS-CSM1-0.historical', 'none', 'r2i1p1f1', 'day', 'pr', 'gn', 'v20200716']
# ['CMIP6.CMIP.CAS.FGOALS-g3.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190826']
# ['CMIP6.CMIP.CCCma.CanESM5.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190429']
# ['CMIP6.CMIP.CCCR-IITM.IITM-ESM.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191226']
# ['CMIP6.CMIP.CMCC.CMCC-CM2-SR5.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200616']
# ['CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20180917']
# ['CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1-HR.historical', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20191021']
# ['CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20181206']
# ['CMIP6.CMIP.CSIRO.ACCESS-ESM1-5.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191115']
# ['CMIP6.CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200310']
# ['CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200225']
# ['CMIP6.CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200217']
# ['CMIP6.CMIP.INM.INM-CM4-8.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190530']
# ['CMIP6.CMIP.INM.INM-CM5-0.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190610']
# ['CMIP6.CMIP.IPSL.IPSL-CM6A-LR.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20180803']
# ['CMIP6.CMIP.KIOST.KIOST-ESM.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20191202']
# ['CMIP6.CMIP.MIROC.MIROC6.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191016']
# ['CMIP6.CMIP.MIROC.MIROC-ES2L.historical', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20191129']
# ['CMIP6.CMIP.MOHC.HadGEM3-GC31-LL.historical', 'none', 'r1i1p1f3', 'day', 'pr', 'gn', 'v20190624']
# ['CMIP6.CMIP.MOHC.UKESM1-0-LL.historical', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20190627']
# ['CMIP6.CMIP.MPI-M.MPI-ESM1-2-HR.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.CMIP.MPI-M.MPI-ESM1-2-LR.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.CMIP.MRI.MRI-ESM2-0.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190603']
# ['CMIP6.CMIP.NCAR.CESM2.historical', 'none', 'r4i1p1f1', 'day', 'pr', 'gn', 'v20190401']
# ['CMIP6.CMIP.NCAR.CESM2-WACCM.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190415']
# ['CMIP6.CMIP.NCC.NorESM2-LM.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190815']
# ['CMIP6.CMIP.NCC.NorESM2-MM.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.CMIP.NIMS-KMA.KACE-1-0-G.historical', 'none', 'r2i1p1f1', 'day', 'pr', 'gr', 'v20190920']
# ['CMIP6.CMIP.NOAA-GFDL.GFDL-CM4.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.CMIP.NOAA-GFDL.GFDL-ESM4.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190726']
# ['CMIP6.CMIP.NUIST.NESM3.historical', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190812']
# ['CMIP6.ScenarioMIP.AS-RCEC.TaiESM1.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200902']
# ['CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190315']
# ['CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190318']
# ['CMIP6.ScenarioMIP.BCC.BCC-CSM2-MR.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190318']
# ['CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp126', 'none', 'r2i1p1f1', 'day', 'pr', 'gn', 'v20191106']
# ['CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp245', 'none', 'r2i1p1f1', 'day', 'pr', 'gn', 'v20200720']
# ['CMIP6.ScenarioMIP.CAMS.CAMS-CSM1-0.ssp585', 'none', 'r2i1p1f1', 'day', 'pr', 'gn', 'v20191106']
# ['CMIP6.ScenarioMIP.CAS.FGOALS-g3.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200927']
# ['CMIP6.ScenarioMIP.CAS.FGOALS-g3.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190818']
# ['CMIP6.ScenarioMIP.CAS.FGOALS-g3.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190818']
# ['CMIP6.ScenarioMIP.CCCma.CanESM5.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190429']
# ['CMIP6.ScenarioMIP.CCCma.CanESM5.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190429']
# ['CMIP6.ScenarioMIP.CCCma.CanESM5.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190429']
# ['CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20201112']
# ['CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200915']
# ['CMIP6.ScenarioMIP.CCCR-IITM.IITM-ESM.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200915']
# ['CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200717']
# ['CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200617']
# ['CMIP6.ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200622']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp126', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20200127']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1-HR.ssp585', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20191202']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp126', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20190219']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp245', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20190219']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-CM6-1.ssp585', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20190219']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp126', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20190328']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp245', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20190328']
# ['CMIP6.ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585', 'none', 'r1i1p1f2', 'day', 'pr', 'gr', 'v20191021']
# ['CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191115']
# ['CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191115']
# ['CMIP6.ScenarioMIP.CSIRO.ACCESS-ESM1-5.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191115']
# ['CMIP6.ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200310']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200310']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200310']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20201123']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200225']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200225']
# ['CMIP6.ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20200225']
# ['CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190603']
# ['CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190603']
# ['CMIP6.ScenarioMIP.INM.INM-CM4-8.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190603']
# ['CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190619']
# ['CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190619']
# ['CMIP6.ScenarioMIP.INM.INM-CM5-0.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20190724']
# ['CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20190903']
# ['CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20190119']
# ['CMIP6.ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr', 'v20190903']
# ['CMIP6.ScenarioMIP.KIOST.KIOST-ESM.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20191202']
# ['CMIP6.ScenarioMIP.KIOST.KIOST-ESM.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20191202']
# ['CMIP6.ScenarioMIP.KIOST.KIOST-ESM.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20210125']
# ['CMIP6.ScenarioMIP.MIROC.MIROC6.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191016']
# ['CMIP6.ScenarioMIP.MIROC.MIROC6.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191016']
# ['CMIP6.ScenarioMIP.MIROC.MIROC6.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191016']
# ['CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp126', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20200318']
# ['CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp245', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20200318']
# ['CMIP6.ScenarioMIP.MIROC.MIROC-ES2L.ssp585', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20200318']
# ['CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp126', 'none', 'r1i1p1f3', 'day', 'pr', 'gn', 'v20200114']
# ['CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp245', 'none', 'r1i1p1f3', 'day', 'pr', 'gn', 'v20190908']
# ['CMIP6.ScenarioMIP.MOHC.HadGEM3-GC31-LL.ssp585', 'none', 'r1i1p1f3', 'day', 'pr', 'gn', 'v20200114']
# ['CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp126', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20190708']
# ['CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp245', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20190715']
# ['CMIP6.ScenarioMIP.MOHC.UKESM1-0-LL.ssp585', 'none', 'r1i1p1f2', 'day', 'pr', 'gn', 'v20190726']
# ['CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190710']
# ['CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190603']
# ['CMIP6.ScenarioMIP.MRI.MRI-ESM2-0.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCAR.CESM2.ssp126', 'none', 'r4i1p1f1', 'day', 'pr', 'gn', 'v20200528']
# ['CMIP6.ScenarioMIP.NCAR.CESM2.ssp245', 'none', 'r4i1p1f1', 'day', 'pr', 'gn', 'v20200528']
# ['CMIP6.ScenarioMIP.NCAR.CESM2.ssp585', 'none', 'r4i1p1f1', 'day', 'pr', 'gn', 'v20200528']
# ['CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190815']
# ['CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190815']
# ['CMIP6.ScenarioMIP.NCAR.CESM2-WACCM.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20200702']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-LM.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NCC.NorESM2-MM.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20191108']
# ['CMIP6.ScenarioMIP.NIMS-KMA.KACE-1-0-G.ssp126', 'none', 'r2i1p1f1', 'day', 'pr', 'gr', 'v20191011']
# ['CMIP6.ScenarioMIP.NIMS-KMA.KACE-1-0-G.ssp245', 'none', 'r2i1p1f1', 'day', 'pr', 'gr', 'v20191125']
# ['CMIP6.ScenarioMIP.NIMS-KMA.KACE-1-0-G.ssp585', 'none', 'r2i1p1f1', 'day', 'pr', 'gr', 'v20191011']
# ['CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-CM4.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gr1', 'v20180701']
# ['CMIP6.ScenarioMIP.NUIST.NESM3.ssp126', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190806']
# ['CMIP6.ScenarioMIP.NUIST.NESM3.ssp245', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190805']
# ['CMIP6.ScenarioMIP.NUIST.NESM3.ssp585', 'none', 'r1i1p1f1', 'day', 'pr', 'gn', 'v20190811']

# %%
with open(output_metadata_filename, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in rows:
        spamwriter.writerow(row)

# %% [markdown]
# ## CORDEX

# %%
AR6regions_by_CORDEX_domain = dict(
    AUS = ['NAU','CAU','EAU','SAU','NZ'],
    SEA = ['SEA'],
    WAS = ['ARP','SAS','WCA'],#,'TIB'],
    EAS = ['TIB','ECA','EAS'],#'SAS'
    CAM = ['NSA','SCA','CAR'],
    SAM = ['NWS','NSA','SAM','NES','SWS','SES','SSA'],
    NAM = ['NWN','NEN','WNA','CNA','ENA','NCA'],#,'GAP'],
    #EUR = ['MED','WCE','NEU'],
    AFR = ['WAF','SAH','CAF','WSAF','ESAF','MDG','SEAF','NEAF','ARP']
)


for CORDEX_domain in AR6regions_by_CORDEX_domain:
    metadata_input_filename = 'CORDEX-'+CORDEX_domain+'_spi6.csv'
    output_metadata_filename = 'CORDEX-'+CORDEX_domain+'_day_pr_md.csv'

    rows = []
    with open(metadata_input_filename) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            newrow = row[1:]
            #.replace('"','')
            #finalrow = newrow.split(',')[1:]
            finalrow = []
            for elt in newrow:
                finalrow.append(elt.replace('"',''))
            if 'DATA_REF_SYNTAX' in finalrow:
                finalrow.append('PANELS')
            else:
                finalrow = finalrow + AR6regions_by_CORDEX_domain[CORDEX_domain]
            print finalrow
            rows.append(finalrow)
            
    with open(output_metadata_filename, 'w') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=',',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        for row in rows:
            spamwriter.writerow(row)
# Out:
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CCCma-CanESM2.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CCCma-CanESM2.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20201114', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20191130', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20191130', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160818', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160902', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160902', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20140225', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20140225', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20150521', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v3', 'day', 'pr', 'v20170705', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.UCAN.CCCma-CanESM2.historical.r1i1p1', 'UCAN-WRF341I', 'v2', 'day', 'pr', 'v20161020', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['CORDEX.output.SAM-44.UCAN.CCCma-CanESM2.rcp85.r1i1p1', 'UCAN-WRF341I', 'v2', 'day', 'pr', 'v20191223', 'NWS', 'NSA', 'SAM', 'NES', 'SWS', 'SES', 'SSA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.MOHC-HadGEM2-ES.historical.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.historical.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CCCma-CanESM2.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20180221', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CCCma-CanESM2.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20180417', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20181203', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20181211', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20181017', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20181107', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20180626', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.OURANOS.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'OURANOS-CRCM5', 'v1', 'day', 'pr', 'v20181008', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'pr', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'pr', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'pr', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'pr', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'pr', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'pr', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'pr', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'pr', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'pr', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20171212', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20171212', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20170912', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20170912', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20180719', 'SEA']
# ['CORDEX.output.SEA-22.RU-CORE.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'RU-CORE-RegCM4-3', 'v4', 'day', 'pr', 'v20180719', 'SEA']
# ['CORDEX.output.SEA-22.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20180528', 'SEA']
# ['CORDEX.output.SEA-22.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20180528', 'SEA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'pr', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'pr', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'pr', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'pr', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20191219', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20200211', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20200106', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20200304', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'pr', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20160824', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20160825', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20161130', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20161201', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'pr', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'pr', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'pr', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'pr', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'pr', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'pr', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'pr', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'pr', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'pr', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'pr', 'v20140804', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'pr', 'v20140915', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'pr', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.historical.r1i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'pr', 'v20140207', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.rcp85.r1i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'pr', 'v20140207', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'pr', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'pr', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'pr', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.historical.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp26.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp85.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'pr', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'pr', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']

# %% [markdown]
# ## EURO CORDEX

# %%
metadata_input_filename = 'CORDEX-EUR11_day_pr_md.txt'
output_metadata_filename = 'CORDEX-EUR_day_pr_md.csv'

rows = []
test = open(metadata_input_filename,'r')
for wline in test.readlines():
    tmp = wline.replace(' ','').replace('\n','').replace('.',';').split(';')
    if 'DATA_REF_SYNTAX' in tmp:
        tmp.append('PANELS')
        ttmp = tmp
    else:
        ttmp = ['.'.join(tmp[0:7])] + tmp[8:] + ['NEU','WCE','MED']
    rows.append( ttmp )
rows
# Out:
# [['DATA_REF_SYNTAX',
#   'MODEL_ID',
#   'RCM_VERSION_ID',
#   'FREQUENCY',
#   'VAR_NAME',
#   'VERSION_NO',
#   'SUBPANEL',
#   'PANELS'],
#  ['cordex.output.EUR-11.CLMcom.CCCma-CanESM2.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20171121',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.CLMcom.CCCma-CanESM2.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20171121',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.CCCma-CanESM2.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170329',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.CCCma-CanESM2.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170329',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20150127',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20150127',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20150127',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190510',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190419',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190702',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190131',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190208',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20200713',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20200925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20200925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v2',
#   'day',
#   'pr',
#   'v20191015',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v2',
#   'day',
#   'pr',
#   'v20191015',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20181212',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20181212',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190418',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170207',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170207',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.RMIB-UGent.CNRM-CERFACS-CNRM-CM5.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170207',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.ICHEC-EC-EARTH.rcp26.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170523',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191210',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200609',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20181126',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20181126',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20170410',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170410',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.ICHEC-EC-EARTH.rcp26.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170208',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170606',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp26.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170206',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200330',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200706',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.ICHEC-EC-EARTH.rcp26.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20201111',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.historical.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190108',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190108',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.historical.r3i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190212',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190212',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.ICHEC-EC-EARTH.rcp26.r3i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190620',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140313',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140324',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190820',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190820',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.historical.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190108',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.ICHEC-EC-EARTH.rcp85.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190103',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.historical.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190115',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.ICHEC-EC-EARTH.rcp85.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190115',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200702',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.IPSL-IPSL-CM5A-MR.historical.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191029',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191029',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MIROC-MIROC5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20171121',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.CLMcom.MIROC-MIROC5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20171121',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MIROC-MIROC5.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180707',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.MIROC-MIROC5.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170329',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.MIROC-MIROC5.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170329',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.MIROC-MIROC5.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20150320',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20150320',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200609',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200924',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191004',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190512',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20190512',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20200229',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.reklies.output.EUR-11.GERICS.MOHC-HadGEM2-ES.historical',
#   'REMO2015',
#   'v1',
#   'day',
#   'pr',
#   'v20170412',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170412',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20160620',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20160705',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v2',
#   'mon',
#   'pr',
#   'v20160830',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200330',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200330',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20201111',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20131026',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170504',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20140515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191219',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200102',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200306',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200518',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191101',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200113',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.ICTP.MPI-M-MPI-ESM-LR.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190502',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190619',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190625',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200623',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200330',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200706',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160419',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160525',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160525',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1a',
#   'mon',
#   'pr',
#   'v20160803',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1a',
#   'mon',
#   'pr',
#   'v20160803',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1',
#   'v1a',
#   'mon',
#   'pr',
#   'v20170504',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex-reklies.output.EUR-11.UHOH.MPI-M-MPI-ESM-LR.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190304',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.UHOH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20170524',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200211',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200221',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160419',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160525',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20160525',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.historical.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191116',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp85.r2i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191116',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200424',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200921',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.MPI-M-MPI-ESM-LR.historical.r3i1p1',
#   'v1',
#   'mon',
#   'pr20190925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.MPI-M-MPI-ESM-LR.rcp85.r3i1p1',
#   'v1',
#   'mon',
#   'pr20190925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.historical.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191001',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.MPI-M-MPI-ESM-LR.rcp85.r3i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191001',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191210',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20191217',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20201203',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.CNRM.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20201112',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.NCC-NorESM1-M.historical.r1i1p1',
#   'v3',
#   'mon',
#   'pr',
#   'v20190522',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.DMI.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v3',
#   'mon',
#   'pr',
#   'v20190522',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20181107',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20181212',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.NCC-NorESM1-M.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190925',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.IPSL.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'day',
#   'pr',
#   'v20190919',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190415',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190412',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.KNMI.NCC-NorESM1-M.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200515',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20200706',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.MOHC.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20201111',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.NCC-NorESM1-M.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180820',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp85.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180820',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.SMHI.NCC-NorESM1-M.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20190115',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.historical.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED'],
#  ['cordex.output.EUR-11.GERICS.NOAA-GFDL-GFDL-ESM2G.rcp26.r1i1p1',
#   'v1',
#   'mon',
#   'pr',
#   'v20180710',
#   'NEU',
#   'WCE',
#   'MED']]

# %%
with open(output_metadata_filename, 'w') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in rows:
        spamwriter.writerow(row)
