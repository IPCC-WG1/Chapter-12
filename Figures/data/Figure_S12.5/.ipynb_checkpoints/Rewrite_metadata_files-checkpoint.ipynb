# %% [markdown]
# ## CORDEX

# %%
import csv

AR6regions_by_CORDEX_domain = dict(
    AUS = ['NAU','CAU','EAU','SAU','NZ'],
    SEA = ['SEA'],
    WAS = ['ARP','SAS','WCA'],#,'TIB'],
    EAS = ['TIB','ECA','EAS'],#'SAS'
    CAM = ['NSA','SCA','CAR'],
    #SAM = ['NWS','NSA','SAM','NES','SWS','SES','SSA'],
    NAM = ['NWN','NEN','WNA','CNA','ENA','NCA'],#,'GAP'],
    #EUR = ['MED','WCE','NEU'],
    AFR = ['WAF','SAH','CAF','WSAF','ESAF','MDG','SEAF','NEAF','ARP']
)


for CORDEX_domain in AR6regions_by_CORDEX_domain:
    metadata_input_filename = 'CORDEX-'+CORDEX_domain+'_sfcWind.csv'
    output_metadata_filename = 'CORDEX-'+CORDEX_domain+'_day_sfcWind_md.csv'

    rows = []
    with open(metadata_input_filename) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            newrow = row[1:]
            #.replace('"','')
            #finalrow = newrow.split(',')[1:]
            finalrow = []
            for elt in newrow:
                finalrow.append(elt.replace('"',''))
            if 'DATA_REF_SYNTAX' in finalrow:
                finalrow.append('PANELS')
            else:
                finalrow = finalrow + AR6regions_by_CORDEX_domain[CORDEX_domain]
            print finalrow
            rows.append(finalrow)
            
    with open(output_metadata_filename, 'w') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=',',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        for row in rows:
            spamwriter.writerow(row)
# Out:
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.CLMcom-HZG.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-HZG-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200312', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.rcp45.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20170206', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17-CLM3-5', 'v1', 'day', 'sfcWind', 'v20180710', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.rcp45.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CCCma-CanESM2.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.rcp45.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.ECMWF-ERAINT.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.rcp45.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.MIROC-MIROC5.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.rcp45.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NCC-NorESM1-M.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NOAA-GFDL-GFDL-ESM2M.rcp45.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44i.CSIRO.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'CSIRO-CCAM-2008', 'v1', 'day', 'sfcWind', 'v20201120', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp45.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp45.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CCCma-CanESM2.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.historical.r1i1p1', 'UNSW-WRF360L', 'v1', 'day', 'sfcWind', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp45.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp45.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-0.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.historical.r1i1p1', 'UNSW-WRF360L', 'v1', 'day', 'sfcWind', 'v20180614', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp45.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp45.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360J', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['CORDEX.output.AUS-44.UNSW.CSIRO-BOM-ACCESS1-3.rcp85.r1i1p1', 'UNSW-WRF360K', 'v1', 'day', 'sfcWind', 'v20200927', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'SEA']
# ['CORDEX.output.SEA-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['CORDEX.output.SEA-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'SEA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-22.ICTP.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'sfcWind', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'sfcWind', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'sfcWind', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-3', 'v4', 'day', 'sfcWind', 'v20150213', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp45.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20150522', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141105', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['CORDEX.output.CAM-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20170508', 'NSA', 'SCA', 'CAR']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-4', 'v0', 'day', 'sfcWind', 'v20190502', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp45.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.rcp45.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171009', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20171115', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM5-0-2', 'v1', 'day', 'sfcWind', 'v20170914', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.rcp45.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['CORDEX.output.EAS-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20150504', 'TIB', 'ECA', 'EAS']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20191219', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20200103', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20200211', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20200106', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20200304', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.CLMcom-ETH.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-ETH-COSMO-crCLIM-v1-1', 'v1', 'day', 'sfcWind', 'v20191217', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MIROC-MIROC5.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.historical.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp26.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-22.ORNL.NCC-NorESM1-M.rcp85.r1i1p1', 'ORNL-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20160824', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20160824', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CCCma-CanESM2.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20160825', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170113', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20161130', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20161201', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20161201', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170321', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.rcp45.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.IITM.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'IITM-RegCM4-4', 'v5', 'day', 'sfcWind', 'v20170311', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20140918', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp45.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20140225', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20170314', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp45.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['CORDEX.output.WAS-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v2', 'day', 'sfcWind', 'v20150521', 'ARP', 'SAS', 'WCA']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.rcp45.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20201015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20191218', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.historical.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20191219', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp26.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.CLMcom-KIT.NCC-NorESM1-M.rcp85.r1i1p1', 'CLMcom-KIT-CCLM5-0-15', 'v1', 'day', 'sfcWind', 'v20200103', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.historical.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp26.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-22.ICTP.NCC-NorESM1-M.rcp85.r1i1p1', 'ICTP-RegCM4-7', 'v0', 'day', 'sfcWind', 'v20190502', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp45.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.ICHEC-EC-EARTH.historical.r12i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.ICHEC-EC-EARTH.rcp45.r12i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.ICHEC-EC-EARTH.rcp85.r12i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MOHC-HadGEM2-ES.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.CLMcom.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'CLMcom-CCLM4-8-17', 'v1', 'day', 'sfcWind', 'v20140401', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'sfcWind', 'v20140804', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.rcp45.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'sfcWind', 'v20140915', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v2', 'day', 'sfcWind', 'v20140915', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.IPSL-IPSL-CM5A-LR.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160705', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MIROC-MIROC5.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160728', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20170620', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.NOAA-GFDL-GFDL-ESM2G.historical.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.GERICS.NOAA-GFDL-GFDL-ESM2G.rcp26.r1i1p1', 'GERICS-REMO2009', 'v1', 'day', 'sfcWind', 'v20160630', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.historical.r12i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'sfcWind', 'v20170403', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'KNMI-RACMO22T', 'v1', 'day', 'sfcWind', 'v20170403', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.historical.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'sfcWind', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'sfcWind', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'sfcWind', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.KNMI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'KNMI-RACMO22T', 'v2', 'day', 'sfcWind', 'v20160802', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.historical.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp26.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp45.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.ICHEC-EC-EARTH.rcp85.r12i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.MPI-CSC.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'MPI-CSC-REMO2009', 'v1', 'day', 'sfcWind', 'v20160412', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CNRM-CERFACS-CNRM-CM5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.CSIRO-QCCCE-CSIRO-Mk3-6-0.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp45.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.IPSL-IPSL-CM5A-MR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MIROC-MIROC5.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20141217', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140612', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp26.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20160803', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NCC-NorESM1-M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.SMHI.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20130927', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.CCCma-CanESM2.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.CCCma-CanESM2.rcp45.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['CORDEX.output.AFR-44.UQAM.MPI-M-MPI-ESM-LR.rcp45.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20150616', 'WAF', 'SAH', 'CAF', 'WSAF', 'ESAF', 'MDG', 'SEAF', 'NEAF', 'ARP']
# ['DATA_REF_SYNTAX', 'MODEL_ID', 'RCM_VERSION_ID', 'FREQUENCY', 'VAR_NAME', 'VERSION_NO', 'PANELS']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.historical.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.rcp45.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.CCCma.CCCma-CanESM2.rcp85.r1i1p1', 'CCCma-CanRCM4', 'r2', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.historical.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191015', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp26.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191025', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.GERICS.NCC-NorESM1-M.rcp85.r1i1p1', 'GERICS-REMO2015', 'v1', 'day', 'sfcWind', 'v20191029', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.MOHC-HadGEM2-ES.historical.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.ISU.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'ISU-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.historical.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MOHC-HadGEM2-ES.rcp85.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'NCAR-RegCM4', 'v4-4-rc8', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.NOAA-GFDL-GFDL-ESM2M.historical.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.NCAR.NOAA-GFDL-GFDL-ESM2M.rcp85.r1i1p1', 'NCAR-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UA.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'UA-WRF', 'v3-5-1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.CCCma-CanESM2.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-LR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-LR.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.historical.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-22.UQAM.MPI-M-MPI-ESM-MR.rcp85.r1i1p1', 'UQAM-CRCM5', 'v1', 'day', 'sfcWind', 'v20200831', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.historical.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.rcp45.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.DMI.ICHEC-EC-EARTH.rcp85.r3i1p1', 'DMI-HIRHAM5', 'v1', 'day', 'sfcWind', 'v20131108', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.historical.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.rcp45.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.CCCma-CanESM2.rcp85.r1i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.historical.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp26.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp45.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
# ['CORDEX.output.NAM-44.SMHI.ICHEC-EC-EARTH.rcp85.r12i1p1', 'SMHI-RCA4', 'v1', 'day', 'sfcWind', 'v20140401', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA']
