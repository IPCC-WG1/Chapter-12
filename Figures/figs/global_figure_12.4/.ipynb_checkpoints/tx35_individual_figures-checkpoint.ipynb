# %% [markdown]
# # tx35 individual global figures for the multipanel Figure 1 of Chapter 12

# %% [markdown]
# ## Produces the figures for:
# - 20412060 ssp585 - historical (mid-21st century)
# - 20812100 ssp585 - historical (late-21st century)
# - 20812100 ssp126 - historical (late-21st century)
# - the colorbar

# %%
# -- Preparing the files

# -- Select the periods by scenario
# -- Compute annual sums
# -- Split the annual files
# -- Using CliMAF:
# --   - compute the individual differences
# --   - compute the ensemble statistics
# --   - start the plot of the ensemble median
# --   - code model agreement

# %%
import os, glob
import xarray as xr
from IPython.display import Image
import PIL

# %% [markdown]
# ## The input files are provided by Atlas (Maialen Iturbide)
# They have a dimension 'member', which means that all the members of the CMIP6 ensemble are within the same files (for each year and scenario).
#
# We will first split the files by model to work on clearly identified individual model files.

# %%
# WBGT = /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/
# SPI = /data/ciles/IPCC/SOD/SPI/CMIP6/CMIP6Amon-DF6-ALLfar-mask.nc

# %%
# !ls /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/*/
# Out:
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/:
# WBGT_Exceed31_ACCESS-CM2_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-CM2_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-CM2_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/:
# WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/BCC-CSM2-MR/:
# WBGT_Exceed31_BCC-CSM2-MR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_BCC-CSM2-MR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_BCC-CSM2-MR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_BCC-CSM2-MR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/:
# WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CNRM-CM6-1/:
# WBGT_Exceed31_CNRM-CM6-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CNRM-CM6-1-HR/:
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-CM6-1-HR_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-CM6-1-HR_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-CM6-1-HR_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CNRM-ESM2-1/:
# WBGT_Exceed31_CNRM-ESM2-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed31_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed33_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed35_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/EC-Earth3/:
# WBGT_Exceed31_EC-Earth3_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/EC-Earth3-Veg/:
# WBGT_Exceed31_EC-Earth3-Veg_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_EC-Earth3-Veg_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_EC-Earth3-Veg_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp126_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_EC-Earth3-Veg_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/FGOALS-g3/:
# WBGT_Exceed31_FGOALS-g3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_FGOALS-g3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_FGOALS-g3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_FGOALS-g3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/GFDL-CM4/:
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_GFDL-CM4_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_GFDL-CM4_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_GFDL-CM4_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/GFDL-ESM4/:
# WBGT_Exceed31_GFDL-ESM4_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_GFDL-ESM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_GFDL-ESM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_GFDL-ESM4_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/HadGEM3-GC31-LL/:
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-LL_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-LL_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-LL_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/HadGEM3-GC31-MM/:
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed33_HadGEM3-GC31-MM_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1.5K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2041-2060_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_3.0K_QDM_HI.nc
# WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/INM-CM4-8/:
# WBGT_Exceed31_INM-CM4-8_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_INM-CM4-8_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_INM-CM4-8_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_INM-CM4-8_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/INM-CM5-0/:
# WBGT_Exceed31_INM-CM5-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_INM-CM5-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_INM-CM5-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_INM-CM5-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/:
# WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/:
# WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/:
# WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/:
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-LR/:
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MRI-ESM2-0/:
# WBGT_Exceed31_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed31_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/NorESM2-LM/:
# WBGT_Exceed31_NorESM2-LM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_NorESM2-LM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-LM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-LM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/NorESM2-MM/:
# WBGT_Exceed31_NorESM2-MM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed31_NorESM2-MM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed33_NorESM2-MM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc
# WBGT_Exceed35_NorESM2-MM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc
#
# /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/UKESM1-0-LL/:
# WBGT_Exceed31_UKESM1-0-LL_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed31_UKESM1-0-LL_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed33_UKESM1-0-LL_ssp585_r1i1p1f2_4.0K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp126_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp126_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_1.5K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_2.0K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_3.0K_QDM_HI.nc
# WBGT_Exceed35_UKESM1-0-LL_ssp585_r1i1p1f2_4.0K_QDM_HI.nc

# %%
# -- Function to split a multi-member file in individual files
# -- Uses Xarray
def split_ensemble_file(ensemble_file, output_pattern, variable):
    if not os.path.isdir(os.path.dirname(output_pattern)):
        os.makedirs(os.path.dirname(output_pattern))
    import xarray as xr
    dat = xr.open_dataset(ensemble_file)[variable]
    for member in dat.member:
        member_name = str(member.values)
        print member_name
        outfilename = output_pattern+member_name+'.nc'
        if not os.path.isfile(outfilename):
            print 'Save '+outfilename
            member_dat = dat.loc[:,member_name,:,:]
            member_dat.to_netcdf(outfilename)
        else:
            print outfilename+' already exists'

# %%
variable='tx35'

# -- Compute the annual sums
exp_list = [
    dict(experiment='historical',
         years = range(1971,2014)),
    dict(experiment='ssp585',
         years = range(2041,2061)),
    dict(experiment='ssp585',
         years = range(2081,2101)),
    dict(experiment='ssp126',
         years = range(2081,2101)),
]

for exp_dict in exp_list:
    years = exp_dict['years']
    experiment = exp_dict['experiment']
    for year in years:
        wfile = '/data/jservon/IPCC/'+variable+'/CMIP6_'+experiment+'_'+variable+'_'+str(year)+'.nc4'
        output_pattern = '/data/jservon/IPCC/'+variable+'/individual_models/CMIP6_'+experiment+'_'+variable+'_'+str(year)+'_'
        split_ensemble_file(wfile, output_pattern, variable)
#
# Out:
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1971_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1972_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1973_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1974_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1975_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1976_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1977_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1978_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1979_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1980_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1981_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1982_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1983_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-CM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_GFDL-CM4_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM-1-2-HAM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_MPI-ESM-1-2-HAM_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_historical_tx35_1984_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# ...
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2095_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2095_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2095_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2095_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2096_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2097_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2098_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2099_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_CanESM5_r1i1p1f1.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_EC-Earth3_r1i1p1f1.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_EC-Earth3-Veg_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_KACE-1-0-G_r2i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/tx35/individual_models/CMIP6_ssp126_tx35_2100_UKESM1-0-LL_r1i1p1f2.nc already exists

# %% [markdown]
# ### Import the CliMAF library to do the pretreatments (https://climaf.readthedocs.io/en/master/)

# %%
from climaf.api import *

# %% [markdown]
# ### Declare the access to the archive

# %%
pattern = '/data/jservon/IPCC/${variable}/individual_models/CMIP6_${experiment}_${variable}_${period}_${member}.nc'
cproject('tx_individual_models_cmip6_ch12','experiment','period','member',('variable','tx35'), ensemble=['member'], separator='%')
dataloc(project='tx_individual_models_cmip6_ch12', url=pattern)
# Out:
# warning  : Redefining project tx_individual_models_cmip6_ch12
# <climaf.dataloc.dataloc instance at 0x2ac671702e18>

# %% [markdown]
# ## Work on the individual models:
# - create scenario and baseline ensembles => select common models
# - compute annual sums
# - compute climatologies
# - compute differences

# %%
exp_list = [
    dict(experiment='ssp585',
         period = '2041-2060'),
    dict(experiment='ssp585',
         period = '2081-2100'),
    dict(experiment='ssp126',
         period = '2081-2100'),
]

# -- Create ensemble for historical baseline
req_baseline = ds(project='tx_individual_models_cmip6_ch12',
                  experiment = 'historical',
                  period = '1971-2010',
                  member = '*'
                 )
ens_baseline = req_baseline.explore('ensemble')

# -- Loop on the scenarios
ens_diff = dict()
for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    period = exp['period']
    
    # -- Create ensemble object for the scenario
    req_exp = ds(project='tx_individual_models_cmip6_ch12',
                 experiment = experiment,
                 period = period,
                 member = '*'
                )
    ens_exp = req_exp.explore('ensemble')
    
    # -- Extract common members
    wens_baseline, wens_exp = ensemble_intersection([ens_baseline, ens_exp])
    #
    # -- Compute annual sums
    yearsum_baseline = ccdo(wens_baseline, operator='yearsum')
    yearsum_exp      = ccdo(wens_exp, operator='yearsum')
    
    # -- Climatologies
    clim_baseline = clim_average(yearsum_baseline, 'ANM')
    clim_exp      = clim_average(yearsum_exp, 'ANM')
    
    # -- Changes = Scenario minus baselines
    diff_exp_baseline = fsub(clim_exp, clim_baseline)
    ens_diff[experiment+'_'+period] = diff_exp_baseline

# %%
pp_colorbar = dict(proj   = 'Robinson',
                   colors = '-250 -150 -80 -40 -15 -5 5 15 40 80 150 250',
                   color  = 'temp_diff_18lev',#NCV_blu_red',
                   mpCenterLonF = 0,
                   contours = 1,
                   focus = 'land',
                   tiMainFontHeightF=0.03,
                   gsnStringFontHeightF=0.02,
                   gsnRightString='', gsnLeftString=''
                  )

# %%
pp = pp_colorbar.copy()
pp.update(
    dict(options='gsnAddCyclic=True|lbLabelBarOn=False|lbBoxEndCapStyle=TriangleBothEnds')
)

# %%
# -- Plot the individual models
wfuture = 'ssp585_2081-2100'
iplot_members(ens_diff[wfuture], N=1, **pp)

# %%
iplot_members(ens_diff[wfuture], N=2, **pp)

# %%
# -- Colorbar
def extract_labelbar(figure_file,labelbar_file) :
    import PIL
    im = PIL.Image.open(figure_file)
    #box=(left, upper, right, lower).
    im_crop = im.crop((55, 550, 930, 642))
    im_crop.save(labelbar_file, quality=95)

# -- Base plot for the colorbar
plot_4colorbar = plot(ens_diff[wfuture][ens_diff[wfuture].keys()[0]],
                      options='lbOrientation=horizontal|lbLabelFontHeightF=0.015|lbBoxEndCapStyle=TriangleBothEnds',
                      **pp_colorbar)

# -- color bar file
colorbar_file = '/home/jservon/Chapter12_IPCC/figs/global_figure_1/'+variable+'_colorbar.png'

# -- Extract the colorbar
extract_labelbar(cfile(plot_4colorbar),colorbar_file)

Image(colorbar_file)

# %% [markdown]
# ## Ensemble statistics

# %%
pp['tiMainFontHeightF'] = 0.025

wfuture = 'ssp585_2041-2060'
ensmedian_field = ccdo_ens(ens_diff[wfuture], operator='enspctl,50')
p1 = plot(ensmedian_field,
          title = '(a) Change in # days Tx>35~F34~0~F~C 2041-2060, SSP5-8.5',
          **pp
         )

wfuture = 'ssp585_2081-2100'
ensmedian_field = ccdo_ens(ens_diff[wfuture], operator='enspctl,50')
p2 = plot(ensmedian_field,
          title = '(b) 2081-2100, SSP5-8.5',
          **pp
         )

wfuture = 'ssp126_2081-2100'
ensmedian_field = ccdo_ens(ens_diff[wfuture], operator='enspctl,50')
p3 = plot(ensmedian_field,
          title = '(c) 2081-2100, SSP1-2.6',
          **pp
         )

mp = cpage(fig_lines=[[p1,p2,p3]],
            insert=colorbar_file,
            insert_width=400, page_width=1200
          )
iplot(mp)

# %%
# -- For the three figures, prepare:

# -- Ensemble Median
ensmedian_field
# -- Hatching
hatching_field
# -- Stippling
stippling_field

# %%
wfuture = 'ssp126_2081-2100'

mask_pos_dict = dict()
mask_neg_dict = dict()

for mem in ens_diff[wfuture]:
    mask_pos_dict[mem] = ccdo(ens_diff[wfuture][mem], operator='gtc,0')
    mask_neg_dict[mem] = ccdo(ens_diff[wfuture][mem], operator='ltc,0')
ens_mask_pos = cens(mask_pos_dict)
ens_mask_neg = cens(mask_neg_dict)

perc_ens_pos = fmul( fdiv( ccdo_ens(ens_mask_pos, operator='enssum'), len(ens_diff[wfuture]) ), 100 )
perc_ens_neg = fmul( fdiv( ccdo_ens(ens_mask_neg, operator='enssum'), len(ens_diff[wfuture]) ), 100 )

mask_inf90_pos = ccdo(perc_ens_pos, operator='ltc,90')
mask_inf90_neg = ccdo(perc_ens_neg, operator='ltc,90')

# %%
# Trouver un moyen de mettre la mediane commme condition de base

# %%
iplot( plot(perc_ens_pos, perc_ens_pos, shade_below=90, focus='land',
            proj='Robinson',
            shading_options='gsnShadeLow=3|gsnShadeFillScales=0.3|cnMonoLineThickness=True|cnLineThicknessF=3.0') )

# %%
len(ens_diff[wfuture])
# Out:
# 25
