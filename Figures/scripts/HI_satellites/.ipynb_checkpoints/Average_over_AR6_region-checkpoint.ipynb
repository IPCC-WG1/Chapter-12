# %% [markdown]
# # Compute WBGT regional averages for the satellite plots

# %%
import regionmask
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import json
import glob

# %% [markdown]
# ### Import the CliMAF library to do the pretreatments (https://climaf.readthedocs.io/en/master/)

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %% [markdown]
# ## Start with CMIP6 data

# %%
lof = glob.glob('/data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/*/*_*-*_QDM_HI.nc')
outdir = '/data/jservon/IPCC/WBGT/CMIP6/'
for wfile in lof:
    #print wfile
    # -- Get model, realization, and threshold
    dumsplit = wfile.split('/')[-1].split('_')
    thres = dumsplit[1]
    model = dumsplit[2]
    scenario = dumsplit[3]
    realization = dumsplit[4]
    period = dumsplit[5]
    if '.' not in period:
        #print model, realization, thres, scenario, period
        target = outdir+model+'_'+realization+'_'+thres+'_'+scenario+'_'+period+'.nc'
        cmd = 'cdo -b 32 setmissval,1e+20 -copy '+wfile+' '+target
        print cmd
        cmd2 = 'ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above '+thres+' degC" '+target
        os.system(cmd)
        os.system(cmd2)
    # -- Add coordinates attribute
    # -- set FillValue
# Out:
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed31_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed31_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed33_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed31_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed33_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed35_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed33_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed35_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed35_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/CanESM5/WBGT_Exceed35_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/CanESM5_r1i1p1f1_Exceed35_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/
ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed33_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed35_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed35_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed31_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed35_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed31_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed35_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed35_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed33_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KIOST-ESM/WBGT_Exceed31_KIOST-ESM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KIOST-ESM_r1i1p1f1_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed31_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed35_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed35_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed31_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed31_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed31_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed35_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed35_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed35_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed31_MIROC-ES2L_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed33_MIROC-ES2L_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MIROC-ES2L_r1i1p1f2_Exceed33_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MIROC-ES2L/WBGT_Exceed35_MIROC-ES2L_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/
ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-CM2_r1i1p1f1_Exceed33_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/WBGT_Exceed33_ACCESS-CM2_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-CM2_r1i1p1f1_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/WBGT_Exceed35_ACCESS-CM2_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-CM2_r1i1p1f1_Exceed35_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-CM2_r1i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-CM2/WBGT_Exceed31_ACCESS-CM2_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-CM2_r1i1p1f1_Exceed31_ssp585_1995-2014.nc
# ...
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed33_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed31_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed33_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed31_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed35_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed35_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed31_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed31_MPI-ESM1-2-HR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed31_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed33_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed35_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed35_MPI-ESM1-2-HR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed35_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed33_MPI-ESM1-2-HR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/MPI-ESM1-2-HR/WBGT_Exceed35_MPI-ESM1-2-HR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/MPI-ESM1-2-HR_r1i1p1f1_Exceed35_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/HadGEM3-GC31-MM/WBGT_Exceed35_HadGEM3-GC31-MM_ssp585_r1i1p1f3_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/HadGEM3-GC31-MM_r1i1p1f3_Exceed35_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/HadGEM3-GC31-MM/WBGT_Exceed31_HadGEM3-GC31-MM_ssp585_r1i1p1f3_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/HadGEM3-GC31-MM_r1i1p1f3_Exceed31_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/HadGEM3-GC31-MM/WBGT_Exceed35_HadGEM3-GC31-MM_ssp126_r1i1p1f3_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6
ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed35_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed35_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed31_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed33_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed31_KACE-1-0-G_ssp585_r2i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed33_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed35_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed33_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed31_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed33_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed31_KACE-1-0-G_ssp126_r2i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed31_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed35_KACE-1-0-G_ssp585_r2i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed35_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/KACE-1-0-G/WBGT_Exceed33_KACE-1-0-G_ssp585_r2i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed31_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed31_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed33_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed33_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CMIP6_share/ACCESS-ESM1-5/WBGT_Exceed35_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed35_ssp585_2041-2060.nc

# %% [markdown]
# ## CMIP6

# %%
lof = glob.glob('/data/ciles/IPCC/FGD/HI_NOAA/CMIP6/*/*_*-*_QDM_HI.nc')
outdir = '/data/jservon/IPCC/HI_NOAA/CMIP6/'
for wfile in lof:
    #print wfile
    # -- Get model, realization, and threshold
    dumsplit = wfile.split('/')[-1].split('_')
    thres = dumsplit[1]
    model = dumsplit[2]
    scenario = dumsplit[3]
    realization = dumsplit[4]
    period = dumsplit[5]
    #if '.' not in period:
    #print model, realization, thres, scenario, period
    target = outdir+model+'_'+realization+'_'+thres+'_'+scenario+'_'+period+'.nc'
    cmd = 'cdo -b 32 setmissval,1e+20 -copy '+wfile+' '+target
    print cmd
    cmd2 = 'ncatted -O -a coordinates,HI,o,c,"time lat lon" -a units,HI,o,c,days -a long_name,HI,o,c,"Number of days per year with HI temperature above '+thres+' degC" '+target
    os.system(cmd)
    os.system(cmd2)
    # -- Add coordinates attribute
    # -- set FillValue
# Out:
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed27_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed27_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed41_CanESM5_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CanESM5/HI_Exceed32_CanESM5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CanESM5_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed27_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed32_MPI-ESM1-2-LR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed32_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MPI-ESM1-2-LR/HI_Exceed41_MPI-ESM1-2-LR_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MPI-ESM1-2-LR_r1i1p1f1_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed41_NorESM2-MM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed41_NorESM2-MM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed27_NorESM2-MM_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed27_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed32_NorESM2-MM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed32_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed27_NorESM2-MM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed32_NorESM2-MM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed41_NorESM2-MM_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed41_NorESM2-MM_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed41_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/NorESM2-MM/HI_Exceed27_NorESM2-MM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/NorESM2-MM_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6
ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp126_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp126_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp126_r1i1p1f2_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp126_r1i1p1f2_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed27_CNRM-ESM2-1_ssp585_r1i1p1f2_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed27_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed32_CNRM-ESM2-1_ssp585_r1i1p1f2_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed32_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/CNRM-ESM2-1/HI_Exceed41_CNRM-ESM2-1_ssp585_r1i1p1f2_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/CNRM-ESM2-1_r1i1p1f2_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed32_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed32_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed41_MRI-ESM2-0_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed41_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/MRI-ESM2-0/HI_Exceed27_MRI-ESM2-0_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/MRI-ESM2-0_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed41_BCC-CSM2-MR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed27_BCC-CSM2-MR_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exceed27_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed41_BCC-CSM2-MR_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed27_BCC-CSM2-MR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed27_BCC-CSM2-MR_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/BCC-CSM2-MR/HI_Exceed32_BCC-CSM2-MR_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/BCC-CSM2-MR_r1i1p1f1_Exce
r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp126_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp126_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed27_EC-Earth3_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed27_EC-Earth3_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed27_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed41_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed41_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed41_EC-Earth3_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed41_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed41_EC-Earth3_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed27_EC-Earth3_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed27_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed41_EC-Earth3_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed41_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed27_EC-Earth3_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed27_EC-Earth3_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed27_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/EC-Earth3/HI_Exceed32_EC-Earth3_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/EC-Earth3_r1i1p1f1_Exceed32_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed27_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed27_KIOST-ESM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed27_KIOST-ESM_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed27_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed27_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed27_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed32_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed32_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp585_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp585_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed32_KIOST-ESM_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed32_ssp126_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp585_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed27_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KIOST-ESM/HI_Exceed41_KIOST-ESM_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KIOST-ESM_r1i1p1f1_Exceed41_ssp585_3.0K.nc
# ...
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed32_KACE-1-0-G_ssp585_r2i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed27_KACE-1-0-G_ssp585_r2i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed27_ssp585_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed41_KACE-1-0-G_ssp585_r2i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed41_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed32_KACE-1-0-G_ssp126_r2i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed32_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed32_KACE-1-0-G_ssp585_r2i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed32_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed27_KACE-1-0-G_ssp126_r2i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed27_ssp126_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed41_KACE-1-0-G_ssp585_r2i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exceed41_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/KACE-1-0-G/HI_Exceed41_KACE-1-0-G_ssp585_r2i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/KACE-1-0-G_r2i1p1f1_Exce
2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed41_ACCESS-ESM1-5_ssp585_r1i1p1f1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed41_ssp585_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed27_ACCESS-ESM1-5_ssp126_r1i1p1f1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed27_ssp126_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed32_ACCESS-ESM1-5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed32_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed41_ACCESS-ESM1-5_ssp585_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed41_ssp585_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed32_ACCESS-ESM1-5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed32_ssp126_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed41_ACCESS-ESM1-5_ssp126_r1i1p1f1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed41_ssp126_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed27_ACCESS-ESM1-5_ssp126_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed27_ssp126_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed27_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed27_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed27_ACCESS-ESM1-5_ssp585_r1i1p1f1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed27_ssp585_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed32_ACCESS-ESM1-5_ssp585_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed32_ssp585_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed27_ACCESS-ESM1-5_ssp126_r1i1p1f1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed27_ssp126_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed32_ACCESS-ESM1-5_ssp585_r1i1p1f1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed32_ssp585_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP6/ACCESS-ESM1-5/HI_Exceed41_ACCESS-ESM1-5_ssp126_r1i1p1f1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP6/ACCESS-ESM1-5_r1i1p1f1_Exceed41_ssp126_2041-2060.nc

# %% [markdown]
# ## CMIP5

# %%
lof = glob.glob('/data/ciles/IPCC/FGD/HI_NOAA/CMIP5/*/*_*-*_QDM_HI.nc')
outdir = '/data/jservon/IPCC/HI_NOAA/CMIP5/'
for wfile in lof:
    #print wfile
    # -- Get model, realization, and threshold
    dumsplit = wfile.split('/')[-1].split('_')
    thres = dumsplit[1]
    model = dumsplit[2]
    scenario = dumsplit[3]
    realization = dumsplit[4]
    period = dumsplit[5]
    #if '.' not in period:
    #print model, realization, thres, scenario, period
    target = outdir+model+'_'+realization+'_'+thres+'_'+scenario+'_'+period+'.nc'
    cmd = 'cdo -b 32 setmissval,1e+20 -copy '+wfile+' '+target
    print cmd
    cmd2 = 'ncatted -O -a coordinates,HI,o,c,"time lat lon" -a units,HI,o,c,days -a long_name,HI,o,c,"Number of days per year with HI temperature above '+thres+' degC" '+target
    os.system(cmd)
    os.system(cmd2)
    # -- Add coordinates attribute
    # -- set FillValue
# Out:
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed32_GFDL-ESM2G_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed32_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed41_GFDL-ESM2G_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed41_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed32_GFDL-ESM2G_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed32_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed41_GFDL-ESM2G_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed41_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed41_GFDL-ESM2G_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed41_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed41_GFDL-ESM2G_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed41_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed27_GFDL-ESM2G_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2G_r1i1p1_Exceed27_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2G/HI_Exceed32_GFDL-ESM2G_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM
rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed41_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed32_HadGEM2-CC_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed32_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed32_HadGEM2-CC_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed32_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed27_HadGEM2-CC_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed27_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed27_HadGEM2-CC_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed27_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed32_HadGEM2-CC_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed32_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed32_HadGEM2-CC_rcp85_r1i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed32_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed41_HadGEM2-CC_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed41_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/HadGEM2-CC/HI_Exceed41_HadGEM2-CC_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/HadGEM2-CC_r1i1p1_Exceed41_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed32_GFDL-ESM2M_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed32_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed27_GFDL-ESM2M_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed27_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/GFDL-ESM2M/HI_Exceed41_GFDL-ESM2M_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/GFDL-ESM2M_r1i1p1_Exceed41_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5
rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed41_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed32_IPSL-CM5B-LR_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed32_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed32_IPSL-CM5B-LR_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed32_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed27_IPSL-CM5B-LR_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed27_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed27_IPSL-CM5B-LR_rcp85_r1i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed27_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed27_IPSL-CM5B-LR_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed27_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed41_IPSL-CM5B-LR_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed41_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed41_IPSL-CM5B-LR_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed41_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed32_IPSL-CM5B-LR_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed32_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/IPSL-CM5B-LR/HI_Exceed32_IPSL-CM5B-LR_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/IPSL-CM5B-LR_r1i1p1_Exceed32_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp26_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp26_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp26_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp26_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp26_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp26_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp26_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp26_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp26_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp26_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp26_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp26_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp26_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp26_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp26_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp26_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed32_CESM1-CAM5_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed32_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed41_CESM1-CAM5_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed41_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/HI_NOAA/CMIP5/CESM1-CAM5/HI_Exceed27_CESM1-CAM5_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/HI_NOAA/CMIP5/CESM1-CAM5_r1i1p1_Exceed27_rcp85_2.0K.nc

# %% [markdown]
# ## CORDEX

# %%
CORDEX_domains = [
    # -- Africa
    #'AFR-22','AFR-44',
    # -- AustralAsia
    #'AUS-22','AUS-44',
    # -- Central America
    #'CAM-22','CAM-44',
    # -- North America
    #'NAM-22','NAM-44',
    # -- South America
    #'SAM-22',
    'SAM-44',
    # -- Asia
    #'EAS-22','EAS-44',
    #'WAS-22','WAS-44',
    #'SEA-22',
    # -- Europe
    #'EUR-11',
    
]
for CORDEX_domain in CORDEX_domains:
    lof = glob.glob('/data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-'+CORDEX_domain+'_share/*/*_QDM_HI.nc')
    outdir = '/data/jservon/IPCC/WBGT/CORDEX/'+CORDEX_domain+'/'
    if not os.path.isdir(outdir):
        os.makedirs(outdir)
    for wfile in lof:
        #print wfile
        # -- Get model, realization, and threshold
        dumsplit = wfile.split('/')[-1].split('_')
        thres = dumsplit[1]
        GCM = dumsplit[2]
        RCM = dumsplit[3]
        scenario = dumsplit[4]
        realization = dumsplit[5]
        period = dumsplit[6]
        #print model, realization, thres, scenario, period
        target = outdir+GCM+'--'+RCM+'_'+realization+'_'+thres+'_'+scenario+'_'+period+'.nc'
        cmd = 'cdo -b 32 setmissval,1e+20 -copy '+wfile+' '+target
        print cmd
        cmd2 = 'ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above '+thres+' degC" '+target
        print cmd2
        os.system(cmd)
        os.system(cmd2)
        # -- Add coordinates attribute
        # -- set FillValue
# Out:
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_1995-2014.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_3.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_1.5K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_1.5K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2081-2100.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2081-2100.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2081-2100.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2081-2100.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1.5K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_1.5K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_1.5K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_1995-2014.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_3.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_1995-2014.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_3.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_3.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed35_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2041-2060.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed35_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed31_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2041-2060.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed31 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed31_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2041-2060.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2041-2060.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4/WBGT_Exceed33_NOAA-GFDL-GFDL-ESM2M_SMHI-RCA4_rcp85_r1i1p1_2.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_Exceed33_rcp85_2.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/ICHEC-EC-EARTH_SMHI-RCA4/WBGT_Exceed35_ICHEC-EC-EARTH_SMHI-RCA4_rcp26_r12i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed35_rcp26_1995-2014.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed35 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed35_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/ICHEC-EC-EARTH_SMHI-RCA4/WBGT_Exceed33_ICHEC-EC-EARTH_SMHI-RCA4_rcp85_r12i1p1_4.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed33_rcp85_4.0K.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed33_rcp85_4.0K.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/ICHEC-EC-EARTH_SMHI-RCA4/WBGT_Exceed33_ICHEC-EC-EARTH_SMHI-RCA4_rcp26_r12i1p1_1995-2014_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed33_rcp26_1995-2014.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exceed33_rcp26_1995-2014.nc
# cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/ICHEC-EC-EARTH_SMHI-RCA4/WBGT_Exceed35_ICHEC-EC-EARTH_SMHI-RCA4_rcp26_r12i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_Exce
do -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/NCC-NorESM1-M_SMHI-RCA4/WBGT_Exceed33_NCC-NorESM1-M_SMHI-RCA4_rcp26_r1i1p1_2081-2100_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NCC-NorESM1-M--SMHI-RCA4_r1i1p1_Exceed33_rcp26_2081-2100.nc
# ncatted -O -a coordinates,WBGTindoor,o,c,"time lat lon" -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,"Number of days per year with wet-bulb temperature above Exceed33 degC" /data/jservon/IPCC/WBGT/CORDEX/SAM-44/NCC-NorESM1-M--SMHI-RCA4_r1i1p1_Exceed33_rcp26_2081-2100.nc

# %%
# !ncdump -h /data/jservon/IPCC/WBGT/CORDEX/SAM-44/CCCma-CanESM2--UCAN-WRF341I_r1i1p1_Exceed35_rcp85_2041-2060.nc
# Out:
# netcdf CCCma-CanESM2--UCAN-WRF341I_r1i1p1_Exceed35_rcp85_2041-2060 {
# dimensions:
# 	time = UNLIMITED ; // (20 currently)
# 	rlon = 146 ;
# 	rlat = 167 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "days since 2041-12-31" ;
# 		time:calendar = "365_day" ;
# 		time:axis = "T" ;
# 	double lon(rlat, rlon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:_CoordinateAxisType = "Lon" ;
# 	double lat(rlat, rlon) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:_CoordinateAxisType = "Lat" ;
# 	double rlon(rlon) ;
# 		rlon:standard_name = "projection_x_coordinate" ;
# 		rlon:long_name = "longitude in rotated pole grid" ;
# 		rlon:units = "degrees" ;
# 		rlon:axis = "X" ;
# 	double rlat(rlat) ;
# 		rlat:standard_name = "projection_y_coordinate" ;
# 		rlat:long_name = "latitude in rotated pole grid" ;
# 		rlat:units = "degrees" ;
# 		rlat:axis = "Y" ;
# 	float WBGTindoor(time, rlat, rlon) ;
# 		WBGTindoor:_FillValue = 1.e+20f ;
# 		WBGTindoor:missing_value = 1.e+20f ;
# 		WBGTindoor:coordinates = "time lat lon" ;
# 		WBGTindoor:units = "days" ;
# 		WBGTindoor:long_name = "Number of days per year with wet-bulb temperature above Exceed35 degC" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.6" ;
# 		:coordinates = "threshold" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:history = "Fri Feb  5 09:26:15 2021: ncatted -O -a coordinates,WBGTindoor,o,c,time lat lon -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,Number of days per year with wet-bulb temperature above Exceed35 degC /data/jservon/IPCC/WBGT/CORDEX/SAM-44/CCCma-CanESM2--UCAN-WRF341I_r1i1p1_Exceed35_rcp85_2041-2060.nc\nFri Feb 05 09:26:15 2021: cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-SAM-44_share/CCCma-CanESM2_UCAN-WRF341I/WBGT_Exceed35_CCCma-CanESM2_UCAN-WRF341I_rcp85_r1i1p1_2041-2060_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/SAM-44/CCCma-CanESM2--UCAN-WRF341I_r1i1p1_Exceed35_rcp85_2041-2060.nc" ;
# }

# %% [markdown]
# ### Declare CliMAF project to get the data

# %%
pattern = '/data/jservon/IPCC/HI_NOAA/CMIP6/${member}_${thres}_${experiment}_${clim_period}.nc'
cproject('HI_cmip6_ch12','experiment','clim_period','member',('period','fx'),('thres','Exceed41'), ('variable','HI'), ensemble=['member'], separator='%')
dataloc(project='HI_cmip6_ch12', url=pattern)
# Out:
# <climaf.dataloc.dataloc instance at 0x2afb8f8fe878>

# %%
pattern = '/data/jservon/IPCC/WBGT/CORDEX/${CORDEX_domain}/${member}_${thres}_${experiment}_${period}.nc'
cproject('wbgt_cordex_ch12','experiment','period','CORDEX_domain','member','thres', ('variable','WBGTindoor'), ensemble=['member'], separator='%')
dataloc(project='wbgt_cordex_ch12', url=pattern) 
pattern_gwl = '/data/jservon/IPCC/WBGT/CORDEX/${CORDEX_domain}/${member}_${thres}_${experiment}_${GWL}.nc'
cproject('wbgt_cordex_GWL_ch12','experiment','CORDEX_domain',('period','fx'),'GWL','member','thres', ('variable','WBGTindoor'), ensemble=['member'], separator='%')
dataloc(project='wbgt_cordex_GWL_ch12', url=pattern_gwl)
# Out:
# <climaf.dataloc.dataloc instance at 0x2aecd8d54098>

# %%
pattern = '/data/jservon/IPCC/WBGT/CORDEX/${CORDEX_domain}/${member}_${thres}_${experiment}_${clim_period}.nc'
cproject('wbgt_cordex_ch12_test','experiment',('period','fx'),'clim_period','CORDEX_domain','member','thres', ('variable','WBGTindoor'), ensemble=['member'], separator='%')
dataloc(project='wbgt_cordex_ch12_test', url=pattern)
# Out:
# <climaf.dataloc.dataloc instance at 0x2aecd8d106c8>

# %%
def weighted_mean(da, weights, dim):
    """Reduce da by a weighted mean along some dimension(s).

    Parameters
    ----------
    da : DataArray
        Object over which the weighted reduction operation is applied.    
    weights : DataArray
        An array of weights associated with the values in this Dataset.
    dim : str or sequence of str, optional
        Dimension(s) over which to apply the weighted `mean`.
        
    Returns
    -------
    weighted_mean : DataArray
        New DataArray with weighted mean applied to its data and
        the indicated dimension(s) removed.
    """

    weighted_sum = (da * weights).sum(dim=dim, skipna=True)
    # need to mask weights where data is not valid
    masked_weights = weights.where(da.notnull())
    sum_of_weights = masked_weights.sum(dim=dim, skipna=True)
    valid_weights = sum_of_weights != 0
    sum_of_weights = sum_of_weights.where(valid_weights)

    return weighted_sum / sum_of_weights

def average_over_AR6_region(filename, variable, region_name):

    # -- AR6 regions
    #ar6_all = regionmask.defined_regions.ar6.all
    # -- Get the regions
    ar6_land = regionmask.defined_regions.ar6.land

    #ax = ar6_all.plot()
    # -- Get land/sea mask (generic)
    land_110 = regionmask.defined_regions.natural_earth.land_110

    # -- Get data
    ds = xr.open_dataset(filename, decode_times=False)
    dat = ds[variable]
    dat.values = np.array(dat.values, dtype=np.float32)

    # -- Mask the data
    mask_3D = ar6_land.mask_3D(dat) # AR6 mask
    land_mask = land_110.mask_3D(dat) # Land sea mask
    mask_lsm = mask_3D * land_mask.squeeze(drop=True) # Combine the two

    weights = np.cos(np.deg2rad(dat.lat))
    
    if region_name=='all':
        return weighted_mean(dat, mask_3D * weights, ("lon", "lat"))
    else:
        if isinstance(region_name, list):
            res = list()
            for region in region_name:
                region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region))
                dat_region = dat.where(region_mask)
                weights_region = weights.where(region_mask)
                res.append( weighted_mean(dat_region, region_mask*weights_region, ("lon","lat")) )
            return res
        else:
            region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region_name))
            dat_region = dat.where(region_mask)
            weights_region = weights.where(region_mask)            
            return weighted_mean(dat_region, region_mask*weights_region, ("lon","lat"))
    
def regions_contained(lon, lat, regions):

    # determine if the longitude needs to be wrapped
    regions_is_180 = regions.lon_180
    grid_is_180 = regionmask.core.utils._is_180(lon.min(), lon.max())

    wrap_lon = not regions_is_180 == grid_is_180

    lon_orig = lon.copy()
    if wrap_lon:
        lon = regionmask.core.utils._wrapAngle(lon, wrap_lon)

    lon = np.asarray(lon).squeeze()
    lat = np.asarray(lat).squeeze()

    if lon.ndim == 1 and lat.ndim == 1:
        poly = shapely.geometry.box(lon.min(), lat.min(), lon.max(), lat.max())

    # convex_hull is not really what we need
    # https://gist.github.com/dwyerk/10561690
    #     elif lon.ndim == 2 and lat.ndim == 2:
    #         # get the convex hull from all points
    #         lonlat = np.stack([lon.ravel(), lat.ravel()], axis=1)
    #         multipoint = shapely.geometry.MultiPoint(lonlat)
    #         poly = multipoint.convex_hull
    else:
        raise ValueError("Cannot currently handle 2D coordinates")

    fully_contained = list()
    for region_poly in regions.polygons:
        res = poly.contains(region_poly)

        fully_contained.append(res)

    return xr.DataArray(
        fully_contained, dims=["region"], coords=dict(region=regions.numbers)
    )

if None:
    region_name = "all"
    variable = 'tx35'
    filename = "/data/jservon/IPCC/tx35/individual_models/CMIP6_ssp585_tx35_2100_NorESM2-LM_r1i1p1f1.nc"

    tmp = average_over_AR6_region(filename, variable, region_name)
    tmp

# %% [markdown]
# ### Start with baseline, mid-term, late-term, ssp126 and ssp585

# %%
wthres = '41'
thres = 'Exceed'+wthres

# %%
thres = 'Exceed'+wthres

exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='ssp585',
         clim_period = '1995-2014'),    
    # -- Mid term
    dict(experiment='ssp585',
         clim_period = '2041-2060'),
    dict(experiment='ssp126',
         clim_period = '2041-2060'),
    # -- Late term
    dict(experiment='ssp585',
         clim_period = '2081-2100'),
    dict(experiment='ssp126',
         clim_period = '2081-2100'),
]

# -- Loop on the scenarios
ens_exp_dict = dict()
for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    clim_period = exp['clim_period']
    
    # -- Create ensemble object for the scenario
    req_exp = ds(project='HI_cmip6_ch12',
                 experiment = experiment,
                 clim_period = clim_period,
                 member = '*',
                 #thres = thres
                )
    ens_exp = req_exp.explore('ensemble')
    
    # -- Climatologies
    ens_exp_dict[experiment+'_'+clim_period] = clim_average(ens_exp, 'ANM')

# %% [markdown]
# ### Then GWLs (mix ssp126 and ssp585)

# %%
thres = 'Exceed'+wthres
variable = 'wbgt'

# -- Loop on the scenarios
ens_GWL_dict = dict()
for GWL in ['1.5K','2.0K','3.0K','4.0K']:
    #
    if GWL in ['1.5K','2.0K']:
        # -- Create ensemble object for the scenario
        req_ssp126 = ds(project='HI_cmip6_ch12',
                     experiment = 'ssp126',
                     clim_period = GWL,
                     member = '*'
                     )
        ens_ssp126 = req_ssp126.explore('ensemble')

        # -- Create ensemble object for the scenario
        req_ssp585 = ds(project='HI_cmip6_ch12',
                     experiment = 'ssp585',
                     clim_period = GWL,
                     member = '*',
                    )
        ens_ssp585 = req_ssp585.explore('ensemble')
        #
        # -- Merge ensembles
        GWL_ens = merge_climaf_ensembles([add_prefix_suffix_to_ens_req(ens_ssp126,suffix='_ssp126'),
                                          add_prefix_suffix_to_ens_req(ens_ssp585,suffix='_ssp585')])
    else:
        # -- Create ensemble object for the scenario
        req_ssp585 = ds(project='HI_cmip6_ch12',
                     experiment = 'ssp585',
                     clim_period = GWL,
                     member = '*',
                    )
        GWL_ens = req_ssp585.explore('ensemble')
        
    # -- Climatologies
    ens_GWL_dict[GWL] = clim_average(GWL_ens, 'ANM')

# %%
ens_GWL_dict['1.5K'].keys()
# Out:
# ['INM-CM5-0_r1i1p1f1_ssp585',
#  'MPI-ESM1-2-HR_r1i1p1f1_ssp585',
#  'ACCESS-ESM1-5_r1i1p1f1_ssp126',
#  'MPI-ESM1-2-HR_r1i1p1f1_ssp126',
#  'KIOST-ESM_r1i1p1f1_ssp126',
#  'INM-CM4-8_r1i1p1f1_ssp585',
#  'CNRM-CM6-1_r1i1p1f2_ssp126',
#  'MRI-ESM2-0_r1i1p1f1_ssp585',
#  'BCC-CSM2-MR_r1i1p1f1_ssp126',
#  'NorESM2-LM_r1i1p1f1_ssp585',
#  'MRI-ESM2-0_r1i1p1f1_ssp126',
#  'ACCESS-CM2_r1i1p1f1_ssp585',
#  'ACCESS-CM2_r1i1p1f1_ssp126',
#  'CNRM-ESM2-1_r1i1p1f2_ssp126',
#  'GFDL-ESM4_r1i1p1f1_ssp585',
#  'CNRM-CM6-1_r1i1p1f2_ssp585',
#  'NorESM2-MM_r1i1p1f1_ssp585',
#  'INM-CM5-0_r1i1p1f1_ssp126',
#  'MIROC-ES2L_r1i1p1f2_ssp126',
#  'ACCESS-ESM1-5_r1i1p1f1_ssp585',
#  'EC-Earth3-Veg_r1i1p1f1_ssp126',
#  'UKESM1-0-LL_r1i1p1f2_ssp126',
#  'BCC-CSM2-MR_r1i1p1f1_ssp585',
#  'CNRM-CM6-1-HR_r1i1p1f2_ssp585',
#  'MPI-ESM1-2-LR_r1i1p1f1_ssp585',
#  'GFDL-CM4_r1i1p1f1_ssp585',
#  'HadGEM3-GC31-LL_r1i1p1f3_ssp585',
#  'INM-CM4-8_r1i1p1f1_ssp126',
#  'CNRM-ESM2-1_r1i1p1f2_ssp585',
#  'KACE-1-0-G_r2i1p1f1_ssp126',
#  'EC-Earth3_r1i1p1f1_ssp585',
#  'EC-Earth3-Veg_r1i1p1f1_ssp585',
#  'FGOALS-g3_r1i1p1f1_ssp585',
#  'HadGEM3-GC31-MM_r1i1p1f3_ssp585',
#  'HadGEM3-GC31-LL_r1i1p1f3_ssp126',
#  'EC-Earth3_r1i1p1f1_ssp126',
#  'MIROC-ES2L_r1i1p1f2_ssp585',
#  'KIOST-ESM_r1i1p1f1_ssp585',
#  'CNRM-CM6-1-HR_r1i1p1f2_ssp126',
#  'KACE-1-0-G_r2i1p1f1_ssp585',
#  'HadGEM3-GC31-MM_r1i1p1f3_ssp126',
#  'UKESM1-0-LL_r1i1p1f2_ssp585',
#  'MPI-ESM1-2-LR_r1i1p1f1_ssp126']

# %%
ens_exp_dict.keys()
# Out:
# ['ssp585_2081-2100',
#  'ssp126_2041-2060',
#  'ssp585_2041-2060',
#  'ssp126_2081-2100',
#  'ssp585_1995-2014']

# %%
regional_averages = dict()

# -- Loop on experiments / horizons
for ens_exp in ens_exp_dict:
    print ens_exp
    regional_averages[ens_exp] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_exp_dict[ens_exp]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'HI', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            print region_name
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            if region_name not in regional_averages[ens_exp]:
                regional_averages[ens_exp][region_name] = [region_value]
            else:
                regional_averages[ens_exp][region_name].append(region_value)
# Out:
# ssp585_2081-2100
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CanESM5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ssp126_2041-2060
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CanESM5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ssp585_2041-2060
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CanESM5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ssp126_2081-2100
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CanESM5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ssp585_1995-2014
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CanESM5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN

# %%
for GWL in ens_GWL_dict :
    print GWL
    regional_averages[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), 'HI', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            print region_name
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            if region_name not in regional_averages[GWL]:
                regional_averages[GWL][region_name] = [region_value]
            else:
                regional_averages[GWL][region_name].append(region_value)
# Out:
# 3.0K
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# 1.5K
# INM-CM5-0_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM5-0_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-MM_r1i1p1f3_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-MM_r1i1p1f3_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# 4.0K
# CNRM-CM6-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-MM_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# 2.0K
# INM-CM5-0_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-HR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-ESM2-1_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# INM-CM4-8_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MRI-ESM2-0_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-LM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-ESM4_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-CM2_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# NorESM2-MM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3-Veg_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# BCC-CSM2-MR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MPI-ESM1-2-LR_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# GFDL-CM4_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# ACCESS-ESM1-5_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# FGOALS-g3_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-MM_r1i1p1f3_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-LL_r1i1p1f3_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# EC-Earth3_r1i1p1f1_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# MIROC-ES2L_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KIOST-ESM_r1i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# CNRM-CM6-1-HR_r1i1p1f2_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# KACE-1-0-G_r2i1p1f1_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# HadGEM3-GC31-MM_r1i1p1f3_ssp126
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN
# UKESM1-0-LL_r1i1p1f2_ssp585
# GIC
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# SCA
# CAR
# NWS
# NSA
# NES
# SAM
# SWS
# SES
# SSA
# NEU
# WCE
# EEU
# MED
# SAH
# WAF
# CAF
# NEAF
# SEAF
# WSAF
# ESAF
# MDG
# RAR
# WSB
# ESB
# RFE
# WCA
# ECA
# TIB
# EAS
# ARP
# SAS
# SEA
# NAU
# CAU
# EAU
# SAU
# NZ
# EAN
# WAN

# %% [markdown]
# ### Compute the ensemble statistics

# %%
import numpy
quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# ssp126_2081-2100 NEN
# ssp126_2081-2100 NCA
# ssp126_2081-2100 WAN
# ssp126_2081-2100 EEU
# ssp126_2081-2100 CAR
# ssp126_2081-2100 WSAF
# ssp126_2081-2100 CAU
# ssp126_2081-2100 WSB
# ssp126_2081-2100 NAU
# ssp126_2081-2100 SWS
# ssp126_2081-2100 NEU
# ssp126_2081-2100 NES
# ssp126_2081-2100 TIB
# ssp126_2081-2100 WNA
# ssp126_2081-2100 SES
# ssp126_2081-2100 SAM
# ssp126_2081-2100 NWS
# ssp126_2081-2100 NSA
# ssp126_2081-2100 SCA
# ssp585_2081-2100 RAR
# ssp585_2081-2100 SEA
# ssp585_2081-2100 SAS
# ssp585_2081-2100 NWN
# ssp585_2081-2100 EAU
# ssp585_2081-2100 SAU
# ssp585_2081-2100 ENA
# ssp585_2081-2100 WAF
# ssp585_2081-2100 WCA
# ssp585_2081-2100 SAH
# ssp585_2081-2100 GIC
# ssp585_2081-2100 ESB
# ssp585_2081-2100 RFE
# ssp585_2081-2100 CNA
# ssp585_2081-2100 EAS
# ssp585_2081-2100 ARP
# ssp585_2081-2100 MED
# ssp585_2081-2100 ECA
# ssp585_2081-2100 NEAF
# ssp585_2081-2100 EAN
# ssp585_2081-2100 WCE
# ssp585_2081-2100 SSA
# ssp585_2081-2100 ESAF
# 1.5K NEN
# 1.5K NCA
# 1.5K WAN
# 1.5K EEU
# 1.5K CAR
# 1.5K WSAF
# 1.5K CAU
# 1.5K WSB
# 1.5K NAU
# 1.5K SWS
# 1.5K NEU
# 1.5K NES
# 1.5K TIB
# 1.5K WNA
# 1.5K SES
# 1.5K SAM
# 1.5K NWS
# 1.5K NSA
# 1.5K SCA
# 1.5K MDG
# 1.5K CAF
# 1.5K SEAF
# 1.5K NZ
# 1.5K RAR
# 1.5K SEA
# 1.5K SAS
# 1.5K NWN
# 1.5K EAU
# 1.5K SAU
# 1.5K ENA
# 1.5K WAF
# 1.5K WCA
# 1.5K SAH
# 1.5K GIC
# 1.5K ESB
# 1.5K RFE
# 1.5K CNA
# 1.5K EAS
# 1.5K ARP
# 1.5K MED
# 1.5K ECA
# 1.5K NEAF
# 1.5K EAN
# 1.5K WCE
# 1.5K SSA
# 1.5K ESAF
# 2.0K NEN
# 2.0K NCA
# 2.0K WAN
# 2.0K EEU
# 2.0K CAR
# 2.0K WSAF
# 2.0K CAU
# 2.0K WSB
# 2.0K NAU
# 2.0K SWS
# 2.0K NEU
# 2.0K NES
# 2.0K TIB
# 2.0K WNA
# 2.0K SES
# 2.0K SAM
# 2.0K NWS
# 2.0K NSA
# 2.0K SCA
# 2.0K MDG
# 2.0K CAF
# 2.0K SEAF
# 2.0K NZ
# 2.0K RAR
# 2.0K SEA
# 2.0K SAS
# 2.0K NWN
# 2.0K EAU
# 2.0K SAU
# 2.0K ENA
# 2.0K WAF
# 2.0K WCA
# 2.0K SAH
# 2.0K GIC
# 2.0K ESB
# 2.0K RFE
# 2.0K CNA
# 2.0K EAS
# 2.0K ARP
# 2.0K MED
# 2.0K ECA
# 2.0K NEAF
# 2.0K EAN
# 2.0K WCE
# 2.0K SSA
# 2.0K ESAF
# 3.0K NEN
# 3.0K NCA
# 3.0K WAN
# 3.0K EEU
# 3.0K CAR
# 3.0K WSAF
# 3.0K CAU
# 3.0K WSB
# 3.0K NAU
# 3.0K SWS
# 3.0K NEU
# 3.0K NES
# 3.0K TIB
# 3.0K WNA
# 3.0K SES
# 3.0K SAM
# 3.0K NWS
# 3.0K NSA
# 3.0K SCA
# 3.0K MDG
# 3.0K CAF
# 3.0K SEAF
# 3.0K NZ
# 3.0K RAR
# 3.0K SEA
# 3.0K SAS
# 3.0K NWN
# 3.0K EAU
# 3.0K SAU
# 3.0K ENA
# 3.0K WAF
# 3.0K WCA
# 3.0K SAH
# 3.0K GIC
# 3.0K ESB
# 3.0K RFE
# 3.0K CNA
# 3.0K EAS
# 3.0K ARP
# 3.0K MED
# 3.0K ECA
# 3.0K NEAF
# 3.0K EAN
# 3.0K WCE
# 3.0K SSA
# 3.0K ESAF
# ssp585_2041-2060 NEN
# ssp585_2041-2060 NCA
# ssp585_2041-2060 WAN
# ssp585_2041-2060 EEU
# ssp585_2041-2060 CAR
# ssp585_2041-2060 WSAF
# ssp585_2041-2060 CAU
# ssp585_2041-2060 WSB
# ssp585_2041-2060 NAU
# ssp585_2041-2060 SWS
# ssp585_2041-2060 NEU
# ssp585_2041-2060 NES
# ssp585_2041-2060 TIB
# ssp585_2041-2060 WNA
# ssp585_2041-2060 SES
# ssp585_2041-2060 SAM
# ssp585_2041-2060 NWS
# ssp585_2041-2060 NSA
# ssp585_2041-2060 SCA
# ssp585_2041-2060 MDG
# ssp585_2041-2060 CAF
# ssp585_2041-2060 SEAF
# ssp585_2041-2060 NZ
# ssp585_2041-2060 RAR
# ssp585_2041-2060 SEA
# ssp585_2041-2060 SAS
# ssp585_2041-2060 NWN
# ssp585_2041-2060 EAU
# ssp585_2041-2060 SAU
# ssp585_2041-2060 ENA
# ssp585_2041-2060 WAF
# ssp585_2041-2060 WCA
# ssp585_2041-2060 SAH
# ssp585_2041-2060 GIC
# ssp585_2041-2060 ESB
# ssp585_2041-2060 RFE
# ssp585_2041-2060 CNA
# ssp585_2041-2060 EAS
# ssp585_2041-2060 ARP
# ssp585_2041-2060 MED
# ssp585_2041-2060 ECA
# ssp585_2041-2060 NEAF
# ssp585_2041-2060 EAN
# ssp585_2041-2060 WCE
# ssp585_2041-2060 SSA
# ssp585_2041-2060 ESAF
# ssp126_2041-2060 NEN
# ssp126_2041-2060 NCA
# ssp126_2041-2060 WAN
# ssp126_2041-2060 EEU
# ssp126_2041-2060 CAR
# ssp126_2041-2060 WSAF
# ssp126_2041-2060 CAU
# ssp126_2041-2060 WSB
# ssp126_2041-2060 NAU
# ssp126_2041-2060 SWS
# ssp126_2041-2060 NEU
# ssp126_2041-2060 NES
# ssp126_2041-2060 TIB
# ssp126_2041-2060 WNA
# ssp126_2041-2060 SES
# ssp126_2041-2060 SAM
# ssp126_2041-2060 NWS
# ssp126_2041-2060 NSA
# ssp126_2041-2060 SCA
# ssp126_2041-2060 MDG
# ssp126_2041-2060 CAF
# ssp126_2041-2060 SEAF
# ssp126_2041-2060 NZ
# ssp126_2041-2060 RAR
# ssp126_2041-2060 SEA
# ssp126_2041-2060 SAS
# ssp126_2041-2060 NWN
# ssp126_2041-2060 EAU
# ssp126_2041-2060 SAU
# ssp126_2041-2060 ENA
# ssp126_2041-2060 WAF
# ssp126_2041-2060 WCA
# ssp126_2041-2060 SAH
# ssp126_2041-2060 GIC
# ssp126_2041-2060 ESB
# ssp126_2041-2060 RFE
# ssp126_2041-2060 CNA
# ssp126_2041-2060 EAS
# ssp126_2041-2060 ARP
# ssp126_2041-2060 MED
# ssp126_2041-2060 ECA
# ssp126_2041-2060 NEAF
# ssp126_2041-2060 EAN
# ssp126_2041-2060 WCE
# ssp126_2041-2060 SSA
# ssp126_2041-2060 ESAF
# 4.0K NEN
# 4.0K NCA
# 4.0K WAN
# 4.0K EEU
# 4.0K CAR
# 4.0K WSAF
# 4.0K CAU
# 4.0K WSB
# 4.0K NAU
# 4.0K SWS
# 4.0K NEU
# 4.0K NES
# 4.0K TIB
# 4.0K WNA
# 4.0K SES
# 4.0K SAM
# 4.0K NWS
# 4.0K NSA
# 4.0K SCA
# 4.0K MDG
# 4.0K CAF
# 4.0K SEAF
# 4.0K NZ
# 4.0K RAR
# 4.0K SEA
# 4.0K SAS
# 4.0K NWN
# 4.0K EAU
# 4.0K SAU
# 4.0K ENA
# 4.0K WAF
# 4.0K WCA
# 4.0K SAH
# 4.0K GIC
# 4.0K ESB
# 4.0K RFE
# 4.0K CNA
# 4.0K EAS
# 4.0K ARP
# 4.0K MED
# 4.0K ECA
# 4.0K NEAF
# 4.0K EAN
# 4.0K WCE
# 4.0K SSA
# 4.0K ESAF

# %%
wthres
# Out:
# '41'

# %%
import json
ensemble = 'CMIP6'
outfilename = '/home/jservon/Chapter12_IPCC/data/HI_satellites/'+ensemble+'_HI'+wthres+'_AR6_regional_averages.json'
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %% [markdown]
# ### Differences

# %%
regional_averages_diff = dict()

# -- Loop on experiments / horizons
#wind_ens_clim_exp_dict[exp]
for ens_exp in ens_exp_dict:
    if ens_exp not in ['ssp585_1995-2014']:
        print ens_exp
        regional_averages_diff[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_exp_dict[ens_exp]:
            if mem in ens_exp_dict['ssp585_1995-2014']:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                #print cfile(ens_exp_dict[ens_exp][mem])
                #cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_exp_dict[ens_exp][mem])
                #os.system(cmd)
                tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'HI', 'all')
                tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['ssp585_1995-2014'][mem]), 'HI', 'all')
                region_names = tmp.abbrevs
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    region_value_baseline = float(tmp_baseline.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    if region_name not in regional_averages_diff[ens_exp]:
                        regional_averages_diff[ens_exp][region_name] = [region_value - region_value_baseline]
                    else:
                        regional_averages_diff[ens_exp][region_name].append(region_value - region_value_baseline)
        #
# Out:
# ssp585_2081-2100
# HadGEM3-GC31-MM_r1i1p1f3
# CNRM-CM6-1_r1i1p1f2
# ACCESS-CM2_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# MPI-ESM1-2-LR_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# EC-Earth3_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# CanESM5_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# ssp126_2041-2060
# HadGEM3-GC31-MM_r1i1p1f3
# CNRM-CM6-1_r1i1p1f2
# ACCESS-CM2_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# MPI-ESM1-2-LR_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# EC-Earth3_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# CanESM5_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# ssp585_2041-2060
# HadGEM3-GC31-MM_r1i1p1f3
# CNRM-CM6-1_r1i1p1f2
# ACCESS-CM2_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# MPI-ESM1-2-LR_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# EC-Earth3_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# CanESM5_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# ssp126_2081-2100
# HadGEM3-GC31-MM_r1i1p1f3
# CNRM-CM6-1_r1i1p1f2
# ACCESS-CM2_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# MPI-ESM1-2-LR_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# EC-Earth3_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# CanESM5_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2

# %%
for GWL in ens_GWL_dict:
    print GWL
    regional_averages_diff[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        wmem = mem.replace('_ssp585','').replace('_ssp126','')
        #if mem.replace('_85','').replace('_26','') in ens_exp_dict['historical_1995-2014']:
        if wmem in ens_exp_dict['ssp585_1995-2014']:
            print wmem
            # -- Compute the averages for each AR6 region thanks to regionmask
            tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), 'HI', 'all')
            tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['ssp585_1995-2014'][wmem]), 'HI', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                region_value_baseline = float(tmp_baseline.sel(region=list(tmp_baseline.abbrevs).index(region_name)).values)
                if region_name not in regional_averages_diff[GWL]:
                    regional_averages_diff[GWL][region_name] = [region_value - region_value_baseline]
                else:
                    regional_averages_diff[GWL][region_name].append(region_value - region_value_baseline)
# Out:
# 3.0K
# HadGEM3-GC31-MM_r1i1p1f3
# CNRM-CM6-1_r1i1p1f2
# ACCESS-CM2_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# MPI-ESM1-2-LR_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# EC-Earth3_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# EC-Earth3-Veg_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# 1.5K
# INM-CM5-0_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# ACCESS-ESM1-5_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# KIOST-ESM_r1i1p1f1
# INM-CM4-8_r1i1p1f1
# CNRM-CM6-1_r1i1p1f2
# MRI-ESM2-0_r1i1p1f1
# BCC-CSM2-MR_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# ACCESS-CM2_r1i1p1f1
# ACCESS-CM2_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# GFDL-ESM4_r1i1p1f1
# CNRM-CM6-1_r1i1p1f2
# NorESM2-MM_r1i1p1f1
# INM-CM5-0_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# BCC-CSM2-MR_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# MPI-ESM1-2-LR_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# INM-CM4-8_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# KACE-1-0-G_r2i1p1f1
# EC-Earth3_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# HadGEM3-GC31-MM_r1i1p1f3
# HadGEM3-GC31-LL_r1i1p1f3
# EC-Earth3_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# KACE-1-0-G_r2i1p1f1
# HadGEM3-GC31-MM_r1i1p1f3
# UKESM1-0-LL_r1i1p1f2
# MPI-ESM1-2-LR_r1i1p1f1
# 4.0K
# CNRM-CM6-1_r1i1p1f2
# ACCESS-ESM1-5_r1i1p1f1
# HadGEM3-GC31-MM_r1i1p1f3
# EC-Earth3_r1i1p1f1
# ACCESS-CM2_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# GFDL-CM4_r1i1p1f1
# KACE-1-0-G_r2i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# HadGEM3-GC31-LL_r1i1p1f3
# EC-Earth3-Veg_r1i1p1f1
# MRI-ESM2-0_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# 2.0K
# INM-CM5-0_r1i1p1f1
# MPI-ESM1-2-HR_r1i1p1f1
# ACCESS-ESM1-5_r1i1p1f1
# CNRM-ESM2-1_r1i1p1f2
# INM-CM4-8_r1i1p1f1
# CNRM-CM6-1_r1i1p1f2
# MRI-ESM2-0_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# ACCESS-CM2_r1i1p1f1
# CNRM-CM6-1_r1i1p1f2
# GFDL-ESM4_r1i1p1f1
# ACCESS-CM2_r1i1p1f1
# NorESM2-MM_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# EC-Earth3-Veg_r1i1p1f1
# UKESM1-0-LL_r1i1p1f2
# BCC-CSM2-MR_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# MPI-ESM1-2-LR_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# HadGEM3-GC31-LL_r1i1p1f3
# KACE-1-0-G_r2i1p1f1
# EC-Earth3_r1i1p1f1
# ACCESS-ESM1-5_r1i1p1f1
# FGOALS-g3_r1i1p1f1
# HadGEM3-GC31-MM_r1i1p1f3
# HadGEM3-GC31-LL_r1i1p1f3
# EC-Earth3_r1i1p1f1
# MIROC-ES2L_r1i1p1f2
# KIOST-ESM_r1i1p1f1
# CNRM-CM6-1-HR_r1i1p1f2
# KACE-1-0-G_r2i1p1f1
# HadGEM3-GC31-MM_r1i1p1f3
# UKESM1-0-LL_r1i1p1f2

# %%
quantiles_dict = dict()
for clim_period in regional_averages_diff:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages_diff[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages_diff[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]

import json

ensemble = 'CMIP6'
outfilename = '/home/jservon/Chapter12_IPCC/data/HI_satellites/'+ensemble+'_HI'+wthres+'_diff_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)
# Out:
# ssp126_2081-2100 NEN
# ssp126_2081-2100 NCA
# ssp126_2081-2100 WAN
# ssp126_2081-2100 EEU
# ssp126_2081-2100 CAR
# ssp126_2081-2100 WSAF
# ssp126_2081-2100 CAU
# ssp126_2081-2100 WSB
# ssp126_2081-2100 NAU
# ssp126_2081-2100 SWS
# ssp126_2081-2100 NEU
# ssp126_2081-2100 NES
# ssp126_2081-2100 TIB
# ssp126_2081-2100 WNA
# ssp126_2081-2100 SES
# ssp126_2081-2100 SAM
# ssp126_2081-2100 NWS
# ssp126_2081-2100 NSA
# ssp126_2081-2100 SCA
# ssp126_2081-2100 MDG
# ssp126_2081-2100 CAF
# ssp126_2081-2100 SEAF
# ssp126_2081-2100 NZ
# ssp126_2081-2100 RAR
# ssp126_2081-2100 SEA
# ssp126_2081-2100 SAS
# ssp126_2081-2100 NWN
# ssp126_2081-2100 EAU
# ssp126_2081-2100 SAU
# ssp126_2081-2100 ENA
# ssp126_2081-2100 WAF
# ssp126_2081-2100 WCA
# ssp126_2081-2100 SAH
# ssp126_2081-2100 GIC
# ssp126_2081-2100 ESB
# ssp126_2081-2100 RFE
# ssp126_2081-2100 CNA
# ssp126_2081-2100 EAS
# ssp126_2081-2100 ARP
# ssp126_2081-2100 MED
# ssp126_2081-2100 ECA
# ssp126_2081-2100 NEAF
# ssp126_2081-2100 EAN
# ssp126_2081-2100 WCE
# ssp126_2081-2100 SSA
# ssp126_2081-2100 ESAF
# 2.0K NEN
# 2.0K NCA
# 2.0K WAN
# 2.0K EEU
# 2.0K CAR
# 2.0K WSAF
# 2.0K CAU
# 1.5K EAN
# 1.5K WCE
# 1.5K SSA
# 1.5K ESAF
# 3.0K NEN
# 3.0K NCA
# 3.0K WAN
# 3.0K EEU
# 3.0K CAR
# 3.0K WSAF
# 3.0K CAU
# 3.0K WSB
# 3.0K NAU
# 3.0K SWS
# 3.0K NEU
# 3.0K NES
# 3.0K TIB
# 3.0K WNA
# 3.0K SES
# 3.0K SAM
# 3.0K NWS
# 3.0K NSA
# 3.0K SCA
# 3.0K MDG
# 3.0K CAF
# 3.0K SEAF
# 3.0K NZ
# 3.0K RAR
# 3.0K SEA
# 3.0K SAS
# 3.0K NWN
# 3.0K EAU
# 3.0K SAU
# 3.0K ENA
# 3.0K WAF
# 3.0K WCA
# 3.0K SAH
# 3.0K GIC
# 3.0K ESB
# 3.0K RFE
# 3.0K CNA
# 3.0K EAS
# 3.0K ARP
# 3.0K MED
# 3.0K ECA
# 3.0K NEAF
# 3.0K EAN
# 3.0K WCE
# 3.0K SSA
# 3.0K ESAF
# ssp585_2041-2060 NEN
# ssp585_2041-2060 NCA
# ssp585_2041-2060 WAN
# ssp585_2041-2060 EEU
# ssp585_2041-2060 CAR
# ssp585_2041-2060 WSAF
# ssp585_2041-2060 CAU
# ssp585_2041-2060 WSB
# ssp585_2041-2060 NAU
# ssp585_2041-2060 SWS
# ssp585_2041-2060 NEU
# ssp585_2041-2060 NES
# ssp585_2041-2060 TIB
# ssp585_2041-2060 WNA
# ssp585_2041-2060 SES
# ssp585_2041-2060 SAM
# ssp585_2041-2060 NWS
# ssp585_2041-2060 NSA
# ssp585_2041-2060 SCA
# ssp585_2041-2060 MDG
# ssp585_2041-2060 CAF
# ssp585_2041-2060 SEAF
# ssp585_2041-2060 NZ
# ssp585_2041-2060 RAR
# ssp585_2041-2060 SEA
# ssp585_2041-2060 SAS
# ssp585_2041-2060 NWN
# ssp585_2041-2060 EAU
# ssp585_2041-2060 SAU
# ssp585_2041-2060 ENA
# ssp585_2041-2060 WAF
# ssp585_2041-2060 WCA
# ssp585_2041-2060 SAH
# ssp585_2041-2060 GIC
# ssp585_2041-2060 ESB
# ssp585_2041-2060 RFE
# ssp585_2041-2060 CNA
# ssp585_2041-2060 EAS
# ssp585_2041-2060 ARP
# ssp585_2041-2060 MED
# ssp585_2041-2060 ECA
# ssp585_2041-2060 NEAF
# ssp585_2041-2060 EAN
# ssp585_2041-2060 WCE
# ssp585_2041-2060 SSA
# ssp585_2041-2060 ESAF
# ssp126_2041-2060 NEN
# ssp126_2041-2060 NCA
# ssp126_2041-2060 WAN
# ssp126_2041-2060 EEU
# ssp126_2041-2060 CAR
# ssp126_2041-2060 WSAF
# ssp126_2041-2060 CAU
# ssp126_2041-2060 WSB
# ssp126_2041-2060 NAU
# ssp126_2041-2060 SWS
# ssp126_2041-2060 NEU
# ssp126_2041-2060 NES
# ssp126_2041-2060 TIB
# ssp126_2041-2060 WNA
# ssp126_2041-2060 SES
# ssp126_2041-2060 SAM
# ssp126_2041-2060 NWS
# ssp126_2041-2060 NSA
# ssp126_2041-2060 SCA
# ssp126_2041-2060 MDG
# ssp126_2041-2060 CAF
# ssp126_2041-2060 SEAF
# ssp126_2041-2060 NZ
# ssp126_2041-2060 RAR
# ssp126_2041-2060 SEA
# ssp126_2041-2060 SAS
# ssp126_2041-2060 NWN
# ssp126_2041-2060 EAU
# ssp126_2041-2060 SAU
# ssp126_2041-2060 ENA
# ssp126_2041-2060 WAF
# ssp126_2041-2060 WCA
# ssp126_2041-2060 SAH
# ssp126_2041-2060 GIC
# ssp126_2041-2060 ESB
# ssp126_2041-2060 RFE
# ssp126_2041-2060 CNA
# ssp126_2041-2060 EAS
# ssp126_2041-2060 ARP
# ssp126_2041-2060 MED
# ssp126_2041-2060 ECA
# ssp126_2041-2060 NEAF
# ssp126_2041-2060 EAN
# ssp126_2041-2060 WCE
# ssp126_2041-2060 SSA
# ssp126_2041-2060 ESAF
# 4.0K NEN
# 4.0K NCA
# 4.0K WAN
# 4.0K EEU
# 4.0K CAR
# 4.0K WSAF
# 4.0K CAU
# 4.0K WSB
# 4.0K NAU
# 4.0K SWS
# 4.0K NEU
# 4.0K NES
# 4.0K TIB
# 4.0K WNA
# 4.0K SES
# 4.0K SAM
# 4.0K NWS
# 4.0K NSA
# 4.0K SCA
# 4.0K MDG
# 4.0K CAF
# 4.0K SEAF
# 4.0K NZ
# 4.0K RAR
# 4.0K SEA
# 4.0K SAS
# 4.0K NWN
# 4.0K EAU
# 4.0K SAU
# 4.0K ENA
# 4.0K WAF
# 4.0K WCA
# 4.0K SAH
# 4.0K GIC
# 4.0K ESB
# 4.0K RFE
# 4.0K CNA
# 4.0K EAS
# 4.0K ARP
# 4.0K MED
# 4.0K ECA
# 4.0K NEAF
# 4.0K EAN
# 4.0K WCE
# 4.0K SSA
# 4.0K ESAF

# %%
# !mkdir -p /home/jservon/Chapter12_IPCC/data/HI_satellites/

# %% [markdown]
# ## CMIP5

# %%
pattern = '/data/jservon/IPCC/HI_NOAA/CMIP5/${member}_${thres}_${experiment}_${clim_period}.nc'
cproject('HI_cmip5_ch12','experiment','clim_period','member',('period','fx'),('thres','Exceed41'), ('variable','HI'), ensemble=['member'], separator='%')
dataloc(project='HI_cmip5_ch12', url=pattern)
# Out:
# <climaf.dataloc.dataloc instance at 0x2afb9125fd88>

# %%
thres = 'Exceed'+wthres
# -- Scenarios - timelines
# ---------------------------------------------------------------------------

exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='rcp85',
         clim_period = '1995-2014'),    
    # -- Mid term
    dict(experiment='rcp85',
         clim_period = '2041-2060'),
    dict(experiment='rcp26',
         clim_period = '2041-2060'),
    # -- Late term
    dict(experiment='rcp85',
         clim_period = '2081-2100'),
    dict(experiment='rcp26',
         clim_period = '2081-2100'),
]

# -- Loop on the scenarios
ens_exp_dict = dict()
for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    clim_period = exp['clim_period']
    
    # -- Create ensemble object for the scenario
    req_exp = ds(project='HI_cmip5_ch12',
                 experiment = experiment,
                 clim_period = clim_period,
                 member = '*',
                )
    ens_exp = req_exp.explore('ensemble')
    
    # -- Climatologies
    ens_exp_dict[experiment+'_'+clim_period] = clim_average(ens_exp, 'ANM')
#

# %%
# -- Global Warming Levels
# ---------------------------------------------------------------------------
ens_GWL_dict = dict()

# -- Loop on the GWLs
for GWL in ['1.5K','2.0K','3.0K','4.0K']:
    #
    if GWL in ['1.5K','2.0K']:
        # -- Create ensemble object for the scenario
        req_rcp26 = ds(project='HI_cmip5_ch12',
                     experiment = 'rcp26',
                     clim_period = GWL,
                     member = '*',
                    )
        ens_rcp26 = req_rcp26.explore('ensemble')

        # -- Create ensemble object for the scenario
        req_rcp85 = ds(project='HI_cmip5_ch12',
                     experiment = 'rcp85',
                     clim_period = GWL,
                     member = '*',
                    )
        ens_rcp85 = req_rcp85.explore('ensemble')
        #
        # -- Merge ensembles
        GWL_ens = merge_climaf_ensembles([add_prefix_suffix_to_ens_req(ens_rcp26,suffix='_rcp26'),
                                          add_prefix_suffix_to_ens_req(ens_rcp85,suffix='_rcp85')])
    else:
        # -- Create ensemble object for the scenario
        req_rcp85 = ds(project='HI_cmip5_ch12',
                     experiment = 'rcp85',
                     clim_period = GWL,
                     member = '*',
                    )
        GWL_ens = req_rcp85.explore('ensemble')
        
    # -- Climatologies
    ens_GWL_dict[GWL] = clim_average(GWL_ens, 'ANM')

# %%
ens_GWL_dict
# Out:
# {'1.5K': cens({'BNU-ESM_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%BNU-ESM_r1i1p1%Exceed41')),'CESM1-CAM5_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%CESM1-CAM5_r1i1p1%Exceed41')),'CNRM-CM5_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%CNRM-CM5_r1i1p1%Exceed41')),'CSIRO-Mk3-6-0_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%CSIRO-Mk3-6-0_r1i1p1%Exceed41')),'GFDL-CM3_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%GFDL-CM3_r1i1p1%Exceed41')),'HadGEM2-AO_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%HadGEM2-AO_r1i1p1%Exceed41')),'HadGEM2-ES_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%HadGEM2-ES_r1i1p1%Exceed41')),'IPSL-CM5A-LR_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%IPSL-CM5A-LR_r1i1p1%Exceed41')),'IPSL-CM5A-MR_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%IPSL-CM5A-MR_r1i1p1%Exceed41')),'bcc-csm1-1-m_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%bcc-csm1-1-m_r1i1p1%Exceed41')),'bcc-csm1-1_r1i1p1_rcp26':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp26%1.5K%bcc-csm1-1_r1i1p1%Exceed41')),'ACCESS1-0_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%1.5K%ACCESS1-0_r1i1p1%Exceed41')),'ACCESS1-3_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%1.5K%ACCESS1-3_r1i1p1%Exceed41')),'BNU-ESM_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%1.5K%BNU-ESM_r1i1p1%Exceed41')),'CESM1-CAM5_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%1.5K%CESM1-CAM5_r1i1p1%Exceed41')),'CNRM-CM5_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%1.5K%CNRM-CM5_r1i1p1%Exceed41')),'CSIRO-Mk3-6-0_r1i1p1_rcp85':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85
r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%HadGEM2-AO_r1i1p1%Exceed41')),'HadGEM2-CC_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%HadGEM2-CC_r1i1p1%Exceed41')),'HadGEM2-ES_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%HadGEM2-ES_r1i1p1%Exceed41')),'IPSL-CM5A-LR_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%IPSL-CM5A-LR_r1i1p1%Exceed41')),'IPSL-CM5A-MR_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%IPSL-CM5A-MR_r1i1p1%Exceed41')),'IPSL-CM5B-LR_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%IPSL-CM5B-LR_r1i1p1%Exceed41')),'bcc-csm1-1-m_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%bcc-csm1-1-m_r1i1p1%Exceed41')),'bcc-csm1-1_r1i1p1':time_average(ds('HI_cmip5_ch12%%HI%fx%global%rcp85%4.0K%bcc-csm1-1_r1i1p1%Exceed41'))})}

# %%
regional_averages_CMIP5 = dict()

# -- Loop on experiments / horizons
for ens_exp in ens_exp_dict:
    print ens_exp
    regional_averages_CMIP5[ens_exp] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_exp_dict[ens_exp]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'HI', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            #print region_name
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            if region_name not in regional_averages_CMIP5[ens_exp]:
                regional_averages_CMIP5[ens_exp][region_name] = [region_value]
            else:
                regional_averages_CMIP5[ens_exp][region_name].append(region_value)
#
for GWL in ens_GWL_dict :
    print GWL
    regional_averages_CMIP5[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), 'HI', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            #print region_name
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            if region_name not in regional_averages_CMIP5[GWL]:
                regional_averages_CMIP5[GWL][region_name] = [region_value]
            else:
                regional_averages_CMIP5[GWL][region_name].append(region_value)
# Out:
# rcp85_1995-2014
# bcc-csm1-1_r1i1p1
# inmcm4_r1i1p1
# BNU-ESM_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# MRI-ESM1_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# HadGEM2-CC_r1i1p1
# CESM1-CAM5_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# CanESM2_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# GFDL-CM3_r1i1p1
# bcc-csm1-1-m_r1i1p1
# HadGEM2-AO_r1i1p1
# HadGEM2-ES_r1i1p1
# rcp26_2041-2060
# CNRM-CM5_r1i1p1
# MRI-ESM1_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-CC_r1i1p1
# HadGEM2-ES_r1i1p1
# bcc-csm1-1-m_r1i1p1
# 1.5K
# IPSL-CM5A-MR_r1i1p1_rcp85
# GFDL-CM3_r1i1p1_rcp26
# CESM1-CAM5_r1i1p1_rcp85
# GFDL-ESM2M_r1i1p1_rcp85
# IPSL-CM5A-LR_r1i1p1_rcp85
# HadGEM2-AO_r1i1p1_rcp85
# bcc-csm1-1_r1i1p1_rcp26
# HadGEM2-ES_r1i1p1_rcp85
# CESM1-CAM5_r1i1p1_rcp26
# CSIRO-Mk3-6-0_r1i1p1_rcp85
# CNRM-CM5_r1i1p1_rcp85
# IPSL-CM5A-LR_r1i1p1_rcp26
# NorESM1-M_r1i1p1_rcp85
# IPSL-CM5B-LR_r1i1p1_rcp85
# bcc-csm1-1_r1i1p1_rcp85
# GFDL-ESM2G_r1i1p1_rcp85
# BNU-ESM_r1i1p1_rcp26
# CNRM-CM5_r1i1p1_rcp26
# ACCESS1-3_r1i1p1_rcp85
# MRI-CGCM3_r1i1p1_rcp85
# ACCESS1-0_r1i1p1_rcp85
# bcc-csm1-1-m_r1i1p1_rcp26
# IPSL-CM5A-MR_r1i1p1_rcp26
# CSIRO-Mk3-6-0_r1i1p1_rcp26
# HadGEM2-ES_r1i1p1_rcp26
# BNU-ESM_r1i1p1_rcp85
# MRI-ESM1_r1i1p1_rcp85
# HadGEM2-CC_r1i1p1_rcp85
# GFDL-CM3_r1i1p1_rcp85
# bcc-csm1-1-m_r1i1p1_rcp85
# HadGEM2-AO_r1i1p1_rcp26
# 4.0K
# BNU-ESM_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# HadGEM2-AO_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-CC_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# HadGEM2-ES_r1i1p1
# CNRM-CM5_r1i1p1
# bcc-csm1-1-m_r1i1p1
# 2.0K
# IPSL-CM5A-MR_r1i1p1_rcp85
# GFDL-CM3_r1i1p1_rcp26
# CNRM-CM5_r1i1p1_rcp85
# IPSL-CM5A-LR_r1i1p1_rcp85
# HadGEM2-AO_r1i1p1_rcp85
# bcc-csm1-1-m_r1i1p1_rcp26
# HadGEM2-ES_r1i1p1_rcp85
# CSIRO-Mk3-6-0_r1i1p1_rcp85
# CESM1-CAM5_r1i1p1_rcp85
# IPSL-CM5A-LR_r1i1p1_rcp26
# NorESM1-M_r1i1p1_rcp85
#    44.24246232710639,
#    56.08157902196109,
#    67.07197512136639,
#    16.76925956986703,
#    32.81356375734132,
#    21.779131785505513,
#    50.7043028003909,
#    17.49172185117714,
#    31.180171459648868,
#    29.398206309100573,
#    34.17417784293647,
#    70.85728732886447,
#    80.90744408861123,
#    31.85356405219395,
#    22.329566498307567,
#    39.66956420660603,
#    19.67400280120445,
#    10.537561176937443,
#    15.962808080926425,
#    43.344303649961056,
#    44.96626331243182,
#    38.29069091986604,
#    28.385443263139077,
#    40.80084324739406],
#   'WSB': [13.394870889781089,
#    2.449538972509036,
#    7.791989768876812,
#    18.256259941376815,
#    1.3665969550900556,
#    4.661132307524686,
#    1.6316683426141518,
#    3.806730964025217,
#    1.6537808800244815,
#    3.48039893904661,
#    3.6138991984002806,
#    5.484934993160401,
#    18.10970571844031,
#    19.28427651008321,
#    4.5692301362231404,
#    2.864963449312689,
#    1.1497796601241457,
#    2.077659630981768,
#    1.363522400508366,
#    0.4887588967437046,
#    2.985992652384116,
#    6.162321760730647,
#    2.2073140321265163,
#    2.372309401917428,
#    2.6636423265897613]}}

# %%
quantiles_dict = dict()
for clim_period in regional_averages_CMIP5:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages_CMIP5[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages_CMIP5[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# rcp85_2081-2100 NEN
# rcp85_2081-2100 NCA
# rcp85_2081-2100 WAN
# rcp85_2081-2100 EEU
# rcp85_2081-2100 CAR
# rcp85_2081-2100 WSAF
# rcp85_2081-2100 CAU
# rcp85_2081-2100 WSB
# rcp85_2081-2100 NAU
# rcp85_2081-2100 SWS
# rcp85_2081-2100 NEU
# rcp85_2081-2100 NES
# rcp85_2081-2100 TIB
# rcp85_2081-2100 WNA
# rcp85_2081-2100 SES
# rcp85_2081-2100 SAM
# rcp85_2081-2100 NWS
# rcp85_2081-2100 NSA
# rcp85_2081-2100 SCA
# rcp85_2081-2100 MDG
# rcp85_2081-2100 CAF
# rcp85_2081-2100 SEAF
# rcp85_2081-2100 NZ
# rcp85_2081-2100 RAR
# rcp85_2081-2100 SEA
# rcp85_2081-2100 SAS
# rcp85_2081-2100 NWN
# rcp85_2081-2100 EAU
# rcp85_2081-2100 SAU
# rcp85_2081-2100 ENA
# rcp85_2081-2100 WAF
# rcp85_2081-2100 WCA
# rcp85_2081-2100 SAH
# rcp85_2081-2100 GIC
# rcp85_2081-2100 ESB
# rcp85_2081-2100 RFE
# rcp85_2081-2100 CNA
# rcp85_2081-2100 EAS
# rcp85_2081-2100 ARP
# rcp85_2081-2100 MED
# rcp85_2081-2100 ECA
# rcp85_2081-2100 NEAF
# rcp85_2081-2100 EAN
# rcp85_2081-2100 WCE
# rcp85_2081-2100 SSA
# rcp85_2081-2100 ESAF
# rcp85_1995-2014 NEN
# rcp85_1995-2014 NCA
# rcp85_1995-2014 WAN
# rcp85_1995-2014 EEU
# rcp85_1995-2014 CAR
# rcp85_1995-2014 WSAF
# rcp85_1995-2014 CAU
# rcp85_1995-2014 WSB
# rcp85_1995-2014 NAU
# rcp85_1995-2014 SWS
# rcp85_1995-2014 NEU
# rcp85_1995-2014 NES
# rcp85_1995-2014 TIB
# rcp85_1995-2014 WNA
# rcp85_1995-2014 SES
# rcp85_1995-2014 SAM
# rcp85_1995-2014 NWS
# rcp85_1995-2014 NSA
# rcp85_1995-2014 SCA
# rcp85_1995-2014 MDG
# rcp85_1995-2014 CAF
# rcp85_1995-2014 SEAF
# rcp85_1995-2014 NZ
# rcp85_1995-2014 RAR
# rcp85_1995-2014 SEA
# rcp85_1995-2014 SAS
# rcp85_1995-2014 NWN
# rcp85_1995-2014 EAU
# rcp85_1995-2014 SAU
# rcp85_1995-2014 ENA
# rcp85_1995-2014 WAF
# rcp85_1995-2014 WCA
# rcp85_1995-2014 SAH
# rcp85_1995-2014 GIC
# rcp85_1995-2014 ESB
# rcp85_1995-2014 RFE
# rcp85_1995-2014 CNA
# rcp85_1995-2014 EAS
# rcp85_1995-2014 ARP
# rcp85_1995-2014 MED
# rcp85_1995-2014 ECA
# rcp85_1995-2014 NEAF
# rcp85_1995-2014 EAN
# rcp85_1995-2014 WCE
# rcp85_1995-2014 SSA
# rcp85_1995-2014 ESAF
# 1.5K NEN
# 1.5K NCA
# 1.5K WAN
# 1.5K EEU
# 1.5K CAR
# 1.5K WSAF
# 1.5K CAU
# 1.5K WSB
# 1.5K NAU
# 1.5K SWS
# 1.5K NEU
# 1.5K NES
# 1.5K TIB
# 1.5K WNA
# 1.5K SES
# 1.5K SAM
# 1.5K NWS
# 1.5K NSA
# 1.5K SCA
# 1.5K MDG
# 1.5K CAF
# 1.5K SEAF
# 1.5K NZ
# 1.5K RAR
# 1.5K SEA
# 1.5K SAS
# 1.5K NWN
# 1.5K EAU
# 1.5K SAU
# 1.5K ENA
# 1.5K WAF
# 1.5K WCA
# 1.5K SAH
# 1.5K GIC
# 1.5K ESB
# 1.5K RFE
# 1.5K CNA
# 1.5K EAS
# 1.5K ARP
# 1.5K MED
# 1.5K ECA
# 1.5K NEAF
# 1.5K EAN
# 1.5K WCE
# 1.5K SSA
# 1.5K ESAF
# 2.0K NEN
# 2.0K NCA
# 2.0K WAN
# 2.0K EEU
# 2.0K CAR
# 2.0K WSAF
# 2.0K CAU
# 2.0K WSB
# 2.0K NAU
# 2.0K SWS
# 2.0K NEU
# 2.0K NES
# 2.0K TIB
# 2.0K WNA
# 2.0K SES
# 2.0K SAM
# 2.0K NWS
# 2.0K NSA
# 2.0K SCA
# 2.0K MDG
# 2.0K CAF
# 2.0K SEAF
# 2.0K NZ
# 2.0K RAR
# 2.0K SEA
# 2.0K SAS
# 2.0K NWN
# 2.0K EAU
# 2.0K SAU
# 2.0K ENA
# 2.0K WAF
# 2.0K WCA
# 2.0K SAH
# 2.0K GIC
# 2.0K ESB
# 2.0K RFE
# 2.0K CNA
# 2.0K EAS
# 2.0K ARP
# 2.0K MED
# 2.0K ECA
# 2.0K NEAF
# 2.0K EAN
# 2.0K WCE
# 2.0K SSA
# 2.0K ESAF
# 3.0K NEN
# 3.0K NCA
# 3.0K WAN
# 3.0K EEU
# 3.0K CAR
# 3.0K WSAF
# 3.0K CAU
# 3.0K WSB
# 3.0K NAU
# 3.0K SWS
# 3.0K NEU
# 3.0K NES
# 3.0K TIB
# 3.0K WNA
# 3.0K SES
# 3.0K SAM
# 3.0K NWS
# 3.0K NSA
# 3.0K SCA
# 3.0K MDG
# 3.0K CAF
# 3.0K SEAF
# 3.0K NZ
# 3.0K RAR
# 3.0K SEA
# 3.0K SAS
# 3.0K NWN
# 3.0K EAU
# 3.0K SAU
# 3.0K ENA
# 3.0K WAF
# 3.0K WCA
# 3.0K SAH
# 3.0K GIC
# 3.0K ESB
# 3.0K RFE
# 3.0K CNA
# 3.0K EAS
# 3.0K ARP
# 3.0K MED
# 3.0K ECA
# 3.0K NEAF
# 3.0K EAN
# 3.0K WCE
# 3.0K SSA
# 3.0K ESAF
# rcp26_2041-2060 NEN
# rcp26_2041-2060 NCA
# rcp26_2041-2060 WAN
# rcp26_2041-2060 EEU
# rcp26_2041-2060 CAR
# rcp26_2041-2060 WSAF
# rcp26_2041-2060 CAU
# rcp26_2041-2060 WSB
# rcp26_2041-2060 NAU
# rcp26_2041-2060 SWS
# rcp26_2041-2060 NEU
# rcp26_2041-2060 NES
# rcp26_2041-2060 TIB
# rcp26_2041-2060 WNA
# rcp26_2041-2060 SES
# rcp26_2041-2060 SAM
# rcp26_2041-2060 NWS
# rcp26_2041-2060 NSA
# rcp26_2041-2060 SCA
# rcp26_2041-2060 MDG
# rcp26_2041-2060 CAF
# rcp26_2041-2060 SEAF
# rcp26_2041-2060 NZ
# rcp26_2041-2060 RAR
# rcp26_2041-2060 SEA
# rcp26_2041-2060 SAS
# rcp26_2041-2060 NWN
# rcp26_2041-2060 EAU
# rcp26_2041-2060 SAU
# rcp26_2041-2060 ENA
# rcp26_2041-2060 WAF
# rcp26_2041-2060 WCA
# rcp26_2041-2060 SAH
# rcp26_2041-2060 GIC
# rcp26_2041-2060 ESB
# rcp26_2041-2060 RFE
# rcp26_2041-2060 CNA
# rcp26_2041-2060 EAS
# rcp26_2041-2060 ARP
# rcp26_2041-2060 MED
# rcp26_2041-2060 ECA
# rcp26_2041-2060 NEAF
# rcp26_2041-2060 EAN
# rcp26_2041-2060 WCE
# rcp26_2041-2060 SSA
# rcp26_2041-2060 ESAF
# rcp85_2041-2060 NEN
# rcp85_2041-2060 NCA
# rcp85_2041-2060 WAN
# rcp85_2041-2060 EEU
# rcp85_2041-2060 CAR
# rcp85_2041-2060 WSAF
# rcp85_2041-2060 CAU
# rcp85_2041-2060 WSB
# rcp85_2041-2060 NAU
# rcp85_2041-2060 SWS
# rcp85_2041-2060 NEU
# rcp85_2041-2060 NES
# rcp85_2041-2060 TIB
# rcp85_2041-2060 WNA
# rcp85_2041-2060 SES
# rcp85_2041-2060 SAM
# rcp85_2041-2060 NWS
# rcp85_2041-2060 NSA
# rcp85_2041-2060 SCA
# rcp85_2041-2060 MDG
# rcp85_2041-2060 CAF
# rcp85_2041-2060 SEAF
# rcp85_2041-2060 NZ
# rcp85_2041-2060 RAR
# rcp85_2041-2060 SEA
# rcp85_2041-2060 SAS
# rcp85_2041-2060 NWN
# rcp85_2041-2060 EAU
# rcp85_2041-2060 SAU
# rcp85_2041-2060 ENA
# rcp85_2041-2060 WAF
# rcp85_2041-2060 WCA
# rcp85_2041-2060 SAH
# rcp85_2041-2060 GIC
# rcp85_2041-2060 ESB
# rcp85_2041-2060 RFE
# rcp85_2041-2060 CNA
# rcp85_2041-2060 EAS
# rcp85_2041-2060 ARP
# rcp85_2041-2060 MED
# rcp85_2041-2060 ECA
# rcp85_2041-2060 NEAF
# rcp85_2041-2060 EAN
# rcp85_2041-2060 WCE
# rcp85_2041-2060 SSA
# rcp85_2041-2060 ESAF
# 4.0K NEN
# 4.0K NCA
# 4.0K WAN
# 4.0K EEU
# 4.0K CAR
# 4.0K WSAF
# 4.0K CAU
# 4.0K WSB
# 4.0K NAU
# 4.0K SWS
# 4.0K NEU
# 4.0K NES
# 4.0K TIB
# 4.0K WNA
# 4.0K SES
# 4.0K SAM
# 4.0K NWS
# 4.0K NSA
# 4.0K SCA
# 4.0K MDG
# 4.0K CAF
# 4.0K SEAF
# 4.0K NZ
# 4.0K RAR
# 4.0K SEA
# 4.0K SAS
# 4.0K NWN
# 4.0K EAU
# 4.0K SAU
# 4.0K ENA
# 4.0K WAF
# 4.0K WCA
# 4.0K SAH
# 4.0K GIC
# 4.0K ESB
# 4.0K RFE
# 4.0K CNA
# 4.0K EAS
# 4.0K ARP
# 4.0K MED
# 4.0K ECA
# 4.0K NEAF
# 4.0K EAN
# 4.0K WCE
# 4.0K SSA
# 4.0K ESAF
# rcp26_2081-2100 NEN
# rcp26_2081-2100 NCA
# rcp26_2081-2100 WAN
# rcp26_2081-2100 EEU
# rcp26_2081-2100 CAR
# rcp26_2081-2100 WSAF
# rcp26_2081-2100 CAU
# rcp26_2081-2100 WSB
# rcp26_2081-2100 NAU
# rcp26_2081-2100 SWS
# rcp26_2081-2100 NEU
# rcp26_2081-2100 NES
# rcp26_2081-2100 TIB
# rcp26_2081-2100 WNA
# rcp26_2081-2100 SES
# rcp26_2081-2100 SAM
# rcp26_2081-2100 NWS
# rcp26_2081-2100 NSA
# rcp26_2081-2100 SCA
# rcp26_2081-2100 MDG
# rcp26_2081-2100 CAF
# rcp26_2081-2100 SEAF
# rcp26_2081-2100 NZ
# rcp26_2081-2100 RAR
# rcp26_2081-2100 SEA
# rcp26_2081-2100 SAS
# rcp26_2081-2100 NWN
# rcp26_2081-2100 EAU
# rcp26_2081-2100 SAU
# rcp26_2081-2100 ENA
# rcp26_2081-2100 WAF
# rcp26_2081-2100 WCA
# rcp26_2081-2100 SAH
# rcp26_2081-2100 GIC
# rcp26_2081-2100 ESB
# rcp26_2081-2100 RFE
# rcp26_2081-2100 CNA
# rcp26_2081-2100 EAS
# rcp26_2081-2100 ARP
# rcp26_2081-2100 MED
# rcp26_2081-2100 ECA
# rcp26_2081-2100 NEAF
# rcp26_2081-2100 EAN
# rcp26_2081-2100 WCE
# rcp26_2081-2100 SSA
# rcp26_2081-2100 ESAF

# %%
import json
ensemble = 'CMIP5'
outfilename = '/home/jservon/Chapter12_IPCC/data/HI_satellites/'+ensemble+'_HI'+wthres+'_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %% [markdown]
# ### Differences

# %%
regional_averages_diff = dict()

# -- Loop on experiments / horizons
#wind_ens_clim_exp_dict[exp]
for ens_exp in ens_exp_dict:
    if ens_exp not in ['rcp85_1995-2014']:
        print ens_exp
        regional_averages_diff[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_exp_dict[ens_exp]:
            if mem in ens_exp_dict['rcp85_1995-2014']:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                #print cfile(ens_exp_dict[ens_exp][mem])
                #cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_exp_dict[ens_exp][mem])
                #os.system(cmd)
                tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'HI', 'all')
                tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['rcp85_1995-2014'][mem]), 'HI', 'all')
                region_names = tmp.abbrevs
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    region_value_baseline = float(tmp_baseline.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    if region_name not in regional_averages_diff[ens_exp]:
                        regional_averages_diff[ens_exp][region_name] = [region_value - region_value_baseline]
                    else:
                        regional_averages_diff[ens_exp][region_name].append(region_value - region_value_baseline)
        #
# Out:
# rcp26_2041-2060
# HadGEM2-AO_r1i1p1
# BNU-ESM_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# CanESM2_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# GFDL-CM3_r1i1p1
# HadGEM2-ES_r1i1p1
# bcc-csm1-1-m_r1i1p1
# rcp85_2041-2060
# bcc-csm1-1_r1i1p1
# inmcm4_r1i1p1
# BNU-ESM_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# MRI-ESM1_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# HadGEM2-CC_r1i1p1
# CESM1-CAM5_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# CanESM2_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# GFDL-CM3_r1i1p1
# bcc-csm1-1-m_r1i1p1
# HadGEM2-AO_r1i1p1
# HadGEM2-ES_r1i1p1
# rcp26_2081-2100
# HadGEM2-AO_r1i1p1
# BNU-ESM_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# CanESM2_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# GFDL-CM3_r1i1p1
# HadGEM2-ES_r1i1p1
# bcc-csm1-1-m_r1i1p1
# rcp85_2081-2100
# bcc-csm1-1_r1i1p1
# inmcm4_r1i1p1
# BNU-ESM_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# MRI-ESM1_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# HadGEM2-CC_r1i1p1
# CESM1-CAM5_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# CanESM2_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# GFDL-CM3_r1i1p1
# bcc-csm1-1-m_r1i1p1
# HadGEM2-AO_r1i1p1
# HadGEM2-ES_r1i1p1

# %%
ens_GWL_dict['3.0K'].keys()
# Out:
# ['IPSL-CM5B-LR_r1i1p1',
#  'HadGEM2-AO_r1i1p1',
#  'BNU-ESM_r1i1p1',
#  'ACCESS1-3_r1i1p1',
#  'ACCESS1-0_r1i1p1',
#  'MRI-CGCM3_r1i1p1',
#  'NorESM1-M_r1i1p1',
#  'CNRM-CM5_r1i1p1',
#  'MRI-ESM1_r1i1p1',
#  'GFDL-ESM2M_r1i1p1',
#  'IPSL-CM5A-MR_r1i1p1',
#  'GFDL-CM3_r1i1p1',
#  'CESM1-CAM5_r1i1p1',
#  'bcc-csm1-1_r1i1p1',
#  'GFDL-ESM2G_r1i1p1',
#  'CSIRO-Mk3-6-0_r1i1p1',
#  'IPSL-CM5A-LR_r1i1p1',
#  'HadGEM2-CC_r1i1p1',
#  'HadGEM2-ES_r1i1p1',
#  'bcc-csm1-1-m_r1i1p1']

# %%
for GWL in ens_GWL_dict:
    print GWL
    regional_averages_diff[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        wmem = mem.replace('_rcp85','').replace('_rcp26','')
        #if mem.replace('_85','').replace('_26','') in ens_exp_dict['historical_1995-2014']:
        if wmem in ens_exp_dict['rcp85_1995-2014']:
            print wmem
            # -- Compute the averages for each AR6 region thanks to regionmask
            tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), 'HI', 'all')
            tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['rcp85_1995-2014'][wmem]), 'HI', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                region_value_baseline = float(tmp_baseline.sel(region=list(tmp_baseline.abbrevs).index(region_name)).values)
                if region_name not in regional_averages_diff[GWL]:
                    regional_averages_diff[GWL][region_name] = [region_value - region_value_baseline]
                else:
                    regional_averages_diff[GWL][region_name].append(region_value - region_value_baseline)
# Out:
# 3.0K
# IPSL-CM5B-LR_r1i1p1
# HadGEM2-AO_r1i1p1
# BNU-ESM_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# MRI-CGCM3_r1i1p1
# NorESM1-M_r1i1p1
# CNRM-CM5_r1i1p1
# MRI-ESM1_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# GFDL-ESM2G_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-CC_r1i1p1
# HadGEM2-ES_r1i1p1
# bcc-csm1-1-m_r1i1p1
# 1.5K
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# CESM1-CAM5_r1i1p1
# GFDL-ESM2M_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-AO_r1i1p1
# bcc-csm1-1_r1i1p1
# HadGEM2-ES_r1i1p1
# CESM1-CAM5_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# CNRM-CM5_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# NorESM1-M_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# bcc-csm1-1_r1i1p1
# GFDL-ESM2G_r1i1p1
# BNU-ESM_r1i1p1
# CNRM-CM5_r1i1p1
# ACCESS1-3_r1i1p1
# MRI-CGCM3_r1i1p1
# ACCESS1-0_r1i1p1
# bcc-csm1-1-m_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# HadGEM2-ES_r1i1p1
# BNU-ESM_r1i1p1
# MRI-ESM1_r1i1p1
# HadGEM2-CC_r1i1p1
# GFDL-CM3_r1i1p1
# bcc-csm1-1-m_r1i1p1
# HadGEM2-AO_r1i1p1
# 4.0K
# BNU-ESM_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# HadGEM2-AO_r1i1p1
# CESM1-CAM5_r1i1p1
# bcc-csm1-1_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-CC_r1i1p1
# ACCESS1-3_r1i1p1
# ACCESS1-0_r1i1p1
# HadGEM2-ES_r1i1p1
# CNRM-CM5_r1i1p1
# bcc-csm1-1-m_r1i1p1
# 2.0K
# IPSL-CM5A-MR_r1i1p1
# GFDL-CM3_r1i1p1
# CNRM-CM5_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# HadGEM2-AO_r1i1p1
# bcc-csm1-1-m_r1i1p1
# HadGEM2-ES_r1i1p1
# CSIRO-Mk3-6-0_r1i1p1
# CESM1-CAM5_r1i1p1
# IPSL-CM5A-LR_r1i1p1
# NorESM1-M_r1i1p1
# IPSL-CM5B-LR_r1i1p1
# bcc-csm1-1_r1i1p1
# GFDL-ESM2G_r1i1p1
# BNU-ESM_r1i1p1
# CESM1-CAM5_r1i1p1
# ACCESS1-3_r1i1p1
# MRI-CGCM3_r1i1p1
# ACCESS1-0_r1i1p1
# IPSL-CM5A-MR_r1i1p1
# BNU-ESM_r1i1p1
# MRI-ESM1_r1i1p1
# HadGEM2-CC_r1i1p1
# GFDL-CM3_r1i1p1
# bcc-csm1-1-m_r1i1p1
# GFDL-ESM2M_r1i1p1

# %%
quantiles_dict = dict()
for clim_period in regional_averages_diff:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages_diff[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages_diff[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]

import json

ensemble = 'CMIP5'
outfilename = '/home/jservon/Chapter12_IPCC/data/HI_satellites/'+ensemble+'_HI'+wthres+'_diff_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)
# Out:
# rcp85_2081-2100 NEN
# rcp85_2081-2100 NCA
# rcp85_2081-2100 WAN
# rcp85_2081-2100 EEU
# rcp85_2081-2100 CAR
# rcp85_2081-2100 WSAF
# rcp85_2081-2100 CAU
# rcp85_2081-2100 WSB
# rcp85_2081-2100 NAU
# rcp85_2081-2100 SWS
# rcp85_2081-2100 NEU
# rcp85_2081-2100 NES
# rcp85_2081-2100 TIB
# rcp85_2081-2100 WNA
# rcp85_2081-2100 SES
# rcp85_2081-2100 SAM
# rcp85_2081-2100 NWS
# rcp85_2081-2100 NSA
# rcp85_2081-2100 SCA
# rcp85_2081-2100 MDG
# rcp85_2081-2100 CAF
# rcp85_2081-2100 SEAF
# rcp85_2081-2100 NZ
# rcp85_2081-2100 RAR
# rcp85_2081-2100 SEA
# rcp85_2081-2100 SAS
# rcp85_2081-2100 NWN
# rcp85_2081-2100 EAU
# rcp85_2081-2100 SAU
# rcp85_2081-2100 ENA
# rcp85_2081-2100 WAF
# rcp85_2081-2100 WCA
# rcp85_2081-2100 SAH
# rcp85_2081-2100 GIC
# rcp85_2081-2100 ESB
# rcp85_2081-2100 RFE
# rcp85_2081-2100 CNA
# rcp85_2081-2100 EAS
# rcp85_2081-2100 ARP
# rcp85_2081-2100 MED
# rcp85_2081-2100 ECA
# rcp85_2081-2100 NEAF
# rcp85_2081-2100 EAN
# rcp85_2081-2100 WCE
# rcp85_2081-2100 SSA
# rcp85_2081-2100 ESAF
# 1.5K NEN
# 1.5K NCA
# 1.5K WAN
# 1.5K EEU
# 1.5K CAR
# 1.5K WSAF
# 1.5K CAU
# 1.5K WSB
# 1.5K NAU
# 1.5K SWS
# 1.5K NEU
# 1.5K NES
# 1.5K TIB
# 1.5K WNA
# 1.5K SES
# 1.5K SAM
# 1.5K NWS
# 1.5K NSA
# 1.5K SCA
# 1.5K MDG
# 1.5K CAF
# 1.5K SEAF
# 1.5K NZ
# 1.5K RAR
# 1.5K SEA
# 1.5K SAS
# 1.5K NWN
# 1.5K EAU
# 1.5K SAU
# 1.5K ENA
# 1.5K WAF
# 1.5K WCA
# 1.5K SAH
# 1.5K GIC
# 1.5K ESB
# 1.5K RFE
# 1.5K CNA
# 1.5K EAS
# 1.5K ARP
# 1.5K MED
# 1.5K ECA
# 1.5K NEAF
# 1.5K EAN
# 1.5K WCE
# 1.5K SSA
# 1.5K ESAF
# 2.0K NEN
# 2.0K NCA
# 2.0K WAN
# 2.0K EEU
# 2.0K CAR
# 2.0K WSAF
# 2.0K CAU
# 2.0K WSB
# 2.0K NAU
# 2.0K SWS
# 2.0K NEU
# 2.0K NES
# 2.0K TIB
# 2.0K WNA
# 2.0K SES
# 2.0K SAM
# 2.0K NWS
# 2.0K NSA
# 2.0K SCA
# 2.0K MDG
# 2.0K CAF
# 2.0K SEAF
# 2.0K NZ
# 2.0K RAR
# 2.0K SEA
# 2.0K SAS
# 2.0K NWN
# 2.0K EAU
# 2.0K SAU
# 2.0K ENA
# 2.0K WAF
# 2.0K WCA
# 2.0K SAH
# 2.0K GIC
# 2.0K ESB
# 2.0K RFE
# 2.0K CNA
# 2.0K EAS
# 2.0K ARP
# 2.0K MED
# 2.0K ECA
# 2.0K NEAF
# 2.0K EAN
# 2.0K WCE
# 2.0K SSA
# 2.0K ESAF
# 3.0K NEN
# 3.0K NCA
# 3.0K WAN
# 3.0K EEU
# 3.0K CAR
# 3.0K WSAF
# 3.0K CAU
# 3.0K WSB
# 3.0K NAU
# 3.0K SWS
# 3.0K NEU
# 3.0K NES
# 3.0K TIB
# 3.0K WNA
# 3.0K SES
# 3.0K SAM
# 3.0K NWS
# 3.0K NSA
# 3.0K SCA
# 3.0K MDG
# 3.0K CAF
# 3.0K SEAF
# 3.0K NZ
# 3.0K RAR
# 3.0K SEA
# 3.0K SAS
# 3.0K NWN
# 3.0K EAU
# 3.0K SAU
# 3.0K ENA
# 3.0K WAF
# 3.0K WCA
# 3.0K SAH
# 3.0K GIC
# 3.0K ESB
# 3.0K RFE
# 3.0K CNA
# 3.0K EAS
# 3.0K ARP
# 3.0K MED
# 3.0K ECA
# 3.0K NEAF
# 3.0K EAN
# 3.0K WCE
# 3.0K SSA
# 3.0K ESAF
# rcp26_2041-2060 NEN
# rcp26_2041-2060 NCA
# rcp26_2041-2060 WAN
# rcp26_2041-2060 EEU
# rcp26_2041-2060 CAR
# rcp26_2041-2060 WSAF
# rcp26_2041-2060 CAU
# rcp26_2041-2060 WSB
# rcp26_2041-2060 NAU
# rcp26_2041-2060 SWS
# rcp26_2041-2060 NEU
# rcp26_2041-2060 NES
# rcp26_2041-2060 TIB
# rcp26_2041-2060 WNA
# rcp26_2041-2060 SES
# rcp26_2041-2060 SAM
# rcp26_2041-2060 NWS
# rcp26_2041-2060 NSA
# rcp26_2041-2060 SCA
# rcp26_2041-2060 MDG
# rcp26_2041-2060 CAF
# rcp26_2041-2060 SEAF
# rcp26_2041-2060 NZ
# rcp26_2041-2060 RAR
# rcp26_2041-2060 SEA
# rcp26_2041-2060 SAS
# rcp26_2041-2060 NWN
# rcp26_2041-2060 EAU
# rcp26_2041-2060 SAU
# rcp26_2041-2060 ENA
# rcp26_2041-2060 WAF
# rcp26_2041-2060 WCA
# rcp26_2041-2060 SAH
# rcp26_2041-2060 GIC
# rcp26_2041-2060 ESB
# rcp26_2041-2060 RFE
# rcp26_2041-2060 CNA
# rcp26_2041-2060 EAS
# rcp26_2041-2060 ARP
# rcp26_2041-2060 MED
# rcp26_2041-2060 ECA
# rcp26_2041-2060 NEAF
# rcp26_2041-2060 EAN
# rcp26_2041-2060 WCE
# rcp26_2041-2060 SSA
# rcp26_2041-2060 ESAF
# rcp85_2041-2060 NEN
# rcp85_2041-2060 NCA
# rcp85_2041-2060 WAN
# rcp85_2041-2060 EEU
# rcp85_2041-2060 CAR
# rcp85_2041-2060 WSAF
# rcp85_2041-2060 CAU
# rcp85_2041-2060 WSB
# rcp85_2041-2060 NAU
# rcp85_2041-2060 SWS
# rcp85_2041-2060 NEU
# rcp85_2041-2060 NES
# rcp85_2041-2060 TIB
# rcp85_2041-2060 WNA
# rcp85_2041-2060 SES
# rcp85_2041-2060 SAM
# rcp85_2041-2060 NWS
# rcp85_2041-2060 NSA
# rcp85_2041-2060 SCA
# rcp85_2041-2060 MDG
# rcp85_2041-2060 CAF
# rcp85_2041-2060 SEAF
# rcp85_2041-2060 NZ
# rcp85_2041-2060 RAR
# rcp85_2041-2060 SEA
# rcp85_2041-2060 SAS
# rcp85_2041-2060 NWN
# rcp85_2041-2060 EAU
# rcp85_2041-2060 SAU
# rcp85_2041-2060 ENA
# rcp85_2041-2060 WAF
# rcp85_2041-2060 WCA
# rcp85_2041-2060 SAH
# rcp85_2041-2060 GIC
# rcp85_2041-2060 ESB
# rcp85_2041-2060 RFE
# rcp85_2041-2060 CNA
# rcp85_2041-2060 EAS
# rcp85_2041-2060 ARP
# rcp85_2041-2060 MED
# rcp85_2041-2060 ECA
# rcp85_2041-2060 NEAF
# rcp85_2041-2060 EAN
# rcp85_2041-2060 WCE
# rcp85_2041-2060 SSA
# rcp85_2041-2060 ESAF
# 4.0K NEN
# 4.0K NCA
# 4.0K WAN
# 4.0K EEU
# 4.0K CAR
# 4.0K WSAF
# 4.0K CAU
# 4.0K WSB
# 4.0K NAU
# 4.0K SWS
# 4.0K NEU
# 4.0K NES
# 4.0K TIB
# 4.0K WNA
# 4.0K SES
# 4.0K SAM
# 4.0K NWS
# 4.0K NSA
# 4.0K SCA
# 4.0K MDG
# 4.0K CAF
# 4.0K SEAF
# 4.0K NZ
# 4.0K RAR
# 4.0K SEA
# 4.0K SAS
# 4.0K NWN
# 4.0K EAU
# 4.0K SAU
# 4.0K ENA
# 4.0K WAF
# 4.0K WCA
# 4.0K SAH
# 4.0K GIC
# 4.0K ESB
# 4.0K RFE
# 4.0K CNA
# 4.0K EAS
# 4.0K ARP
# 4.0K MED
# 4.0K ECA
# 4.0K NEAF
# 4.0K EAN
# 4.0K WCE
# 4.0K SSA
# 4.0K ESAF
# rcp26_2081-2100 NEN
# rcp26_2081-2100 NCA
# rcp26_2081-2100 WAN
# rcp26_2081-2100 EEU
# rcp26_2081-2100 CAR
# rcp26_2081-2100 WSAF
# rcp26_2081-2100 CAU
# rcp26_2081-2100 WSB
# rcp26_2081-2100 NAU
# rcp26_2081-2100 SWS
# rcp26_2081-2100 NEU
# rcp26_2081-2100 NES
# rcp26_2081-2100 TIB
# rcp26_2081-2100 WNA
# rcp26_2081-2100 SES
# rcp26_2081-2100 SAM
# rcp26_2081-2100 NWS
# rcp26_2081-2100 NSA
# rcp26_2081-2100 SCA
# rcp26_2081-2100 MDG
# rcp26_2081-2100 CAF
# rcp26_2081-2100 SEAF
# rcp26_2081-2100 NZ
# rcp26_2081-2100 RAR
# rcp26_2081-2100 SEA
# rcp26_2081-2100 SAS
# rcp26_2081-2100 NWN
# rcp26_2081-2100 EAU
# rcp26_2081-2100 SAU
# rcp26_2081-2100 ENA
# rcp26_2081-2100 WAF
# rcp26_2081-2100 WCA
# rcp26_2081-2100 SAH
# rcp26_2081-2100 GIC
# rcp26_2081-2100 ESB
# rcp26_2081-2100 RFE
# rcp26_2081-2100 CNA
# rcp26_2081-2100 EAS
# rcp26_2081-2100 ARP
# rcp26_2081-2100 MED
# rcp26_2081-2100 ECA
# rcp26_2081-2100 NEAF
# rcp26_2081-2100 EAN
# rcp26_2081-2100 WCE
# rcp26_2081-2100 SSA
# rcp26_2081-2100 ESAF

# %% [markdown]
# ## CORDEX, all domains

# %%
clog('critical')
thres = 'Exceed'+wthres
# -- Scenarios - timelines
# ---------------------------------------------------------------------------
CORDEX_domains = [
    # -- Africa
    'AFR-22','AFR-44',
    # -- AustralAsia
    'AUS-22','AUS-44',
    # -- Central America
    'CAM-22','CAM-44',
    # -- North America
    'NAM-22','NAM-44',
    # -- South America
    'SAM-22','SAM-44',
    # -- Asia
    'EAS-22','EAS-44',
    'WAS-22','WAS-44',
    'SEA-22',
    # -- Europe
    'EUR-11',
    
]

exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='rcp85',
         period = '1995-2014'),    
    # -- Mid term
    dict(experiment='rcp85',
         period = '2041-2060'),
    dict(experiment='rcp26',
         period = '2041-2060'),
    # -- Late term
    dict(experiment='rcp85',
         period = '2081-2100'),
    dict(experiment='rcp26',
         period = '2081-2100'),
]

ens_exp_dict_CORDEX = dict()
ens_GWL_dict_CORDEX = dict()

#for CORDEX_domain in ['AFR-22']:
for CORDEX_domain in CORDEX_domains:
    #
    # -- We use the first three letters of the CORDEX_domain to identify the region
    short_CORDEX_domain = CORDEX_domain[0:3]

    # -- Loop on the scenarios
    ens_exp_dict_CORDEX[short_CORDEX_domain] = dict()
    for exp in exp_list:
        #
        # -- Experiment and period
        experiment = exp['experiment']
        period = exp['period']

        # -- Create ensemble object for the scenario
        req_exp = ds(project='wbgt_cordex_ch12_test',
                     experiment = experiment,
                     #realization='r1i1p1',
                     clim_period = period,
                     CORDEX_domain = CORDEX_domain,
                     member = '*',
                     thres = thres
                    )
        try:
            ens_exp = add_prefix_suffix_to_ens_req(req_exp.explore('ensemble'), suffix='_'+CORDEX_domain)
            #
            # -- Climatologies
            # If there is already a short_CORDEX_domain in the results, we merge the results of the new one
            if experiment+'_'+period in ens_exp_dict_CORDEX[short_CORDEX_domain]:
                #res_copy = ens_exp_dict_CORDEX[short_CORDEX_domain][experiment+'_'+period].copy()
                #final_ens = merge_climaf_ensembles([res_copy, clim_average(ens_exp, 'ANM')])
                ens_exp_dict_CORDEX[short_CORDEX_domain][experiment+'_'+period].update( clim_average(ens_exp, 'ANM') )
            else:
                ens_exp_dict_CORDEX[short_CORDEX_domain][experiment+'_'+period] = clim_average(ens_exp, 'ANM')
                #final_ens = clim_average(ens_exp, 'ANM')
            #ens_exp_dict_CORDEX[short_CORDEX_domain][experiment+'_'+period] = final_ens
        except:
            print 'no data found for ', req_exp
    #


    # -- Global Warming Levels
    # ---------------------------------------------------------------------------
    ens_GWL_dict_CORDEX[short_CORDEX_domain] = dict()

    # -- Loop on the GWLs
    for GWL in ['1.5K','2.0K','3.0K','4.0K']:
        #
        if GWL in ['1.5K']:
            # -- Create ensemble object for the scenario
            req_rcp26 = ds(project='wbgt_cordex_ch12_test',
                         experiment = 'rcp26',
                         #realization='r1i1p1',
                         clim_period = GWL,
                         CORDEX_domain = CORDEX_domain,
                         member = '*',
                         thres = thres
                        )
            try:
                ens_rcp26 = req_rcp26.explore('ensemble')
            except:
                print 'No data found for ',req_rcp26
                ens_rcp26 = cens(dict())

            # -- Create ensemble object for the scenario
            req_rcp85 = ds(project='wbgt_cordex_ch12_test',
                         experiment = 'rcp85',
                         #  realization='r1i1p1',
                         clim_period = GWL,
                         CORDEX_domain = CORDEX_domain,
                         member = '*',
                         thres = thres
                        )
            try:
                ens_rcp85 = req_rcp85.explore('ensemble')
            except:
                print 'No data found for ',req_rcp85
                ens_rcp85 = cens(dict())
            #
            # -- Merge ensembles
            GWL_ens = merge_climaf_ensembles([add_prefix_suffix_to_ens_req(ens_rcp26,suffix='_rcp26'),
                                              add_prefix_suffix_to_ens_req(ens_rcp85,suffix='_rcp85')])
        else:
            # -- Create ensemble object for the scenario
            req_rcp85 = ds(project='wbgt_cordex_ch12_test',
                         experiment = 'rcp85',
                         #  realization='r1i1p1',
                         clim_period = GWL,
                         CORDEX_domain = CORDEX_domain,
                         member = '*',
                         thres = thres
                        )
            GWL_ens = req_rcp85.explore('ensemble')
        #
        # -- Rename the members with the CORDEX domain for future merge
        renamed_GWL_ens = add_prefix_suffix_to_ens_req(GWL_ens, suffix='_'+CORDEX_domain)
        #
        # -- if GWL in ens_GWL_dict_CORDEX[short_CORDEX_domain]:
        if GWL in ens_GWL_dict_CORDEX[short_CORDEX_domain]:
            res_copy = ens_GWL_dict_CORDEX[short_CORDEX_domain][GWL].copy()
            final_ens = merge_climaf_ensembles([res_copy, clim_average(renamed_GWL_ens, 'ANM')])
            # We merge the new one with the old one
        else:
            # We just add the new one
            final_ens = clim_average(renamed_GWL_ens, 'ANM')
        #
        # -- Climatologies
        ens_GWL_dict_CORDEX[short_CORDEX_domain][GWL] = final_ens
    #
# Out:
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2041-2060%AUS-44%*%Exceed31')
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2081-2100%AUS-44%*%Exceed31')
# No data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%1.5K%AUS-44%*%Exceed31')
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2041-2060%NAM-44%*%Exceed31')
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2081-2100%NAM-44%*%Exceed31')
# No data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%1.5K%NAM-44%*%Exceed31')
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2041-2060%EAS-44%*%Exceed31')
# no data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%2081-2100%EAS-44%*%Exceed31')
# No data found for  ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp26%1.5K%EAS-44%*%Exceed31')

# %%
#
# -- Loop on the short CORDEX domains
# -- short_CORDEX_domains = ['AFR','EAS',...]
regional_averages_CORDEX = dict()

# -- Merge the dictionary with scenarios and the one with the GWLs
#ens_CORDEX = ens_exp_dict_CORDEX.copy()
#ens_CORDEX.update(ens_GWL_dict_CORDEX)

AR6regions_by_CORDEX_domain = dict(
    AUS = ['NAU','CAU','EAU','SAU','NZ'],
    SEA = ['SEA'],
    WAS = ['ARP','SAS','WCA'],#,'TIB'],
    EAS = ['TIB','ECA','EAS'],#'SAS'
    CAM = ['NSA','SCA','CAR'],
    SAM = ['NWS','NSA','SAM','NES','SWS','SES','SSA'],
    NAM = ['NWN','NEN','WNA','CNA','ENA','NCA'],#,'GAP'],
    EUR = ['MED','WCE','NEU'],
    AFR = ['WAF','SAH','CAF','WSAF','ESAF','MDG','SEAF','NEAF','ARP']
)

for ens_CORDEX in [ens_exp_dict_CORDEX, ens_GWL_dict_CORDEX]:
    for short_CORDEX_domain in ens_CORDEX:
        print short_CORDEX_domain
        if short_CORDEX_domain not in regional_averages_CORDEX:
            regional_averages_CORDEX[short_CORDEX_domain] = dict()

        # -- Loop on experiments / horizons
        for ens_exp in ens_CORDEX[short_CORDEX_domain]:
            if ens_exp not in ['3.0K']:
                print ens_exp
                regional_averages_CORDEX[short_CORDEX_domain][ens_exp] = dict()
                # -- Loop on the members of each ensemble
                for mem in ens_CORDEX[short_CORDEX_domain][ens_exp]:
                    #if 'CCCma-CanESM2--UCAN-WRF341I' not in mem:
                    print mem
                    # -- Compute the averages for each AR6 region thanks to regionmask
                    # --> We regrid on a 0.25° grid with conservative regridding
                    tmp = average_over_AR6_region(
                                cfile(regridn(ens_CORDEX[short_CORDEX_domain][ens_exp][mem], cdogrid='r1440x720', option='remapbil')),
                                'WBGTindoor', 'all')
                    region_names = tmp.abbrevs
                    #for tmp_region_name in region_names:
                    for tmp_region_name in AR6regions_by_CORDEX_domain[short_CORDEX_domain]:
                        #region_name = str(tmp_region_name.values)
                        region_name = tmp_region_name
                        print region_name
                        region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
                        if region_name not in regional_averages_CORDEX[short_CORDEX_domain][ens_exp]:
                            regional_averages_CORDEX[short_CORDEX_domain][ens_exp][region_name] = [region_value]
                        else:
                            regional_averages_CORDEX[short_CORDEX_domain][ens_exp][region_name].append(region_value)
# Out:
# SEA
# rcp85_1995-2014
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NOAA-GFDL-GFDL-ESM2M--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# rcp26_2041-2060
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# rcp85_2041-2060
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NOAA-GFDL-GFDL-ESM2M--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# rcp26_2081-2100
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# rcp85_2081-2100
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NOAA-GFDL-GFDL-ESM2M--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# SAM
# rcp85_1995-2014
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp26_2041-2060
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp85_2041-2060
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp26_2081-2100
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp85_2081-2100
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NAM
# rcp85_1995-2014
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# rcp85_2041-2060
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# rcp85_2081-2100
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# AUS
# rcp85_1995-2014
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# rcp85_2041-2060
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# rcp85_2081-2100
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CAM
# rcp85_1995-2014
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# rcp26_2041-2060
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# rcp85_2041-2060
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# rcp26_2081-2100
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# rcp85_2081-2100
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# EAS
# rcp85_1995-2014
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EAS-44
# TIB
# ECA
# EAS
# rcp85_2041-2060
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EAS-44
# TIB
# ECA
# EAS
# rcp85_2081-2100
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EAS-44
# TIB
# ECA
# EAS
# WAS
# rcp85_1995-2014
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# rcp26_2041-2060
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# rcp85_2041-2060
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# rcp26_2081-2100
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# rcp85_2081-2100
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# AFR
# rcp85_1995-2014
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# rcp26_2041-2060
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2G--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# rcp85_2041-2060
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# rcp26_2081-2100
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2G--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# rcp85_2081-2100
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# EUR
# rcp85_1995-2014
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# rcp26_2041-2060
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NOAA-GFDL-GFDL-ESM2G--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# rcp85_2041-2060
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# rcp26_2081-2100
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NOAA-GFDL-GFDL-ESM2G--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# rcp85_2081-2100
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# SEA
# 1.5K
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_rcp85_SEA-22
# SEA
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_rcp85_SEA-22
# SEA
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_rcp26_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_rcp85_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_rcp85_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_rcp85_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_rcp85_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_rcp26_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_rcp85_SEA-22
# SEA
# NOAA-GFDL-GFDL-ESM2M--ICTP-RegCM4-3_r1i1p1_rcp85_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_rcp26_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_rcp26_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_rcp85_SEA-22
# SEA
# 4.0K
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# 2.0K
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# NOAA-GFDL-GFDL-ESM2M--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SEA-22
# SEA
# MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# NCC-NorESM1-M--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# IPSL-IPSL-CM5A-LR--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# ICHEC-EC-EARTH--ICTP-RegCM4-3_r1i1p1_SEA-22
# SEA
# MPI-M-MPI-ESM-MR--ICTP-RegCM4-7_r1i1p1_SEA-22
# SEA
# SAM
# 1.5K
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp26_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp26_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp26_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp26_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp26_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_rcp85_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 4.0K
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 2.0K
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2--UCAN-WRF341I_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_SAM-44
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NAM
# 1.5K
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_rcp85_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_rcp85_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_rcp85_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_rcp85_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# 4.0K
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# 2.0K
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR--UQAM-CRCM5_r1i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_NAM-44
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# AUS
# 1.5K
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_rcp85_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# 4.0K
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# 2.0K
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17-CLM3-5_r12i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-0--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CSIRO-BOM-ACCESS1-3--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17-CLM3-5_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360J_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CCCma-CanESM2--UNSW-WRF360K_r1i1p1_AUS-44
# NAU
# CAU
# EAU
# SAU
# NZ
# CAM
# 1.5K
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp26_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp26_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp26_CAM-44
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp26_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_rcp85_CAM-44
# NSA
# SCA
# CAR
# 4.0K
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# 2.0K
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_CAM-44
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_CAM-44
# NSA
# SCA
# CAR
# EAS
# 1.5K
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_rcp85_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_rcp85_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_rcp85_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_rcp85_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_rcp85_EAS-44
# TIB
# ECA
# EAS
# 4.0K
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EAS-44
# TIB
# ECA
# EAS
# 2.0K
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--CLMcom-CCLM5-0-2_r12i1p1_EAS-44
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR--CLMcom-CCLM5-0-2_r1i1p1_EAS-44
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EAS-44
# TIB
# ECA
# EAS
# WAS
# 1.5K
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp26_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp26_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp26_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp26_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp26_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--IITM-RegCM4-4_r1i1p1_rcp85_WAS-44
# ARP
# SAS
# WCA
# 4.0K
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# 2.0K
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CCCma-CanESM2--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR--IITM-RegCM4-4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_WAS-44
# ARP
# SAS
# WCA
# AFR
# 1.5K
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# ...
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r12i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_rcp85_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_rcp26_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# 4.0K
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# 2.0K
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CSIRO-QCCCE-CSIRO-Mk3-6-0--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-LR--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--MPI-CSC-REMO2009_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MIROC-MIROC5--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--GERICS-REMO2009_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--KNMI-RACMO22T_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NOAA-GFDL-GFDL-ESM2M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# CCCma-CanESM2--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_AFR-44
# WAF
# SAH
# CAF
# WSAF
# ESAF
# MDG
# SEAF
# NEAF
# ARP
# EUR
# 1.5K
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--DMI-HIRHAM5_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--IPSL-WRF381P_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_rcp26_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_rcp85_EUR-11
# MED
# WCE
# NEU
# 4.0K
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU
# 2.0K
# ICHEC-EC-EARTH--DMI-HIRHAM5_r12i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--GERICS-REMO2015_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--CNRM-ALADIN53_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--DMI-HIRHAM5_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--DMI-HIRHAM5_r3i1p1_EUR-11
# MED
# WCE
# NEU
# CCCma-CanESM2--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-CCLM4-8-17_r12i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--ICTP-RegCM4-6_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--CLMcom-ETH-COSMO-crCLIM-v1-1_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MIROC-MIROC5--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-CCLM4-8-17_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--IPSL-WRF381P_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES--CNRM-ALADIN63_r1i1p1_EUR-11
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--KNMI-RACMO22E_r1i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--GERICS-REMO2015_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--SMHI-RCA4_r3i1p1_EUR-11
# MED
# WCE
# NEU
# NCC-NorESM1-M--CLMcom-ETH-COSMO-crCLIM-v1-1_r1i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--MPI-CSC-REMO2009_r2i1p1_EUR-11
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5--SMHI-RCA4_r1i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--KNMI-RACMO22E_r12i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r2i1p1_EUR-11
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR--CLMcom-ETH-COSMO-crCLIM-v1-1_r3i1p1_EUR-11
# MED
# WCE
# NEU
# ICHEC-EC-EARTH--GERICS-REMO2015_r12i1p1_EUR-11
# MED
# WCE
# NEU

# %%
ens_exp_dict_CORDEX['SEA'].keys()# ens_GWL_dict_CORDEX
# Out:
# ['rcp85_1995-2014',
#  'rcp26_2041-2060',
#  'rcp85_2041-2060',
#  'rcp26_2081-2100',
#  'rcp85_2081-2100']

# %%
quantiles_dict = dict()
for short_CORDEX_domain in regional_averages_CORDEX:
    for clim_period in regional_averages_CORDEX[short_CORDEX_domain]:
        if clim_period not in quantiles_dict:
            quantiles_dict[clim_period] = dict()
        for region_name in regional_averages_CORDEX[short_CORDEX_domain][clim_period]:
            print clim_period, region_name
            #quantiles_dict[clim_period][region_name] = dict()
            dat = np.array(regional_averages_CORDEX[short_CORDEX_domain][clim_period][region_name])
            q10 = np.quantile(dat, 0.1)
            q50 = np.quantile(dat, 0.5)
            q90 = np.quantile(dat, 0.9)
            quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# rcp85_2081-2100 SEA
# rcp85_1995-2014 SEA
# 1.5K SEA
# 2.0K SEA
# rcp26_2041-2060 SEA
# rcp85_2041-2060 SEA
# 4.0K SEA
# rcp26_2081-2100 SEA
# rcp85_2081-2100 SES
# rcp85_2081-2100 SAM
# rcp85_2081-2100 NWS
# rcp85_2081-2100 NSA
# rcp85_2081-2100 SWS
# rcp85_2081-2100 SSA
# rcp85_2081-2100 NES
# rcp85_1995-2014 SES
# rcp85_1995-2014 SAM
# rcp85_1995-2014 NWS
# rcp85_1995-2014 NSA
# rcp85_1995-2014 SWS
# rcp85_1995-2014 SSA
# rcp85_1995-2014 NES
# 1.5K SES
# 1.5K SAM
# 1.5K NWS
# 1.5K NSA
# 1.5K SWS
# 1.5K SSA
# 1.5K NES
# 2.0K SES
# 2.0K SAM
# 2.0K NWS
# 2.0K NSA
# 2.0K SWS
# 2.0K SSA
# 2.0K NES
# rcp26_2041-2060 SES
# rcp26_2041-2060 SAM
# rcp26_2041-2060 NWS
# rcp26_2041-2060 NSA
# rcp26_2041-2060 SWS
# rcp26_2041-2060 SSA
# rcp26_2041-2060 NES
# rcp85_2041-2060 SES
# rcp85_2041-2060 SAM
# rcp85_2041-2060 NWS
# rcp85_2041-2060 NSA
# rcp85_2041-2060 SWS
# rcp85_2041-2060 SSA
# rcp85_2041-2060 NES
# 4.0K SES
# 4.0K SAM
# 4.0K NWS
# 4.0K NSA
# 4.0K SWS
# 4.0K SSA
# 4.0K NES
# rcp26_2081-2100 SES
# rcp26_2081-2100 SAM
# rcp26_2081-2100 NWS
# rcp26_2081-2100 NSA
# rcp26_2081-2100 SWS
# rcp26_2081-2100 SSA
# rcp26_2081-2100 NES
# 2.0K NEN
# 2.0K ENA
# 2.0K WNA
# 2.0K CNA
# 2.0K NCA
# 2.0K NWN
# rcp85_1995-2014 NEN
# rcp85_1995-2014 ENA
# rcp85_1995-2014 WNA
# rcp85_1995-2014 CNA
# rcp85_1995-2014 NCA
# rcp85_1995-2014 NWN
# 1.5K NEN
# 1.5K ENA
# 1.5K WNA
# 1.5K CNA
# 1.5K NCA
# 1.5K NWN
# rcp85_2081-2100 NEN
# rcp85_2081-2100 ENA
# rcp85_2081-2100 WNA
# rcp85_2081-2100 CNA
# rcp85_2081-2100 NCA
# rcp85_2081-2100 NWN
# rcp85_2041-2060 NEN
# rcp85_2041-2060 ENA
# rcp85_2041-2060 WNA
# rcp85_2041-2060 CNA
# rcp85_2041-2060 NCA
# rcp85_2041-2060 NWN
# 4.0K NEN
# 4.0K ENA
# 4.0K WNA
# 4.0K CNA
# 4.0K NCA
# 4.0K NWN
# 2.0K NZ
# 2.0K EAU
# 2.0K SAU
# 2.0K CAU
# 2.0K NAU
# rcp85_1995-2014 NZ
# rcp85_1995-2014 EAU
# rcp85_1995-2014 SAU
# rcp85_1995-2014 CAU
# rcp85_1995-2014 NAU
# 1.5K NZ
# 1.5K EAU
# 1.5K SAU
# 1.5K CAU
# 1.5K NAU
# rcp85_2081-2100 NZ
# rcp85_2081-2100 EAU
# rcp85_2081-2100 SAU
# rcp85_2081-2100 CAU
# rcp85_2081-2100 NAU
# rcp85_2041-2060 NZ
# rcp85_2041-2060 EAU
# rcp85_2041-2060 SAU
# rcp85_2041-2060 CAU
# rcp85_2041-2060 NAU
# 4.0K NZ
# 4.0K EAU
# 4.0K SAU
# 4.0K CAU
# 4.0K NAU
# rcp85_2081-2100 NSA
# rcp85_2081-2100 SCA
# rcp85_2081-2100 CAR
# rcp85_1995-2014 NSA
# rcp85_1995-2014 SCA
# rcp85_1995-2014 CAR
# 1.5K NSA
# 1.5K SCA
# 1.5K CAR
# 2.0K NSA
# 2.0K SCA
# 2.0K CAR
# rcp26_2041-2060 NSA
# rcp26_2041-2060 SCA
# rcp26_2041-2060 CAR
# rcp85_2041-2060 NSA
# rcp85_2041-2060 SCA
# rcp85_2041-2060 CAR
# 4.0K NSA
# 4.0K SCA
# 4.0K CAR
# rcp26_2081-2100 NSA
# rcp26_2081-2100 SCA
# rcp26_2081-2100 CAR
# 2.0K EAS
# 2.0K ECA
# 2.0K TIB
# rcp85_1995-2014 EAS
# rcp85_1995-2014 ECA
# rcp85_1995-2014 TIB
# 1.5K EAS
# 1.5K ECA
# 1.5K TIB
# rcp85_2081-2100 EAS
# rcp85_2081-2100 ECA
# rcp85_2081-2100 TIB
# rcp85_2041-2060 EAS
# rcp85_2041-2060 ECA
# rcp85_2041-2060 TIB
# 4.0K EAS
# 4.0K ECA
# 4.0K TIB
# rcp85_2081-2100 ARP
# rcp85_2081-2100 SAS
# rcp85_2081-2100 WCA
# rcp85_1995-2014 ARP
# rcp85_1995-2014 SAS
# rcp85_1995-2014 WCA
# 1.5K ARP
# 1.5K SAS
# 1.5K WCA
# 2.0K ARP
# 2.0K SAS
# 2.0K WCA
# rcp26_2041-2060 ARP
# rcp26_2041-2060 SAS
# rcp26_2041-2060 WCA
# rcp85_2041-2060 ARP
# rcp85_2041-2060 SAS
# rcp85_2041-2060 WCA
# 4.0K ARP
# 4.0K SAS
# 4.0K WCA
# rcp26_2081-2100 ARP
# rcp26_2081-2100 SAS
# rcp26_2081-2100 WCA
# rcp85_2081-2100 ARP
# rcp85_2081-2100 SAH
# rcp85_2081-2100 NEAF
# rcp85_2081-2100 WAF
# rcp85_2081-2100 WSAF
# rcp85_2081-2100 MDG
# rcp85_2081-2100 ESAF
# rcp85_2081-2100 SEAF
# rcp85_2081-2100 CAF
# rcp85_1995-2014 ARP
# rcp85_1995-2014 SAH
# rcp85_1995-2014 NEAF
# rcp85_1995-2014 WAF
# rcp85_1995-2014 WSAF
# rcp85_1995-2014 MDG
# rcp85_1995-2014 ESAF
# rcp85_1995-2014 SEAF
# rcp85_1995-2014 CAF
# 1.5K ARP
# 1.5K SAH
# 1.5K NEAF
# 1.5K WAF
# 1.5K WSAF
# 1.5K MDG
# 1.5K ESAF
# 1.5K SEAF
# 1.5K CAF
# 2.0K ARP
# 2.0K SAH
# 2.0K NEAF
# 2.0K WAF
# 2.0K WSAF
# 2.0K MDG
# 2.0K ESAF
# 2.0K SEAF
# 2.0K CAF
# rcp26_2041-2060 ARP
# rcp26_2041-2060 SAH
# rcp26_2041-2060 NEAF
# rcp26_2041-2060 WAF
# rcp26_2041-2060 WSAF
# rcp26_2041-2060 MDG
# rcp26_2041-2060 ESAF
# rcp26_2041-2060 SEAF
# rcp26_2041-2060 CAF
# rcp85_2041-2060 ARP
# rcp85_2041-2060 SAH
# rcp85_2041-2060 NEAF
# rcp85_2041-2060 WAF
# rcp85_2041-2060 WSAF
# rcp85_2041-2060 MDG
# rcp85_2041-2060 ESAF
# rcp85_2041-2060 SEAF
# rcp85_2041-2060 CAF
# 4.0K ARP
# 4.0K SAH
# 4.0K NEAF
# 4.0K WAF
# 4.0K WSAF
# 4.0K MDG
# 4.0K ESAF
# 4.0K SEAF
# 4.0K CAF
# rcp26_2081-2100 ARP
# rcp26_2081-2100 SAH
# rcp26_2081-2100 NEAF
# rcp26_2081-2100 WAF
# rcp26_2081-2100 WSAF
# rcp26_2081-2100 MDG
# rcp26_2081-2100 ESAF
# rcp26_2081-2100 SEAF
# rcp26_2081-2100 CAF
# rcp85_2081-2100 MED
# rcp85_2081-2100 NEU
# rcp85_2081-2100 WCE
# rcp85_1995-2014 MED
# rcp85_1995-2014 NEU
# rcp85_1995-2014 WCE
# 1.5K MED
# 1.5K NEU
# 1.5K WCE
# 2.0K MED
# 2.0K NEU
# 2.0K WCE
# rcp26_2041-2060 MED
# rcp26_2041-2060 NEU
# rcp26_2041-2060 WCE
# rcp85_2041-2060 MED
# rcp85_2041-2060 NEU
# rcp85_2041-2060 WCE
# 4.0K MED
# 4.0K NEU
# 4.0K WCE
# rcp26_2081-2100 MED
# rcp26_2081-2100 NEU
# rcp26_2081-2100 WCE

# %%
regional_averages_CORDEX[short_CORDEX_domain].keys()
# Out:
# ['1.5K', '4.0K', '2.0K']
# ['1.5K', '4.0K', '2.0K']

# %%
import json
ensemble = 'CORDEX'
outfilename = '/home/jservon/Chapter12_IPCC/data/WBGT_satellites/'+ensemble+'_WBGT'+wthres+'_AR6_regional_averages.json'
print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)
# Out:
# /home/jservon/Chapter12_IPCC/data/WBGT_satellites/CORDEX_WBGT31_AR6_regional_averages.json

# %%
# Creer une grille lon/lat pour chaque CORDEX domain
# regriller sur cette grille
# missing values outside the domain
#   => ok to retrieve the regions
#   => not ok to check if the region is completely covered
#   => check by hand?
#   => if CORDEX_domain = ... ; then subregions = [...]
#   => if partially covered => No!
# AFR, 3 domains for America, Aus = ok, 3 domains over Asia, 1 over Europe =
#   8 domains = feasable
# AFR, et Asia = ok; need Europe, and the Americas

# %%
# Prendre un champ de chaque domain, faire un plot avec toutes les regions
# Selectionner a la main

# Si on prend les regions partiellement couvertes:
#  - on regrille CMIP6 et CMIP5 sur tous les domains CORDEX
#  - en multipliant par un mask pour mettre des missing

# %%
ncdump(ens_CORDEX[short_CORDEX_domain][ens_exp][mem])
# Out:
# netcdf \074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67 {
# dimensions:
# 	time = UNLIMITED ; // (1 currently)
# 	bnds = 2 ;
# 	x = 477 ;
# 	y = 497 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 2045-12-30" ;
# 		time:calendar = "360_day" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	double lon(y, x) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude on Cross Points" ;
# 		lon:units = "degrees_east" ;
# 		lon:_CoordinateAxisType = "Lon" ;
# 	double lat(y, x) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude on Cross Points" ;
# 		lat:units = "degrees_north" ;
# 		lat:_CoordinateAxisType = "Lat" ;
# 	double x(x) ;
# 		x:standard_name = "projection_x_coordinate" ;
# 		x:long_name = "x-coordinate in Cartesian system" ;
# 		x:units = "m" ;
# 		x:axis = "X" ;
# 	double y(y) ;
# 		y:standard_name = "projection_y_coordinate" ;
# 		y:long_name = "y-coordinate in Cartesian system" ;
# 		y:units = "m" ;
# 		y:axis = "Y" ;
# 	float WBGTindoor(time, y, x) ;
# 		WBGTindoor:long_name = "Number of days per year with wet-bulb temperature above Exceed33 degC" ;
# 		WBGTindoor:units = "days" ;
# 		WBGTindoor:coordinates = "lat lon" ;
# 		WBGTindoor:_FillValue = 1.e+20f ;
# 		WBGTindoor:missing_value = 1.e+20f ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Wed Feb 03 16:41:26 2021: cdo -O -timmean -selname,WBGTindoor /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc /data/jservon/climafcache/17/074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67_34809.nc\nWed Feb  3 15:47:08 2021: ncatted -O -a coordinates,WBGTindoor,o,c,time lat lon -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,Number of days per year with wet-bulb temperature above Exceed33 degC /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc\nWed Feb 03 15:47:07 2021: cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-AFR-22_share/MOHC-HadGEM2-ES_ICTP-RegCM4-7/WBGT_Exceed33_MOHC-HadGEM2-ES_ICTP-RegCM4-7_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc" ;
# 		:Conventions = "CF-1.6" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "time_average(ds(\'wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp85%3.0K%AFR-22%MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1%Exceed33\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.13 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/jservon/climafcache/17/074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67.nc
# ncdump(time_average(ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp85%3.0K%AFR-22%MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1%Exceed33')))

# %%
# If region is not entireley covered => 0
# Do the map with regions on top and hatching
# Start the barplot:
# - retrieve values from json file
# - do the plot for one region
# Start to build the multiplot
#

# %% [markdown]
# #
# #
# #

# %%
regionmask.defined_regions.ar6.all.abbrevs.index('CAR')
# Out:
# 8

# %%
ar6_land = regionmask.defined_regions.ar6.land
ar6_land
# Out:
# <regionmask.Regions>
# Name:     AR6 reference regions (land only)
# Source:   Iturbide et al., 2020 (Earth Syst. Sci. Data)
#
# Regions:
#   0  GIC  Greenland/Iceland
#   1  NWN  N.W.North-America
#   2  NEN  N.E.North-America
#   3  WNA    W.North-America
#   4  CNA    C.North-America
# ..   ...                ...
#  41  EAU        E.Australia
#  42  SAU        S.Australia
#  43   NZ        New-Zealand
#  44  EAN       E.Antarctica
#  45  WAN       W.Antarctica
#
# [46 regions]

# %%
ar6_land.abbrevs
# Out:
# [u'GIC',
#  u'NWN',
#  u'NEN',
#  u'WNA',
#  u'CNA',
#  u'ENA',
#  u'NCA',
#  u'SCA',
#  u'CAR',
#  u'NWS',
#  u'NSA',
#  u'NES',
#  u'SAM',
#  u'SWS',
#  u'SES',
#  u'SSA',
#  u'NEU',
#  u'WCE',
#  u'EEU',
#  u'MED',
#  u'SAH',
#  u'WAF',
#  u'CAF',
#  u'NEAF',
#  u'SEAF',
#  u'WSAF',
#  u'ESAF',
#  u'MDG',
#  u'RAR',
#  u'WSB',
#  u'ESB',
#  u'RFE',
#  u'WCA',
#  u'ECA',
#  u'TIB',
#  u'EAS',
#  u'ARP',
#  u'SAS',
#  u'SEA',
#  u'NAU',
#  u'CAU',
#  u'EAU',
#  u'SAU',
#  u'NZ',
#  u'EAN',
#  u'WAN']

# %%
ar6_land.names
# Out:
# [u'Greenland/Iceland',
#  u'N.W.North-America',
#  u'N.E.North-America',
#  u'W.North-America',
#  u'C.North-America',
#  u'E.North-America',
#  u'N.Central-America',
#  u'S.Central-America',
#  u'Caribbean',
#  u'N.W.South-America',
#  u'N.South-America',
#  u'N.E.South-America',
#  u'South-American-Monsoon',
#  u'S.W.South-America',
#  u'S.E.South-America',
#  u'S.South-America',
#  u'N.Europe',
#  u'West&Central-Europe',
#  u'E.Europe',
#  u'Mediterranean',
#  u'Sahara',
#  u'Western-Africa',
#  u'Central-Africa',
#  u'N.Eastern-Africa',
#  u'S.Eastern-Africa',
#  u'W.Southern-Africa',
#  u'E.Southern-Africa',
#  u'Madagascar',
#  u'Russian-Arctic',
#  u'W.Siberia',
#  u'E.Siberia',
#  u'Russian-Far-East',
#  u'W.C.Asia',
#  u'E.C.Asia',
#  u'Tibetan-Plateau',
#  u'E.Asia',
#  u'Arabian-Peninsula',
#  u'S.Asia',
#  u'S.E.Asia',
#  u'N.Australia',
#  u'C.Australia',
#  u'E.Australia',
#  u'S.Australia',
#  u'New-Zealand',
#  u'E.Antarctica',
#  u'W.Antarctica']
