# %% [markdown]
# # Compute the time slices and GWLs for wind CMIP6

# %% [markdown]
# ### Author: Jerome Servonat
# ### Contact: jerome.servonnat at lsce.ipsl.fr

# %% [markdown]
# ### Import CliMAF

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %%
csync(True)
# Out:
# error    : file /data/jservon/climafcache/b1/c97e30df7296a9bd8fdb6eaa3294d4bbe2214f9ab6dce74197e5db.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/b1/c97e30df7296a9bd8fdb6eaa3294d4bbe2214f9ab6dce74197e5db.png is removed
# error    : file /data/jservon/climafcache/4d/e28fad043bc5532160456531d843dabd2630bace98411726a5a7b8.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/4d/e28fad043bc5532160456531d843dabd2630bace98411726a5a7b8.png is removed
# error    : file /data/jservon/climafcache/Rtmp4vTlGd/filef524e3bd160.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp4vTlGd/filef524e3bd160.png is removed
# error    : file /data/jservon/climafcache/Rtmp4vTlGd/filef524373d9e94.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp4vTlGd/filef524373d9e94.png is removed
# error    : file /data/jservon/climafcache/Rtmp4vTlGd/filef5244347fe2c.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp4vTlGd/filef5244347fe2c.png is removed
# error    : file /data/jservon/climafcache/Rtmp4vTlGd/filef5246007cfcd.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp4vTlGd/filef5246007cfcd.png is removed
# error    : file /data/jservon/climafcache/84/65aade9d7ed9301cb33398409facde21c90b166da80378e41c679f.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/84/65aade9d7ed9301cb33398409facde21c90b166da80378e41c679f.png is removed
# error    : file /data/jservon/climafcache/4f/0496d4826e044ddb113340740eec103116a798a27d321aa221a735.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/4f/0496d4826e044ddb113340740eec103116a798a27d321aa221a735.png is removed
# error    : file /data/jservon/climafcache/12/6e17f7227ec2ab30a9bbf44987c8941c7dcb628962d69d1f8df2ec.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/12/6e17f7227ec2ab30a9bbf44987c8941c7dcb628962d69d1f8df2ec.png is removed
# error    : file /data/jservon/climafcache/Rtmp7Lb4M4/file2f4815fb8a1d.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp7Lb4M4/file2f4815fb8a1d.png is removed
# error    : file /data/jservon/climafcache/Rtmp7Lb4M4/file2f482d059776.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp7Lb4M4/file2f482d059776.png is removed
# error    : file /data/jservon/climafcache/Rtmp7Lb4M4/file2f48ff0dfc0.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/Rtmp7Lb4M4/file2f48ff0dfc0.png is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1974_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1974_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1976_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1976_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1971_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1971_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1973_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1973_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1972_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1972_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1975_EC-Earth3_r1i1p1f1.nc is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/climaf_mcdojwnAn4/CMIP6_historical_wind_1975_EC-Earth3_r1i1p1f1.nc is removed
# error    : file /data/jservon/climafcache/9a/5e39001be0fe54c699f03b77134f63b887c614c72d0737117c894f.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/9a/5e39001be0fe54c699f03b77134f63b887c614c72d0737117c894f.png is removed
# error    : file /data/jservon/climafcache/3f/621452bb515975befb89dd25770f73bd3d15e1eff5db4bcc00d554.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/3f/621452bb515975befb89dd25770f73bd3d15e1eff5db4bcc00d554.png is removed
# error    : file /data/jservon/climafcache/6f/05fa55668fc2dc9d46aec033f95fa0bd3ebd567b052fc4380bb3dd.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/6f/05fa55668fc2dc9d46aec033f95fa0bd3ebd567b052fc4380bb3dd.png is removed
# error    : file /data/jservon/climafcache/88/3bfebbeed2e8070fb28bd5591d06d70870acda1f729e7fb8d82d92.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/88/3bfebbeed2e8070fb28bd5591d06d70870acda1f729e7fb8d82d92.png is removed
# error    : file /data/jservon/climafcache/a0/8b1706acf146255b1d5754772e93eef1201a40fef746626f0f8d11.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/a0/8b1706acf146255b1d5754772e93eef1201a40fef746626f0f8d11.png is removed
# error    : file /data/jservon/climafcache/cd/cb8a55db6f707e7362fa41d599690c3cbc05e700d627cf08712717.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/cd/cb8a55db6f707e7362fa41d599690c3cbc05e700d627cf08712717.png is removed
# error    : file /data/jservon/climafcache/5e/5730c5e61f0b24586dc47252d0e5f298e24c69c086bb9cfee3922e.png is not well formed (no CRS)
# warning  : File /data/jservon/climafcache/5e/5730c5e61f0b24586dc47252d0e5f298e24c69c086bb9cfee3922e.png is removed

# %% [markdown]
# ## 1. Copmpute averages for baseline and future periods for 26 and 85

# %%
lom_per_exp = dict()

# %%
req_dict = dict(project='CMIP5',
                frequency='monthly',
                table = 'Amon',
                version='latest'
               )

exp_dict_list = dict(
    baseline = dict(experiment='historical',
         period='1995-2005'
        ),
    baseline_ext = dict(experiment='rcp85',
         period='2006-2015'
        ),
    rcp26_mid = dict(experiment='rcp26',
         period='2041-2060'
        ),
    rcp26_far = dict(experiment='rcp26',
         period='2081-2100'
        ),
    rcp85_mid = dict(experiment='rcp85',
         period='2041-2060'
        ),
    rcp85_far = dict(experiment='rcp85',
         period='2081-2100'
        )  
)


ens_exp_dict = dict()
for exp in exp_dict_list:
    ens_exp_dict[exp] = dict()
    print exp
    wreq = req_dict.copy()
    wreq.update(exp_dict_list[exp])

    req = ds(model='*',
             variable = 'sfcWind',
             #variable = 'tas',
             **wreq
            )
    models = req.explore('choices')['model']
    ok_models = []
    for model in models:
        req_test = ds(model=model,
                     #variable = 'sfcWind',
                     variable = 'sfcWind',
                     **wreq
                    )
        #if not check_time_consistency_CMIP(req_test):
        #        print model+' not fully covered'
        #else:
        #        print model+' is fine'
        ok_models.append(model)
        ens_exp_dict[exp][model] = req_test.explore('resolve')

    lom_per_exp[exp] = ok_models
# Out:
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid

# %% [markdown]
# # 1. Baseline + baseline ext

# %%
lom_baseline     = lom_per_exp['baseline']
lom_baseline_ext = lom_per_exp['rcp26_mid']
#lom_baseline_ext = lom_per_exp['baseline_ext']
print 'Models not in both sets:'
print set(lom_baseline) ^ set(lom_baseline_ext)
print 'Models in common:'
common_lom_baseline = list( set(lom_baseline) & set(lom_baseline_ext) )
print sorted(common_lom_baseline)
# Out:
# Models not in both sets:
# set(['ACCESS1-0', 'ACCESS1-3', 'GISS-E2-R-CC', 'MIROC4h', 'CNRM-CM5-2', 'CMCC-CM', 'GISS-E2-H-CC', 'CMCC-CMS', 'GFDL-ESM2M', 'HadCM3', 'HadGEM2-CC', 'MPI-ESM-P', 'CMCC-CESM', 'MRI-ESM1'])
# Models in common:
# ['BNU-ESM', 'CESM1-CAM5', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'CanESM2', 'GFDL-CM3', 'GFDL-ESM2G', 'GISS-E2-H', 'GISS-E2-R', 'HadGEM2-AO', 'HadGEM2-ES', 'MIROC-ESM', 'MIROC-ESM-CHEM', 'MIROC5', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3']

# %%
lom_baseline_ext
# Out:
# ['BNU-ESM',
#  'CESM1-CAM5',
#  'CNRM-CM5',
#  'CSIRO-Mk3-6-0',
#  'CanESM2',
#  'GFDL-CM3',
#  'GFDL-ESM2G',
#  'GISS-E2-H',
#  'GISS-E2-R',
#  'HadGEM2-AO',
#  'HadGEM2-ES',
#  'MIROC-ESM',
#  'MIROC-ESM-CHEM',
#  'MIROC5',
#  'MPI-ESM-LR',
#  'MPI-ESM-MR',
#  'MRI-CGCM3']

# %% [markdown]
# ### Create a CliMAF operator to compute sfcWind from uas and vas

# %%
wreq_dict = req_dict.copy()
wreq_dict.update(exp_dict_list['baseline'])
ens_baseline_hist = eds(model=common_lom_baseline,
                        variable = 'sfcWind',
                        **wreq_dict
                       )

wreq_dict = req_dict.copy()
wreq_dict.update(exp_dict_list['baseline_ext'])
ens_baseline_ext = eds(model=common_lom_baseline,
                       variable = 'sfcWind',
                       **wreq_dict
                      )

# %% [markdown]
# ## Compute wind and cat baseline and baseline_ext

# %%
ens_baseline_dict = dict()
for model in common_lom_baseline:
    
    # -- Cat baseline and ext
    ens_baseline_dict[model] = ccdo2(ens_baseline_hist[model], ens_baseline_ext[model], operator='cat')
    print(model)
    
    print(cfile(ens_baseline_dict[model]))
# Out:
# GISS-E2-H
# /data/jservon/climafcache/71/d12bd25cf1bc7a4dc7ff5f7af6d1219726f57e9ef3c48bf52f3cd4.nc
# GFDL-CM3
# /data/jservon/climafcache/34/94f5d27aa59226f8b37a1a1cc2c409748b4ab2c88096791b6ba9ca.nc
# MIROC-ESM
# /data/jservon/climafcache/8c/d72f253a6ae60a232334a444deb091162d78bdda38882a92d62876.nc
# CNRM-CM5
# /data/jservon/climafcache/ad/e063fe84b475bd85054a2b76d3667c688cb66f4e418ec8b251fe5a.nc
# MIROC5
# /data/jservon/climafcache/c4/5b942fac938b723df953d2fb7346064f146705a679578e584bc987.nc
# CanESM2
# /data/jservon/climafcache/0a/8793fff71aff8e69aa262a0fb70d1d2773117ac299c2de71d3b4e0.nc
# BNU-ESM
# /data/jservon/climafcache/2c/dd23bcce9655e925e0995b100bdf699e0f8507a5172266e9871212.nc
# MIROC-ESM-CHEM
# /data/jservon/climafcache/f8/2c4404a29a1bde53db1a2269f13498c199eef2cf0eb1242b6eb90b.nc
# GFDL-ESM2G
# /data/jservon/climafcache/ad/cc93a7ad7b6f6051e19285101ab757a484111fa5b10b951eeec2cf.nc
# HadGEM2-AO
# /data/jservon/climafcache/58/212586890fc95c1c922f033f98c0912fab18edf5a2fbcd476e4ac3.nc
# GISS-E2-R
# /data/jservon/climafcache/4c/25a634a87a7b2ae02c134a98a960f00912bbacb066c379e57130b7.nc
# HadGEM2-ES
# /data/jservon/climafcache/b0/f8f9bc9511aad241111588daef630b3df680ad8c04d84ccd54e507.nc
# CSIRO-Mk3-6-0
# /data/jservon/climafcache/dc/58532f4f3aece8470f75146b8f53cae5469609b63af0b4bd670eec.nc
# MPI-ESM-MR
# /data/jservon/climafcache/6c/82a93bbc61d217fefec1be5d5c7eacfaedaf99e7936c1d2a72718d.nc
# MRI-CGCM3
# /data/jservon/climafcache/76/6ba7094e5199493ba48fc205714178eae2584288e1c7a5c81c1be2.nc
# MPI-ESM-LR
# /data/jservon/climafcache/32/0690337ce52ae37faf464e0238c4418687a680a455d64904eebca5.nc
# CESM1-CAM5
# /data/jservon/climafcache/3e/e40cb1a31e1b9c31d9e810b76dc27d439dc75bd60ad26479492525.nc

# %% [markdown]
# ## Compute averages for each experiment/clim_period

# %%
wind_ens_clim_exp_dict = dict()

for exp in ['rcp26_mid','rcp26_far','rcp85_mid','rcp85_far']:    
    print '--> '+exp
    wind_ens_clim_exp_dict[exp] = clim_average(cens(ens_exp_dict[exp]), 'ANM')
# Out:
# --> rcp26_mid
# --> rcp26_far
# --> rcp85_mid
# --> rcp85_far

# %% [markdown]
# ### Add baseline

# %%
ens_baseline = cens(ens_baseline_dict)
wind_ens_clim_exp_dict['baseline'] = clim_average(ens_baseline, 'ANM')

# %%
wind_ens_clim_exp_dict['baseline'].keys()
# Out:
# ['BNU-ESM',
#  'GFDL-ESM2G',
#  'CSIRO-Mk3-6-0',
#  'HadGEM2-ES',
#  'GISS-E2-H',
#  'GFDL-CM3',
#  'MIROC-ESM',
#  'CNRM-CM5',
#  'MIROC5',
#  'CanESM2',
#  'MIROC-ESM-CHEM',
#  'HadGEM2-AO',
#  'GISS-E2-R',
#  'MPI-ESM-MR',
#  'MRI-CGCM3',
#  'MPI-ESM-LR',
#  'CESM1-CAM5']

# %% [markdown]
# ## Compute averages for each GWLs

# %%
import csv

GWL_csv = '/home/jservon/Chapter12_IPCC/scripts/ATLAS/warming-levels/CMIP5_Atlas_WarmingLevels.csv'

GWL_dict = dict()
i = 0
with open(GWL_csv) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
    for row in spamreader:
        print row
        model = row[0].split('_')[0]
        print model
        GWL_dict[model] = dict()
        if i==0:
            colnames = row
        j = 0
        for elt in row:
            print elt
            GWL_dict[model][colnames[j]] = row[j]
            j = j + 1
        i = i + 1
# Out:
# ['model_run', '1.5_rcp26', '2_rcp26', '3_rcp26', '4_rcp26', '1.5_rcp45', '2_rcp45', '3_rcp45', '4_rcp45', '1.5_rcp85', '2_rcp85', '3_rcp85', '4_rcp85']
# model
# model_run
# 1.5_rcp26
# 2_rcp26
# 3_rcp26
# 4_rcp26
# 1.5_rcp45
# 2_rcp45
# 3_rcp45
# 4_rcp45
# 1.5_rcp85
# 2_rcp85
# 3_rcp85
# 4_rcp85
# ['ACCESS1-0_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2053', 'NA', 'NA', '2028', '2041', '2061', '2081']
# ACCESS1-0
# ACCESS1-0_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2053
# NA
# NA
# 2028
# 2041
# 2061
# 2081
# ['ACCESS1-3_r1i1p1', '9999', '9999', '9999', '9999', '2039', '2056', 'NA', 'NA', '2031', '2042', '2062', '2082']
# ACCESS1-3
# ACCESS1-3_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2039
# 2056
# NA
# NA
# 2031
# 2042
# 2062
# 2082
# ['bcc-csm1-1-m_r1i1p1', '2009', '2043', 'NA', 'NA', '2010', '2035', 'NA', 'NA', '2007', '2028', '2059', '2085']
# bcc-csm1-1-m
# bcc-csm1-1-m_r1i1p1
# 2009
# 2043
# NA
# NA
# 2010
# 2035
# NA
# NA
# 2007
# 2028
# 2059
# 2085
# ['bcc-csm1-1_r1i1p1', '2022', 'NA', 'NA', 'NA', '2021', '2042', 'NA', 'NA', '2019', '2036', '2059', '2083']
# bcc-csm1-1
# bcc-csm1-1_r1i1p1
# 2022
# NA
# NA
# NA
# 2021
# 2042
# NA
# NA
# 2019
# 2036
# 2059
# 2083
# ['BNU-ESM_r1i1p1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# BNU-ESM
# BNU-ESM_r1i1p1
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ['CanESM2_r1i1p1', '2013', '2032', 'NA', 'NA', '2017', '2031', '2075', 'NA', '2012', '2026', '2049', '2068']
# CanESM2
# CanESM2_r1i1p1
# 2013
# 2032
# NA
# NA
# 2017
# 2031
# 2075
# NA
# 2012
# 2026
# 2049
# 2068
# ['CCSM4_r1i1p1', '2016', 'NA', 'NA', 'NA', '2017', '2039', 'NA', 'NA', '2014', '2030', '2057', '2077']
# CCSM4
# CCSM4_r1i1p1
# 2016
# NA
# NA
# NA
# 2017
# 2039
# NA
# NA
# 2014
# 2030
# 2057
# 2077
# ['CESM1-BGC_r1i1p1', '9999', '9999', '9999', '9999', '2018', '2043', 'NA', 'NA', '2017', '2033', '2058', '2080']
# CESM1-BGC
# CESM1-BGC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2018
# 2043
# NA
# NA
# 2017
# 2033
# 2058
# 2080
# ['CMCC-CMS_r1i1p1', '9999', '9999', '9999', '9999', '2037', '2055', 'NA', 'NA', '2029', '2041', '2061', '2077']
# CMCC-CMS
# CMCC-CMS_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2037
# 2055
# NA
# NA
# 2029
# 2041
# 2061
# 2077
# ['CMCC-CM_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2050', 'NA', 'NA', '2029', '2041', '2060', '2078']
# CMCC-CM
# CMCC-CM_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2050
# NA
# NA
# 2029
# 2041
# 2060
# 2078
# ['CNRM-CM5_r1i1p1', '2042', 'NA', 'NA', 'NA', '2036', '2057', 'NA', 'NA', '2030', '2044', '2067', '2087']
# CNRM-CM5
# CNRM-CM5_r1i1p1
# 2042
# NA
# NA
# NA
# 2036
# 2057
# NA
# NA
# 2030
# 2044
# 2067
# 2087
# ['CSIRO-Mk3-6-0_r1i1p1', '2035', 'NA', 'NA', 'NA', '2034', '2047', 'NA', 'NA', '2034', '2044', '2064', '2082']
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_r1i1p1
# 2035
# NA
# NA
# NA
# 2034
# 2047
# NA
# NA
# 2034
# 2044
# 2064
# 2082
# ['EC-EARTH_r12i1p1', '2023', 'NA', 'NA', 'NA', '2022', '2044', 'NA', 'NA', '2018', '2034', '2060', '2082']
# EC-EARTH
# EC-EARTH_r12i1p1
# 2023
# NA
# NA
# NA
# 2022
# 2044
# NA
# NA
# 2018
# 2034
# 2060
# 2082
# ['EC-EARTH_r3i1p1', '9999', '9999', '9999', '9999', '2022', '2044', 'NA', 'NA', '2020', '2038', '2061', '2081']
# EC-EARTH
# EC-EARTH_r3i1p1
# 9999
# 9999
# 9999
# 9999
# 2022
# 2044
# NA
# NA
# 2020
# 2038
# 2061
# 2081
# ['FGOALS-g2_r1i1p1', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999']
# FGOALS-g2
# FGOALS-g2_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# ['GFDL-CM3_r1i1p1', '2021', '2049', 'NA', 'NA', '9999', '9999', '9999', '9999', '2022', '2034', '2054', '2070']
# GFDL-CM3
# GFDL-CM3_r1i1p1
# 2021
# 2049
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 2022
# 2034
# 2054
# 2070
# ['GFDL-ESM2G_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2050', 'NA', 'NA', 'NA', '2037', '2054', '2080', 'NA']
# GFDL-ESM2G
# GFDL-ESM2G_r1i1p1
# NA
# NA
# NA
# NA
# 2050
# NA
# NA
# NA
# 2037
# 2054
# 2080
# NA
# ['GFDL-ESM2M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2046', 'NA', 'NA', 'NA', '2036', '2051', '2081', 'NA']
# GFDL-ESM2M
# GFDL-ESM2M_r1i1p1
# NA
# NA
# NA
# NA
# 2046
# NA
# NA
# NA
# 2036
# 2051
# 2081
# NA
# ['HadGEM2-CC_r1i1p1', '9999', '9999', '9999', '9999', '2036', '2052', 'NA', 'NA', '2027', '2039', '2056', '2072']
# HadGEM2-CC
# HadGEM2-CC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2036
# 2052
# NA
# NA
# 2027
# 2039
# 2056
# 2072
# ['HadGEM2-ES_r1i1p1', '2023', 'NA', 'NA', 'NA', '2028', '2043', '2078', 'NA', '2023', '2035', '2054', '2071']
# HadGEM2-ES
# HadGEM2-ES_r1i1p1
# 2023
# NA
# NA
# NA
# 2028
# 2043
# 2078
# NA
# 2023
# 2035
# 2054
# 2071
# ['inmcm4_r1i1p1', '9999', '9999', '9999', '9999', '2060', 'NA', 'NA', 'NA', '2044', '2057', '2083', 'NA']
# inmcm4
# inmcm4_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2060
# NA
# NA
# NA
# 2044
# 2057
# 2083
# NA
# ['IPSL-CM5A-LR_r1i1p1', '2009', '2031', 'NA', 'NA', '2013', '2029', '2069', 'NA', '2009', '2025', '2047', '2065']
# IPSL-CM5A-LR
# IPSL-CM5A-LR_r1i1p1
# 2009
# 2031
# NA
# NA
# 2013
# 2029
# 2069
# NA
# 2009
# 2025
# 2047
# 2065
# ['IPSL-CM5A-MR_r1i1p1', '2015', '2046', 'NA', 'NA', '2016', '2032', '2076', 'NA', '2015', '2030', '2050', '2066']
# IPSL-CM5A-MR
# IPSL-CM5A-MR_r1i1p1
# 2015
# 2046
# NA
# NA
# 2016
# 2032
# 2076
# NA
# 2015
# 2030
# 2050
# 2066
# ['IPSL-CM5B-LR_r1i1p1', '9999', '9999', '9999', '9999', '2026', '2048', 'NA', 'NA', '2022', '2037', '2061', '2084']
# IPSL-CM5B-LR
# IPSL-CM5B-LR_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2026
# 2048
# NA
# NA
# 2022
# 2037
# 2061
# 2084
# ['MIROC-ESM-CHEM_r1i1p1', '2018', '2034', 'NA', 'NA', '2022', '2036', '2073', 'NA', '2018', '2030', '2050', '2067']
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_r1i1p1
# 2018
# 2034
# NA
# NA
# 2022
# 2036
# 2073
# NA
# 2018
# 2030
# 2050
# 2067
# ['MIROC-ESM_r1i1p1', '2021', '2040', 'NA', 'NA', '2020', '2033', '2068', 'NA', '2020', '2030', '2052', '2069']
# MIROC-ESM
# MIROC-ESM_r1i1p1
# 2021
# 2040
# NA
# NA
# 2020
# 2033
# 2068
# NA
# 2020
# 2030
# 2052
# 2069
# ['MIROC5_r1i1p1', '2046', 'NA', 'NA', 'NA', '2039', '2071', 'NA', 'NA', '2033', '2048', '2071', 'NA']
# MIROC5
# MIROC5_r1i1p1
# 2046
# NA
# NA
# NA
# 2039
# 2071
# NA
# NA
# 2033
# 2048
# 2071
# NA
# ['MPI-ESM-LR_r1i1p1', '2022', 'NA', 'NA', 'NA', '2022', '2042', 'NA', 'NA', '2017', '2036', '2061', '2081']
# MPI-ESM-LR
# MPI-ESM-LR_r1i1p1
# 2022
# NA
# NA
# NA
# 2022
# 2042
# NA
# NA
# 2017
# 2036
# 2061
# 2081
# ['MPI-ESM-MR_r1i1p1', '2023', 'NA', 'NA', 'NA', '2023', '2045', 'NA', 'NA', '2019', '2038', '2060', '2082']
# MPI-ESM-MR
# MPI-ESM-MR_r1i1p1
# 2023
# NA
# NA
# NA
# 2023
# 2045
# NA
# NA
# 2019
# 2038
# 2060
# 2082
# ['MRI-CGCM3_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2053', '2084', 'NA', 'NA', '2041', '2052', '2076', 'NA']
# MRI-CGCM3
# MRI-CGCM3_r1i1p1
# NA
# NA
# NA
# NA
# 2053
# 2084
# NA
# NA
# 2041
# 2052
# 2076
# NA
# ['NorESM1-M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2039', '2072', 'NA', 'NA', '2032', '2048', '2072', 'NA']
# NorESM1-M
# NorESM1-M_r1i1p1
# NA
# NA
# NA
# NA
# 2039
# 2072
# NA
# NA
# 2032
# 2048
# 2072
# NA

# %%
ens_dict_per_GWL = dict()
list_of_GWLs = ['1.5','2','3','4']
for GWL in list_of_GWLs:
    ens_dict_per_GWL[GWL] = dict()

for scenario in ['26','85']:
    list_of_models = lom_per_exp['rcp'+scenario+'_far']
    for wmodel in list_of_models:
        if wmodel in GWL_dict:
            print 'We have : ', wmodel
            print GWL_dict[wmodel]
            for GWL in list_of_GWLs:
                if scenario=='26': GWL_scenario = GWL+'_rcp26'
                if scenario=='85': GWL_scenario = GWL+'_rcp85'

                # --> file nc
                # --> period
                central_year = GWL_dict[wmodel][GWL_scenario]
                if central_year not in ['NA','9999']:
                    start_year = str( int(central_year)-9 )
                    end_year = str( int(central_year)+10 )
                    dat = ds(model = wmodel,
                             experiment='rcp'+scenario,
                             period=start_year+'-'+end_year,
                             variable = 'sfcWind',
                             **req_dict
                             )
                    ens_dict_per_GWL[GWL][wmodel+'_'+scenario] = clim_average(dat, 'ANM')
                    print cfile(ens_dict_per_GWL[GWL][wmodel+'_'+scenario])
        else:
            print 'We dont have GWL info for ',wmodel
# Out:
# We have :  BNU-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': 'NA', '2_rcp45': 'NA', '1.5_rcp85': 'NA', '3_rcp85': 'NA', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': 'NA', '3_rcp26': 'NA', 'model_run': 'BNU-ESM_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  CESM1-CAM5
# We have :  CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/6b/135e5cc20b2e96cf118ee0fc9a8cd218d0858d7e098fa123420acf.nc
# We have :  CSIRO-Mk3-6-0
# {'4_rcp45': 'NA', '1.5_rcp26': '2035', '2_rcp85': '2044', '2_rcp45': '2047', '1.5_rcp85': '2034', '3_rcp85': '2064', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2034', '3_rcp26': 'NA', 'model_run': 'CSIRO-Mk3-6-0_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/10/3ef474ef6bc48dd928dd5cd800351778892778da035093b98bbb66.nc
# We have :  CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/01/381714d211bd0a860cf6e71f92eecead4b4145a957c3e7b656c89d.nc
# /data/jservon/climafcache/35/df82e1b8eb3c62b3f46ae52aba6d4963f5dbae7becc35691759f01.nc
# We have :  GFDL-CM3
# {'4_rcp45': '9999', '1.5_rcp26': '2021', '2_rcp85': '2034', '2_rcp45': '9999', '1.5_rcp85': '2022', '3_rcp85': '2054', '4_rcp85': '2070', '3_rcp45': '9999', '4_rcp26': 'NA', '1.5_rcp45': '9999', '3_rcp26': 'NA', 'model_run': 'GFDL-CM3_r1i1p1', '2_rcp26': '2049'}
# /data/jservon/climafcache/e9/9130ccc7ec9b2ea16909e8d15d322c09ce677bceaed690bc524a9b.nc
# /data/jservon/climafcache/e2/5f3a8ff07cc63a379655f6ac91960a19228916ea1b863327e85837.nc
# We have :  GFDL-ESM2G
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2054', '2_rcp45': 'NA', '1.5_rcp85': '2037', '3_rcp85': '2080', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2050', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2G_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  GISS-E2-H
# We dont have GWL info for  GISS-E2-R
# We dont have GWL info for  HadGEM2-AO
# We have :  HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/dd/080826fdc5b6237f6c29491e09259b8bfd23d4d6501880f8407a27.nc
# We have :  MIROC-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': '2021', '2_rcp85': '2030', '2_rcp45': '2033', '1.5_rcp85': '2020', '3_rcp85': '2052', '4_rcp85': '2069', '3_rcp45': '2068', '4_rcp26': 'NA', '1.5_rcp45': '2020', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM_r1i1p1', '2_rcp26': '2040'}
# /data/jservon/climafcache/81/39054700d5243d85e4cf5e7dce7e3958781cb4299e430f6344f0a6.nc
# /data/jservon/climafcache/b9/7581421754f2a9a64d9600514d01423cd9a9c69038a22b7184b4e4.nc
# We have :  MIROC-ESM-CHEM
# {'4_rcp45': 'NA', '1.5_rcp26': '2018', '2_rcp85': '2030', '2_rcp45': '2036', '1.5_rcp85': '2018', '3_rcp85': '2050', '4_rcp85': '2067', '3_rcp45': '2073', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM-CHEM_r1i1p1', '2_rcp26': '2034'}
# /data/jservon/climafcache/26/6dc165a2c61999b4653e5847249f462a540cde407ff0bfcda4ec23.nc
# /data/jservon/climafcache/f9/6131e4611547437e7ad81cdb27b4469c01d9f3e76e611a70239a27.nc
# We have :  MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b6/8ab8a42d9f81c92b312c9ed3c9bf2ea06e1aa2511cd99c9781485b.nc
# We have :  MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/82/658e94a1ac204810092a080c063e1df29661dd4a380285a9c9d124.nc
# We have :  MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/e8/3ec89a733d9581d488017df204c3453550eaff38d8baec1f0ff04b.nc
# We have :  MRI-CGCM3
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2052', '2_rcp45': '2084', '1.5_rcp85': '2041', '3_rcp85': '2076', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2053', '3_rcp26': 'NA', 'model_run': 'MRI-CGCM3_r1i1p1', '2_rcp26': 'NA'}
# We have :  ACCESS1-0
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2053', '1.5_rcp85': '2028', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2033', '3_rcp26': '9999', 'model_run': 'ACCESS1-0_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/10/6bda8954ff7aaf2090cde31a1c25e8a167f0eed49199b80d6e8dac.nc
# /data/jservon/climafcache/73/36060fd66929b1ad89aa8adc2c1e6f52238a4db76ac8aa6445b56f.nc
# /data/jservon/climafcache/c0/ea77e2d61da898b9fe00c094c5928cd17f551c199528e38711fd61.nc
# /data/jservon/climafcache/78/705364920cc770ce0cf069291bb62c78148f8d931a21630b6923b3.nc
# We have :  ACCESS1-3
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2042', '2_rcp45': '2056', '1.5_rcp85': '2031', '3_rcp85': '2062', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2039', '3_rcp26': '9999', 'model_run': 'ACCESS1-3_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/58/a1309feba254b1c75cc3abb6946e65b83ad8c83c0e14c47fb1aa5b.nc
# /data/jservon/climafcache/2a/907c9d31bab4efa1453f52386f4e3eb6490d6468960f61b6e694b6.nc
# /data/jservon/climafcache/e5/c292ae0bb4b468bfabdea1987e118572fab3a2badfcb85e2926915.nc
# /data/jservon/climafcache/6d/22ffd9203a32b497f0a3fd82a5101571651ba2822ffbda71445a4e.nc
# We have :  BNU-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': 'NA', '2_rcp45': 'NA', '1.5_rcp85': 'NA', '3_rcp85': 'NA', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': 'NA', '3_rcp26': 'NA', 'model_run': 'BNU-ESM_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  CESM1-CAM5
# We dont have GWL info for  CMCC-CESM
# We have :  CMCC-CM
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2050', '1.5_rcp85': '2029', '3_rcp85': '2060', '4_rcp85': '2078', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2033', '3_rcp26': '9999', 'model_run': 'CMCC-CM_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/b0/a4f475b57d91b65ecffe28eb5831ced9b52a69a67bbe6435a86f19.nc
# /data/jservon/climafcache/8b/fea35e6ba4631339ef024df8ee9637da3d64a9334195eebc5d629e.nc
# /data/jservon/climafcache/ae/cb50c6777372cb0519a310187282082caf48a59cb40e5734d81d3a.nc
# /data/jservon/climafcache/25/25ea35e328bb156b77fd4202733d5e1c4b4b366ae439b1fb695207.nc
# We have :  CMCC-CMS
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2055', '1.5_rcp85': '2029', '3_rcp85': '2061', '4_rcp85': '2077', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2037', '3_rcp26': '9999', 'model_run': 'CMCC-CMS_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/1e/df004c51735c585ea1172dd33a433aeb25f2166e00be95278e84f2.nc
# /data/jservon/climafcache/9d/673c51a5b28106fe5e5f40bde76aed05fabc1aa297273713dd2ce1.nc
# /data/jservon/climafcache/84/efcdf202071552ec7502a5a77756b915fd021444ec860ec254110a.nc
# /data/jservon/climafcache/9c/611fb4a8ba39285b9acb475c0b578fe11eecb118fd325a68065813.nc
# We have :  CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/1a/81a008d88d26f1b40f82c8c6626941febf40927bb738013799dfd0.nc
# /data/jservon/climafcache/66/f268cb3cad4542be70b6084a6b6b58c6ca8e06270681e5f64c670e.nc
# /data/jservon/climafcache/35/8d316bc0bbce1e38fb2a741913ef74ca1b2e32e6ba87828ac9ef4d.nc
# /data/jservon/climafcache/85/b0e8bf4ed4a0fda527179dfe32f6d4a9fe66126b79f623cdd89255.nc
# We have :  CSIRO-Mk3-6-0
# {'4_rcp45': 'NA', '1.5_rcp26': '2035', '2_rcp85': '2044', '2_rcp45': '2047', '1.5_rcp85': '2034', '3_rcp85': '2064', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2034', '3_rcp26': 'NA', 'model_run': 'CSIRO-Mk3-6-0_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/bb/cfc49b676d312cac86bab80822f7bf99c7c50ae576b6ea4cc15f4f.nc
# /data/jservon/climafcache/e2/3a95309466c6a96cbee8af1cabd4bcf79273d12f089ee01d8af658.nc
# /data/jservon/climafcache/ea/6d2b91cc288a692ea0cedc0e4e42d59aebc40652702f7d3561e834.nc
# /data/jservon/climafcache/38/a2e7d0304f311df32703446b861edb00206c81eec5ffa6c2ef34ff.nc
# We have :  CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/9d/b755ab5335ae04a65f94e873e90bfa6f37f13b780074ed178b669f.nc
# /data/jservon/climafcache/c4/9999b9e7e46e3ad8be621dc93bd87ae1eb8c8df3d0d77db27fb418.nc
# /data/jservon/climafcache/6a/92da480fa7072506d9672838a04ba3c3208af2574ac520d5882c2c.nc
# /data/jservon/climafcache/0c/6f5c3f0ced1865a6b3b54142a0c6d9cae83584b2d6f42171d9d59d.nc
# We have :  GFDL-CM3
# {'4_rcp45': '9999', '1.5_rcp26': '2021', '2_rcp85': '2034', '2_rcp45': '9999', '1.5_rcp85': '2022', '3_rcp85': '2054', '4_rcp85': '2070', '3_rcp45': '9999', '4_rcp26': 'NA', '1.5_rcp45': '9999', '3_rcp26': 'NA', 'model_run': 'GFDL-CM3_r1i1p1', '2_rcp26': '2049'}
# /data/jservon/climafcache/9f/0084ea295a064b886332a56c41cdcc11408031026a9b0281bb2ad6.nc
# /data/jservon/climafcache/ea/68b75e2258eb74949df12143e0b9e761ba11c9cf1bffc2cc955084.nc
# /data/jservon/climafcache/5f/3c98eb71cce4efe5d3edaba3474297e9b451ffd7dc58a40080c32a.nc
# /data/jservon/climafcache/45/ea35345a28b701646a4cb3200b864b9b1df21363d428e7721aafe5.nc
# We have :  GFDL-ESM2G
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2054', '2_rcp45': 'NA', '1.5_rcp85': '2037', '3_rcp85': '2080', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2050', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2G_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/62/0170de79c0efc8ae106e9be681e7821b738374279be7e2121149b8.nc
# /data/jservon/climafcache/b1/af773ec384db7b8be4defc099975cbd704a5c8e50bc1e2ef7ac884.nc
# /data/jservon/climafcache/50/ace1ed6a0a05021c76a527227b80106fc31b06aab7d804ed80384e.nc
# We have :  GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b3/29904781e7aab2f90a3c33125828b13e65e4ff6139dd87cb2150ef.nc
# /data/jservon/climafcache/9b/51ab8edef1f6f67c3372989acafa938bdcca39b9194c1f58eb00d2.nc
# /data/jservon/climafcache/d0/eb64980f02e225d76e8d6e6109be090995b1a32f1aacff1919d14a.nc
# We dont have GWL info for  GISS-E2-H
# We dont have GWL info for  GISS-E2-H-CC
# We dont have GWL info for  GISS-E2-R
# We dont have GWL info for  GISS-E2-R-CC
# We dont have GWL info for  HadGEM2-AO
# We have :  HadGEM2-CC
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2039', '2_rcp45': '2052', '1.5_rcp85': '2027', '3_rcp85': '2056', '4_rcp85': '2072', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2036', '3_rcp26': '9999', 'model_run': 'HadGEM2-CC_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/07/8852b8dcdaff43c1d03f2b128322b73c7833426bec4c8be4627228.nc
# /data/jservon/climafcache/04/72c9df8cce96ebfdd330f7cc3e03648ab8dd86b2fe2b09ccc0fc9d.nc
# /data/jservon/climafcache/93/92976938072a894f3b2d7aa3560f97f8d1fbd6425166c08a83746c.nc
# /data/jservon/climafcache/fd/ec29d44cdd383d11ebfbaaec2a85f32d377577063e31d83be44f1c.nc
# We have :  HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b5/8f86fb11a974dba02dc1ae692ee6c4fa646c86460863d48e63af9e.nc
# /data/jservon/climafcache/9b/ebe502dd81616e3767002279559477b59eafea73e42c415926d924.nc
# /data/jservon/climafcache/cc/f12696605e6385ec03f8cad660239af7b1e3bfd1c97eed29ee5136.nc
# /data/jservon/climafcache/5e/82f9120d97c4cbb54f65abdb06d56b61eccb01dd7cd1fbbd7520c7.nc
# We have :  MIROC-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': '2021', '2_rcp85': '2030', '2_rcp45': '2033', '1.5_rcp85': '2020', '3_rcp85': '2052', '4_rcp85': '2069', '3_rcp45': '2068', '4_rcp26': 'NA', '1.5_rcp45': '2020', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM_r1i1p1', '2_rcp26': '2040'}
# /data/jservon/climafcache/a7/ca31ab08a4fbf45cd798525584d80a0ec330c42ad595eb823120f7.nc
# /data/jservon/climafcache/28/6e6e4f7b10c80b905690a727a50900d3d2269fae219a5b4aac288a.nc
# /data/jservon/climafcache/04/05944c1b0b0f21e21fa629f3d0e1026850231b158f2fbcc228add7.nc
# /data/jservon/climafcache/b8/11fd3e42d160b54b6f346e82413d45d7da85b74e4352b80c721b99.nc
# We have :  MIROC-ESM-CHEM
# {'4_rcp45': 'NA', '1.5_rcp26': '2018', '2_rcp85': '2030', '2_rcp45': '2036', '1.5_rcp85': '2018', '3_rcp85': '2050', '4_rcp85': '2067', '3_rcp45': '2073', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM-CHEM_r1i1p1', '2_rcp26': '2034'}
# /data/jservon/climafcache/ba/e15f1fed8781fc5b5aef67c7f490be41a29883957984238eef2aed.nc
# /data/jservon/climafcache/91/85c5a95df06ec793ae6f7e82e129c3c483b91165126192b3b0e95a.nc
# /data/jservon/climafcache/97/6ddd57a09086fed9b53ef13e3295b9c778f4d88dea43cf452aba43.nc
# /data/jservon/climafcache/0d/6c979521cc028a4f5f32a503c0efffbc95254077c8df7c59290f2b.nc
# We have :  MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/1f/e014fad3504b5cb9cc97d0de2fb6f5ff10f5eff20544105842939f.nc
# /data/jservon/climafcache/a4/cbd779dc966f5c2f6b9e482147f7d32fdf0e975801bdca41e008a9.nc
# /data/jservon/climafcache/e4/44f67d57910091556b08704101abb3fd852e1f56325865d1253674.nc
# We have :  MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/ed/483858fc057b758ee4db843a845ff2dc26204fbc4ee6de38526df5.nc
# /data/jservon/climafcache/81/81d7c98cb991821e31c8e1f540dec030410f67a86b05506b33f787.nc
# /data/jservon/climafcache/b9/70a97cd917baf9ce7292e86dd27925301ab5f3802688b8dc63c2ea.nc
# /data/jservon/climafcache/b5/5bfd15477102ad6179f5ea3a033822fb3f6c040df323527026f2f4.nc
# We have :  MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/e0/3d098fbeb156f61b8f5a6e64b6a1478378b6bab7676e29f0e250bb.nc
# /data/jservon/climafcache/c2/59eb8befbde1cb1a9f2d8b7ed6b56153ea762b8030085a77488e67.nc
# /data/jservon/climafcache/8b/dac84d71ae106d57b78f31275637b9d8d94a8391c0adbe16d7bbbd.nc
# /data/jservon/climafcache/96/6f12396f5e7c778d26f9fff4c18b11f7171ec4fc42faee77b39ba5.nc
# We have :  MRI-CGCM3
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2052', '2_rcp45': '2084', '1.5_rcp85': '2041', '3_rcp85': '2076', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2053', '3_rcp26': 'NA', 'model_run': 'MRI-CGCM3_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/19/348a90b1794f11ea481a1089e92a74919dd70568d5ffad1943e172.nc
# /data/jservon/climafcache/f0/f1841c2ff98598712ef97588f11630f796ee9f3ba3f4697e72c7e6.nc
# /data/jservon/climafcache/9a/50c6f075aa1f553fd9eaa848286b990b381b7661a1339e95e77317.nc
# We dont have GWL info for  MRI-ESM1

# %%
ens_dict_per_GWL[GWL]
# Out:
# {'ACCESS1-0_85': time_average(ds('CMIP5%%sfcWind%2072-2091%global%/bdd%ACCESS1-0%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'ACCESS1-3_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%ACCESS1-3%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CMCC-CMS_85': time_average(ds('CMIP5%%sfcWind%2068-2087%global%/bdd%CMCC-CMS%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CMCC-CM_85': time_average(ds('CMIP5%%sfcWind%2069-2088%global%/bdd%CMCC-CM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CNRM-CM5_85': time_average(ds('CMIP5%%sfcWind%2078-2097%global%/bdd%CNRM-CM5%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CSIRO-Mk3-6-0_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CanESM2_85': time_average(ds('CMIP5%%sfcWind%2059-2078%global%/bdd%CanESM2%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'GFDL-CM3_85': time_average(ds('CMIP5%%sfcWind%2061-2080%global%/bdd%GFDL-CM3%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'HadGEM2-CC_85': time_average(ds('CMIP5%%sfcWind%2063-2082%global%/bdd%HadGEM2-CC%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'HadGEM2-ES_85': time_average(ds('CMIP5%%sfcWind%2062-2081%global%/bdd%HadGEM2-ES%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MIROC-ESM-CHEM_85': time_average(ds('CMIP5%%sfcWind%2058-2077%global%/bdd%MIROC-ESM-CHEM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MIROC-ESM_85': time_average(ds('CMIP5%%sfcWind%2060-2079%global%/bdd%MIROC-ESM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MPI-ESM-LR_85': time_average(ds('CMIP5%%sfcWind%2072-2091%global%/bdd%MPI-ESM-LR%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MPI-ESM-MR_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%MPI-ESM-MR%Amon%rcp85%r1i1p1%monthly%*%latest'))}

# %%
#We dont have GWL info for  GISS-E2-H
#We dont have GWL info for  GISS-E2-R
#We dont have GWL info for  GISS-E2-H-CC
#We dont have GWL info for  GISS-E2-R-CC
#We dont have GWL info for  HadGEM2-AO
#We dont have GWL info for  CMCC-CESM
#We dont have GWL info for  MRI-ESM1

# %% [markdown]
# ## Compute regional averages per clim_period / GWL

# %% [markdown]
# ### Function to compute the reginal averages

# %%
import regionmask
import xarray as xr

def weighted_mean(da, weights, dim):
    """Reduce da by a weighted mean along some dimension(s).

    Parameters
    ----------
    da : DataArray
        Object over which the weighted reduction operation is applied.    
    weights : DataArray
        An array of weights associated with the values in this Dataset.
    dim : str or sequence of str, optional
        Dimension(s) over which to apply the weighted `mean`.
        
    Returns
    -------
    weighted_mean : DataArray
        New DataArray with weighted mean applied to its data and
        the indicated dimension(s) removed.
    """

    weighted_sum = (da * weights).sum(dim=dim, skipna=True)
    # need to mask weights where data is not valid
    masked_weights = weights.where(da.notnull())
    sum_of_weights = masked_weights.sum(dim=dim, skipna=True)
    valid_weights = sum_of_weights != 0
    sum_of_weights = sum_of_weights.where(valid_weights)

    return weighted_sum / sum_of_weights

def average_over_AR6_region_back(filename, variable, region_name):

    # -- AR6 regions
    #ar6_all = regionmask.defined_regions.ar6.all
    # -- Get the regions
    ar6_land = regionmask.defined_regions.ar6.land

    #ax = ar6_all.plot()
    # -- Get land/sea mask (generic)
    land_110 = regionmask.defined_regions.natural_earth.land_110

    # -- Get data
    ds = xr.open_dataset(filename, decode_times=False)
    dat = ds[variable]
    dat.values = np.array(dat.values, dtype=np.float32)

    # -- Mask the data
    mask_3D = ar6_land.mask_3D(dat) # AR6 mask
    land_mask = land_110.mask_3D(dat) # Land sea mask
    mask_lsm = mask_3D * land_mask.squeeze(drop=True) # Combine the two

    weights = np.cos(np.deg2rad(dat.lat))
    
    if region_name=='all':
        return weighted_mean(dat, mask_3D * weights, ("lon", "lat"))
    else:
        if isinstance(region_name, list):
            res = list()
            for region in region_name:
                region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region))
                dat_region = dat.where(region_mask)
                weights_region = weights.where(region_mask)
                res.append( weighted_mean(dat_region, region_mask*weights_region, ("lon","lat")) )
            return res
        else:
            region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region_name))
            dat_region = dat.where(region_mask)
            weights_region = weights.where(region_mask)            
            return weighted_mean(dat_region, region_mask*weights_region, ("lon","lat"))
    
def average_over_AR6_region(filename, variable, region_name):

    # -- AR6 regions
    #ar6_all = regionmask.defined_regions.ar6.all
    # -- Get the regions
    ar6_land = regionmask.defined_regions.ar6.land

    #ax = ar6_all.plot()
    # -- Get land/sea mask (generic)
    land_110 = regionmask.defined_regions.natural_earth.land_110

    # -- Get data
    ds = xr.open_dataset(filename, decode_times=False)
    dat = ds[variable]
    dat.values = np.array(dat.values, dtype=np.float32)

    # -- Mask the data
    mask_3D = ar6_land.mask_3D(dat) # AR6 mask
    land_mask = land_110.mask_3D(dat) # Land sea mask
    mask_lsm = mask_3D * land_mask.squeeze(drop=True) # Combine the two
    
    # -- Compute weights
    if dat.lat.shape == dat.shape:
        weights = np.cos(np.deg2rad(dat.lat))
    else:
        # -- Case dat is has time dim
        if 'time' in dat.dims:
            matlat = np.mean(dat.values, axis=dat.dims.index('time')) * 0
        else:
            matlat = dat.values * 0

        if dat.dims.index('lat')<dat.dims.index('lon'):
            for i in range(0,dat.shape[dat.dims.index('lon')]):
                matlat[:,i] = dat.lat
        else:
            for i in range(0,dat.shape[dat.dims.index('lon')]):
                matlat[i,:] = dat.lat
    
        weights = np.cos(np.deg2rad(matlat))
    
    if region_name=='all':
        return weighted_mean(dat, mask_3D * weights, ("lon", "lat"))
    else:
        if isinstance(region_name, list):
            res = list()
            for region in region_name:
                region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region))
                dat_region = dat.where(region_mask)
                weights_region = np.where(region_mask, weights, float("nan"))
                #weights_region = weights.where(region_mask)
                res.append( weighted_mean(dat_region, region_mask*weights_region, ("lon","lat")) )
            return res
        else:
            region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region_name))
            dat_region = dat.where(region_mask)
            weights_region = np.where(region_mask, weights, float("nan"))
            #weights_region = weights.where(region_mask)            
            return weighted_mean(dat_region, region_mask*weights_region, ("lon","lat"))
#

def regions_contained(lon, lat, regions):

    # determine if the longitude needs to be wrapped
    regions_is_180 = regions.lon_180
    grid_is_180 = regionmask.core.utils._is_180(lon.min(), lon.max())

    wrap_lon = not regions_is_180 == grid_is_180

    lon_orig = lon.copy()
    if wrap_lon:
        lon = regionmask.core.utils._wrapAngle(lon, wrap_lon)

    lon = np.asarray(lon).squeeze()
    lat = np.asarray(lat).squeeze()

    if lon.ndim == 1 and lat.ndim == 1:
        poly = shapely.geometry.box(lon.min(), lat.min(), lon.max(), lat.max())

    # convex_hull is not really what we need
    # https://gist.github.com/dwyerk/10561690
    #     elif lon.ndim == 2 and lat.ndim == 2:
    #         # get the convex hull from all points
    #         lonlat = np.stack([lon.ravel(), lat.ravel()], axis=1)
    #         multipoint = shapely.geometry.MultiPoint(lonlat)
    #         poly = multipoint.convex_hull
    else:
        raise ValueError("Cannot currently handle 2D coordinates")

    fully_contained = list()
    for region_poly in regions.polygons:
        res = poly.contains(region_poly)

        fully_contained.append(res)

    return xr.DataArray(
        fully_contained, dims=["region"], coords=dict(region=regions.numbers)
    )

if None:
    region_name = "all"
    variable = 'tx35'
    filename = "/data/jservon/IPCC/tx35/individual_models/CMIP6_ssp585_tx35_2100_NorESM2-LM_r1i1p1f1.nc"

    tmp = average_over_AR6_region(filename, variable, region_name)
    tmp

# %% [markdown]
# ## Regional averages for future periods and baseline

# %%
if None:
    regional_averages_CMIP5 = dict()

    # -- Loop on experiments / horizons
    #wind_ens_clim_exp_dict[exp]
    for ens_exp in wind_ens_clim_exp_dict:
        print ens_exp
        regional_averages_CMIP5[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in wind_ens_clim_exp_dict[ens_exp]:
            print mem
            # -- Compute the averages for each AR6 region thanks to regionmask
            tmp = average_over_AR6_region(cfile(wind_ens_clim_exp_dict[ens_exp][mem]), 'sfcWind', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                if region_name not in regional_averages_CMIP5[ens_exp]:
                    regional_averages_CMIP5[ens_exp][region_name] = [region_value]
                else:
                    regional_averages_CMIP5[ens_exp][region_name].append(region_value)
#

# %% [markdown]
# ## Differences for future periods against baseline

# %%
ens_baseline_dict.keys()
# Out:
# ['GFDL-CM3',
#  'MIROC-ESM',
#  'CNRM-CM5',
#  'CanESM2',
#  'GISS-E2-H',
#  'MIROC-ESM-CHEM',
#  'BNU-ESM',
#  'GISS-E2-R',
#  'HadGEM2-AO',
#  'MPI-ESM-LR',
#  'MIROC5',
#  'GFDL-ESM2G',
#  'MRI-CGCM3',
#  'MPI-ESM-MR',
#  'CSIRO-Mk3-6-0',
#  'HadGEM2-ES',
#  'CESM1-CAM5']

# %%
#
regional_averages_diff_CMIP5 = dict()
# -- Loop on experiments / horizons
#wind_ens_clim_exp_dict[exp]
for ens_exp in wind_ens_clim_exp_dict:
    if ens_exp not in ['baseline']:
        print ens_exp
        regional_averages_diff_CMIP5[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in wind_ens_clim_exp_dict[ens_exp]:
            if mem.split('_')[0] in ens_baseline_dict:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                tmp = average_over_AR6_region(cfile(wind_ens_clim_exp_dict[ens_exp][mem]), 'sfcWind', 'all')
                region_names = list(tmp.abbrevs)
                ttmp = average_over_AR6_region(cfile(wind_ens_clim_exp_dict[ens_exp][mem]), 'sfcWind', region_names)
                ttmp_baseline = average_over_AR6_region(cfile(wind_ens_clim_exp_dict['baseline'][mem]), 'sfcWind', region_names)
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    region_value = float(ttmp[list(tmp.abbrevs).index(region_name)])
                    region_value_baseline = float(ttmp_baseline[list(tmp.abbrevs).index(region_name)])
                    if region_value_baseline==0:
                        if region_value==0:
                            perc_val = 0
                        else:
                            perc_val = -99999
                    else:
                        perc_val = 100*(region_value - region_value_baseline)/region_value_baseline
                    if region_name not in regional_averages_diff_CMIP5[ens_exp]:
                        regional_averages_diff_CMIP5[ens_exp][region_name] = [perc_val]
                    else:
                        regional_averages_diff_CMIP5[ens_exp][region_name].append(perc_val)
#
if None:
    regional_averages_diff_CMIP5 = dict()
    # -- Loop on experiments / horizons
    #wind_ens_clim_exp_dict[exp]
    for ens_exp in wind_ens_clim_exp_dict:
        if ens_exp not in ['baseline']:
            print ens_exp
            regional_averages_diff_CMIP5[ens_exp] = dict()
            # -- Loop on the members of each ensemble
            for mem in wind_ens_clim_exp_dict[ens_exp]:
                if mem.split('_')[0] in ens_baseline_dict:
                    print mem
                    # -- Compute the averages for each AR6 region thanks to regionmask
                    tmp = average_over_AR6_region(cfile(wind_ens_clim_exp_dict[ens_exp][mem]), 'sfcWind', 'all')
                    tmp_baseline = average_over_AR6_region(cfile(wind_ens_clim_exp_dict['baseline'][mem]), 'sfcWind', 'all')
                    region_names = tmp.abbrevs
                    for tmp_region_name in region_names:
                        region_name = str(tmp_region_name.values)
                        #print region_name
                        region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                        region_value_baseline = float(tmp_baseline.sel(region=list(tmp.abbrevs).index(region_name)).values)
                        tmpval = 100 * (region_value - region_value_baseline) / region_value_baseline
                        if region_name not in regional_averages_diff_CMIP5[ens_exp]:
                            regional_averages_diff_CMIP5[ens_exp][region_name] = [tmpval]
                        else:
                            regional_averages_diff_CMIP5[ens_exp][region_name].append(tmpval)
            #
# Out:
# rcp26_mid
# BNU-ESM
# GFDL-ESM2G
# CSIRO-Mk3-6-0
# HadGEM2-ES
# GISS-E2-H
# GFDL-CM3
# MIROC-ESM
# CNRM-CM5
# MIROC5
# CanESM2
# MIROC-ESM-CHEM
# HadGEM2-AO
# GISS-E2-R
# MPI-ESM-MR
# MRI-CGCM3
# MPI-ESM-LR
# CESM1-CAM5
# rcp26_far
# BNU-ESM
# GFDL-ESM2G
# CSIRO-Mk3-6-0
# HadGEM2-ES
# GISS-E2-H
# GFDL-CM3
# MIROC-ESM
# CNRM-CM5
# MIROC5
# CanESM2
# MIROC-ESM-CHEM
# HadGEM2-AO
# GISS-E2-R
# MPI-ESM-MR
# MRI-CGCM3
# MPI-ESM-LR
# CESM1-CAM5
# rcp85_far
# CanESM2
# BNU-ESM
# GFDL-ESM2G
# MRI-CGCM3
# HadGEM2-ES
# GISS-E2-H
# GFDL-CM3
# MIROC-ESM
# CNRM-CM5
# HadGEM2-AO
# MIROC-ESM-CHEM
# MIROC5
# GISS-E2-R
# MPI-ESM-MR
# CSIRO-Mk3-6-0
# MPI-ESM-LR
# CESM1-CAM5
# rcp85_mid
# CanESM2
# BNU-ESM
# GFDL-ESM2G
# MRI-CGCM3
# HadGEM2-ES
# GISS-E2-H
# GFDL-CM3
# MIROC-ESM
# CNRM-CM5
# HadGEM2-AO
# MIROC-ESM-CHEM
# MIROC5
# GISS-E2-R
# MPI-ESM-MR
# CSIRO-Mk3-6-0
# MPI-ESM-LR
# CESM1-CAM5

# %% [markdown]
# ## Regional averages for GWLs

# %%
if None:
    for GWL in ens_dict_per_GWL:
        print GWL
        regional_averages_CMIP5[GWL] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_dict_per_GWL[GWL]:
            print mem
            # -- Compute the averages for each AR6 region thanks to regionmask
            tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'sfcWind', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                if region_name not in regional_averages_CMIP5[GWL]:
                    regional_averages_CMIP5[GWL][region_name] = [region_value]
                else:
                    regional_averages_CMIP5[GWL][region_name].append(region_value)

# %% [markdown]
# ## Differences for GWLs

# %%
for GWL in ens_dict_per_GWL:
    print GWL
    regional_averages_diff_CMIP5[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_dict_per_GWL[GWL]:
        wmem = mem.replace('_26','').replace('_85','')
        print wmem
        if wmem in ens_baseline_dict:
            print mem
            tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'sfcWind', 'all')
            region_names = list(tmp.abbrevs)
            ttmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'sfcWind', region_names)
            ttmp_baseline = average_over_AR6_region(cfile(wind_ens_clim_exp_dict['baseline'][wmem]), 'sfcWind', region_names)
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                region_value = float(ttmp[region_names.index(region_name)])
                region_value_baseline = float(ttmp_baseline[region_names.index(region_name)])
                if region_value_baseline==0:
                    if region_value==0:
                        perc_val = 0
                    else:
                        perc_val = -99999
                else:
                    perc_val = 100*(region_value - region_value_baseline)/region_value_baseline
                if region_name not in regional_averages_diff_CMIP5[GWL]:
                    regional_averages_diff_CMIP5[GWL][region_name] = [perc_val]
                else:
                    regional_averages_diff_CMIP5[GWL][region_name].append(perc_val)

if None:
    for GWL in ens_dict_per_GWL:
        print GWL
        regional_averages_diff_CMIP5[GWL] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_dict_per_GWL[GWL]:
            wmem = mem.replace('_26','').replace('_85','')
            print wmem
            if wmem in ens_baseline_dict:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'sfcWind', 'all')
                tmp_baseline = average_over_AR6_region(cfile(wind_ens_clim_exp_dict['baseline'][wmem]), 'sfcWind', 'all')
                region_names = tmp.abbrevs
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    #print region_name
                    region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    region_value_baseline = float(tmp_baseline.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    tmpval = 100 * (region_value - region_value_baseline) / region_value_baseline
                    if region_name not in regional_averages_diff_CMIP5[GWL]:
                        regional_averages_diff_CMIP5[GWL][region_name] = [tmpval]
                    else:
                        regional_averages_diff_CMIP5[GWL][region_name].append(tmpval)
# Out:
# 1.5
# MPI-ESM-MR
# MPI-ESM-MR_26
# MIROC5
# MIROC5_26
# MRI-CGCM3
# MRI-CGCM3_85
# MPI-ESM-LR
# MPI-ESM-LR_85
# GFDL-ESM2G
# GFDL-ESM2G_85
# MPI-ESM-MR
# MPI-ESM-MR_85
# HadGEM2-CC
# CMCC-CM
# CNRM-CM5
# CNRM-CM5_26
# CMCC-CMS
# CNRM-CM5
# CNRM-CM5_85
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_26
# CanESM2
# CanESM2_26
# ACCESS1-3
# MPI-ESM-LR
# MPI-ESM-LR_26
# MIROC5
# MIROC5_85
# MIROC-ESM
# MIROC-ESM_85
# GFDL-CM3
# GFDL-CM3_26
# MIROC-ESM
# MIROC-ESM_26
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_26
# GFDL-CM3
# GFDL-CM3_85
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_85
# ACCESS1-0
# HadGEM2-ES
# HadGEM2-ES_85
# GFDL-ESM2M
# HadGEM2-ES
# HadGEM2-ES_26
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_85
# CanESM2
# CanESM2_85
# 3
# ACCESS1-0
# MRI-CGCM3
# MRI-CGCM3_85
# MPI-ESM-MR
# MPI-ESM-MR_85
# CNRM-CM5
# CNRM-CM5_85
# MPI-ESM-LR
# MPI-ESM-LR_85
# MIROC-ESM
# MIROC-ESM_85
# HadGEM2-ES
# HadGEM2-ES_85
# GFDL-ESM2G
# GFDL-ESM2G_85
# GFDL-ESM2M
# ACCESS1-3
# HadGEM2-CC
# CMCC-CM
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_85
# GFDL-CM3
# GFDL-CM3_85
# CMCC-CMS
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_85
# MIROC5
# MIROC5_85
# CanESM2
# CanESM2_85
# 2
# MRI-CGCM3
# MRI-CGCM3_85
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_26
# GFDL-ESM2G
# GFDL-ESM2G_85
# MPI-ESM-MR
# MPI-ESM-MR_85
# HadGEM2-CC
# CMCC-CM
# CMCC-CMS
# CNRM-CM5
# CNRM-CM5_85
# MPI-ESM-LR
# MPI-ESM-LR_85
# CanESM2
# CanESM2_26
# ACCESS1-3
# MIROC5
# MIROC5_85
# MIROC-ESM
# MIROC-ESM_85
# GFDL-CM3
# GFDL-CM3_26
# MIROC-ESM
# MIROC-ESM_26
# GFDL-CM3
# GFDL-CM3_85
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_85
# ACCESS1-0
# HadGEM2-ES
# HadGEM2-ES_85
# GFDL-ESM2M
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_85
# CanESM2
# CanESM2_85
# 4
# ACCESS1-0
# CNRM-CM5
# CNRM-CM5_85
# MPI-ESM-LR
# MPI-ESM-LR_85
# MIROC-ESM
# MIROC-ESM_85
# HadGEM2-ES
# HadGEM2-ES_85
# MPI-ESM-MR
# MPI-ESM-MR_85
# ACCESS1-3
# HadGEM2-CC
# CMCC-CM
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_85
# GFDL-CM3
# GFDL-CM3_85
# CMCC-CMS
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_85
# CanESM2
# CanESM2_85

# %% [markdown]
# ### Compute the percentiles per region and save in json

# %%
if None:
    quantiles_dict = dict()
    for clim_period in regional_averages_CMIP5:
        quantiles_dict[clim_period] = dict()
        for region_name in regional_averages_CMIP5[clim_period]:
            print clim_period, region_name
            quantiles_dict[clim_period][region_name] = dict()
            dat = np.array(regional_averages_CMIP5[clim_period][region_name])

            q10 = np.quantile(dat, 0.1)
            q50 = np.quantile(dat, 0.5)
            q90 = np.quantile(dat, 0.9)
            quantiles_dict[clim_period][region_name] = [q10, q50, q90]

    import json
    ensemble = 'CMIP5'
    outfilename = '/home/jservon/Chapter12_IPCC/data/wind_satellites/'+ensemble+'_sfcWind_AR6_regional_averages.json'
    #print outfilename
    with open(outfilename, 'w') as fp:
        json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %%
quantiles_dict = dict()
for clim_period in regional_averages_diff_CMIP5:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages_diff_CMIP5[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages_diff_CMIP5[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]

import json
ensemble = 'CMIP5'
outfilename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.5/'+ensemble+'_sfcWind_diff-perc-baseline_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)
# Out:
# 1.5 NEN
# 1.5 NCA
# 1.5 WAN
# 1.5 EEU
# 1.5 CAR
# 1.5 WSAF
# 1.5 CAU
# 1.5 WSB
# 1.5 NAU
# 1.5 SWS
# 1.5 NEU
# 1.5 NES
# 1.5 TIB
# 1.5 WNA
# 1.5 SES
# 1.5 SAM
# 1.5 NWS
# 1.5 NSA
# 1.5 SCA
# 1.5 MDG
# 1.5 CAF
# 1.5 SEAF
# 1.5 NZ
# 1.5 RAR
# 1.5 SEA
# 1.5 SAS
# 1.5 NWN
# 1.5 EAU
# 1.5 SAU
# 1.5 ENA
# 1.5 WAF
# 1.5 WCA
# 1.5 SAH
# 1.5 GIC
# 1.5 ESB
# 1.5 RFE
# 1.5 CNA
# 1.5 EAS
# 1.5 ARP
# 1.5 MED
# 1.5 ECA
# 1.5 NEAF
# 1.5 EAN
# 1.5 WCE
# 1.5 SSA
# 1.5 ESAF
# rcp26_far NEN
# rcp26_far NCA
# rcp26_far WAN
# rcp26_far EEU
# rcp26_far CAR
# rcp26_far WSAF
# rcp26_far CAU
# rcp26_far WSB
# rcp26_far NAU
# rcp26_far SWS
# rcp26_far NEU
# rcp26_far NES
# rcp26_far TIB
# rcp26_far WNA
# rcp26_far SES
# rcp26_far SAM
# rcp26_far NWS
# rcp26_far NSA
# rcp26_far SCA
# rcp26_far MDG
# rcp26_far CAF
# rcp26_far SEAF
# rcp26_far NZ
# rcp26_far RAR
# rcp26_far SEA
# rcp26_far SAS
# rcp26_far NWN
# rcp26_far EAU
# rcp26_far SAU
# rcp26_far ENA
# rcp26_far WAF
# rcp26_far WCA
# rcp26_far SAH
# rcp26_far GIC
# rcp26_far ESB
# rcp26_far RFE
# rcp26_far CNA
# rcp26_far EAS
# rcp26_far ARP
# rcp26_far MED
# rcp26_far ECA
# rcp26_far NEAF
# rcp26_far EAN
# rcp26_far WCE
# rcp26_far SSA
# rcp26_far ESAF
# rcp26_mid NEN
# rcp26_mid NCA
# rcp26_mid WAN
# rcp26_mid EEU
# rcp26_mid CAR
# rcp26_mid WSAF
# rcp26_mid CAU
# rcp26_mid WSB
# rcp26_mid NAU
# rcp26_mid SWS
# rcp26_mid NEU
# rcp26_mid NES
# rcp26_mid TIB
# rcp26_mid WNA
# rcp26_mid SES
# rcp26_mid SAM
# rcp26_mid NWS
# rcp26_mid NSA
# rcp26_mid SCA
# rcp26_mid MDG
# rcp26_mid CAF
# rcp26_mid SEAF
# rcp26_mid NZ
# rcp26_mid RAR
# rcp26_mid SEA
# rcp26_mid SAS
# rcp26_mid NWN
# rcp26_mid EAU
# rcp26_mid SAU
# rcp26_mid ENA
# rcp26_mid WAF
# rcp26_mid WCA
# rcp26_mid SAH
# rcp26_mid GIC
# rcp26_mid ESB
# rcp26_mid RFE
# rcp26_mid CNA
# rcp26_mid EAS
# rcp26_mid ARP
# rcp26_mid MED
# rcp26_mid ECA
# rcp26_mid NEAF
# rcp26_mid EAN
# rcp26_mid WCE
# rcp26_mid SSA
# rcp26_mid ESAF
# rcp85_far NEN
# rcp85_far NCA
# rcp85_far WAN
# rcp85_far EEU
# rcp85_far CAR
# rcp85_far WSAF
# rcp85_far CAU
# rcp85_far WSB
# rcp85_far NAU
# rcp85_far SWS
# rcp85_far NEU
# rcp85_far NES
# rcp85_far TIB
# rcp85_far WNA
# rcp85_far SES
# rcp85_far SAM
# rcp85_far NWS
# rcp85_far NSA
# rcp85_far SCA
# rcp85_far MDG
# rcp85_far CAF
# rcp85_far SEAF
# rcp85_far NZ
# rcp85_far RAR
# rcp85_far SEA
# rcp85_far SAS
# rcp85_far NWN
# rcp85_far EAU
# rcp85_far SAU
# rcp85_far ENA
# rcp85_far WAF
# rcp85_far WCA
# rcp85_far SAH
# rcp85_far GIC
# rcp85_far ESB
# rcp85_far RFE
# rcp85_far CNA
# rcp85_far EAS
# rcp85_far ARP
# rcp85_far MED
# rcp85_far ECA
# rcp85_far NEAF
# rcp85_far EAN
# rcp85_far WCE
# rcp85_far SSA
# rcp85_far ESAF
# 3 NEN
# 3 NCA
# 3 WAN
# 3 EEU
# 3 CAR
# 3 WSAF
# 3 CAU
# 3 WSB
# 3 NAU
# 3 SWS
# 3 NEU
# 3 NES
# 3 TIB
# 3 WNA
# 3 SES
# 3 SAM
# 3 NWS
# 3 NSA
# 3 SCA
# 3 MDG
# 3 CAF
# 3 SEAF
# 3 NZ
# 3 RAR
# 3 SEA
# 3 SAS
# 3 NWN
# 3 EAU
# 3 SAU
# 3 ENA
# 3 WAF
# 3 WCA
# 3 SAH
# 3 GIC
# 3 ESB
# 3 RFE
# 3 CNA
# 3 EAS
# 3 ARP
# 3 MED
# 3 ECA
# 3 NEAF
# 3 EAN
# 3 WCE
# 3 SSA
# 3 ESAF
# 2 NEN
# 2 NCA
# 2 WAN
# 2 EEU
# 2 CAR
# 2 WSAF
# 2 CAU
# 2 WSB
# 2 NAU
# 2 SWS
# 2 NEU
# 2 NES
# 2 TIB
# 2 WNA
# 2 SES
# 2 SAM
# 2 NWS
# 2 NSA
# 2 SCA
# 2 MDG
# 2 CAF
# 2 SEAF
# 2 NZ
# 2 RAR
# 2 SEA
# 2 SAS
# 2 NWN
# 2 EAU
# 2 SAU
# 2 ENA
# 2 WAF
# 2 WCA
# 2 SAH
# 2 GIC
# 2 ESB
# 2 RFE
# 2 CNA
# 2 EAS
# 2 ARP
# 2 MED
# 2 ECA
# 2 NEAF
# 2 EAN
# 2 WCE
# 2 SSA
# 2 ESAF
# 4 NEN
# 4 NCA
# 4 WAN
# 4 EEU
# 4 CAR
# 4 WSAF
# 4 CAU
# 4 WSB
# 4 NAU
# 4 SWS
# 4 NEU
# 4 NES
# 4 TIB
# 4 WNA
# 4 SES
# 4 SAM
# 4 NWS
# 4 NSA
# 4 SCA
# 4 MDG
# 4 CAF
# 4 SEAF
# 4 NZ
# 4 RAR
# 4 SEA
# 4 SAS
# 4 NWN
# 4 EAU
# 4 SAU
# 4 ENA
# 4 WAF
# 4 WCA
# 4 SAH
# 4 GIC
# 4 ESB
# 4 RFE
# 4 CNA
# 4 EAS
# 4 ARP
# 4 MED
# 4 ECA
# 4 NEAF
# 4 EAN
# 4 WCE
# 4 SSA
# 4 ESAF
# rcp85_mid NEN
# rcp85_mid NCA
# rcp85_mid WAN
# rcp85_mid EEU
# rcp85_mid CAR
# rcp85_mid WSAF
# rcp85_mid CAU
# rcp85_mid WSB
# rcp85_mid NAU
# rcp85_mid SWS
# rcp85_mid NEU
# rcp85_mid NES
# rcp85_mid TIB
# rcp85_mid WNA
# rcp85_mid SES
# rcp85_mid SAM
# rcp85_mid NWS
# rcp85_mid NSA
# rcp85_mid SCA
# rcp85_mid MDG
# rcp85_mid CAF
# rcp85_mid SEAF
# rcp85_mid NZ
# rcp85_mid RAR
# rcp85_mid SEA
# rcp85_mid SAS
# rcp85_mid NWN
# rcp85_mid EAU
# rcp85_mid SAU
# rcp85_mid ENA
# rcp85_mid WAF
# rcp85_mid WCA
# rcp85_mid SAH
# rcp85_mid GIC
# rcp85_mid ESB
# rcp85_mid RFE
# rcp85_mid CNA
# rcp85_mid EAS
# rcp85_mid ARP
# rcp85_mid MED
# rcp85_mid ECA
# rcp85_mid NEAF
# rcp85_mid EAN
# rcp85_mid WCE
# rcp85_mid SSA
# rcp85_mid ESAF

# %%
# -- Get the list of models that have both uas and vas
# -- create the ensemble and compute sfcWind

# -- historical 1995_2014 (cat historical and rcp85)
# -- rcp85 2041-2060 and 2081-2100
# -- rcp26 2041-2060 and 2081-2100
# -- GWLs => use the file

# %% [markdown]
# ## CMIP6

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %%
# -- Function to split a multi-member file in individual files
# -- Uses Xarray
def split_ensemble_file(ensemble_file, output_pattern, variable):
    if not os.path.isdir(os.path.dirname(output_pattern)):
        os.makedirs(os.path.dirname(output_pattern))
    import xarray as xr
    dat = xr.open_dataset(ensemble_file)[variable]
    for member in dat.member:
        member_name = str(member.values)
        print member_name
        outfilename = output_pattern+member_name+'.nc'
        if not os.path.isfile(outfilename):
            print 'Save '+outfilename
            member_dat = dat.loc[:,member_name,:,:]
            member_dat.to_netcdf(outfilename)
        else:
            print outfilename+' already exists'

variable='wind'
exp_list = [
    #dict(experiment='historical',
    #     period = '1995-2014'),
    #dict(experiment='ssp585',
    #     period = '2041-2060'),
    #dict(experiment='ssp585',
    #     period = '2081-2100'),
    #dict(experiment='ssp126',
    #     period = '2081-2100'),
    dict(experiment='ssp126',
         years = range(2041,2061)),
]
for exp_dict in exp_list:
    years = exp_dict['years']
    experiment = exp_dict['experiment']
    for year in years:
        wfile = '/data/jservon/IPCC/wind/CMIP6_wind/CMIP6Amon_'+experiment+'_'+variable+'_'+str(year)+'.nc4'
        output_pattern = '/data/jservon/IPCC/wind/individual_models/CMIP6_'+experiment+'_'+variable+'_'+str(year)+'_'
        split_ensemble_file(wfile, output_pattern, variable)
#
# Out:
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2041_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2042_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2043_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2044_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2045_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2046_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2047_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2048_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2049_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2050_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2051_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2052_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2053_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2053_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2053_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2053_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# ...
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2056_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2057_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2058_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2059_UKESM1-0-LL_r1i1p1f2.nc already exists
# ACCESS-CM2_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_ACCESS-CM2_r1i1p1f1.nc already exists
# ACCESS-ESM1-5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_ACCESS-ESM1-5_r1i1p1f1.nc already exists
# AWI-CM-1-1-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_AWI-CM-1-1-MR_r1i1p1f1.nc already exists
# BCC-CSM2-MR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_BCC-CSM2-MR_r1i1p1f1.nc already exists
# CAMS-CSM1-0_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CAMS-CSM1-0_r2i1p1f1.nc already exists
# CanESM5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CanESM5_r1i1p1f1.nc already exists
# CESM2-WACCM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CESM2-WACCM_r1i1p1f1.nc already exists
# CESM2_r4i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CESM2_r4i1p1f1.nc already exists
# CMCC-CM2-SR5_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CMCC-CM2-SR5_r1i1p1f1.nc already exists
# CNRM-CM6-1-HR_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CNRM-CM6-1-HR_r1i1p1f2.nc already exists
# CNRM-CM6-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CNRM-CM6-1_r1i1p1f2.nc already exists
# CNRM-ESM2-1_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_CNRM-ESM2-1_r1i1p1f2.nc already exists
# EC-Earth3-Veg_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_EC-Earth3-Veg_r1i1p1f1.nc already exists
# EC-Earth3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_EC-Earth3_r1i1p1f1.nc already exists
# FGOALS-g3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_FGOALS-g3_r1i1p1f1.nc already exists
# GFDL-ESM4_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_GFDL-ESM4_r1i1p1f1.nc already exists
# HadGEM3-GC31-LL_r1i1p1f3
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_HadGEM3-GC31-LL_r1i1p1f3.nc already exists
# IITM-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_IITM-ESM_r1i1p1f1.nc already exists
# INM-CM4-8_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_INM-CM4-8_r1i1p1f1.nc already exists
# INM-CM5-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_INM-CM5-0_r1i1p1f1.nc already exists
# IPSL-CM6A-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_IPSL-CM6A-LR_r1i1p1f1.nc already exists
# KACE-1-0-G_r2i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_KACE-1-0-G_r2i1p1f1.nc already exists
# KIOST-ESM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_KIOST-ESM_r1i1p1f1.nc already exists
# MIROC-ES2L_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_MIROC-ES2L_r1i1p1f2.nc already exists
# MIROC6_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_MIROC6_r1i1p1f1.nc already exists
# MPI-ESM1-2-HR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_MPI-ESM1-2-HR_r1i1p1f1.nc already exists
# MPI-ESM1-2-LR_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_MPI-ESM1-2-LR_r1i1p1f1.nc already exists
# MRI-ESM2-0_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_MRI-ESM2-0_r1i1p1f1.nc already exists
# NESM3_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_NESM3_r1i1p1f1.nc already exists
# NorESM2-LM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_NorESM2-LM_r1i1p1f1.nc already exists
# NorESM2-MM_r1i1p1f1
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_NorESM2-MM_r1i1p1f1.nc already exists
# UKESM1-0-LL_r1i1p1f2
# /data/jservon/IPCC/wind/individual_models/CMIP6_ssp126_wind_2060_UKESM1-0-LL_r1i1p1f2.nc already exists

# %%
pattern = '/data/jservon/IPCC/${variable}/individual_models/CMIP6_${experiment}_${variable}_${period}_${member}.nc'
cproject('wind_individual_models_cmip6_ch12','experiment','period','member',('variable','wind'), ensemble=['member'], separator='%')
dataloc(project='wind_individual_models_cmip6_ch12', url=pattern)
# Out:
# <climaf.dataloc.dataloc instance at 0x2af7dcccf908>

# %% [markdown]
# ## Time averages for future periods and baseline

# %%
## Baseline + GWL + time slices = ok...

# %%
req_dict = dict(project='wind_individual_models_cmip6_ch12')

req = ds(experiment='historical', period='1995-2014', member='*',project='wind_individual_models_cmip6_ch12')
req.explore('choices')
# Out:
# {'member': ['ACCESS-CM2_r1i1p1f1',
#   'ACCESS-ESM1-5_r1i1p1f1',
#   'AWI-CM-1-1-MR_r1i1p1f1',
#   'BCC-CSM2-MR_r1i1p1f1',
#   'CAMS-CSM1-0_r2i1p1f1',
#   'CESM2-WACCM_r1i1p1f1',
#   'CMCC-CM2-SR5_r1i1p1f1',
#   'CNRM-CM6-1-HR_r1i1p1f2',
#   'CNRM-CM6-1_r1i1p1f2',
#   'CNRM-ESM2-1_r1i1p1f2',
#   'CanESM5_r1i1p1f1',
#   'EC-Earth3-AerChem_r1i1p1f1',
#   'EC-Earth3-Veg-LR_r1i1p1f1',
#   'EC-Earth3-Veg_r1i1p1f1',
#   'EC-Earth3_r1i1p1f1',
#   'FGOALS-g3_r1i1p1f1',
#   'GFDL-CM4_r1i1p1f1',
#   'GFDL-ESM4_r1i1p1f1',
#   'HadGEM3-GC31-LL_r1i1p1f3',
#   'IITM-ESM_r1i1p1f1',
#   'INM-CM4-8_r1i1p1f1',
#   'INM-CM5-0_r1i1p1f1',
#   'IPSL-CM6A-LR_r1i1p1f1',
#   'KACE-1-0-G_r2i1p1f1',
#   'KIOST-ESM_r1i1p1f1',
#   'MIROC-ES2L_r1i1p1f2',
#   'MIROC6_r1i1p1f1',
#   'MPI-ESM1-2-HR_r1i1p1f1',
#   'MPI-ESM1-2-LR_r1i1p1f1',
#   'MRI-ESM2-0_r1i1p1f1',
#   'NorESM2-LM_r1i1p1f1',
#   'NorESM2-MM_r1i1p1f1',
#   'TaiESM1_r1i1p1f1',
#   'UKESM1-0-LL_r1i1p1f2']}

# %%
exp_list = [
    dict(experiment='historical',
         period = '1995-2014'),
    dict(experiment='ssp585',
         period = '2041-2060'),
    dict(experiment='ssp585',
         period = '2081-2100'),
    dict(experiment='ssp126',
         period = '2081-2100'),
    dict(experiment='ssp126',
         period = '2041-2060'),
]

ens_exp_dict = dict()
for exp in exp_list:
        experiment = exp['experiment']
        period = exp['period']
        
        req = ds(experiment=experiment,
                 period=period,
                 member='*',
                 project='wind_individual_models_cmip6_ch12')

        ens_exp = req.explore('ensemble')
        #
        # -- Climatologies
        clim_exp      = clim_average(ens_exp, 'ANM')

        # -- Changes = Scenario minus baselines
        ens_exp_dict[experiment+'_'+period] = clim_exp

# %%
if None:
    regional_averages = dict()

    # -- Loop on experiments / horizons
    #wind_ens_clim_exp_dict[exp]
    for ens_exp in ens_exp_dict:
        print ens_exp
        regional_averages[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_exp_dict[ens_exp]:
            print mem
            # -- Compute the averages for each AR6 region thanks to regionmask
            #cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_exp_dict[ens_exp][mem])
            #os.system(cmd)
            tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'wind', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                if region_name not in regional_averages[ens_exp]:
                    regional_averages[ens_exp][region_name] = [region_value]
                else:
                    regional_averages[ens_exp][region_name].append(region_value)
    #

# %%
regional_averages_diff = dict()

if None:
    # -- Loop on experiments / horizons
    #wind_ens_clim_exp_dict[exp]
    for ens_exp in ens_exp_dict:
        if ens_exp not in ['historical_1995-2014']:
            print ens_exp
            regional_averages_diff[ens_exp] = dict()
            # -- Loop on the members of each ensemble
            for mem in ens_exp_dict[ens_exp]:
                if mem in ens_exp_dict['historical_1995-2014']:
                    print mem
                    # -- Compute the averages for each AR6 region thanks to regionmask
                    #print cfile(ens_exp_dict[ens_exp][mem])
                    #cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_exp_dict[ens_exp][mem])
                    #os.system(cmd)
                    tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'wind', 'all')
                    tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['historical_1995-2014'][mem]), 'wind', 'all')
                    region_names = tmp.abbrevs
                    for tmp_region_name in region_names:
                        region_name = str(tmp_region_name.values)
                        region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                        region_value_baseline = float(tmp_baseline.sel(region=list(tmp.abbrevs).index(region_name)).values)
                        tmpval = 100 * (region_value - region_value_baseline) / region_value_baseline
                        if region_name not in regional_averages_diff[ens_exp]:
                            regional_averages_diff[ens_exp][region_name] = [tmpval]
                        else:
                            regional_averages_diff[ens_exp][region_name].append(tmpval)
            #
#
for ens_exp in ens_exp_dict:
    if ens_exp not in ['historical_1995-2014']:
        print ens_exp
        regional_averages_diff[ens_exp] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_exp_dict[ens_exp]:
            if mem in ens_exp_dict['historical_1995-2014']:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'wind', 'all')
                region_names = list(tmp.abbrevs)
                ttmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), 'wind', region_names)
                ttmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['historical_1995-2014'][mem]), 'wind', region_names)
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    region_value = float(ttmp[list(tmp.abbrevs).index(region_name)])
                    region_value_baseline = float(ttmp_baseline[list(tmp.abbrevs).index(region_name)])
                    if region_value_baseline==0:
                        if region_value==0:
                            perc_val = 0
                        else:
                            perc_val = -99999
                    else:
                        perc_val = 100*(region_value - region_value_baseline)/region_value_baseline
                    if region_name not in regional_averages_diff[ens_exp]:
                        regional_averages_diff[ens_exp][region_name] = [perc_val]
                    else:
                        regional_averages_diff[ens_exp][region_name].append(perc_val)
# Out:
# ssp585_2081-2100
# ACCESS-CM2_r1i1p1f1
# INM-CM4-8_r1i1p1f1
# GFDL-CM4_r1i1p1f1
# GFDL-ESM4_r1i1p1f1
# CMCC-CM2-SR5_r1i1p1f1
# NorESM2-LM_r1i1p1f1
# IPSL-CM6A-LR_r1i1p1f1
# error    : Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/modfs/modtools/miniconda2/envs/analyse_2.7_v2/lib/python2.7/site-packages/IPython/core/ultratb.py", line 1132, in get_records
# KeyboardInterrupt

# %%
#ssp585_2081-2100
#MIROC6_r1i1p1f1
#/data/jservon/climafcache/e2/3aa8cbaa06d21c19cecd4ac5847e4ed31be105f91dcddbd3f439c7.nc
#SES (EXP,baseline) =  1.83608290053 1.74512893604
#index =  14 14
#EXP obj =  time_average(c_sfcWind(cncks(ds('CMIP6%%uas%2081-2100%global%/bdd%MIROC6%MIROC%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='uas'),cncks(ds('CMIP6%%vas%2081-2100%global%/bdd%MIROC6%MIROC%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='vas')))
#Baseline obj =  time_average(c_sfcWind(cncks(ds('CMIP6%%uas%1995-2014%global%/bdd%MIROC6%MIROC%CMIP%Amon%historical%r1i1p1f1%gn%latest'),Var='uas'),cncks(ds('CMIP6%%vas%1995-2014%global%/bdd%MIROC6%MIROC%CMIP%Amon%historical%r1i1p1f1%gn%latest'),Var='vas')))
#Baseline file =  /data/jservon/climafcache/89/88b677481ac0958a3f066593a04705e5ee8611f0c16914be3bacf3.nc
#MRI-ESM2-0_r1i1p1f1
#/data/jservon/climafcache/4f/f8d395e93df6891a802dc978f83f993b48760459f93851542a48c6.nc

#ssp585_2081-2100
#MRI-ESM2-0_r1i1p1f1
#/data/jservon/climafcache/4f/f8d395e93df6891a802dc978f83f993b48760459f93851542a48c6.nc
#SES (EXP,baseline) =  1.90005605827 1.85712259389
#index =  14 14
#EXP obj =  time_average(c_sfcWind(cncks(ds('CMIP6%%uas%2081-2100%global%/bdd%MRI-ESM2-0%MRI%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='uas'),cncks(ds('CMIP6%%vas%2081-2100%global%/bdd%MRI-ESM2-0%MRI%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='vas')))
#EXP file =  time_average(c_sfcWind(cncks(ds('CMIP6%%uas%2081-2100%global%/bdd%MRI-ESM2-0%MRI%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='uas'),cncks(ds('CMIP6%%vas%2081-2100%global%/bdd%MRI-ESM2-0%MRI%ScenarioMIP%Amon%ssp585%r1i1p1f1%gn%latest'),Var='vas')))
#Baseline obj =  time_average(c_sfcWind(cncks(ds('CMIP6%%uas%1995-2014%global%/bdd%MRI-ESM2-0%MRI%CMIP%Amon%historical%r1i1p1f1%gn%latest'),Var='uas'),cncks(ds('CMIP6%%vas%1995-2014%global%/bdd%MRI-ESM2-0%MRI%CMIP%Amon%historical%r1i1p1f1%gn%latest'),Var='vas')))
#Baseline file =  /data/jservon/climafcache/5f/dbb0242c5a3872ed87826a8919abcde87e63b892673fb983470e38.nc

# %% [markdown]
# ### GWLs

# %%
import csv
GWL_csv = '/home/jservon/Chapter12_IPCC/scripts/ATLAS/warming-levels/CMIP6_Atlas_WarmingLevels.csv'

GWL_dict = dict()
i = 0
with open(GWL_csv) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
    for row in spamreader:
        print row
        model = row[0]#.split('_')[0]
        print model
        GWL_dict[model] = dict()
        if i==0:
            colnames = row
        j = 1
        for elt in row[1:len(row)]:
            print elt
            GWL_dict[model][colnames[j]] = row[j]
            j = j + 1
        i = i + 1

# %%
clog('critical')
ens_dict_per_GWL = dict()
list_of_GWLs = ['1.5','2','3','4']
for GWL in list_of_GWLs:
    ens_dict_per_GWL[GWL] = dict()


for scenario in ['26','85']:
    
    if scenario=='26': req_scenario = 'ssp126'
    if scenario=='85': req_scenario = 'ssp585'
    list_of_models = ens_exp_dict[req_scenario+'_2041-2060'].keys()
    for wmodel_realization in GWL_dict:
        if wmodel_realization:
            print wmodel_realization
            wmodel = wmodel_realization.split('_')[0]
            realization = wmodel_realization.split('_')[1]
            print wmodel
            print 'We have : ', wmodel_realization
            for GWL in list_of_GWLs:
                if scenario=='26': GWL_scenario = GWL+'_ssp126'
                if scenario=='85': GWL_scenario = GWL+'_ssp585'

                # --> file nc
                # --> period
                central_year = GWL_dict[wmodel_realization][GWL_scenario]
                if central_year not in ['NA','9999'] and int(central_year)>2025:
                    print 'central_year = ',central_year
                    start_year = str( int(central_year)-9 )
                    end_year = str( int(central_year)+10 )

                    dat_wind = ds(experiment=experiment,
                                 period=period,
                                 member=wmodel_realization,
                                 project='wind_individual_models_cmip6_ch12')

                    try:
                        #ens_dict_per_GWL[GWL][wmodel+'_'+scenario] = clim_average(c_sfcWind(dat_uas, dat_vas), 'ANM')
                        print cfile(clim_average(dat_wind, 'ANM'))
                        ens_dict_per_GWL[GWL][wmodel_realization+'_'+scenario] = clim_average(dat_wind, 'ANM')
                    except:
                        print 'An error occured for ',wmodel+'_'+scenario, GWL
        else:
            print 'We dont have GWL info for ',wmodel_realization

# %% [markdown]
# ### Raw values

# %%
if None:
    # -- Loop on experiments / horizons
    for GWL in ens_dict_per_GWL:
        print GWL
        regional_averages[GWL] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_dict_per_GWL[GWL]:
            print mem
            # -- Compute the averages for each AR6 region thanks to regionmask
            cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_dict_per_GWL[GWL][mem])
            os.system(cmd)
            tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'wind', 'all')
            region_names = tmp.abbrevs
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                #print region_name
                region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                if region_name not in regional_averages[GWL]:
                    regional_averages[GWL][region_name] = [region_value]
                else:
                    regional_averages[GWL][region_name].append(region_value)

# %% [markdown]
# ### Differences with baseline

# %%
for GWL in ens_dict_per_GWL:
    print GWL
    regional_averages_diff[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_dict_per_GWL[GWL]:
        wmem = mem.replace('_26','').replace('_85','')
        print wmem
        if wmem in ens_exp_dict['historical_1995-2014']:
            print mem
            tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'wind', 'all')
            region_names = list(tmp.abbrevs)
            ttmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'wind', region_names)
            ttmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['historical_1995-2014'][wmem]), 'wind', region_names)
            for tmp_region_name in region_names:
                region_name = str(tmp_region_name.values)
                region_value = float(ttmp[region_names.index(region_name)])
                region_value_baseline = float(ttmp_baseline[region_names.index(region_name)])
                if region_value_baseline==0:
                    if region_value==0:
                        perc_val = 0
                    else:
                        perc_val = -99999
                else:
                    perc_val = 100*(region_value - region_value_baseline)/region_value_baseline
                if region_name not in regional_averages_diff[GWL]:
                    regional_averages_diff[GWL][region_name] = [perc_val]
                else:
                    regional_averages_diff[GWL][region_name].append(perc_val)

if None:
    #regional_averages = dict()
    # -- Loop on experiments / horizons
    for GWL in ens_dict_per_GWL:
        print GWL
        regional_averages_diff[GWL] = dict()
        # -- Loop on the members of each ensemble
        for mem in ens_dict_per_GWL[GWL]:
            wmem = mem.replace('_85','').replace('_26','')
            #if mem.replace('_85','').replace('_26','') in ens_exp_dict['historical_1995-2014']:
            if wmem in ens_exp_dict['historical_1995-2014']:
                print wmem
                # -- Compute the averages for each AR6 region thanks to regionmask
                cmd = 'ncrename -v .uas,wind -v .vas,wind -v .sfcWind,wind '+cfile(ens_dict_per_GWL[GWL][mem])
                #os.system(cmd)
                tmp = average_over_AR6_region(cfile(ens_dict_per_GWL[GWL][mem]), 'wind', 'all')
                tmp_baseline = average_over_AR6_region(cfile(ens_exp_dict['historical_1995-2014'][wmem]), 'wind', 'all')
                region_names = tmp.abbrevs
                for tmp_region_name in region_names:
                    region_name = str(tmp_region_name.values)
                    #print region_name
                    region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name)).values)
                    region_value_baseline = float(tmp_baseline.sel(region=list(tmp_baseline.abbrevs).index(region_name)).values)
                    tmpval = 100 * (region_value - region_value_baseline) / region_value_baseline
                    if region_name not in regional_averages_diff[GWL]:
                        regional_averages_diff[GWL][region_name] = [tmpval]
                    else:
                        regional_averages_diff[GWL][region_name].append(tmpval)

# %%
quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]

import json

ensemble = 'CMIP6'
outfilename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.5/'+ensemble+'_sfcWind_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %%
quantiles_dict = dict()
for clim_period in regional_averages_diff:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages_diff[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages_diff[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]

import json

ensemble = 'CMIP6'
outfilename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.5/'+ensemble+'_sfcWind_diff-perc-baseline_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %%
#EC-Earth3-Veg_r1i1p1f1 ==> Archive a trous!
#An error occured for  EC-Earth3-Veg_85 1.5
#An error occured for  EC-Earth3-Veg_26 1.5

#NorESM2-LM_r1i1p1f1 ==> ni uas, ni vas, ni sfcWind
#An error occured for  NorESM2-LM_85 3

#NorESM2-MM_r1i1p1f1 ==> Archive a trous!
#NorESM2-MM_85 1.5

#UKESM1-0-LL_r1i1p1f2 ==> grids do not match
#An error occured for  UKESM1-0-LL_85 1.5
#An error occured for  UKESM1-0-LL_85 2
#An error occured for  UKESM1-0-LL_85 3
#An error occured for  UKESM1-0-LL_85 4

#FGOALS-g3_r1i1p1f1 ==> Archive a trous!
#An error occured for  FGOALS-g3_85 3

#KACE-1-0-G_r2i1p1f1 ==> grids do not match
#An error occured for  KACE-1-0-G_85 1.5
#An error occured for  KACE-1-0-G_85 2
#An error occured for  KACE-1-0-G_85 3
#An error occured for  KACE-1-0-G_85 4

#HadGEM3-GC31-LL_r1i1p1f3 ==> uas, mais pas vas!!!
#An error occured for  HadGEM3-GC31-LL_85 1.5
#An error occured for  HadGEM3-GC31-LL_85 2
