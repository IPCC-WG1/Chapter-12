# %% [markdown]
# # Compute the time slices and GWLs for wind CMIP5

# %% [markdown]
# ### Author: Jerome Servonat
# ### Contact: jerome.servonnat at lsce.ipsl.fr

# %% [markdown]
# ### Import CliMAF

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %% [markdown]
# ## 1. Copmpute averages for baseline and future periods for 26 and 85

# %%
lom_per_exp = dict()

# %%
req_dict = dict(project='CMIP5',
                frequency='monthly',
                table = 'Amon',
                version='latest'
               )

exp_dict_list = dict(
    baseline = dict(experiment='historical',
         period='1995-2005'
        ),
    baseline_ext = dict(experiment='rcp85',
         period='2006-2015'
        ),
    rcp26_mid = dict(experiment='rcp26',
         period='2041-2060'
        ),
    rcp26_far = dict(experiment='rcp26',
         period='2081-2100'
        ),
    rcp85_mid = dict(experiment='rcp85',
         period='2041-2060'
        ),
    rcp85_far = dict(experiment='rcp85',
         period='2081-2100'
        )  
)


ens_exp_dict = dict()
for exp in exp_dict_list:
    ens_exp_dict[exp] = dict()
    print exp
    wreq = req_dict.copy()
    wreq.update(exp_dict_list[exp])

    req = ds(model='*',
             variable = 'sfcWind',
             **wreq
            )
    models = req.explore('choices')['model']
    ok_models = []
    for model in models:
        req_test = ds(model=model,
                     variable = 'sfcWind',
                     **wreq
                    )
        if not check_time_consistency_CMIP(req_test):
            print model+' not fully covered'
        else:
            print model+' is fine'
            ok_models.append(model)
            ens_exp_dict[exp][model] = req_test.explore('resolve')

    lom_per_exp[exp] = ok_models
# Out:
# baseline_ext
# ACCESS1-0 is fine
# ACCESS1-3 is fine
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CMCC-CESM is fine
# CMCC-CM is fine
# CMCC-CMS is fine
# CNRM-CM5 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GFDL-ESM2M is fine
# GISS-E2-H is fine
# GISS-E2-H-CC is fine
# GISS-E2-R is fine
# GISS-E2-R-CC is fine
# HadGEM2-AO is fine
# HadGEM2-CC is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# IPSL-CM5B-LR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MRI-CGCM3 is fine
# MRI-ESM1 is fine
# rcp85_far
# ACCESS1-0 is fine
# ACCESS1-3 is fine
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CMCC-CESM is fine
# CMCC-CM is fine
# CMCC-CMS is fine
# CNRM-CM5 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GFDL-ESM2M is fine
# GISS-E2-H is fine
# GISS-E2-H-CC is fine
# GISS-E2-R is fine
# GISS-E2-R-CC is fine
# HadGEM2-AO is fine
# HadGEM2-CC is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# IPSL-CM5B-LR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MRI-CGCM3 is fine
# MRI-ESM1 is fine
# rcp26_far
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CNRM-CM5 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GISS-E2-H is fine
# GISS-E2-R is fine
# HadGEM2-AO is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MRI-CGCM3 is fine
# baseline
# ACCESS1-0 is fine
# ACCESS1-3 is fine
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CMCC-CESM is fine
# CMCC-CM is fine
# CMCC-CMS is fine
# CNRM-CM5 is fine
# CNRM-CM5-2 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GFDL-ESM2M is fine
# GISS-E2-H is fine
# GISS-E2-H-CC is fine
# GISS-E2-R is fine
# GISS-E2-R-CC is fine
# HadCM3 is fine
# HadGEM2-AO is fine
# HadGEM2-CC is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# IPSL-CM5B-LR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC4h is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MPI-ESM-P is fine
# MRI-CGCM3 is fine
# MRI-ESM1 is fine
# rcp26_mid
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CNRM-CM5 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GISS-E2-H is fine
# GISS-E2-R is fine
# HadGEM2-AO is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MRI-CGCM3 is fine
# rcp85_mid
# ACCESS1-0 is fine
# ACCESS1-3 is fine
# BNU-ESM is fine
# CESM1-CAM5 is fine
# CMCC-CESM is fine
# CMCC-CM is fine
# CMCC-CMS is fine
# CNRM-CM5 is fine
# CSIRO-Mk3-6-0 is fine
# CanESM2 is fine
# GFDL-CM3 is fine
# GFDL-ESM2G is fine
# GFDL-ESM2M is fine
# GISS-E2-H is fine
# GISS-E2-H-CC is fine
# GISS-E2-R is fine
# GISS-E2-R-CC is fine
# HadGEM2-AO is fine
# HadGEM2-CC is fine
# HadGEM2-ES is fine
# IPSL-CM5A-LR is fine
# IPSL-CM5A-MR is fine
# IPSL-CM5B-LR is fine
# MIROC-ESM is fine
# MIROC-ESM-CHEM is fine
# MIROC5 is fine
# MPI-ESM-LR is fine
# MPI-ESM-MR is fine
# MRI-CGCM3 is fine
# MRI-ESM1 is fine

# %% [markdown]
# # 1. Baseline + baseline ext

# %%
lom_baseline     = lom_per_exp['baseline']
lom_baseline_ext = lom_per_exp['baseline_ext']
print 'Models not in both sets:'
print set(lom_baseline) ^ set(lom_baseline_ext)
print 'Models in common:'
common_lom_baseline = list( set(lom_baseline) & set(lom_baseline_ext) )
print common_lom_baseline
# Out:
# Models not in both sets:
# set(['HadCM3', 'CNRM-CM5-2', 'MIROC4h', 'MPI-ESM-P'])
# Models in common:
# ['ACCESS1-0', 'ACCESS1-3', 'IPSL-CM5B-LR', 'MIROC5', 'CMCC-CMS', 'MIROC-ESM', 'HadGEM2-AO', 'CanESM2', 'MPI-ESM-MR', 'CSIRO-Mk3-6-0', 'GISS-E2-R-CC', 'BNU-ESM', 'GFDL-ESM2G', 'CMCC-CM', 'GFDL-ESM2M', 'IPSL-CM5A-MR', 'IPSL-CM5A-LR', 'GFDL-CM3', 'CNRM-CM5', 'GISS-E2-H', 'MIROC-ESM-CHEM', 'HadGEM2-ES', 'GISS-E2-R', 'HadGEM2-CC', 'GISS-E2-H-CC', 'CMCC-CESM', 'MRI-CGCM3', 'MPI-ESM-LR', 'MRI-ESM1', 'CESM1-CAM5']

# %% [markdown]
# ### Create a CliMAF operator to compute sfcWind from uas and vas

# %%
wreq_dict = req_dict.copy()
wreq_dict.update(exp_dict_list['baseline'])
ens_baseline_hist = eds(model=common_lom_baseline,
                        variable = 'sfcWind',
                        **wreq_dict
                       )

wreq_dict = req_dict.copy()
wreq_dict.update(exp_dict_list['baseline_ext'])
ens_baseline_ext = eds(model=common_lom_baseline,
                       variable = 'sfcWind',
                       **wreq_dict
                      )

# %% [markdown]
# ## Compute wind and cat baseline and baseline_ext

# %%
ens_baseline_dict = dict()
for model in common_lom_baseline:
    
    # -- Cat baseline and ext
    ens_baseline_dict[model] = ccdo2(ens_baseline_hist[model], ens_baseline_ext[model], operator='cat')
    print(model)
    
    print(cfile(ens_baseline_dict[model]))
# Out:
# ACCESS1-0
# /data/jservon/climafcache/68/c26d88fdc0829099a36dc669c87db3671a99f6d52155b29c0036ce.nc
# ACCESS1-3
# /data/jservon/climafcache/94/d9290c0f273e61678c627c951a0e02a06fa0f165d6b9df7e4b88ee.nc
# IPSL-CM5B-LR
# /data/jservon/climafcache/a9/acc5f6a1a6675124d7ca16b8ad73ebc7311ddd7b903a9f4668c1ad.nc
# MIROC5
# /data/jservon/climafcache/c4/5b942fac938b723df953d2fb7346064f146705a679578e584bc987.nc
# CMCC-CMS
# /data/jservon/climafcache/30/e96b689efde8c31f4d3f74536bca75f273b14cf470ac74dba87581.nc
# MIROC-ESM
# /data/jservon/climafcache/8c/d72f253a6ae60a232334a444deb091162d78bdda38882a92d62876.nc
# HadGEM2-AO
# /data/jservon/climafcache/58/212586890fc95c1c922f033f98c0912fab18edf5a2fbcd476e4ac3.nc
# CanESM2
# /data/jservon/climafcache/0a/8793fff71aff8e69aa262a0fb70d1d2773117ac299c2de71d3b4e0.nc
# MPI-ESM-MR
# /data/jservon/climafcache/6c/82a93bbc61d217fefec1be5d5c7eacfaedaf99e7936c1d2a72718d.nc
# CSIRO-Mk3-6-0
# /data/jservon/climafcache/dc/58532f4f3aece8470f75146b8f53cae5469609b63af0b4bd670eec.nc
# GISS-E2-R-CC
# /data/jservon/climafcache/7e/ba0e0f8abe8b284cdcfbdd86da3ebebb394c82814492c1b6a9e4c1.nc
# BNU-ESM
# /data/jservon/climafcache/2c/dd23bcce9655e925e0995b100bdf699e0f8507a5172266e9871212.nc
# GFDL-ESM2G
# /data/jservon/climafcache/ad/cc93a7ad7b6f6051e19285101ab757a484111fa5b10b951eeec2cf.nc
# CMCC-CM
# /data/jservon/climafcache/9b/a41cfdd401014da5628d452e38fee69f72fcd55851ae4410eeb23f.nc
# GFDL-ESM2M
# /data/jservon/climafcache/51/46e64be43477f10d982c6c7edfa5edb1b343310c37316ed238d2d9.nc
# IPSL-CM5A-MR
# /data/jservon/climafcache/89/72ad811e2a8e87f929d72f0cb637afdb5fcbd6cafd3d0239b4d09c.nc
# IPSL-CM5A-LR
# /data/jservon/climafcache/fe/7b3209497ceaab53bcec6cca538e6c96b1dbe26f47f5ea0b374e0f.nc
# GFDL-CM3
# /data/jservon/climafcache/34/94f5d27aa59226f8b37a1a1cc2c409748b4ab2c88096791b6ba9ca.nc
# CNRM-CM5
# /data/jservon/climafcache/ad/e063fe84b475bd85054a2b76d3667c688cb66f4e418ec8b251fe5a.nc
# GISS-E2-H
# /data/jservon/climafcache/71/d12bd25cf1bc7a4dc7ff5f7af6d1219726f57e9ef3c48bf52f3cd4.nc
# MIROC-ESM-CHEM
# /data/jservon/climafcache/f8/2c4404a29a1bde53db1a2269f13498c199eef2cf0eb1242b6eb90b.nc
# HadGEM2-ES
# /data/jservon/climafcache/b0/f8f9bc9511aad241111588daef630b3df680ad8c04d84ccd54e507.nc
# GISS-E2-R
# /data/jservon/climafcache/4c/25a634a87a7b2ae02c134a98a960f00912bbacb066c379e57130b7.nc
# HadGEM2-CC
# /data/jservon/climafcache/0e/cdaed7c46b560db8c21289df50ef73dece874101bef712212b6735.nc
# GISS-E2-H-CC
# /data/jservon/climafcache/f8/1c675ae3bf9617d9cea82a5febd55797a8484fc1525fb5a0aedf3e.nc
# CMCC-CESM
# /data/jservon/climafcache/9e/c9dddf7f453938b7d1420712a20e66164296ae5fab0cf151591975.nc
# MRI-CGCM3
# /data/jservon/climafcache/76/6ba7094e5199493ba48fc205714178eae2584288e1c7a5c81c1be2.nc
# MPI-ESM-LR
# /data/jservon/climafcache/32/0690337ce52ae37faf464e0238c4418687a680a455d64904eebca5.nc
# MRI-ESM1
# /data/jservon/climafcache/58/4fcc5115b4361b61f6102a08d6e1fe7730a4b4849ea06c7495be65.nc
# CESM1-CAM5
# /data/jservon/climafcache/3e/e40cb1a31e1b9c31d9e810b76dc27d439dc75bd60ad26479492525.nc

# %% [markdown]
# ## Compute averages for each experiment/clim_period

# %%
ens_clim_exp_dict = dict()

for exp in ['rcp26_mid','rcp26_far','rcp85_mid','rcp85_far']:    
    print '--> '+exp
    ens_clim_exp_dict[exp] = clim_average(cens(ens_exp_dict[exp]), 'ANM')
# Out:
# --> rcp26_mid
# --> rcp26_far
# --> rcp85_mid
# --> rcp85_far

# %% [markdown]
# ## Create metadata file

# %%
for exp in ens_exp_dict:
    for mem in ens_exp_dict[exp]:
        print ens_exp_dict[exp][mem]
# Out:
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%ACCESS1-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%ACCESS1-3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%IPSL-CM5B-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CMCC-CMS%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%HadGEM2-ES%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CMCC-CM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MPI-ESM-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CanESM2%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-R-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%BNU-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GFDL-ESM2G%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GFDL-ESM2M%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%IPSL-CM5A-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%IPSL-CM5A-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GFDL-CM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CNRM-CM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-H%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC-ESM-CHEM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%HadGEM2-AO%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-R%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%HadGEM2-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-H-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CMCC-CESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MRI-CGCM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MPI-ESM-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MRI-ESM1%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CESM1-CAM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%ACCESS1-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%ACCESS1-3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%IPSL-CM5B-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MIROC5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CMCC-CMS%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MIROC-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%HadGEM2-ES%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CMCC-CM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MPI-ESM-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CanESM2%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GISS-E2-R-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%BNU-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GFDL-ESM2G%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GFDL-ESM2M%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%IPSL-CM5A-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%IPSL-CM5A-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GFDL-CM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CNRM-CM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GISS-E2-H%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MIROC-ESM-CHEM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%HadGEM2-AO%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GISS-E2-R%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%HadGEM2-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%GISS-E2-H-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CMCC-CESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MRI-CGCM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MPI-ESM-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%MRI-ESM1%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2006-2015%global%/bdd%CESM1-CAM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%IPSL-CM5A-LR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GFDL-CM3%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC-ESM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CNRM-CM5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%HadGEM2-AO%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CanESM2%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC-ESM-CHEM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%BNU-ESM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-R%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MIROC5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MPI-ESM-LR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GISS-E2-H%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%GFDL-ESM2G%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MRI-CGCM3%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%MPI-ESM-MR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%HadGEM2-ES%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%CESM1-CAM5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2041-2060%global%/bdd%IPSL-CM5A-MR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%ACCESS1-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%ACCESS1-3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%IPSL-CM5B-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CMCC-CMS%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%HadGEM2-ES%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CMCC-CM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MPI-ESM-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CanESM2%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-R-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%BNU-ESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GFDL-ESM2G%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GFDL-ESM2M%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%IPSL-CM5A-MR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%IPSL-CM5A-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GFDL-CM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CNRM-CM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-H%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC-ESM-CHEM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%HadGEM2-AO%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-R%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%HadGEM2-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-H-CC%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CMCC-CESM%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MRI-CGCM3%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MPI-ESM-LR%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MRI-ESM1%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CESM1-CAM5%Amon%rcp85%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%IPSL-CM5A-LR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GFDL-CM3%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC-ESM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CNRM-CM5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%HadGEM2-AO%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CanESM2%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC-ESM-CHEM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%BNU-ESM%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-R%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MIROC5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MPI-ESM-LR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GISS-E2-H%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%GFDL-ESM2G%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MRI-CGCM3%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%MPI-ESM-MR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%HadGEM2-ES%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%CESM1-CAM5%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%2081-2100%global%/bdd%IPSL-CM5A-MR%Amon%rcp26%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%ACCESS1-0%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%ACCESS1-3%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%IPSL-CM5B-LR%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MIROC5%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CMCC-CMS%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%HadCM3%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MIROC-ESM%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%HadGEM2-ES%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CMCC-CM%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MPI-ESM-P%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MPI-ESM-MR%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CSIRO-Mk3-6-0%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CanESM2%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GISS-E2-R-CC%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%BNU-ESM%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CNRM-CM5-2%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MIROC4h%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GFDL-ESM2G%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GFDL-ESM2M%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%IPSL-CM5A-MR%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%IPSL-CM5A-LR%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GFDL-CM3%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CNRM-CM5%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GISS-E2-H%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MIROC-ESM-CHEM%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%HadGEM2-AO%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GISS-E2-R%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%HadGEM2-CC%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%GISS-E2-H-CC%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CMCC-CESM%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MRI-CGCM3%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MPI-ESM-LR%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%MRI-ESM1%Amon%historical%r1i1p1%monthly%atmos%latest')
# ds('CMIP5%%sfcWind%1995-2005%global%/bdd%CESM1-CAM5%Amon%historical%r1i1p1%monthly%atmos%latest')

# %%
import xarray as xr
def get_tracking_id(ncfile):
    nc = xr.open_dataset(ncfile)
    tracking_id = nc.tracking_id
    nc.close()
    return tracking_id


rows = [['DATA_REF_SYNTAX','FREQUENCY','MODELING_REALM','TABLE_ID','ENS_MEMBER','VERSION_NO','VAR_NAME','HANDLE']]
for exp in ens_exp_dict:
    for mem in ens_exp_dict[exp]:
        try:
            dat = ens_exp_dict[exp][mem]
            print dat.baseFiles()
        except:
            dat = ens_exp_dict[exp][mem].operands[0]
            print dat.baseFiles()
        ds_kvp = dat.explore('resolve').kvp
        ncfile = dat.baseFiles().split(' ')[0]
        try:
            tracking_id = get_tracking_id(ncfile)
        except:
            tracking_id = ''
        dataset_descr = 'CMIP5.output.'+dat.baseFiles().split('/')[4]+'.'+ds_kvp['model']+'.'+ds_kvp['experiment']
        dataset_descr += ','+ds_kvp['frequency']
        dataset_descr += ','+ds_kvp['realm']
        dataset_descr += ','+ds_kvp['table']
        dataset_descr += ','+ds_kvp['realization']
        dataset_descr += ',version_no'
        dataset_descr += ','+ds_kvp['variable']
        dataset_descr += ','+tracking_id
        print(dataset_descr)
        rows.append([dataset_descr])
# Out:
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e7a63ab0-d619-4d26-8db3-5e84ecdbeb57
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8
# /bdd/CMIP5/output/IPSL/IPSL-CM5B-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5B-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,193268df-9374-4767-b13c-764f52cafed6
# /bdd/CMIP5/output/MIROC/MIROC5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e02f4e70-fe8b-413f-8621-dc726b92ba86
# /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_204001-204912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_205001-205912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_206001-206912.nc
# CMIP5.output.CMCC.CMCC-CMS.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a6fd336c-bf9b-456d-b8dc-28728287ae6f
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9cdcb68e-a6a6-4bf5-909e-0117fe713561
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_203012-205511.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_205512-208011.nc
# CMIP5.output.MOHC.HadGEM2-ES.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f04360e5-0e3a-42ba-8a9d-fbda7dd4886d
# /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_204101-205012.nc /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_205101-206012.nc
# CMIP5.output.CMCC.CMCC-CM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f290e978-a4f3-4c83-b50d-21e6419201d6
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f2a7759c-c7d4-4fa8-a923-4ed1646c70e4
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,16e32d18-6f23-479d-8e18-57cce93eaf04
# /bdd/CMIP5/output/CCCma/CanESM2/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CCCma.CanESM2.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c1dc1007-04ab-4cdd-a53f-a7bc9101e64f
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_rcp85_r1i1p1_202601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_rcp85_r1i1p1_205101-207512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f7c8b517-c378-42ec-8de3-2f845d97b561
# /bdd/CMIP5/output/BNU/BNU-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.BNU.BNU-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_205601-206012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3fa56cde-e7e9-46c3-b3ba-56626961a819
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_205601-206012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,077dc3ea-0f63-4135-8afa-1ef565de0930
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3fd1f619-478b-49c9-bbea-18c7d788e7e3
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp85_r1i1p1_200601-230012.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,72ab0ed8-6830-4df5-adaf-a180b615b3b3
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_205601-206012.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c68e7f9c-45ff-45f3-9aae-20a3e776cf8f
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp85_r1i1p1_200601-205512.nc /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp85_r1i1p1_205601-210012.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,aa467087-fb99-4f2b-8e71-78cd146761c1
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp85_r1i1p1_200601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp85_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,dd135321-0dfd-4457-9521-c761de7a7182
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,334efade-85a4-4115-9943-9a6dcf434a3b
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,12605a03-0021-4b4a-bbc3-f12507500a4a
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp85_r1i1p1_202601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp85_r1i1p1_205101-207512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,12910d79-71ed-40ae-8ffd-32d684aefc9d
# /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_203012-205511.nc /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_205512-208011.nc
# CMIP5.output.MOHC.HadGEM2-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a7429005-5d8d-4be5-a721-201bd5f4239f
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H-CC_rcp85_r1i1p1_200601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-H-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H-CC_rcp85_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,5deaa23b-4bf0-49af-9f0c-9db6ffbcc618
# /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_203601-204512.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_204601-205512.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_205601-206512.nc
# CMIP5.output.CMCC.CMCC-CESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,fb2f863b-3d3b-417c-81e7-94299c4f934e
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-CGCM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a292f03f-3129-41cb-9c0f-f6064be9f56e
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9dcf0555-d5c5-48d9-889a-99e697a16d4f
# /bdd/CMIP5/output/MRI/MRI-ESM1/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-ESM1_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-ESM1.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,44750a34-4f2d-4185-b8eb-e79bfb38b883
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e7a63ab0-d619-4d26-8db3-5e84ecdbeb57
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8
# /bdd/CMIP5/output/IPSL/IPSL-CM5B-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5B-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,193268df-9374-4767-b13c-764f52cafed6
# /bdd/CMIP5/output/MIROC/MIROC5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e02f4e70-fe8b-413f-8621-dc726b92ba86
# /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_200601-200912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_201001-201912.nc
# CMIP5.output.CMCC.CMCC-CMS.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,dd48b71c-20fe-4f04-8c93-d3155a245c59
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9cdcb68e-a6a6-4bf5-909e-0117fe713561
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_200512-203011.nc
# CMIP5.output.MOHC.HadGEM2-ES.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,33cd54d6-095c-45a7-8e51-72517d96da06
# /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_200601-201012.nc /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_201101-202012.nc
# CMIP5.output.CMCC.CMCC-CM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,bf93ef8b-af62-4f5d-8f02-2b45a9068d47
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f2a7759c-c7d4-4fa8-a923-4ed1646c70e4
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,16e32d18-6f23-479d-8e18-57cce93eaf04
# /bdd/CMIP5/output/CCCma/CanESM2/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CCCma.CanESM2.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c1dc1007-04ab-4cdd-a53f-a7bc9101e64f
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_rcp85_r1i1p1_200601-202512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,0a74e37f-ebec-4488-be60-fb96567f64e3
# /bdd/CMIP5/output/BNU/BNU-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.BNU.BNU-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_200601-201012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_201101-201512.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8066d101-b8ae-43ad-b073-792b88c06edc
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_200601-201012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_201101-201512.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ea8a6429-fcaf-4a14-a995-e16a95eed198
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3fd1f619-478b-49c9-bbea-18c7d788e7e3
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp85_r1i1p1_200601-230012.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,72ab0ed8-6830-4df5-adaf-a180b615b3b3
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_200601-201012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_201101-201512.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8cac9f3b-5ac5-4c50-9c90-7280129f5487
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp85_r1i1p1_200601-205512.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,aa467087-fb99-4f2b-8e71-78cd146761c1
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp85_r1i1p1_200601-205012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,dd135321-0dfd-4457-9521-c761de7a7182
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,334efade-85a4-4115-9943-9a6dcf434a3b
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,12605a03-0021-4b4a-bbc3-f12507500a4a
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp85_r1i1p1_200601-202512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,411a01d3-70cc-4581-a142-0e80d983abeb
# /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_200512-203011.nc
# CMIP5.output.MOHC.HadGEM2-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,dd4309ab-07d9-44f4-be05-46e3f2186942
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H-CC_rcp85_r1i1p1_200601-205012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,5deaa23b-4bf0-49af-9f0c-9db6ffbcc618
# /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_200601-201512.nc
# CMIP5.output.CMCC.CMCC-CESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ec4e2933-9ad5-4703-b1df-814f06de25b5
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-CGCM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a292f03f-3129-41cb-9c0f-f6064be9f56e
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9dcf0555-d5c5-48d9-889a-99e697a16d4f
# /bdd/CMIP5/output/MRI/MRI-ESM1/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-ESM1_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-ESM1.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,44750a34-4f2d-4185-b8eb-e79bfb38b883
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp26_r1i1p1_200601-230012.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e57e2a83-b646-44e2-befb-45f5cf161e00
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_205601-206012.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,04d57635-f322-4594-b81f-6cddf979c319
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,08235c7b-d0ae-40e9-8459-29bee00a2fea
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp26_r1i1p1_200601-205512.nc /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp26_r1i1p1_205601-210012.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,901c127b-5428-46b4-bf3d-7d9b19b1e55f
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b366f140-6ba5-4d85-ae13-bb6e4dde0b5d
# /bdd/CMIP5/output/CCCma/CanESM2/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.CCCma.CanESM2.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a1cbffbc-1111-4570-84f2-32dc6607c588
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8362f803-0a0e-4b78-a94e-964152ab31bf
# /bdd/CMIP5/output/BNU/BNU-ESM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.BNU.BNU-ESM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a17c85bc-dad8-4caf-8b73-21425e32d08c
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp26_r1i1p1_202601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp26_r1i1p1_205101-207512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3ccc4285-ea5c-405d-bd7a-5416d55dd74b
# /bdd/CMIP5/output/MIROC/MIROC5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a27fb6be-d1fb-4ee0-a2f0-3b6be2c90bcd
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,42927ecf-c142-4229-befb-7cde60a92761
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp26_r1i1p1_200601-205012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp26_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f2018638-4244-48ae-bc51-2f9d79817434
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_205601-206012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,4f5b4e07-931c-47c8-8047-702a85ccd350
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-CGCM3.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a2206795-1231-494b-816e-1f8b8ea2e34e
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,76c874d6-a848-4ef3-a8d2-ff9c39e3cd20
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8733d89d-9289-40ed-b7cd-262fb70abc74
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_203012-205511.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_205512-208011.nc
# CMIP5.output.MOHC.HadGEM2-ES.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b05386d4-8bca-4557-bb31-16a86612d497
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c43f60ee-421d-4670-ae54-f641456bde3d
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,51ff61de-93eb-416c-a277-b15edb3f2074
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e7a63ab0-d619-4d26-8db3-5e84ecdbeb57
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8
# /bdd/CMIP5/output/IPSL/IPSL-CM5B-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5B-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,193268df-9374-4767-b13c-764f52cafed6
# /bdd/CMIP5/output/MIROC/MIROC5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e02f4e70-fe8b-413f-8621-dc726b92ba86
# /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_208001-208912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_209001-210012.nc
# CMIP5.output.CMCC.CMCC-CMS.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,bc8dfc97-a0c0-40c1-b60b-904317f64121
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9cdcb68e-a6a6-4bf5-909e-0117fe713561
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_208012-209912.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_209912-212411.nc
# CMIP5.output.MOHC.HadGEM2-ES.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d1b84b78-3247-47b9-a115-c2d696b4cfbf
# /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_208101-209012.nc /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_209101-210012.nc
# CMIP5.output.CMCC.CMCC-CM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,446aaef0-53a6-4761-8e81-fd3874cc6ebf
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f2a7759c-c7d4-4fa8-a923-4ed1646c70e4
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,16e32d18-6f23-479d-8e18-57cce93eaf04
# /bdd/CMIP5/output/CCCma/CanESM2/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.CCCma.CanESM2.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c1dc1007-04ab-4cdd-a53f-a7bc9101e64f
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_rcp85_r1i1p1_207601-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,77e31ad6-798a-4aef-af41-1d4ecef3d7e0
# /bdd/CMIP5/output/BNU/BNU-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.BNU.BNU-ESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_208101-208512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_208601-209012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_209101-209512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_209601-210012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,af8c56ee-04fc-4587-98ef-c830a40034b1
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_208101-208512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_208601-209012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_209101-209512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_209601-210012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,fb730b5a-1979-429c-bf27-9d7b4d31710f
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3fd1f619-478b-49c9-bbea-18c7d788e7e3
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp85_r1i1p1_200601-230012.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,72ab0ed8-6830-4df5-adaf-a180b615b3b3
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_208101-208512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_208601-209012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_209101-209512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_209601-210012.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c6643af2-b49f-42f0-8a48-d4ead2fc7966
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp85_r1i1p1_205601-210012.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,322135a3-2ea2-4ec5-8e7c-e08371514352
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp85_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,6390cd61-2ef8-44a5-a0c1-11f4c3a231c3
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,334efade-85a4-4115-9943-9a6dcf434a3b
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,12605a03-0021-4b4a-bbc3-f12507500a4a
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp85_r1i1p1_207601-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,fd0cc4a7-46fc-45fd-a4ac-dc3e32bc8003
# /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_208012-209912.nc /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_210001-210012.nc
# CMIP5.output.MOHC.HadGEM2-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b5599022-8861-4586-a126-18c496cdf9e6
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H-CC_rcp85_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,2ed40bc1-0ae6-4f07-8f6c-0ca60cd87e3d
# /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_207601-208512.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_208601-209512.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_rcp85_r1i1p1_209601-210012.nc
# CMIP5.output.CMCC.CMCC-CESM.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a6c1b8c6-ec94-4602-9770-a2d83cb32c1d
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-CGCM3.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a292f03f-3129-41cb-9c0f-f6064be9f56e
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9dcf0555-d5c5-48d9-889a-99e697a16d4f
# /bdd/CMIP5/output/MRI/MRI-ESM1/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-ESM1_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-ESM1.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_rcp85_r1i1p1_200601-210012.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,44750a34-4f2d-4185-b8eb-e79bfb38b883
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp26_r1i1p1_200601-230012.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e57e2a83-b646-44e2-befb-45f5cf161e00
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_208101-208512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_208601-209012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_209101-209512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_209601-210012.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,84829f19-4643-4960-9bdd-132a03ecf535
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,08235c7b-d0ae-40e9-8459-29bee00a2fea
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp26_r1i1p1_205601-210012.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b6a89424-167e-4311-aea0-fd67afa7c12c
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b366f140-6ba5-4d85-ae13-bb6e4dde0b5d
# /bdd/CMIP5/output/CCCma/CanESM2/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.CCCma.CanESM2.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a1cbffbc-1111-4570-84f2-32dc6607c588
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8362f803-0a0e-4b78-a94e-964152ab31bf
# /bdd/CMIP5/output/BNU/BNU-ESM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.BNU.BNU-ESM.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a17c85bc-dad8-4caf-8b73-21425e32d08c
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_rcp26_r1i1p1_207601-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9a0030da-b23e-4433-a366-13fc8d071073
# /bdd/CMIP5/output/MIROC/MIROC5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MIROC.MIROC5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a27fb6be-d1fb-4ee0-a2f0-3b6be2c90bcd
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,42927ecf-c142-4229-befb-7cde60a92761
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_rcp26_r1i1p1_205101-210012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,34a29f89-4799-4208-a0ed-c04f58ff97ed
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_208101-208512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_208601-209012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_209101-209512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp26_r1i1p1_209601-210012.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,973d28ad-b20f-4e0d-996a-03f1049636ec
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MRI.MRI-CGCM3.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,a2206795-1231-494b-816e-1f8b8ea2e34e
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,76c874d6-a848-4ef3-a8d2-ff9c39e3cd20
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8733d89d-9289-40ed-b7cd-262fb70abc74
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_208012-209911.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_209912-212411.nc
# CMIP5.output.MOHC.HadGEM2-ES.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,0511a349-f3a9-460f-8fb0-19b6490bc666
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c43f60ee-421d-4670-ae54-f641456bde3d
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp26_r1i1p1_200601-210012.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,51ff61de-93eb-416c-a277-b15edb3f2074
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-0/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-0_historical_r1i1p1_185001-200512.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-0.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d1aade14-0bbf-45f3-9a5a-4f4dec778bf6
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-3_historical_r1i1p1_185001-200512.nc
# CMIP5.output.CSIRO-BOM.ACCESS1-3.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,9cecc4d4-0886-42a5-9458-f372518fe2d4
# /bdd/CMIP5/output/IPSL/IPSL-CM5B-LR/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5B-LR_historical_r1i1p1_185001-200512.nc
# CMIP5.output.IPSL.IPSL-CM5B-LR.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,2159681c-c5cc-4e36-b082-6b8bb2f486b9
# /bdd/CMIP5/output/MIROC/MIROC5/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_historical_r1i1p1_185001-201212.nc
# CMIP5.output.MIROC.MIROC5.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,6a76767e-6e99-4f86-a00e-c4f085166701
# /bdd/CMIP5/output/CMCC/CMCC-CMS/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_historical_r1i1p1_199001-199912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_historical_r1i1p1_200001-200512.nc
# CMIP5.output.CMCC.CMCC-CMS.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,903b4b75-9212-4f4b-be90-53160a742bb1
# /bdd/CMIP5/output/MOHC/HadCM3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadCM3_historical_r1i1p1_198412-200512.nc
# CMIP5.output.MOHC.HadCM3.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,1b1b52cf-0d34-4e67-8fbd-d749ca0ecba4
# /bdd/CMIP5/output/MIROC/MIROC-ESM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MIROC.MIROC-ESM.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,06b584a5-93ba-4f80-82e0-c3e675a476b8
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_historical_r1i1p1_198412-200511.nc
# CMIP5.output.MOHC.HadGEM2-ES.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8c5c43de-6f44-4bb5-9bf9-3c7f9481b431
# /bdd/CMIP5/output/CMCC/CMCC-CM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_historical_r1i1p1_199001-199912.nc /bdd/CMIP5/output/CMCC/CMCC-CM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_historical_r1i1p1_200001-200512.nc
# CMIP5.output.CMCC.CMCC-CM.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,999ef2e3-56ec-486f-8698-2e40c5faf3be
# /bdd/CMIP5/output/MPI-M/MPI-ESM-P/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-P_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MPI-M.MPI-ESM-P.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,35acac96-5f51-4b53-a546-8c5e3dee5173
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MPI-M.MPI-ESM-MR.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ebcd441c-da92-4011-8371-6cd9c9b1761b
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_historical_r1i1p1_185001-200512.nc
# CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,89bf35a9-b574-4e05-a14e-84b5dbcf54ff
# /bdd/CMIP5/output/CCCma/CanESM2/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_historical_r1i1p1_185001-200512.nc
# CMIP5.output.CCCma.CanESM2.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,87370ebf-c0fe-491e-b75e-f2c858f90391
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_historical_r1i1p1_197601-200012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-R-CC/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R-CC_historical_r1i1p1_200101-201012.nc
# CMIP5.output.NASA-GISS.GISS-E2-R-CC.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ae3f075b-5bc3-4f7f-8be2-3f02c1fe5e06
# /bdd/CMIP5/output/BNU/BNU-ESM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_BNU-ESM_historical_r1i1p1_185001-200512.nc
# CMIP5.output.BNU.BNU-ESM.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,7e168a98-4880-416c-92c0-687274884100
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5-2/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5-2_historical_r1i1p1_195001-199912.nc /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5-2/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5-2_historical_r1i1p1_200001-200512.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5-2.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b215e0d0-eba3-4cbe-b1e3-c3a14bcf26a1
# /bdd/CMIP5/output/MIROC/MIROC4h/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC4h_historical_r1i1p1_199101-200012.nc /bdd/CMIP5/output/MIROC/MIROC4h/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC4h_historical_r1i1p1_200101-200512.nc
# CMIP5.output.MIROC.MIROC4h.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3c0314fa-7aad-4bf2-92bf-7928d23e262a
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_historical_r1i1p1_199101-199512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_historical_r1i1p1_199601-200012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_historical_r1i1p1_200101-200512.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2G.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c48beb85-d791-4be3-b2a1-d828c4daea64
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_historical_r1i1p1_199101-199512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_historical_r1i1p1_199601-200012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_historical_r1i1p1_200101-200512.nc
# CMIP5.output.NOAA-GFDL.GFDL-ESM2M.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,3695f30b-0c3b-482a-858f-b40548360f45
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_historical_r1i1p1_185001-200512.nc
# CMIP5.output.IPSL.IPSL-CM5A-MR.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,813421ed-0e77-4ff9-9f95-c121a3c46bee
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_historical_r1i1p1_185001-200512.nc
# CMIP5.output.IPSL.IPSL-CM5A-LR.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,d7147eba-8034-47a0-a60e-8fb77f743348
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_historical_r1i1p1_199501-199912.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_historical_r1i1p1_200001-200412.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_historical_r1i1p1_200501-200512.nc
# CMIP5.output.NOAA-GFDL.GFDL-CM3.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ccd04e35-0aa3-4d8e-8093-ef94d3293ef1
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_historical_r1i1p1_195001-200512.nc
# CMIP5.output.CNRM-CERFACS.CNRM-CM5.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,b3491584-deb9-4a3a-89d2-f99e810a86f5
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H_historical_r1i1p1_195101-200512.nc
# CMIP5.output.NASA-GISS.GISS-E2-H.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,56837076-9d8b-4036-8a4e-53e4dcdcaccd
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MIROC.MIROC-ESM-CHEM.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,fcabf1bd-2432-4af0-8659-3b28bd7694e9
# /bdd/CMIP5/output/NIMR-KMA/HadGEM2-AO/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-AO_historical_r1i1p1_186001-200512.nc
# CMIP5.output.NIMR-KMA.HadGEM2-AO.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,cdd9ea13-021a-40cd-9c48-4752660f2ae6
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_historical_r1i1p1_197601-200012.nc /bdd/CMIP5/output/NASA-GISS/GISS-E2-R/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-R_historical_r1i1p1_200101-200512.nc
# CMIP5.output.NASA-GISS.GISS-E2-R.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,ce84558a-ff27-4dde-b0dd-0c2f085d111b
# /bdd/CMIP5/output/MOHC/HadGEM2-CC/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_historical_r1i1p1_198412-200511.nc
# CMIP5.output.MOHC.HadGEM2-CC.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,e97032fc-e8da-41be-a392-9b8c7fa109d9
# /bdd/CMIP5/output/NASA-GISS/GISS-E2-H-CC/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GISS-E2-H-CC_historical_r1i1p1_195101-201012.nc
# CMIP5.output.NASA-GISS.GISS-E2-H-CC.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f945610b-bbbc-4b5f-89f8-1e58e09779bf
# /bdd/CMIP5/output/CMCC/CMCC-CESM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_historical_r1i1p1_199501-199912.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_historical_r1i1p1_200001-200412.nc /bdd/CMIP5/output/CMCC/CMCC-CESM/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CESM_historical_r1i1p1_200501-200512.nc
# CMIP5.output.CMCC.CMCC-CESM.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,8537f0d0-b296-42f5-b61b-cf2195b1f1aa
# /bdd/CMIP5/output/MRI/MRI-CGCM3/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MRI.MRI-CGCM3.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,f6ed2ea6-65d9-4b3d-b030-6952db3a9daf
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_historical_r1i1p1_185001-200512.nc
# CMIP5.output.MPI-M.MPI-ESM-LR.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,7e4726b2-9ffd-4e17-848f-3d2749d8eb6b
# /bdd/CMIP5/output/MRI/MRI-ESM1/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-ESM1_historical_r1i1p1_185101-200512.nc
# CMIP5.output.MRI.MRI-ESM1.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,c53efe22-9ef8-43a4-ae32-afb7cc439d45
# /bdd/CMIP5/output/NSF-DOE-NCAR/CESM1-CAM5/historical/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CESM1-CAM5_historical_r1i1p1_185001-200512.nc
# CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.historical,monthly,atmos,Amon,r1i1p1,version_no,sfcWind,84631cc1-cc39-4c0f-a9e6-fb42de766be1

# %%
new_rows = []
for row in rows:
    if (len(row)==1):
        print row[0].split(',')
        new_rows.append(row[0].split(','))
    else:
        print row
        new_rows.append(row)
# Out:
# ['DATA_REF_SYNTAX', 'FREQUENCY', 'MODELING_REALM', 'TABLE_ID', 'ENS_MEMBER', 'VERSION_NO', 'VAR_NAME', 'HANDLE']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e7a63ab0-d619-4d26-8db3-5e84ecdbeb57']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8']
# [u'CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'193268df-9374-4767-b13c-764f52cafed6']
# [u'CMIP5.output.MIROC.MIROC5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e02f4e70-fe8b-413f-8621-dc726b92ba86']
# [u'CMIP5.output.CMCC.CMCC-CMS.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a6fd336c-bf9b-456d-b8dc-28728287ae6f']
# [u'CMIP5.output.MIROC.MIROC-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9cdcb68e-a6a6-4bf5-909e-0117fe713561']
# [u'CMIP5.output.MOHC.HadGEM2-ES.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f04360e5-0e3a-42ba-8a9d-fbda7dd4886d']
# [u'CMIP5.output.CMCC.CMCC-CM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f290e978-a4f3-4c83-b50d-21e6419201d6']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f2a7759c-c7d4-4fa8-a923-4ed1646c70e4']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'16e32d18-6f23-479d-8e18-57cce93eaf04']
# [u'CMIP5.output.CCCma.CanESM2.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c1dc1007-04ab-4cdd-a53f-a7bc9101e64f']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f7c8b517-c378-42ec-8de3-2f845d97b561']
# [u'CMIP5.output.BNU.BNU-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3fa56cde-e7e9-46c3-b3ba-56626961a819']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'077dc3ea-0f63-4135-8afa-1ef565de0930']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3fd1f619-478b-49c9-bbea-18c7d788e7e3']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'72ab0ed8-6830-4df5-adaf-a180b615b3b3']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c68e7f9c-45ff-45f3-9aae-20a3e776cf8f']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'aa467087-fb99-4f2b-8e71-78cd146761c1']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'dd135321-0dfd-4457-9521-c761de7a7182']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'334efade-85a4-4115-9943-9a6dcf434a3b']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'12605a03-0021-4b4a-bbc3-f12507500a4a']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'12910d79-71ed-40ae-8ffd-32d684aefc9d']
# [u'CMIP5.output.MOHC.HadGEM2-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a7429005-5d8d-4be5-a721-201bd5f4239f']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'5deaa23b-4bf0-49af-9f0c-9db6ffbcc618']
# [u'CMIP5.output.CMCC.CMCC-CESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'fb2f863b-3d3b-417c-81e7-94299c4f934e']
# [u'CMIP5.output.MRI.MRI-CGCM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a292f03f-3129-41cb-9c0f-f6064be9f56e']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9dcf0555-d5c5-48d9-889a-99e697a16d4f']
# [u'CMIP5.output.MRI.MRI-ESM1.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'44750a34-4f2d-4185-b8eb-e79bfb38b883']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e7a63ab0-d619-4d26-8db3-5e84ecdbeb57']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8']
# [u'CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'193268df-9374-4767-b13c-764f52cafed6']
# [u'CMIP5.output.MIROC.MIROC5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e02f4e70-fe8b-413f-8621-dc726b92ba86']
# [u'CMIP5.output.CMCC.CMCC-CMS.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'dd48b71c-20fe-4f04-8c93-d3155a245c59']
# [u'CMIP5.output.MIROC.MIROC-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9cdcb68e-a6a6-4bf5-909e-0117fe713561']
# [u'CMIP5.output.MOHC.HadGEM2-ES.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'33cd54d6-095c-45a7-8e51-72517d96da06']
# [u'CMIP5.output.CMCC.CMCC-CM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'bf93ef8b-af62-4f5d-8f02-2b45a9068d47']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f2a7759c-c7d4-4fa8-a923-4ed1646c70e4']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'16e32d18-6f23-479d-8e18-57cce93eaf04']
# [u'CMIP5.output.CCCma.CanESM2.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c1dc1007-04ab-4cdd-a53f-a7bc9101e64f']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'0a74e37f-ebec-4488-be60-fb96567f64e3']
# [u'CMIP5.output.BNU.BNU-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8066d101-b8ae-43ad-b073-792b88c06edc']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ea8a6429-fcaf-4a14-a995-e16a95eed198']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3fd1f619-478b-49c9-bbea-18c7d788e7e3']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'72ab0ed8-6830-4df5-adaf-a180b615b3b3']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8cac9f3b-5ac5-4c50-9c90-7280129f5487']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'aa467087-fb99-4f2b-8e71-78cd146761c1']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'dd135321-0dfd-4457-9521-c761de7a7182']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'334efade-85a4-4115-9943-9a6dcf434a3b']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'12605a03-0021-4b4a-bbc3-f12507500a4a']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'411a01d3-70cc-4581-a142-0e80d983abeb']
# [u'CMIP5.output.MOHC.HadGEM2-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'dd4309ab-07d9-44f4-be05-46e3f2186942']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'5deaa23b-4bf0-49af-9f0c-9db6ffbcc618']
# [u'CMIP5.output.CMCC.CMCC-CESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ec4e2933-9ad5-4703-b1df-814f06de25b5']
# [u'CMIP5.output.MRI.MRI-CGCM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a292f03f-3129-41cb-9c0f-f6064be9f56e']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9dcf0555-d5c5-48d9-889a-99e697a16d4f']
# [u'CMIP5.output.MRI.MRI-ESM1.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'44750a34-4f2d-4185-b8eb-e79bfb38b883']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e57e2a83-b646-44e2-befb-45f5cf161e00']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'04d57635-f322-4594-b81f-6cddf979c319']
# [u'CMIP5.output.MIROC.MIROC-ESM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'08235c7b-d0ae-40e9-8459-29bee00a2fea']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'901c127b-5428-46b4-bf3d-7d9b19b1e55f']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b366f140-6ba5-4d85-ae13-bb6e4dde0b5d']
# [u'CMIP5.output.CCCma.CanESM2.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a1cbffbc-1111-4570-84f2-32dc6607c588']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8362f803-0a0e-4b78-a94e-964152ab31bf']
# [u'CMIP5.output.BNU.BNU-ESM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a17c85bc-dad8-4caf-8b73-21425e32d08c']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3ccc4285-ea5c-405d-bd7a-5416d55dd74b']
# [u'CMIP5.output.MIROC.MIROC5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a27fb6be-d1fb-4ee0-a2f0-3b6be2c90bcd']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'42927ecf-c142-4229-befb-7cde60a92761']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f2018638-4244-48ae-bc51-2f9d79817434']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'4f5b4e07-931c-47c8-8047-702a85ccd350']
# [u'CMIP5.output.MRI.MRI-CGCM3.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a2206795-1231-494b-816e-1f8b8ea2e34e']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'76c874d6-a848-4ef3-a8d2-ff9c39e3cd20']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8733d89d-9289-40ed-b7cd-262fb70abc74']
# [u'CMIP5.output.MOHC.HadGEM2-ES.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b05386d4-8bca-4557-bb31-16a86612d497']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c43f60ee-421d-4670-ae54-f641456bde3d']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'51ff61de-93eb-416c-a277-b15edb3f2074']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e7a63ab0-d619-4d26-8db3-5e84ecdbeb57']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8']
# [u'CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'193268df-9374-4767-b13c-764f52cafed6']
# [u'CMIP5.output.MIROC.MIROC5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e02f4e70-fe8b-413f-8621-dc726b92ba86']
# [u'CMIP5.output.CMCC.CMCC-CMS.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'bc8dfc97-a0c0-40c1-b60b-904317f64121']
# [u'CMIP5.output.MIROC.MIROC-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9cdcb68e-a6a6-4bf5-909e-0117fe713561']
# [u'CMIP5.output.MOHC.HadGEM2-ES.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd1b84b78-3247-47b9-a115-c2d696b4cfbf']
# [u'CMIP5.output.CMCC.CMCC-CM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'446aaef0-53a6-4761-8e81-fd3874cc6ebf']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f2a7759c-c7d4-4fa8-a923-4ed1646c70e4']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'16e32d18-6f23-479d-8e18-57cce93eaf04']
# [u'CMIP5.output.CCCma.CanESM2.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c1dc1007-04ab-4cdd-a53f-a7bc9101e64f']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'77e31ad6-798a-4aef-af41-1d4ecef3d7e0']
# [u'CMIP5.output.BNU.BNU-ESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'7fde4648-2ab1-49f1-99d6-5d57b5ccd1f6']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'af8c56ee-04fc-4587-98ef-c830a40034b1']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'fb730b5a-1979-429c-bf27-9d7b4d31710f']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3fd1f619-478b-49c9-bbea-18c7d788e7e3']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'72ab0ed8-6830-4df5-adaf-a180b615b3b3']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c6643af2-b49f-42f0-8a48-d4ead2fc7966']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'322135a3-2ea2-4ec5-8e7c-e08371514352']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'6390cd61-2ef8-44a5-a0c1-11f4c3a231c3']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'334efade-85a4-4115-9943-9a6dcf434a3b']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'12605a03-0021-4b4a-bbc3-f12507500a4a']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'fd0cc4a7-46fc-45fd-a4ac-dc3e32bc8003']
# [u'CMIP5.output.MOHC.HadGEM2-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b5599022-8861-4586-a126-18c496cdf9e6']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H-CC.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'2ed40bc1-0ae6-4f07-8f6c-0ca60cd87e3d']
# [u'CMIP5.output.CMCC.CMCC-CESM.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a6c1b8c6-ec94-4602-9770-a2d83cb32c1d']
# [u'CMIP5.output.MRI.MRI-CGCM3.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a292f03f-3129-41cb-9c0f-f6064be9f56e']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9dcf0555-d5c5-48d9-889a-99e697a16d4f']
# [u'CMIP5.output.MRI.MRI-ESM1.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd6bd6cf6-a8fa-4bf3-8f1a-7b06cab4efde']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp85', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'44750a34-4f2d-4185-b8eb-e79bfb38b883']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e57e2a83-b646-44e2-befb-45f5cf161e00']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'84829f19-4643-4960-9bdd-132a03ecf535']
# [u'CMIP5.output.MIROC.MIROC-ESM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'08235c7b-d0ae-40e9-8459-29bee00a2fea']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b6a89424-167e-4311-aea0-fd67afa7c12c']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b366f140-6ba5-4d85-ae13-bb6e4dde0b5d']
# [u'CMIP5.output.CCCma.CanESM2.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a1cbffbc-1111-4570-84f2-32dc6607c588']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8362f803-0a0e-4b78-a94e-964152ab31bf']
# [u'CMIP5.output.BNU.BNU-ESM.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a17c85bc-dad8-4caf-8b73-21425e32d08c']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9a0030da-b23e-4433-a366-13fc8d071073']
# [u'CMIP5.output.MIROC.MIROC5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a27fb6be-d1fb-4ee0-a2f0-3b6be2c90bcd']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'42927ecf-c142-4229-befb-7cde60a92761']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'34a29f89-4799-4208-a0ed-c04f58ff97ed']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'973d28ad-b20f-4e0d-996a-03f1049636ec']
# [u'CMIP5.output.MRI.MRI-CGCM3.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'a2206795-1231-494b-816e-1f8b8ea2e34e']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'76c874d6-a848-4ef3-a8d2-ff9c39e3cd20']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8733d89d-9289-40ed-b7cd-262fb70abc74']
# [u'CMIP5.output.MOHC.HadGEM2-ES.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'0511a349-f3a9-460f-8fb0-19b6490bc666']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c43f60ee-421d-4670-ae54-f641456bde3d']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'51ff61de-93eb-416c-a277-b15edb3f2074']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-0.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd1aade14-0bbf-45f3-9a5a-4f4dec778bf6']
# [u'CMIP5.output.CSIRO-BOM.ACCESS1-3.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'9cecc4d4-0886-42a5-9458-f372518fe2d4']
# [u'CMIP5.output.IPSL.IPSL-CM5B-LR.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'2159681c-c5cc-4e36-b082-6b8bb2f486b9']
# [u'CMIP5.output.MIROC.MIROC5.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'6a76767e-6e99-4f86-a00e-c4f085166701']
# [u'CMIP5.output.CMCC.CMCC-CMS.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'903b4b75-9212-4f4b-be90-53160a742bb1']
# [u'CMIP5.output.MOHC.HadCM3.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'1b1b52cf-0d34-4e67-8fbd-d749ca0ecba4']
# [u'CMIP5.output.MIROC.MIROC-ESM.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'06b584a5-93ba-4f80-82e0-c3e675a476b8']
# [u'CMIP5.output.MOHC.HadGEM2-ES.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8c5c43de-6f44-4bb5-9bf9-3c7f9481b431']
# [u'CMIP5.output.CMCC.CMCC-CM.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'999ef2e3-56ec-486f-8698-2e40c5faf3be']
# [u'CMIP5.output.MPI-M.MPI-ESM-P.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'35acac96-5f51-4b53-a546-8c5e3dee5173']
# [u'CMIP5.output.MPI-M.MPI-ESM-MR.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ebcd441c-da92-4011-8371-6cd9c9b1761b']
# [u'CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'89bf35a9-b574-4e05-a14e-84b5dbcf54ff']
# [u'CMIP5.output.CCCma.CanESM2.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'87370ebf-c0fe-491e-b75e-f2c858f90391']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R-CC.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ae3f075b-5bc3-4f7f-8be2-3f02c1fe5e06']
# [u'CMIP5.output.BNU.BNU-ESM.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'7e168a98-4880-416c-92c0-687274884100']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5-2.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b215e0d0-eba3-4cbe-b1e3-c3a14bcf26a1']
# [u'CMIP5.output.MIROC.MIROC4h.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3c0314fa-7aad-4bf2-92bf-7928d23e262a']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2G.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c48beb85-d791-4be3-b2a1-d828c4daea64']
# [u'CMIP5.output.NOAA-GFDL.GFDL-ESM2M.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'3695f30b-0c3b-482a-858f-b40548360f45']
# [u'CMIP5.output.IPSL.IPSL-CM5A-MR.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'813421ed-0e77-4ff9-9f95-c121a3c46bee']
# [u'CMIP5.output.IPSL.IPSL-CM5A-LR.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'd7147eba-8034-47a0-a60e-8fb77f743348']
# [u'CMIP5.output.NOAA-GFDL.GFDL-CM3.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ccd04e35-0aa3-4d8e-8093-ef94d3293ef1']
# [u'CMIP5.output.CNRM-CERFACS.CNRM-CM5.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'b3491584-deb9-4a3a-89d2-f99e810a86f5']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'56837076-9d8b-4036-8a4e-53e4dcdcaccd']
# [u'CMIP5.output.MIROC.MIROC-ESM-CHEM.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'fcabf1bd-2432-4af0-8659-3b28bd7694e9']
# [u'CMIP5.output.NIMR-KMA.HadGEM2-AO.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'cdd9ea13-021a-40cd-9c48-4752660f2ae6']
# [u'CMIP5.output.NASA-GISS.GISS-E2-R.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'ce84558a-ff27-4dde-b0dd-0c2f085d111b']
# [u'CMIP5.output.MOHC.HadGEM2-CC.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'e97032fc-e8da-41be-a392-9b8c7fa109d9']
# [u'CMIP5.output.NASA-GISS.GISS-E2-H-CC.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f945610b-bbbc-4b5f-89f8-1e58e09779bf']
# [u'CMIP5.output.CMCC.CMCC-CESM.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'8537f0d0-b296-42f5-b61b-cf2195b1f1aa']
# [u'CMIP5.output.MRI.MRI-CGCM3.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'f6ed2ea6-65d9-4b3d-b030-6952db3a9daf']
# [u'CMIP5.output.MPI-M.MPI-ESM-LR.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'7e4726b2-9ffd-4e17-848f-3d2749d8eb6b']
# [u'CMIP5.output.MRI.MRI-ESM1.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'c53efe22-9ef8-43a4-ae32-afb7cc439d45']
# [u'CMIP5.output.NSF-DOE-NCAR.CESM1-CAM5.historical', u'monthly', u'atmos', u'Amon', u'r1i1p1', u'version_no', u'sfcWind', u'84631cc1-cc39-4c0f-a9e6-fb42de766be1']

# %%
import csv
output_metadata_filename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.5/CMIP5_sfcWind_time_periods.csv'

with open(output_metadata_filename, 'wb') as csvfile:
    writer = csv.writer(csvfile, delimiter=',', quotechar='|')
    for row in new_rows:
        writer.writerow(row)

# %% [markdown]
# #Step 1. Load the netcdf file and get values of several global attributes.
# import urllib
# import json
# import xarray as xr
# def get_tracking_id(ncfile):
#     nc = xr.open_dataset(ncfile)
#     tracking_id = nc.tracking_id
#     nc.close()
#     return tracking_id
#
# wfile = ds('CMIP5%%mrso%2006-2015%global%/bdd%CESM1-CAM5%Lmon%rcp85%r1i1p1%monthly%land%latest').baseFiles()
# pid=get_tracking_id(wfile)
#
# #Remove 'hdl:' from the start of the PID
#
# if pid[0:4] == 'hdl:':
#     pid = pid[4:]
#
# #Go to the webpage for the PID
# pidurl = 'https://handle-esgf.dkrz.de/lp/handles/'+pid
#
# readurl = urllib.urlopen(pidurl)
# data = json.loads(readurl.read())

# %% [markdown]
# there are two kinds of landing pages, data file or data set. dataset landing pages have the proper version number. if it is a data file landing page, dataset can be reached from there.
#
# try:
#     version_number = data["VERSION_NUMBER"]
# except KeyError:
#     datasetpid = data["URL_ORIGINAL_DATA"][0]["dataset"]
#     if datasetpid[0:4] == 'hdl:':
#         datasetpid = datasetpid[4:]
#     datasetpidurl = 'https://handle-esgf.dkrz.de/lp/handles/'+datasetpid
#     readurl_dataset = urllib.urlopen(datasetpidurl)
#     data_dataset = json.loads(readurl_dataset.read())
#     version_number = data_dataset["VERSION_NUMBER"]

# %% [markdown]
# ### Add baseline

# %%
ens_baseline = cens(ens_baseline_dict)
ens_clim_exp_dict['baseline'] = clim_average(ens_baseline, 'ANM')

# %%
ens_clim_exp_dict['baseline'].keys()
# Out:
# ['HadGEM2-AO',
#  'ACCESS1-0',
#  'ACCESS1-3',
#  'CanESM2',
#  'GISS-E2-R-CC',
#  'BNU-ESM',
#  'IPSL-CM5B-LR',
#  'GFDL-ESM2G',
#  'CMCC-CMS',
#  'MRI-CGCM3',
#  'GFDL-ESM2M',
#  'IPSL-CM5A-MR',
#  'IPSL-CM5A-LR',
#  'GISS-E2-H',
#  'GFDL-CM3',
#  'MIROC-ESM',
#  'CNRM-CM5',
#  'HadGEM2-ES',
#  'CMCC-CM',
#  'MIROC-ESM-CHEM',
#  'MIROC5',
#  'GISS-E2-R',
#  'HadGEM2-CC',
#  'GISS-E2-H-CC',
#  'CMCC-CESM',
#  'MPI-ESM-MR',
#  'CSIRO-Mk3-6-0',
#  'MPI-ESM-LR',
#  'MRI-ESM1',
#  'CESM1-CAM5']

# %% [markdown]
# ## Compute averages for each GWLs

# %%
import csv

GWL_csv = '/home/jservon/Chapter12_IPCC/scripts/ATLAS/warming-levels/CMIP5_Atlas_WarmingLevels.csv'

GWL_dict = dict()
i = 0
with open(GWL_csv) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
    for row in spamreader:
        print row
        model = row[0].split('_')[0]
        print model
        GWL_dict[model] = dict()
        if i==0:
            colnames = row
        j = 0
        for elt in row:
            print elt
            GWL_dict[model][colnames[j]] = row[j]
            j = j + 1
        i = i + 1
# Out:
# ['model_run', '1.5_rcp26', '2_rcp26', '3_rcp26', '4_rcp26', '1.5_rcp45', '2_rcp45', '3_rcp45', '4_rcp45', '1.5_rcp85', '2_rcp85', '3_rcp85', '4_rcp85']
# model
# model_run
# 1.5_rcp26
# 2_rcp26
# 3_rcp26
# 4_rcp26
# 1.5_rcp45
# 2_rcp45
# 3_rcp45
# 4_rcp45
# 1.5_rcp85
# 2_rcp85
# 3_rcp85
# 4_rcp85
# ['ACCESS1-0_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2053', 'NA', 'NA', '2028', '2041', '2061', '2081']
# ACCESS1-0
# ACCESS1-0_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2053
# NA
# NA
# 2028
# 2041
# 2061
# 2081
# ['ACCESS1-3_r1i1p1', '9999', '9999', '9999', '9999', '2039', '2056', 'NA', 'NA', '2031', '2042', '2062', '2082']
# ACCESS1-3
# ACCESS1-3_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2039
# 2056
# NA
# NA
# 2031
# 2042
# 2062
# 2082
# ['bcc-csm1-1-m_r1i1p1', '2009', '2043', 'NA', 'NA', '2010', '2035', 'NA', 'NA', '2007', '2028', '2059', '2085']
# bcc-csm1-1-m
# bcc-csm1-1-m_r1i1p1
# 2009
# 2043
# NA
# NA
# 2010
# 2035
# NA
# NA
# 2007
# 2028
# 2059
# 2085
# ['bcc-csm1-1_r1i1p1', '2022', 'NA', 'NA', 'NA', '2021', '2042', 'NA', 'NA', '2019', '2036', '2059', '2083']
# bcc-csm1-1
# bcc-csm1-1_r1i1p1
# 2022
# NA
# NA
# NA
# 2021
# 2042
# NA
# NA
# 2019
# 2036
# 2059
# 2083
# ['BNU-ESM_r1i1p1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# BNU-ESM
# BNU-ESM_r1i1p1
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ['CanESM2_r1i1p1', '2013', '2032', 'NA', 'NA', '2017', '2031', '2075', 'NA', '2012', '2026', '2049', '2068']
# CanESM2
# CanESM2_r1i1p1
# 2013
# 2032
# NA
# NA
# 2017
# 2031
# 2075
# NA
# 2012
# 2026
# 2049
# 2068
# ['CCSM4_r1i1p1', '2016', 'NA', 'NA', 'NA', '2017', '2039', 'NA', 'NA', '2014', '2030', '2057', '2077']
# CCSM4
# CCSM4_r1i1p1
# 2016
# NA
# NA
# NA
# 2017
# 2039
# NA
# NA
# 2014
# 2030
# 2057
# 2077
# ['CESM1-BGC_r1i1p1', '9999', '9999', '9999', '9999', '2018', '2043', 'NA', 'NA', '2017', '2033', '2058', '2080']
# CESM1-BGC
# CESM1-BGC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2018
# 2043
# NA
# NA
# 2017
# 2033
# 2058
# 2080
# ['CMCC-CMS_r1i1p1', '9999', '9999', '9999', '9999', '2037', '2055', 'NA', 'NA', '2029', '2041', '2061', '2077']
# CMCC-CMS
# CMCC-CMS_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2037
# 2055
# NA
# NA
# 2029
# 2041
# 2061
# 2077
# ['CMCC-CM_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2050', 'NA', 'NA', '2029', '2041', '2060', '2078']
# CMCC-CM
# CMCC-CM_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2050
# NA
# NA
# 2029
# 2041
# 2060
# 2078
# ['CNRM-CM5_r1i1p1', '2042', 'NA', 'NA', 'NA', '2036', '2057', 'NA', 'NA', '2030', '2044', '2067', '2087']
# CNRM-CM5
# CNRM-CM5_r1i1p1
# 2042
# NA
# NA
# NA
# 2036
# 2057
# NA
# NA
# 2030
# 2044
# 2067
# 2087
# ['CSIRO-Mk3-6-0_r1i1p1', '2035', 'NA', 'NA', 'NA', '2034', '2047', 'NA', 'NA', '2034', '2044', '2064', '2082']
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_r1i1p1
# 2035
# NA
# NA
# NA
# 2034
# 2047
# NA
# NA
# 2034
# 2044
# 2064
# 2082
# ['EC-EARTH_r12i1p1', '2023', 'NA', 'NA', 'NA', '2022', '2044', 'NA', 'NA', '2018', '2034', '2060', '2082']
# EC-EARTH
# EC-EARTH_r12i1p1
# 2023
# NA
# NA
# NA
# 2022
# 2044
# NA
# NA
# 2018
# 2034
# 2060
# 2082
# ['EC-EARTH_r3i1p1', '9999', '9999', '9999', '9999', '2022', '2044', 'NA', 'NA', '2020', '2038', '2061', '2081']
# EC-EARTH
# EC-EARTH_r3i1p1
# 9999
# 9999
# 9999
# 9999
# 2022
# 2044
# NA
# NA
# 2020
# 2038
# 2061
# 2081
# ['FGOALS-g2_r1i1p1', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999']
# FGOALS-g2
# FGOALS-g2_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# ['GFDL-CM3_r1i1p1', '2021', '2049', 'NA', 'NA', '9999', '9999', '9999', '9999', '2022', '2034', '2054', '2070']
# GFDL-CM3
# GFDL-CM3_r1i1p1
# 2021
# 2049
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 2022
# 2034
# 2054
# 2070
# ['GFDL-ESM2G_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2050', 'NA', 'NA', 'NA', '2037', '2054', '2080', 'NA']
# GFDL-ESM2G
# GFDL-ESM2G_r1i1p1
# NA
# NA
# NA
# NA
# 2050
# NA
# NA
# NA
# 2037
# 2054
# 2080
# NA
# ['GFDL-ESM2M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2046', 'NA', 'NA', 'NA', '2036', '2051', '2081', 'NA']
# GFDL-ESM2M
# GFDL-ESM2M_r1i1p1
# NA
# NA
# NA
# NA
# 2046
# NA
# NA
# NA
# 2036
# 2051
# 2081
# NA
# ['HadGEM2-CC_r1i1p1', '9999', '9999', '9999', '9999', '2036', '2052', 'NA', 'NA', '2027', '2039', '2056', '2072']
# HadGEM2-CC
# HadGEM2-CC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2036
# 2052
# NA
# NA
# 2027
# 2039
# 2056
# 2072
# ['HadGEM2-ES_r1i1p1', '2023', 'NA', 'NA', 'NA', '2028', '2043', '2078', 'NA', '2023', '2035', '2054', '2071']
# HadGEM2-ES
# HadGEM2-ES_r1i1p1
# 2023
# NA
# NA
# NA
# 2028
# 2043
# 2078
# NA
# 2023
# 2035
# 2054
# 2071
# ['inmcm4_r1i1p1', '9999', '9999', '9999', '9999', '2060', 'NA', 'NA', 'NA', '2044', '2057', '2083', 'NA']
# inmcm4
# inmcm4_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2060
# NA
# NA
# NA
# 2044
# 2057
# 2083
# NA
# ['IPSL-CM5A-LR_r1i1p1', '2009', '2031', 'NA', 'NA', '2013', '2029', '2069', 'NA', '2009', '2025', '2047', '2065']
# IPSL-CM5A-LR
# IPSL-CM5A-LR_r1i1p1
# 2009
# 2031
# NA
# NA
# 2013
# 2029
# 2069
# NA
# 2009
# 2025
# 2047
# 2065
# ['IPSL-CM5A-MR_r1i1p1', '2015', '2046', 'NA', 'NA', '2016', '2032', '2076', 'NA', '2015', '2030', '2050', '2066']
# IPSL-CM5A-MR
# IPSL-CM5A-MR_r1i1p1
# 2015
# 2046
# NA
# NA
# 2016
# 2032
# 2076
# NA
# 2015
# 2030
# 2050
# 2066
# ['IPSL-CM5B-LR_r1i1p1', '9999', '9999', '9999', '9999', '2026', '2048', 'NA', 'NA', '2022', '2037', '2061', '2084']
# IPSL-CM5B-LR
# IPSL-CM5B-LR_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2026
# 2048
# NA
# NA
# 2022
# 2037
# 2061
# 2084
# ['MIROC-ESM-CHEM_r1i1p1', '2018', '2034', 'NA', 'NA', '2022', '2036', '2073', 'NA', '2018', '2030', '2050', '2067']
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_r1i1p1
# 2018
# 2034
# NA
# NA
# 2022
# 2036
# 2073
# NA
# 2018
# 2030
# 2050
# 2067
# ['MIROC-ESM_r1i1p1', '2021', '2040', 'NA', 'NA', '2020', '2033', '2068', 'NA', '2020', '2030', '2052', '2069']
# MIROC-ESM
# MIROC-ESM_r1i1p1
# 2021
# 2040
# NA
# NA
# 2020
# 2033
# 2068
# NA
# 2020
# 2030
# 2052
# 2069
# ['MIROC5_r1i1p1', '2046', 'NA', 'NA', 'NA', '2039', '2071', 'NA', 'NA', '2033', '2048', '2071', 'NA']
# MIROC5
# MIROC5_r1i1p1
# 2046
# NA
# NA
# NA
# 2039
# 2071
# NA
# NA
# 2033
# 2048
# 2071
# NA
# ['MPI-ESM-LR_r1i1p1', '2022', 'NA', 'NA', 'NA', '2022', '2042', 'NA', 'NA', '2017', '2036', '2061', '2081']
# MPI-ESM-LR
# MPI-ESM-LR_r1i1p1
# 2022
# NA
# NA
# NA
# 2022
# 2042
# NA
# NA
# 2017
# 2036
# 2061
# 2081
# ['MPI-ESM-MR_r1i1p1', '2023', 'NA', 'NA', 'NA', '2023', '2045', 'NA', 'NA', '2019', '2038', '2060', '2082']
# MPI-ESM-MR
# MPI-ESM-MR_r1i1p1
# 2023
# NA
# NA
# NA
# 2023
# 2045
# NA
# NA
# 2019
# 2038
# 2060
# 2082
# ['MRI-CGCM3_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2053', '2084', 'NA', 'NA', '2041', '2052', '2076', 'NA']
# MRI-CGCM3
# MRI-CGCM3_r1i1p1
# NA
# NA
# NA
# NA
# 2053
# 2084
# NA
# NA
# 2041
# 2052
# 2076
# NA
# ['NorESM1-M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2039', '2072', 'NA', 'NA', '2032', '2048', '2072', 'NA']
# NorESM1-M
# NorESM1-M_r1i1p1
# NA
# NA
# NA
# NA
# 2039
# 2072
# NA
# NA
# 2032
# 2048
# 2072
# NA

# %%
ens_dict_per_GWL = dict()
list_of_GWLs = ['1.5','2','3','4']
for GWL in list_of_GWLs:
    ens_dict_per_GWL[GWL] = dict()

for scenario in ['26','85']:
    list_of_models = lom_per_exp['rcp'+scenario+'_far']
    for wmodel in list_of_models:
        if wmodel in GWL_dict:
            print 'We have : ', wmodel
            print GWL_dict[wmodel]
            for GWL in list_of_GWLs:
                if scenario=='26': GWL_scenario = GWL+'_rcp26'
                if scenario=='85': GWL_scenario = GWL+'_rcp85'

                # --> file nc
                # --> period
                central_year = GWL_dict[wmodel][GWL_scenario]
                if central_year not in ['NA','9999'] and int(central_year)>2015:
                    start_year = str( int(central_year)-9 )
                    end_year = str( int(central_year)+10 )
                    dat = ds(model = wmodel,
                             experiment='rcp'+scenario,
                             period=start_year+'-'+end_year,
                             variable = 'sfcWind',
                             **req_dict
                             )
                    ens_dict_per_GWL[GWL][wmodel+'_'+scenario] = clim_average(dat, 'ANM')
                    print cfile(ens_dict_per_GWL[GWL][wmodel+'_'+scenario])
        else:
            print 'We dont have GWL info for ',wmodel
# Out:
# We have :  BNU-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': 'NA', '2_rcp45': 'NA', '1.5_rcp85': 'NA', '3_rcp85': 'NA', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': 'NA', '3_rcp26': 'NA', 'model_run': 'BNU-ESM_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  CESM1-CAM5
# We have :  CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/6b/135e5cc20b2e96cf118ee0fc9a8cd218d0858d7e098fa123420acf.nc
# We have :  CSIRO-Mk3-6-0
# {'4_rcp45': 'NA', '1.5_rcp26': '2035', '2_rcp85': '2044', '2_rcp45': '2047', '1.5_rcp85': '2034', '3_rcp85': '2064', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2034', '3_rcp26': 'NA', 'model_run': 'CSIRO-Mk3-6-0_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/10/3ef474ef6bc48dd928dd5cd800351778892778da035093b98bbb66.nc
# We have :  CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/35/df82e1b8eb3c62b3f46ae52aba6d4963f5dbae7becc35691759f01.nc
# We have :  GFDL-CM3
# {'4_rcp45': '9999', '1.5_rcp26': '2021', '2_rcp85': '2034', '2_rcp45': '9999', '1.5_rcp85': '2022', '3_rcp85': '2054', '4_rcp85': '2070', '3_rcp45': '9999', '4_rcp26': 'NA', '1.5_rcp45': '9999', '3_rcp26': 'NA', 'model_run': 'GFDL-CM3_r1i1p1', '2_rcp26': '2049'}
# /data/jservon/climafcache/e9/9130ccc7ec9b2ea16909e8d15d322c09ce677bceaed690bc524a9b.nc
# /data/jservon/climafcache/e2/5f3a8ff07cc63a379655f6ac91960a19228916ea1b863327e85837.nc
# We have :  GFDL-ESM2G
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2054', '2_rcp45': 'NA', '1.5_rcp85': '2037', '3_rcp85': '2080', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2050', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2G_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  GISS-E2-H
# We dont have GWL info for  GISS-E2-R
# We dont have GWL info for  HadGEM2-AO
# We have :  HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/dd/080826fdc5b6237f6c29491e09259b8bfd23d4d6501880f8407a27.nc
# We have :  IPSL-CM5A-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2009', '2_rcp85': '2025', '2_rcp45': '2029', '1.5_rcp85': '2009', '3_rcp85': '2047', '4_rcp85': '2065', '3_rcp45': '2069', '4_rcp26': 'NA', '1.5_rcp45': '2013', '3_rcp26': 'NA', 'model_run': 'IPSL-CM5A-LR_r1i1p1', '2_rcp26': '2031'}
# /data/jservon/climafcache/bd/9affb94664d37397ca7e5d6cdc084c2f460a345b5e5f36b64f069b.nc
# We have :  IPSL-CM5A-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2015', '2_rcp85': '2030', '2_rcp45': '2032', '1.5_rcp85': '2015', '3_rcp85': '2050', '4_rcp85': '2066', '3_rcp45': '2076', '4_rcp26': 'NA', '1.5_rcp45': '2016', '3_rcp26': 'NA', 'model_run': 'IPSL-CM5A-MR_r1i1p1', '2_rcp26': '2046'}
# /data/jservon/climafcache/e0/c934f058a77563791852c1ab703b0a6767b74984bbff0954ade755.nc
# We have :  MIROC-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': '2021', '2_rcp85': '2030', '2_rcp45': '2033', '1.5_rcp85': '2020', '3_rcp85': '2052', '4_rcp85': '2069', '3_rcp45': '2068', '4_rcp26': 'NA', '1.5_rcp45': '2020', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM_r1i1p1', '2_rcp26': '2040'}
# /data/jservon/climafcache/81/39054700d5243d85e4cf5e7dce7e3958781cb4299e430f6344f0a6.nc
# /data/jservon/climafcache/b9/7581421754f2a9a64d9600514d01423cd9a9c69038a22b7184b4e4.nc
# We have :  MIROC-ESM-CHEM
# {'4_rcp45': 'NA', '1.5_rcp26': '2018', '2_rcp85': '2030', '2_rcp45': '2036', '1.5_rcp85': '2018', '3_rcp85': '2050', '4_rcp85': '2067', '3_rcp45': '2073', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM-CHEM_r1i1p1', '2_rcp26': '2034'}
# /data/jservon/climafcache/26/6dc165a2c61999b4653e5847249f462a540cde407ff0bfcda4ec23.nc
# /data/jservon/climafcache/f9/6131e4611547437e7ad81cdb27b4469c01d9f3e76e611a70239a27.nc
# We have :  MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b6/8ab8a42d9f81c92b312c9ed3c9bf2ea06e1aa2511cd99c9781485b.nc
# We have :  MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/82/658e94a1ac204810092a080c063e1df29661dd4a380285a9c9d124.nc
# We have :  MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/e8/3ec89a733d9581d488017df204c3453550eaff38d8baec1f0ff04b.nc
# We have :  MRI-CGCM3
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2052', '2_rcp45': '2084', '1.5_rcp85': '2041', '3_rcp85': '2076', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2053', '3_rcp26': 'NA', 'model_run': 'MRI-CGCM3_r1i1p1', '2_rcp26': 'NA'}
# We have :  ACCESS1-0
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2053', '1.5_rcp85': '2028', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2033', '3_rcp26': '9999', 'model_run': 'ACCESS1-0_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/10/6bda8954ff7aaf2090cde31a1c25e8a167f0eed49199b80d6e8dac.nc
# /data/jservon/climafcache/73/36060fd66929b1ad89aa8adc2c1e6f52238a4db76ac8aa6445b56f.nc
# /data/jservon/climafcache/c0/ea77e2d61da898b9fe00c094c5928cd17f551c199528e38711fd61.nc
# /data/jservon/climafcache/78/705364920cc770ce0cf069291bb62c78148f8d931a21630b6923b3.nc
# We have :  ACCESS1-3
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2042', '2_rcp45': '2056', '1.5_rcp85': '2031', '3_rcp85': '2062', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2039', '3_rcp26': '9999', 'model_run': 'ACCESS1-3_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/58/a1309feba254b1c75cc3abb6946e65b83ad8c83c0e14c47fb1aa5b.nc
# /data/jservon/climafcache/2a/907c9d31bab4efa1453f52386f4e3eb6490d6468960f61b6e694b6.nc
# /data/jservon/climafcache/e5/c292ae0bb4b468bfabdea1987e118572fab3a2badfcb85e2926915.nc
# /data/jservon/climafcache/6d/22ffd9203a32b497f0a3fd82a5101571651ba2822ffbda71445a4e.nc
# We have :  BNU-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': 'NA', '2_rcp45': 'NA', '1.5_rcp85': 'NA', '3_rcp85': 'NA', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': 'NA', '3_rcp26': 'NA', 'model_run': 'BNU-ESM_r1i1p1', '2_rcp26': 'NA'}
# We dont have GWL info for  CESM1-CAM5
# We dont have GWL info for  CMCC-CESM
# We have :  CMCC-CM
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2050', '1.5_rcp85': '2029', '3_rcp85': '2060', '4_rcp85': '2078', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2033', '3_rcp26': '9999', 'model_run': 'CMCC-CM_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/b0/a4f475b57d91b65ecffe28eb5831ced9b52a69a67bbe6435a86f19.nc
# /data/jservon/climafcache/8b/fea35e6ba4631339ef024df8ee9637da3d64a9334195eebc5d629e.nc
# /data/jservon/climafcache/ae/cb50c6777372cb0519a310187282082caf48a59cb40e5734d81d3a.nc
# /data/jservon/climafcache/25/25ea35e328bb156b77fd4202733d5e1c4b4b366ae439b1fb695207.nc
# We have :  CMCC-CMS
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2055', '1.5_rcp85': '2029', '3_rcp85': '2061', '4_rcp85': '2077', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2037', '3_rcp26': '9999', 'model_run': 'CMCC-CMS_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/1e/df004c51735c585ea1172dd33a433aeb25f2166e00be95278e84f2.nc
# /data/jservon/climafcache/9d/673c51a5b28106fe5e5f40bde76aed05fabc1aa297273713dd2ce1.nc
# /data/jservon/climafcache/84/efcdf202071552ec7502a5a77756b915fd021444ec860ec254110a.nc
# /data/jservon/climafcache/9c/611fb4a8ba39285b9acb475c0b578fe11eecb118fd325a68065813.nc
# We have :  CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/1a/81a008d88d26f1b40f82c8c6626941febf40927bb738013799dfd0.nc
# /data/jservon/climafcache/66/f268cb3cad4542be70b6084a6b6b58c6ca8e06270681e5f64c670e.nc
# /data/jservon/climafcache/35/8d316bc0bbce1e38fb2a741913ef74ca1b2e32e6ba87828ac9ef4d.nc
# /data/jservon/climafcache/85/b0e8bf4ed4a0fda527179dfe32f6d4a9fe66126b79f623cdd89255.nc
# We have :  CSIRO-Mk3-6-0
# {'4_rcp45': 'NA', '1.5_rcp26': '2035', '2_rcp85': '2044', '2_rcp45': '2047', '1.5_rcp85': '2034', '3_rcp85': '2064', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2034', '3_rcp26': 'NA', 'model_run': 'CSIRO-Mk3-6-0_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/bb/cfc49b676d312cac86bab80822f7bf99c7c50ae576b6ea4cc15f4f.nc
# /data/jservon/climafcache/e2/3a95309466c6a96cbee8af1cabd4bcf79273d12f089ee01d8af658.nc
# /data/jservon/climafcache/ea/6d2b91cc288a692ea0cedc0e4e42d59aebc40652702f7d3561e834.nc
# /data/jservon/climafcache/38/a2e7d0304f311df32703446b861edb00206c81eec5ffa6c2ef34ff.nc
# We have :  CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/c4/9999b9e7e46e3ad8be621dc93bd87ae1eb8c8df3d0d77db27fb418.nc
# /data/jservon/climafcache/6a/92da480fa7072506d9672838a04ba3c3208af2574ac520d5882c2c.nc
# /data/jservon/climafcache/0c/6f5c3f0ced1865a6b3b54142a0c6d9cae83584b2d6f42171d9d59d.nc
# We have :  GFDL-CM3
# {'4_rcp45': '9999', '1.5_rcp26': '2021', '2_rcp85': '2034', '2_rcp45': '9999', '1.5_rcp85': '2022', '3_rcp85': '2054', '4_rcp85': '2070', '3_rcp45': '9999', '4_rcp26': 'NA', '1.5_rcp45': '9999', '3_rcp26': 'NA', 'model_run': 'GFDL-CM3_r1i1p1', '2_rcp26': '2049'}
# /data/jservon/climafcache/9f/0084ea295a064b886332a56c41cdcc11408031026a9b0281bb2ad6.nc
# /data/jservon/climafcache/ea/68b75e2258eb74949df12143e0b9e761ba11c9cf1bffc2cc955084.nc
# /data/jservon/climafcache/5f/3c98eb71cce4efe5d3edaba3474297e9b451ffd7dc58a40080c32a.nc
# /data/jservon/climafcache/45/ea35345a28b701646a4cb3200b864b9b1df21363d428e7721aafe5.nc
# We have :  GFDL-ESM2G
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2054', '2_rcp45': 'NA', '1.5_rcp85': '2037', '3_rcp85': '2080', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2050', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2G_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/62/0170de79c0efc8ae106e9be681e7821b738374279be7e2121149b8.nc
# /data/jservon/climafcache/b1/af773ec384db7b8be4defc099975cbd704a5c8e50bc1e2ef7ac884.nc
# /data/jservon/climafcache/50/ace1ed6a0a05021c76a527227b80106fc31b06aab7d804ed80384e.nc
# We have :  GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b3/29904781e7aab2f90a3c33125828b13e65e4ff6139dd87cb2150ef.nc
# /data/jservon/climafcache/9b/51ab8edef1f6f67c3372989acafa938bdcca39b9194c1f58eb00d2.nc
# /data/jservon/climafcache/d0/eb64980f02e225d76e8d6e6109be090995b1a32f1aacff1919d14a.nc
# We dont have GWL info for  GISS-E2-H
# We dont have GWL info for  GISS-E2-H-CC
# We dont have GWL info for  GISS-E2-R
# We dont have GWL info for  GISS-E2-R-CC
# We dont have GWL info for  HadGEM2-AO
# We have :  HadGEM2-CC
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2039', '2_rcp45': '2052', '1.5_rcp85': '2027', '3_rcp85': '2056', '4_rcp85': '2072', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2036', '3_rcp26': '9999', 'model_run': 'HadGEM2-CC_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/07/8852b8dcdaff43c1d03f2b128322b73c7833426bec4c8be4627228.nc
# /data/jservon/climafcache/04/72c9df8cce96ebfdd330f7cc3e03648ab8dd86b2fe2b09ccc0fc9d.nc
# /data/jservon/climafcache/93/92976938072a894f3b2d7aa3560f97f8d1fbd6425166c08a83746c.nc
# /data/jservon/climafcache/fd/ec29d44cdd383d11ebfbaaec2a85f32d377577063e31d83be44f1c.nc
# We have :  HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b5/8f86fb11a974dba02dc1ae692ee6c4fa646c86460863d48e63af9e.nc
# /data/jservon/climafcache/9b/ebe502dd81616e3767002279559477b59eafea73e42c415926d924.nc
# /data/jservon/climafcache/cc/f12696605e6385ec03f8cad660239af7b1e3bfd1c97eed29ee5136.nc
# /data/jservon/climafcache/5e/82f9120d97c4cbb54f65abdb06d56b61eccb01dd7cd1fbbd7520c7.nc
# We have :  IPSL-CM5A-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2009', '2_rcp85': '2025', '2_rcp45': '2029', '1.5_rcp85': '2009', '3_rcp85': '2047', '4_rcp85': '2065', '3_rcp45': '2069', '4_rcp26': 'NA', '1.5_rcp45': '2013', '3_rcp26': 'NA', 'model_run': 'IPSL-CM5A-LR_r1i1p1', '2_rcp26': '2031'}
# /data/jservon/climafcache/e7/4c796b5f41cabf5ea5b4ac1a107d5c1011c86b9b4e8fab89291c4a.nc
# /data/jservon/climafcache/8c/031c8c13581419227aee568c88eb9756ec1c19fa65ec5587389720.nc
# /data/jservon/climafcache/8c/b44c4bea63d59a3f6ac420b6504f5e6ac0b75dc7cc906e5f044d9c.nc
# We have :  IPSL-CM5A-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2015', '2_rcp85': '2030', '2_rcp45': '2032', '1.5_rcp85': '2015', '3_rcp85': '2050', '4_rcp85': '2066', '3_rcp45': '2076', '4_rcp26': 'NA', '1.5_rcp45': '2016', '3_rcp26': 'NA', 'model_run': 'IPSL-CM5A-MR_r1i1p1', '2_rcp26': '2046'}
# /data/jservon/climafcache/59/2ab07bdb1db57241231418ebb81af7bfc895f4d560b0874e5538ef.nc
# /data/jservon/climafcache/83/e0587284d1dd188a6ab16c0aad720ec286cde234539c4eea6e0228.nc
# /data/jservon/climafcache/8d/b918222fdb995bec064548429466d8ef193c37927d8eaab638b0a1.nc
# We have :  IPSL-CM5B-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2037', '2_rcp45': '2048', '1.5_rcp85': '2022', '3_rcp85': '2061', '4_rcp85': '2084', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2026', '3_rcp26': '9999', 'model_run': 'IPSL-CM5B-LR_r1i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/8b/1808dd3aae4c2fd7eb46f1b5e0e3aaa3c96dbaa3c845445e5baf25.nc
# /data/jservon/climafcache/c8/11787a76d3b8262281e35f6bdf8714bb52bdd80a00f8f1a0bdc260.nc
# /data/jservon/climafcache/16/b50c2e6d64f8b154e7704638ae528017a10f2a14c5cda6981ef341.nc
# /data/jservon/climafcache/41/86732f5e2978be69285cfd54a1012dc7d59456b4a7da3842343dda.nc
# We have :  MIROC-ESM
# {'4_rcp45': 'NA', '1.5_rcp26': '2021', '2_rcp85': '2030', '2_rcp45': '2033', '1.5_rcp85': '2020', '3_rcp85': '2052', '4_rcp85': '2069', '3_rcp45': '2068', '4_rcp26': 'NA', '1.5_rcp45': '2020', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM_r1i1p1', '2_rcp26': '2040'}
# /data/jservon/climafcache/a7/ca31ab08a4fbf45cd798525584d80a0ec330c42ad595eb823120f7.nc
# /data/jservon/climafcache/28/6e6e4f7b10c80b905690a727a50900d3d2269fae219a5b4aac288a.nc
# /data/jservon/climafcache/04/05944c1b0b0f21e21fa629f3d0e1026850231b158f2fbcc228add7.nc
# /data/jservon/climafcache/b8/11fd3e42d160b54b6f346e82413d45d7da85b74e4352b80c721b99.nc
# We have :  MIROC-ESM-CHEM
# {'4_rcp45': 'NA', '1.5_rcp26': '2018', '2_rcp85': '2030', '2_rcp45': '2036', '1.5_rcp85': '2018', '3_rcp85': '2050', '4_rcp85': '2067', '3_rcp45': '2073', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MIROC-ESM-CHEM_r1i1p1', '2_rcp26': '2034'}
# /data/jservon/climafcache/ba/e15f1fed8781fc5b5aef67c7f490be41a29883957984238eef2aed.nc
# /data/jservon/climafcache/91/85c5a95df06ec793ae6f7e82e129c3c483b91165126192b3b0e95a.nc
# /data/jservon/climafcache/97/6ddd57a09086fed9b53ef13e3295b9c778f4d88dea43cf452aba43.nc
# /data/jservon/climafcache/0d/6c979521cc028a4f5f32a503c0efffbc95254077c8df7c59290f2b.nc
# We have :  MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/1f/e014fad3504b5cb9cc97d0de2fb6f5ff10f5eff20544105842939f.nc
# /data/jservon/climafcache/a4/cbd779dc966f5c2f6b9e482147f7d32fdf0e975801bdca41e008a9.nc
# /data/jservon/climafcache/e4/44f67d57910091556b08704101abb3fd852e1f56325865d1253674.nc
# We have :  MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/ed/483858fc057b758ee4db843a845ff2dc26204fbc4ee6de38526df5.nc
# /data/jservon/climafcache/81/81d7c98cb991821e31c8e1f540dec030410f67a86b05506b33f787.nc
# /data/jservon/climafcache/b9/70a97cd917baf9ce7292e86dd27925301ab5f3802688b8dc63c2ea.nc
# /data/jservon/climafcache/b5/5bfd15477102ad6179f5ea3a033822fb3f6c040df323527026f2f4.nc
# We have :  MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/e0/3d098fbeb156f61b8f5a6e64b6a1478378b6bab7676e29f0e250bb.nc
# /data/jservon/climafcache/c2/59eb8befbde1cb1a9f2d8b7ed6b56153ea762b8030085a77488e67.nc
# /data/jservon/climafcache/8b/dac84d71ae106d57b78f31275637b9d8d94a8391c0adbe16d7bbbd.nc
# /data/jservon/climafcache/96/6f12396f5e7c778d26f9fff4c18b11f7171ec4fc42faee77b39ba5.nc
# We have :  MRI-CGCM3
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2052', '2_rcp45': '2084', '1.5_rcp85': '2041', '3_rcp85': '2076', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2053', '3_rcp26': 'NA', 'model_run': 'MRI-CGCM3_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/19/348a90b1794f11ea481a1089e92a74919dd70568d5ffad1943e172.nc
# /data/jservon/climafcache/f0/f1841c2ff98598712ef97588f11630f796ee9f3ba3f4697e72c7e6.nc
# /data/jservon/climafcache/9a/50c6f075aa1f553fd9eaa848286b990b381b7661a1339e95e77317.nc
# We dont have GWL info for  MRI-ESM1

# %%
ens_dict_per_GWL[GWL]
# Out:
# {'ACCESS1-0_85': time_average(ds('CMIP5%%sfcWind%2072-2091%global%/bdd%ACCESS1-0%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'ACCESS1-3_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%ACCESS1-3%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CMCC-CMS_85': time_average(ds('CMIP5%%sfcWind%2068-2087%global%/bdd%CMCC-CMS%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CMCC-CM_85': time_average(ds('CMIP5%%sfcWind%2069-2088%global%/bdd%CMCC-CM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CNRM-CM5_85': time_average(ds('CMIP5%%sfcWind%2078-2097%global%/bdd%CNRM-CM5%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CSIRO-Mk3-6-0_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%CSIRO-Mk3-6-0%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'CanESM2_85': time_average(ds('CMIP5%%sfcWind%2059-2078%global%/bdd%CanESM2%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'GFDL-CM3_85': time_average(ds('CMIP5%%sfcWind%2061-2080%global%/bdd%GFDL-CM3%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'HadGEM2-CC_85': time_average(ds('CMIP5%%sfcWind%2063-2082%global%/bdd%HadGEM2-CC%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'HadGEM2-ES_85': time_average(ds('CMIP5%%sfcWind%2062-2081%global%/bdd%HadGEM2-ES%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'IPSL-CM5A-LR_85': time_average(ds('CMIP5%%sfcWind%2056-2075%global%/bdd%IPSL-CM5A-LR%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'IPSL-CM5A-MR_85': time_average(ds('CMIP5%%sfcWind%2057-2076%global%/bdd%IPSL-CM5A-MR%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'IPSL-CM5B-LR_85': time_average(ds('CMIP5%%sfcWind%2075-2094%global%/bdd%IPSL-CM5B-LR%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MIROC-ESM-CHEM_85': time_average(ds('CMIP5%%sfcWind%2058-2077%global%/bdd%MIROC-ESM-CHEM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MIROC-ESM_85': time_average(ds('CMIP5%%sfcWind%2060-2079%global%/bdd%MIROC-ESM%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MPI-ESM-LR_85': time_average(ds('CMIP5%%sfcWind%2072-2091%global%/bdd%MPI-ESM-LR%Amon%rcp85%r1i1p1%monthly%*%latest')),
#  'MPI-ESM-MR_85': time_average(ds('CMIP5%%sfcWind%2073-2092%global%/bdd%MPI-ESM-MR%Amon%rcp85%r1i1p1%monthly%*%latest'))}

# %%
import xarray as xr
def get_tracking_id(ncfile):
    nc = xr.open_dataset(ncfile)
    tracking_id = nc.tracking_id
    nc.close()
    return tracking_id


rows = [['DATA_REF_SYNTAX','FREQUENCY','MODELING_REALM','TABLE_ID','ENS_MEMBER','VERSION_NO','VAR_NAME','HANDLE']]
mems_15 = ens_dict_per_GWL['1.5'].keys()
mems_2 = ens_dict_per_GWL['2'].keys()
mems_4 = ens_dict_per_GWL['4'].keys()
all_mems = set(mems_15 + mems_2 + mems_4)
for mem in all_mems:
    tmp_GWL_per_mem = []
    if mem in mems_15:
        tmp_GWL_per_mem.append('1.5')
        GWL = '1.5'
    else:
        tmp_GWL_per_mem.append('none')
    if mem in mems_2:
        tmp_GWL_per_mem.append('2')
        GWL = '2'
    else:
        tmp_GWL_per_mem.append('none')
    if mem in mems_4:
        tmp_GWL_per_mem.append('4')
        GWL = '4'
    else:
        tmp_GWL_per_mem.append('none')
    try:
        dat = ens_dict_per_GWL[GWL][mem]
        print dat.baseFiles()
    except:
        dat = ens_dict_per_GWL[GWL][mem].operands[0]
        print dat.baseFiles()
    ds_kvp = dat.explore('resolve').kvp
    ncfile = dat.baseFiles().split(' ')[0]
    try:
        tracking_id = get_tracking_id(ncfile)
    except:
        tracking_id = ''
    dataset_descr = ['CMIP5.output.'+dat.baseFiles().split('/')[4]+'.'+ds_kvp['model']+'.'+ds_kvp['experiment']]
    dataset_descr.append(ds_kvp['frequency'])
    dataset_descr.append(ds_kvp['realm'])
    dataset_descr.append(ds_kvp['table'])
    dataset_descr.append(ds_kvp['realization'])
    dataset_descr.append('version_no')
    dataset_descr.append(ds_kvp['variable'])
    dataset_descr.append(tracking_id)
    dataset_descr = dataset_descr+tmp_GWL_per_mem
    
    print(dataset_descr)
    rows.append(dataset_descr)
# Out:
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'76c874d6-a848-4ef3-a8d2-ff9c39e3cd20', '1.5', 'none', 'none']
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp85_r1i1p1_200601-230012.nc
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'72ab0ed8-6830-4df5-adaf-a180b615b3b3', 'none', '2', '4']
# /bdd/CMIP5/output/MIROC/MIROC5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC5.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'a27fb6be-d1fb-4ee0-a2f0-3b6be2c90bcd', '1.5', 'none', 'none']
# /bdd/CMIP5/output/MRI/MRI-CGCM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MRI-CGCM3_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MRI.MRI-CGCM3.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'a292f03f-3129-41cb-9c0f-f6064be9f56e', '1.5', '2', 'none']
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'9dcf0555-d5c5-48d9-889a-99e697a16d4f', '1.5', '2', '4']
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_205601-206012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2G/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2G_rcp85_r1i1p1_206101-206512.nc
# ['CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'3fa56cde-e7e9-46c3-b3ba-56626961a819', '1.5', '2', 'none']
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-LR_rcp26_r1i1p1_200601-230012.nc
# ['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'e57e2a83-b646-44e2-befb-45f5cf161e00', 'none', '2', 'none']
# /bdd/CMIP5/output/MPI-M/MPI-ESM-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-MR_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MPI-M.MPI-ESM-MR.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'f2a7759c-c7d4-4fa8-a923-4ed1646c70e4', '1.5', '2', '4']
# /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_205512-208011.nc /bdd/CMIP5/output/MOHC/HadGEM2-CC/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-CC_rcp85_r1i1p1_208012-209912.nc
# ['CMIP5.output.MOHC.HadGEM2-CC.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'6a30fce0-8274-4a85-b8d0-0195ae6215eb', '1.5', '2', '4']
# /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_206101-207012.nc /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_207101-208012.nc /bdd/CMIP5/output/CMCC/CMCC-CM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CM_rcp85_r1i1p1_208101-209012.nc
# ['CMIP5.output.CMCC.CMCC-CM.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'c457e362-a315-449a-99fb-198d3aa67225', '1.5', '2', '4']
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp26_r1i1p1_200601-205512.nc
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'901c127b-5428-46b4-bf3d-7d9b19b1e55f', '1.5', 'none', 'none']
# /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_206001-206912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_207001-207912.nc /bdd/CMIP5/output/CMCC/CMCC-CMS/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CMCC-CMS_rcp85_r1i1p1_208001-208912.nc
# ['CMIP5.output.CMCC.CMCC-CMS.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'e979b0b0-06f2-4532-bd36-4a8253096f0f', '1.5', '2', '4']
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'3fd1f619-478b-49c9-bbea-18c7d788e7e3', 'none', '2', '4']
# /bdd/CMIP5/output/CNRM-CERFACS/CNRM-CM5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CNRM-CM5_rcp85_r1i1p1_205601-210012.nc
# ['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'322135a3-2ea2-4ec5-8e7c-e08371514352', '1.5', '2', '4']
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'8362f803-0a0e-4b78-a94e-964152ab31bf', '1.5', '2', 'none']
# /bdd/CMIP5/output/CCCma/CanESM2/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.CCCma.CanESM2.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'a1cbffbc-1111-4570-84f2-32dc6607c588', 'none', '2', 'none']
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-3_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'ca5dc98d-6185-44d9-9ef6-3a8cc1b187c8', '1.5', '2', '4']
# /bdd/CMIP5/output/MPI-M/MPI-ESM-LR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MPI-ESM-LR_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.MPI-M.MPI-ESM-LR.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'42927ecf-c142-4229-befb-7cde60a92761', '1.5', 'none', 'none']
# /bdd/CMIP5/output/MIROC/MIROC5/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC5_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC5.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'e02f4e70-fe8b-413f-8621-dc726b92ba86', '1.5', '2', 'none']
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC-ESM.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'9cdcb68e-a6a6-4bf5-909e-0117fe713561', '1.5', '2', '4']
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_203601-204012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp26_r1i1p1_205601-206012.nc
# ['CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'3142413b-93cf-45fa-8b05-8f173fdb48a5', '1.5', '2', 'none']
# /bdd/CMIP5/output/IPSL/IPSL-CM5A-MR/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5A-MR_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'51ff61de-93eb-416c-a277-b15edb3f2074', 'none', '2', 'none']
# /bdd/CMIP5/output/MIROC/MIROC-ESM/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC-ESM.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'08235c7b-d0ae-40e9-8459-29bee00a2fea', '1.5', '2', 'none']
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp26_r1i1p1_200601-210012.nc
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'8733d89d-9289-40ed-b7cd-262fb70abc74', '1.5', 'none', 'none']
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_206101-206512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_206601-207012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_207101-207512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-CM3/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-CM3_rcp85_r1i1p1_207601-208012.nc
# ['CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'd80b55bb-8511-414a-9a71-a9ec60d1f951', '1.5', '2', '4']
# /bdd/CMIP5/output/MIROC/MIROC-ESM-CHEM/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_MIROC-ESM-CHEM_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'334efade-85a4-4115-9943-9a6dcf434a3b', '1.5', '2', '4']
# /bdd/CMIP5/output/CSIRO-BOM/ACCESS1-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_ACCESS1-0_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'e7a63ab0-d619-4d26-8db3-5e84ecdbeb57', '1.5', '2', '4']
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_205512-208011.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp85_r1i1p1_208012-209912.nc
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'f7d61bad-3370-4079-8c5a-9c6d7229ec5d', '1.5', '2', '4']
# /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_204101-204512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_204601-205012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_205101-205512.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_205601-206012.nc /bdd/CMIP5/output/NOAA-GFDL/GFDL-ESM2M/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_GFDL-ESM2M_rcp85_r1i1p1_206101-206512.nc
# ['CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'077dc3ea-0f63-4135-8afa-1ef565de0930', '1.5', '2', 'none']
# /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_200512-203011.nc /bdd/CMIP5/output/MOHC/HadGEM2-ES/rcp26/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_HadGEM2-ES_rcp26_r1i1p1_203012-205511.nc
# ['CMIP5.output.MOHC.HadGEM2-ES.rcp26', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'7235c164-9281-4686-b4b2-e90ced472254', '1.5', 'none', 'none']
# /bdd/CMIP5/output/CSIRO-QCCCE/CSIRO-Mk3-6-0/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CSIRO-Mk3-6-0_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'16e32d18-6f23-479d-8e18-57cce93eaf04', '1.5', '2', '4']
# /bdd/CMIP5/output/IPSL/IPSL-CM5B-LR/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_IPSL-CM5B-LR_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'193268df-9374-4767-b13c-764f52cafed6', '1.5', '2', '4']
# /bdd/CMIP5/output/CCCma/CanESM2/rcp85/mon/atmos/Amon/r1i1p1/latest/sfcWind/sfcWind_Amon_CanESM2_rcp85_r1i1p1_200601-210012.nc
# ['CMIP5.output.CCCma.CanESM2.rcp85', 'monthly', 'atmos', 'Amon', 'r1i1p1', 'version_no', 'sfcWind', u'c1dc1007-04ab-4cdd-a53f-a7bc9101e64f', 'none', '2', '4']

# %%
import csv
output_metadata_filename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.5/CMIP5_sfcWind_gwl.csv'

with open(output_metadata_filename, 'wb') as csvfile:
    writer = csv.writer(csvfile, delimiter=',', quotechar='|')
    for row in rows:
        writer.writerow(row)

# %%
rows
# Out:
# [['DATA_REF_SYNTAX',
#   'FREQUENCY',
#   'MODELING_REALM',
#   'TABLE_ID',
#   'ENS_MEMBER',
#   'VERSION_NO',
#   'VAR_NAME',
#   'HANDLE'],
#  [['CMIP5.output.MPI-M.MPI-ESM-MR.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'3e856ae0-0358-48cd-ac4a-2d9084cb915a']],
#  [['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'20cc00de-011a-4a4f-8f21-9a942e4ff3c5']],
#  [['CMIP5.output.MIROC.MIROC5.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'91e2aba8-e4fc-4b67-9930-43b1ff922393']],
#  [['CMIP5.output.MRI.MRI-CGCM3.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'9c0382fb-8298-4de2-b610-e32bba4a06d6']],
#  [['CMIP5.output.MPI-M.MPI-ESM-LR.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'18e79bac-662f-455a-a60f-a725b72c7366']],
#  [['CMIP5.output.NCAR.CCSM4.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'76b9fb38-7b4c-40a3-873d-64e521408eb1']],
#  [['CMIP5.output.NOAA-GFDL.GFDL-ESM2G.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'69303b12-3d22-4139-b16e-daf6fe062b36']],
#  [['CMIP5.output.IPSL.IPSL-CM5A-LR.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'9db3cbe5-47d1-4c5c-9f02-4df6ae6746d4']],
#  [['CMIP5.output.MPI-M.MPI-ESM-MR.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'9c218292-628a-417f-88dd-93841ca756fb']],
#  [['CMIP5.output.MOHC.HadGEM2-CC.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'8bde8b25-1d1b-4b8d-b879-5973a9b1e136']],
#  [['CMIP5.output.CMCC.CMCC-CM.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'88867de6-1a4c-44b2-b7bf-9ca5d774d80f']],
#  [['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'69a836ca-7994-404a-9164-392359dacbd8']],
#  [['CMIP5.output.CMCC.CMCC-CMS.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'bdfed860-b7de-4e83-b56b-2ac39ce6dd51']],
#  [['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'5ccaed60-1563-4150-af7e-f0b4c6633e75']],
#  [['CMIP5.output.NOAA-GFDL.GFDL-ESM2M.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'60915298-6f92-46c7-ab2c-cf16eb323334']],
#  [['CMIP5.output.CNRM-CERFACS.CNRM-CM5.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'29f2780b-a8d4-47b2-92b8-1ccf7e084dca']],
#  [['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'd66f7818-fa71-4c6d-b62f-6c362db30e18']],
#  [['CMIP5.output.NCAR.CCSM4.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'99ac709a-1852-4727-a24d-1ac8853407c1']],
#  [['CMIP5.output.BCC.bcc-csm1-1.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'457a5bfd-7c3b-48d2-be4c-3eb8d7ad63b8']],
#  [['CMIP5.output.CCCma.CanESM2.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'e8235fc8-6805-4030-b59a-1a9a6e131933']],
#  [['CMIP5.output.CSIRO-BOM.ACCESS1-3.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'84d000c7-fba5-4a8b-92b0-32ce4a2c4741']],
#  [['CMIP5.output.MPI-M.MPI-ESM-LR.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'ce304f13-2da8-40f0-be44-6936ec56e920']],
#  [['CMIP5.output.BCC.bcc-csm1-1.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'853e77a6-a0c4-4757-b2db-a9da21cc7b55']],
#  [['CMIP5.output.MIROC.MIROC5.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'2f9e4915-f816-4a50-8dad-a67372a4262a']],
#  [['CMIP5.output.MIROC.MIROC-ESM.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'77b65eba-427a-4a6e-91d8-f0c88b88a367']],
#  [['CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'505d9b17-839c-44eb-9633-e32cc2d07321']],
#  [['CMIP5.output.IPSL.IPSL-CM5A-MR.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'48bf6424-df5d-454c-b1e6-e874e3d022d5']],
#  [['CMIP5.output.BCC.bcc-csm1-1-m.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'dd4b1a95-da0d-4f87-807a-f942449bb006']],
#  [['CMIP5.output.MIROC.MIROC-ESM.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'b488f426-dab0-47c7-87a4-af1aab3fa6b2']],
#  [['CMIP5.output.NSF-DOE-NCAR.CESM1-BGC.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'67e4f6e9-ad6d-4ce9-86e3-0452aed14fa5']],
#  [['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'5d6568c9-d8d4-4285-a057-a07d1c53bde5']],
#  [['CMIP5.output.NOAA-GFDL.GFDL-CM3.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'0df97368-f340-4b53-83e6-3e9c9e9dc402']],
#  [['CMIP5.output.MIROC.MIROC-ESM-CHEM.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'521f80fd-1d3e-4fe7-adaa-b54ebd14d360']],
#  [['CMIP5.output.CSIRO-BOM.ACCESS1-0.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'26a71408-c081-4d9e-ad6b-0663956e62e9']],
#  [['CMIP5.output.INM.inmcm4.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'd8b96482-4e60-46f9-9f75-ffac7a49c079']],
#  [['CMIP5.output.MOHC.HadGEM2-ES.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'dd518bb2-de30-49ea-b779-712be97717f0']],
#  [['CMIP5.output.BCC.bcc-csm1-1-m.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'744a4fef-9a83-4874-abfc-9511d6ffaf85']],
#  [['CMIP5.output.NCC.NorESM1-M.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'66c1d0a7-3a42-4e28-a62b-2e2535bd1fce']],
#  [['CMIP5.output.MOHC.HadGEM2-ES.rcp26',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'b8024c2d-b733-4b9d-8bf8-6a09a8e99980']],
#  [['CMIP5.output.CSIRO-QCCCE.CSIRO-Mk3-6-0.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'55f6d1ca-472f-447e-a0f9-d4edf85c1c36']],
#  [['CMIP5.output.IPSL.IPSL-CM5B-LR.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'00fc7b6b-62fe-4efc-a83d-959f61d8d624']],
#  [['CMIP5.output.CCCma.CanESM2.rcp85',
#    'monthly',
#    'land',
#    'Lmon',
#    'r1i1p1',
#    'version_no',
#    'mrso',
#    u'484a8601-6c70-4464-aaff-610c9a8000d7']]]

# %%
#We dont have GWL info for  GISS-E2-H
#We dont have GWL info for  GISS-E2-R
#We dont have GWL info for  GISS-E2-H-CC
#We dont have GWL info for  GISS-E2-R-CC
#We dont have GWL info for  HadGEM2-AO
#We dont have GWL info for  CMCC-CESM
#We dont have GWL info for  MRI-ESM1
