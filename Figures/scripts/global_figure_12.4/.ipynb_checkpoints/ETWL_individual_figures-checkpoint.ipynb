# %%
import os, numpy
from IPython.display import Image

# %% [markdown]
# ## ESL 2050 RCP85

# %%
rcp = 'RCP85'
horizon = 2050
baseline = '/data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc'
future = '/data/ciles/IPCC/SOD/ESL/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP8.5"'
label = '"(p)"'
trim_figure_base = '/home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_q_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
#print(cmd)
#os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)

Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.png ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py /data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc /data/ciles/IPCC/SOD/ESL/globalTWL_RCP85.nc 2050 RCP85 "2050, RCP8.5" "(p)" /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.png png

# %% [markdown]
# ### Colorbar

# %%
Image('/home/jservon/Chapter12_IPCC/figs/global_figure_12.4/ESL_colorbar.png')

# %% [markdown]
# ## ESL 2100 RCP85

# %%
rcp = 'RCP85'
horizon = 2100
baseline = '/data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc'
future = '/data/ciles/IPCC/SOD/ESL/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP8.5"'
label = '"(q)"'
trim_figure_base = '/home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_r_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
#print(cmd)
#os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)


Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_r_ESL_2100_RCP85-final.png ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py /data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc /data/ciles/IPCC/SOD/ESL/globalTWL_RCP85.nc 2100 RCP85 "2100, RCP8.5" "(q)" /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_r_ESL_2100_RCP85-final.png png

# %% [markdown]
# ## ESL 2100 RCP45

# %%
rcp = 'RCP45'
horizon = 2100
baseline = '/data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc'
future = '/data/ciles/IPCC/SOD/ESL/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP4.5"'
label = '"(r)"'
trim_figure_base = '/home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_p_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
#print(cmd)
#os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)

Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_p_ESL_2100_RCP45-final.png ; python /home/jservon/Chapter12_IPCC/scripts/global_figure_12.4/ETWL_plot.py /data/ciles/IPCC/SOD/ESL/globalTWL_baseline.nc /data/ciles/IPCC/SOD/ESL/globalTWL_RCP45.nc 2100 RCP45 "2100, RCP4.5" "(r)" /home/jservon/Chapter12_IPCC/figs/global_figure_12.4/panel_p_ESL_2100_RCP45-final.png png
