# %%
import os, numpy
from IPython.display import Image

# %%
CWD = os.getcwd()
outdatadir = CWD + '/../../data/Figure_12.4/ETWL'
outfigdir = CWD + '/../../figs/global_figure_12.4'

# %%
plot_script = CWD + '/../../scripts/global_figure_12.4/ETWL_plot.py'

# %% [markdown]
# ## ESL 2050 RCP85

# %%
rcp = 'RCP85'
horizon = 2050
baseline = outdatadir+'/globalTWL_baseline.nc'
future = outdatadir+'/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP8.5"'
label = '"(p)"'
trim_figure_base = outfigdir+'/panel_q_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)

Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.pdf ; python /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../scripts/global_figure_12.4/ETWL_plot.py /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_baseline.nc /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_RCP85.nc 2050 RCP85 "2050, RCP8.5" "(p)" /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.pdf pdf
# rm -f /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.png ; python /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../scripts/global_figure_12.4/ETWL_plot.py /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_baseline.nc /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_RCP85.nc 2050 RCP85 "2050, RCP8.5" "(p)" /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_q_ESL_2050_RCP85-final.png png

# %% [markdown]
# ### Colorbar

# %%
Image(outfigdir+'/ESL_colorbar.png')

# %% [markdown]
# ## ESL 2100 RCP85

# %%
rcp = 'RCP85'
horizon = 2100
baseline = outdatadir+'/globalTWL_baseline.nc'
future = outdatadir+'/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP8.5"'
label = '"(q)"'
trim_figure_base = outfigdir+'/panel_r_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
#print(cmd)
#os.system(cmd)


Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_r_ESL_2100_RCP85-final.pdf ; python /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../scripts/global_figure_12.4/ETWL_plot.py /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_baseline.nc /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_RCP85.nc 2100 RCP85 "2100, RCP8.5" "(q)" /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_r_ESL_2100_RCP85-final.pdf pdf

# %% [markdown]
# ## ESL 2100 RCP45

# %%
rcp = 'RCP45'
horizon = 2100
baseline = outdatadir+'/globalTWL_baseline.nc'
future = outdatadir+'/globalTWL_'+rcp+'.nc'
title = '"'+str(horizon)+', RCP4.5"'
label = '"(r)"'
trim_figure_base = outfigdir+'/panel_p_ESL_'+str(horizon)+'_'+rcp+'-final.'

figformat='pdf'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
print(cmd)
os.system(cmd)


figformat='png'
trim_figure = trim_figure_base + figformat
cmd = 'rm -f '+trim_figure+' ; python '+plot_script+' '+baseline+' '+future+' '+str(horizon)+' '+rcp+' '+title+' '+label+' '+trim_figure+' '+figformat
#print(cmd)
#os.system(cmd)

Image(trim_figure)
# Out:
# rm -f /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_p_ESL_2100_RCP45-final.pdf ; python /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../scripts/global_figure_12.4/ETWL_plot.py /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_baseline.nc /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../data/Figure_12.4/ETWL/globalTWL_RCP45.nc 2100 RCP45 "2100, RCP4.5" "(r)" /home/jservon/Chapter12_IPCC/WG1_github/Chapter-12/Figures/scripts/global_figure_12.4/../../figs/global_figure_12.4/panel_p_ESL_2100_RCP45-final.pdf pdf
