# %% [markdown]
# ## Prepare tx35isimip CORDEX files to compute the averages

# %%
import os, glob
import xarray as xr
from IPython.display import Image
from PIL import Image as PILImage

# %% [markdown]
# ## The input files are provided by Atlas (Maialen Iturbide)
# They have a dimension 'member', which means that all the members of the CMIP6 ensemble are within the same files (for each year and scenario).
#
# We will first split the files by model to work on clearly identified individual model files.

# %%
# -- Function to split a multi-member file in individual files
# -- Uses Xarray
def split_ensemble_file(ensemble_file, output_pattern, variable):
    if not os.path.isdir(os.path.dirname(output_pattern)):
        os.makedirs(os.path.dirname(output_pattern))
    import xarray as xr
    dat = xr.open_dataset(ensemble_file)[variable]
    for member in dat.member:
        member_name = str(member.values)
        print member_name
        outfilename = output_pattern+member_name+'.nc'
        if not os.path.isfile(outfilename):
            print 'Save '+outfilename
            member_dat = dat.loc[:,member_name,:,:]
            member_dat.to_netcdf(outfilename)
        else:
            print outfilename+' already exists'

# %%
variable='tx35isimip'
CORDEX_domains = [
    # -- Africa
    #'AFR',
    # -- AustralAsia
    #'AUS',
    # -- Central America
    #'CAM',
    # -- North America
    #'NAM',
    # -- South America
    #'SAM',
    # -- Asia
    #'EAS',
    #'WAS',
    #'SEA',
    # -- Europe
    'EUR',
    
]
# -- Compute the annual sums
exp_list = [
    #dict(experiment='historical',
    #     years = range(1995,2006)),
    dict(experiment='rcp85',
         years = range(2068,2069)),
    #dict(experiment='rcp26',
    #     years = range(2006,2101))
]
for CORDEX_domain in CORDEX_domains:
    for exp_dict in exp_list:
        years = exp_dict['years']
        experiment = exp_dict['experiment']
        for year in years:
            wfile = '/data/jservon/IPCC/tx35/bias_corrected/CORDEX-'+CORDEX_domain+'_'+experiment+'_'+variable+'/'+CORDEX_domain+'-11_'+experiment+'_'+variable+'_'+str(year)+'.nc4'
            output_pattern = '/data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-'+CORDEX_domain+'_'+experiment+'_'+variable+'_'+str(year)+'_'
            split_ensemble_file(wfile, output_pattern, variable)
#
# Out:
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_DMI-HIRHAM5_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_DMI-HIRHAM5_v2.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2.nc already exists
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_DMI-HIRHAM5_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_DMI-HIRHAM5_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1.nc already exists
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1.nc already exists
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2.nc already exists
# IPSL-IPSL-CM5A-MR_r1i1p1_DMI-HIRHAM5_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_IPSL-IPSL-CM5A-MR_r1i1p1_DMI-HIRHAM5_v1.nc already exists
# IPSL-IPSL-CM5A-MR_r1i1p1_GERICS-REMO2015_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_IPSL-IPSL-CM5A-MR_r1i1p1_GERICS-REMO2015_v1.nc already exists
# IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1.nc already exists
# IPSL-IPSL-CM5A-MR_r1i1p1_KNMI-RACMO22E_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_IPSL-IPSL-CM5A-MR_r1i1p1_KNMI-RACMO22E_v1.nc already exists
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_CNRM-ALADIN63_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_CNRM-ALADIN63_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1.nc already exists
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_CNRM-ALADIN63_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_CNRM-ALADIN63_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1.nc already exists
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a.nc already exists
# MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1.nc already exists
# MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# Save /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1.nc
# NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3.nc already exists
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1.nc already exists
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-EUR_rcp85_tx35isimip_2068_NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1.nc already exists

# %%
# !ls /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_*
# Out:
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2006.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2007.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2008.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2009.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2010.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2011.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2012.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2013.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2014.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2015.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2016.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2017.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2018.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2019.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2020.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2021.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2022.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2023.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2024.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2025.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2026.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2027.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2028.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2029.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2030.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2031.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2032.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2033.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2034.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2035.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2036.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2037.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2038.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2039.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2040.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2041.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2042.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2043.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2044.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2045.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2046.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2047.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2048.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2049.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2050.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2051.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2052.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2053.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2054.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2055.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2056.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2057.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2058.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2059.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2060.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2061.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2062.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2063.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2064.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2065.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2066.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2067.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2068.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2069.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2070.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2071.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2072.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2073.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2074.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2075.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2076.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2077.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2078.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2079.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2080.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2081.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2082.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2083.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2084.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2085.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2086.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2087.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2088.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2089.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2090.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2091.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2092.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2093.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2094.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2095.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2096.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2097.nc4
# /data/jservon/IPCC/tx35/bias_corrected/CORDEX-EAS_rcp85_tx35isimip/EAS-22_rcp85_tx35isimip_2098.nc4
