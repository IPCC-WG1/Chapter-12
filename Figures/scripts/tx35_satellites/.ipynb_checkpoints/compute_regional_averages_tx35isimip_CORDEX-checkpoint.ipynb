# %%
import regionmask
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import json
import glob

from climaf.api import *

clog('critical')
pattern = '/data/jservon/IPCC/tx35/bias_corrected/CORDEX_individual_models/CORDEX-${CORDEX_domain}_${experiment}_${variable}_${period}_${member}.nc'
cproject('tx_individual_models_cordex_ch12','CORDEX_domain','experiment','period','member',('variable','tx35isimip'), ensemble=['member'], separator='%')
dataloc(project='tx_individual_models_cordex_ch12', url=pattern)    

exp_dict_list = dict(
    baseline = dict(experiment='historical',
         period='1995-2005'
        ),
    baseline_ext = dict(experiment='rcp85',
         period='2006-2014'
        ),
    rcp26_mid = dict(experiment='rcp26',
         period='2041-2060'
        ),
    rcp26_far = dict(experiment='rcp26',
         period='2081-2100'
        ),
    rcp85_mid = dict(experiment='rcp85',
         period='2041-2060'
        ),
    rcp85_far = dict(experiment='rcp85',
         period='2081-2100'
        )  
)

AR6regions_by_CORDEX_domain = dict(
    AUS = ['NAU','CAU','EAU','SAU','NZ'],
    SEA = ['SEA'],
    WAS = ['ARP','SAS','WCA'],#,'TIB'],
    EAS = ['TIB','ECA','EAS'],#'SAS'
    CAM = ['NSA','SCA','CAR'],
    SAM = ['NWS','NSA','SAM','NES','SWS','SES','SSA'],
    NAM = ['NWN','NEN','WNA','CNA','ENA','NCA'],#,'GAP'],
    EUR = ['MED','WCE','NEU'],
    AFR = ['WAF','SAH','CAF','WSAF','ESAF','MDG','SEAF','NEAF','ARP']
)


CORDEX_domains = AR6regions_by_CORDEX_domain.keys()

all_CORDEX_domains_ens_exp_dict = dict()

for CORDEX_domain in CORDEX_domains:

    ens_exp_dict = dict()
    lom_per_exp = dict()
    for exp in exp_dict_list:
        print exp

        experiment = exp_dict_list[exp]['experiment']
        period = exp_dict_list[exp]['period']

        req = ds(experiment=experiment,
                 CORDEX_domain = CORDEX_domain,
                 period=period,
                 member='*',
                 project='tx_individual_models_cordex_ch12')
        try:
            ens_exp = req.explore('ensemble')
            #
            # -- Climatologies
            clim_exp      = clim_average(ens_exp, 'ANM')

            lom_per_exp[exp] = clim_exp.keys()

            # -- Changes = Scenario minus baselines
            ens_exp_dict[exp] = clim_exp
        except:
            lom_per_exp[exp] = []
            # -- Changes = Scenario minus baselines
            ens_exp_dict[exp] = dict()
            

    lom_baseline     = lom_per_exp['baseline']
    lom_baseline_ext = lom_per_exp['baseline_ext']
    print 'Models not in both sets:'
    print set(lom_baseline) ^ set(lom_baseline_ext)
    print 'Models in common:'
    common_lom_baseline = list( set(lom_baseline) & set(lom_baseline_ext) )
    print common_lom_baseline



    req_dict = dict(project='tx_individual_models_cordex_ch12')
    wreq_dict = req_dict.copy()
    wreq_dict.update(exp_dict_list['baseline'])
    ens_baseline_hist = eds(member=common_lom_baseline,
                            CORDEX_domain = CORDEX_domain,
                            **wreq_dict
                           )

    wreq_dict = req_dict.copy()
    wreq_dict.update(exp_dict_list['baseline_ext'])
    ens_baseline_ext = eds(member=common_lom_baseline,
                           CORDEX_domain = CORDEX_domain,
                           **wreq_dict
                          )
    ens_baseline_dict = dict()
    for mem in ens_baseline_hist:
        ens_baseline_dict[mem] = ccdo2(regrid(ens_baseline_hist[mem], ens_baseline_ext[mem], option='remapnn'),
                                       ens_baseline_ext[mem],
                                       operator='cat')

    # -- Add to the list of ensembles
    ens_baseline = cens(ens_baseline_dict)
    ens_exp_dict['baseline'] = clim_average(ens_baseline, 'ANM')

    ens_exp_dict.pop('baseline_ext')
    
    all_CORDEX_domains_ens_exp_dict[CORDEX_domain] = ens_exp_dict
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['CNRM-CERFACS-CNRM-CM5_r1i1p1_OURANOS-CRCM5_v1', 'CCCma-CanESM2_r1i1p1_OURANOS-CRCM5_v1'])
# Models in common:
# ['NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1', 'CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-3_v4', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1', 'CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-3_v4', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0', 'NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1', 'MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-3_v4'])
# Models in common:
# ['CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2', 'IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3', 'CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3', 'NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3', 'MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1', 'NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0', 'CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['CNRM-CERFACS-CNRM-CM5_r1i1p1_OURANOS-CRCM5_v1', 'CCCma-CanESM2_r1i1p1_OURANOS-CRCM5_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_UA-WRF_v3-5-1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1'])
# Models in common:
# ['CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1', 'MPI-M-MPI-ESM-LR_r1i1p1_OURANOS-CRCM5_v1', 'ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1', 'MOHC-HadGEM2-ES_r1i1p1_ISU-RegCM4_v4-4-rc8', 'MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1', 'CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_UQAM-CRCM5_v1', 'MOHC-HadGEM2-ES_r1i1p1_NCAR-WRF_v3-5-1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set([])
# Models in common:
# ['CSIRO-BOM-ACCESS1-3_r1i1p1_UNSW-WRF360J_v1', 'CSIRO-BOM-ACCESS1-0_r1i1p1_UNSW-WRF360J_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0', 'CSIRO-BOM-ACCESS1-3_r1i1p1_UNSW-WRF360K_v1', 'NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-HZG-CCLM5-0-15_v1', 'CCCma-CanESM2_r1i1p1_UNSW-WRF360K_v1', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17-CLM3-5_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17-CLM3-5_v1', 'CSIRO-BOM-ACCESS1-0_r1i1p1_UNSW-WRF360K_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-HZG-CCLM5-0-15_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_CLMcom-HZG-CCLM5-0-15_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0', 'CCCma-CanESM2_r1i1p1_UNSW-WRF360J_v1']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['MPI-M-MPI-ESM-MR_r1i1p1_RU-CORE-RegCM4-3_v4', 'MOHC-HadGEM2-ES_r1i1p1_RU-CORE-RegCM4-3_v4'])
# Models in common:
# ['MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0', 'NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'IPSL-IPSL-CM5A-LR_r1i1p1_RU-CORE-RegCM4-3_v4', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-4_v0'])
# Models in common:
# ['CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM5-0-2_v1', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM5-0-2_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-4_v0', 'NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-4_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM5-0-2_v1', 'ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM5-0-2_v1']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set([])
# Models in common:
# ['MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2', 'NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2', 'IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2', 'CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5', 'MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5', 'MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5', 'CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2', 'NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1', 'IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2', 'MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2', 'NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['ICHEC-EC-EARTH_r1i1p1_KNMI-RACMO22T_v1', 'ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22T_v1', 'ICHEC-EC-EARTH_r12i1p1_MPI-CSC-REMO2009_v1', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1'])
# Models in common:
# ['MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2009_v1', 'MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22T_v2', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1', 'NCC-NorESM1-M_r1i1p1_CLMcom-KIT-CCLM5-0-15_v1', 'ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1', 'CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1', 'NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0', 'MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1', 'CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1', 'CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1', 'NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0', 'MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-KIT-CCLM5-0-15_v1', 'NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1', 'IPSL-IPSL-CM5A-LR_r1i1p1_GERICS-REMO2009_v1', 'MIROC-MIROC5_r1i1p1_GERICS-REMO2009_v1', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-3_v4', 'MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-3_v4', 'MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-KIT-CCLM5-0-15_v1']
# baseline_ext
# rcp85_far
# rcp26_far
# baseline
# rcp26_mid
# rcp85_mid
# Models not in both sets:
# set(['CNRM-CERFACS-CNRM-CM5_r1i1p1_DMI-HIRHAM5_v2', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_KNMI-RACMO22E_v1', 'MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2', 'MOHC-HadGEM2-ES_r1i1p1_CNRM-ALADIN63_v1', 'MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2', 'NOAA-GFDL-GFDL-ESM2G_r1i1p1_GERICS-REMO2015_v1', 'NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1'])
# Models in common:
# ['MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a', 'MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1', 'NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_DMI-HIRHAM5_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1', 'ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2', 'MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_GERICS-REMO2015_v1', 'MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2', 'MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1', 'IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1', 'NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1', 'ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1', 'ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1', 'ICHEC-EC-EARTH_r12i1p1_DMI-HIRHAM5_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1', 'MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1', 'ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1', 'NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1', 'NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1', 'ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2', 'MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1', 'NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1', 'ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2', 'NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1', 'CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2', 'ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1', 'MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1', 'NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1', 'MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_CNRM-ALADIN63_v1', 'MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1']

# %%
import csv

GWL_csv = '/home/jservon/Chapter12_IPCC/scripts/ATLAS/warming-levels/CMIP5_Atlas_WarmingLevels.csv'

GWL_dict = dict()
i = 0
with open(GWL_csv) as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
    for row in spamreader:
        print row
        model = row[0].split('_')[0]
        print model
        GWL_dict[model] = dict()
        if i==0:
            colnames = row
        j = 0
        for elt in row:
            print elt
            GWL_dict[model][colnames[j]] = row[j]
            j = j + 1
        i = i + 1
        
#

all_CORDEX_domains_ens_dict_per_GWL = dict()

#for CORDEX_domain in ['EUR']:
for CORDEX_domain in CORDEX_domains:

    ens_dict_per_GWL = dict()
    list_of_GWLs = ['1.5','2','3','4']

    for GWL in list_of_GWLs:
        ens_dict_per_GWL[GWL] = dict()

    req_dict = dict(project='tx_individual_models_cordex_ch12')

    for scenario in ['26','85']:
        list_of_models = all_CORDEX_domains_ens_exp_dict[CORDEX_domain]['rcp'+scenario+'_far'].keys()
        for wmodel_realization in list_of_models:
            wmodel = wmodel_realization.split('_')[0]
            GWL_model = None
            for tmp_GWL_model in GWL_dict:
                if tmp_GWL_model in wmodel:
                    GWL_model = tmp_GWL_model
                    break
                    
            if GWL_model:
                print 'We have : ', wmodel
                print GWL_dict[GWL_model]
                for GWL in list_of_GWLs:
                    if scenario=='26': GWL_scenario = GWL+'_rcp26'
                    if scenario=='85': GWL_scenario = GWL+'_rcp85'

                    # --> file nc
                    # --> period
                    central_year = GWL_dict[GWL_model][GWL_scenario]
                    if central_year not in ['NA','9999'] and float(central_year)>=2024:
                        start_year = str( int(central_year)-9 )
                        end_year = str( int(central_year)+10 )

                        dat = ds(member = wmodel_realization,
                                 CORDEX_domain = CORDEX_domain,
                                 experiment = 'rcp'+scenario,
                                 period=start_year+'-'+end_year,
                                 **req_dict
                                 )
                        ens_dict_per_GWL[GWL][wmodel_realization+'_'+scenario] = clim_average(ccdo(dat, operator='yearsum'), 'ANM')
                        print cfile(ens_dict_per_GWL[GWL][wmodel_realization+'_'+scenario])
            else:
                print 'We dont have GWL info for ',wmodel
    #    
    all_CORDEX_domains_ens_dict_per_GWL[CORDEX_domain] = ens_dict_per_GWL
# Out:
# ['model_run', '1.5_rcp26', '2_rcp26', '3_rcp26', '4_rcp26', '1.5_rcp45', '2_rcp45', '3_rcp45', '4_rcp45', '1.5_rcp85', '2_rcp85', '3_rcp85', '4_rcp85']
# model
# model_run
# 1.5_rcp26
# 2_rcp26
# 3_rcp26
# 4_rcp26
# 1.5_rcp45
# 2_rcp45
# 3_rcp45
# 4_rcp45
# 1.5_rcp85
# 2_rcp85
# 3_rcp85
# 4_rcp85
# ['ACCESS1-0_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2053', 'NA', 'NA', '2028', '2041', '2061', '2081']
# ACCESS1-0
# ACCESS1-0_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2053
# NA
# NA
# 2028
# 2041
# 2061
# 2081
# ['ACCESS1-3_r1i1p1', '9999', '9999', '9999', '9999', '2039', '2056', 'NA', 'NA', '2031', '2042', '2062', '2082']
# ACCESS1-3
# ACCESS1-3_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2039
# 2056
# NA
# NA
# 2031
# 2042
# 2062
# 2082
# ['bcc-csm1-1-m_r1i1p1', '2009', '2043', 'NA', 'NA', '2010', '2035', 'NA', 'NA', '2007', '2028', '2059', '2085']
# bcc-csm1-1-m
# bcc-csm1-1-m_r1i1p1
# 2009
# 2043
# NA
# NA
# 2010
# 2035
# NA
# NA
# 2007
# 2028
# 2059
# 2085
# ['bcc-csm1-1_r1i1p1', '2022', 'NA', 'NA', 'NA', '2021', '2042', 'NA', 'NA', '2019', '2036', '2059', '2083']
# bcc-csm1-1
# bcc-csm1-1_r1i1p1
# 2022
# NA
# NA
# NA
# 2021
# 2042
# NA
# NA
# 2019
# 2036
# 2059
# 2083
# ['BNU-ESM_r1i1p1', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# BNU-ESM
# BNU-ESM_r1i1p1
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# ['CanESM2_r1i1p1', '2013', '2032', 'NA', 'NA', '2017', '2031', '2075', 'NA', '2012', '2026', '2049', '2068']
# CanESM2
# CanESM2_r1i1p1
# 2013
# 2032
# NA
# NA
# 2017
# 2031
# 2075
# NA
# 2012
# 2026
# 2049
# 2068
# ['CCSM4_r1i1p1', '2016', 'NA', 'NA', 'NA', '2017', '2039', 'NA', 'NA', '2014', '2030', '2057', '2077']
# CCSM4
# CCSM4_r1i1p1
# 2016
# NA
# NA
# NA
# 2017
# 2039
# NA
# NA
# 2014
# 2030
# 2057
# 2077
# ['CESM1-BGC_r1i1p1', '9999', '9999', '9999', '9999', '2018', '2043', 'NA', 'NA', '2017', '2033', '2058', '2080']
# CESM1-BGC
# CESM1-BGC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2018
# 2043
# NA
# NA
# 2017
# 2033
# 2058
# 2080
# ['CMCC-CMS_r1i1p1', '9999', '9999', '9999', '9999', '2037', '2055', 'NA', 'NA', '2029', '2041', '2061', '2077']
# CMCC-CMS
# CMCC-CMS_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2037
# 2055
# NA
# NA
# 2029
# 2041
# 2061
# 2077
# ['CMCC-CM_r1i1p1', '9999', '9999', '9999', '9999', '2033', '2050', 'NA', 'NA', '2029', '2041', '2060', '2078']
# CMCC-CM
# CMCC-CM_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2033
# 2050
# NA
# NA
# 2029
# 2041
# 2060
# 2078
# ['CNRM-CM5_r1i1p1', '2042', 'NA', 'NA', 'NA', '2036', '2057', 'NA', 'NA', '2030', '2044', '2067', '2087']
# CNRM-CM5
# CNRM-CM5_r1i1p1
# 2042
# NA
# NA
# NA
# 2036
# 2057
# NA
# NA
# 2030
# 2044
# 2067
# 2087
# ['CSIRO-Mk3-6-0_r1i1p1', '2035', 'NA', 'NA', 'NA', '2034', '2047', 'NA', 'NA', '2034', '2044', '2064', '2082']
# CSIRO-Mk3-6-0
# CSIRO-Mk3-6-0_r1i1p1
# 2035
# NA
# NA
# NA
# 2034
# 2047
# NA
# NA
# 2034
# 2044
# 2064
# 2082
# ['EC-EARTH_r12i1p1', '2023', 'NA', 'NA', 'NA', '2022', '2044', 'NA', 'NA', '2018', '2034', '2060', '2082']
# EC-EARTH
# EC-EARTH_r12i1p1
# 2023
# NA
# NA
# NA
# 2022
# 2044
# NA
# NA
# 2018
# 2034
# 2060
# 2082
# ['EC-EARTH_r3i1p1', '9999', '9999', '9999', '9999', '2022', '2044', 'NA', 'NA', '2020', '2038', '2061', '2081']
# EC-EARTH
# EC-EARTH_r3i1p1
# 9999
# 9999
# 9999
# 9999
# 2022
# 2044
# NA
# NA
# 2020
# 2038
# 2061
# 2081
# ['FGOALS-g2_r1i1p1', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999', '9999']
# FGOALS-g2
# FGOALS-g2_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# 9999
# ['GFDL-CM3_r1i1p1', '2021', '2049', 'NA', 'NA', '9999', '9999', '9999', '9999', '2022', '2034', '2054', '2070']
# GFDL-CM3
# GFDL-CM3_r1i1p1
# 2021
# 2049
# NA
# NA
# 9999
# 9999
# 9999
# 9999
# 2022
# 2034
# 2054
# 2070
# ['GFDL-ESM2G_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2050', 'NA', 'NA', 'NA', '2037', '2054', '2080', 'NA']
# GFDL-ESM2G
# GFDL-ESM2G_r1i1p1
# NA
# NA
# NA
# NA
# 2050
# NA
# NA
# NA
# 2037
# 2054
# 2080
# NA
# ['GFDL-ESM2M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2046', 'NA', 'NA', 'NA', '2036', '2051', '2081', 'NA']
# GFDL-ESM2M
# GFDL-ESM2M_r1i1p1
# NA
# NA
# NA
# NA
# 2046
# NA
# NA
# NA
# 2036
# 2051
# 2081
# NA
# ['HadGEM2-CC_r1i1p1', '9999', '9999', '9999', '9999', '2036', '2052', 'NA', 'NA', '2027', '2039', '2056', '2072']
# HadGEM2-CC
# HadGEM2-CC_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2036
# 2052
# NA
# NA
# 2027
# 2039
# 2056
# 2072
# ['HadGEM2-ES_r1i1p1', '2023', 'NA', 'NA', 'NA', '2028', '2043', '2078', 'NA', '2023', '2035', '2054', '2071']
# HadGEM2-ES
# HadGEM2-ES_r1i1p1
# 2023
# NA
# NA
# NA
# 2028
# 2043
# 2078
# NA
# 2023
# 2035
# 2054
# 2071
# ['inmcm4_r1i1p1', '9999', '9999', '9999', '9999', '2060', 'NA', 'NA', 'NA', '2044', '2057', '2083', 'NA']
# inmcm4
# inmcm4_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2060
# NA
# NA
# NA
# 2044
# 2057
# 2083
# NA
# ['IPSL-CM5A-LR_r1i1p1', '2009', '2031', 'NA', 'NA', '2013', '2029', '2069', 'NA', '2009', '2025', '2047', '2065']
# IPSL-CM5A-LR
# IPSL-CM5A-LR_r1i1p1
# 2009
# 2031
# NA
# NA
# 2013
# 2029
# 2069
# NA
# 2009
# 2025
# 2047
# 2065
# ['IPSL-CM5A-MR_r1i1p1', '2015', '2046', 'NA', 'NA', '2016', '2032', '2076', 'NA', '2015', '2030', '2050', '2066']
# IPSL-CM5A-MR
# IPSL-CM5A-MR_r1i1p1
# 2015
# 2046
# NA
# NA
# 2016
# 2032
# 2076
# NA
# 2015
# 2030
# 2050
# 2066
# ['IPSL-CM5B-LR_r1i1p1', '9999', '9999', '9999', '9999', '2026', '2048', 'NA', 'NA', '2022', '2037', '2061', '2084']
# IPSL-CM5B-LR
# IPSL-CM5B-LR_r1i1p1
# 9999
# 9999
# 9999
# 9999
# 2026
# 2048
# NA
# NA
# 2022
# 2037
# 2061
# 2084
# ['MIROC-ESM-CHEM_r1i1p1', '2018', '2034', 'NA', 'NA', '2022', '2036', '2073', 'NA', '2018', '2030', '2050', '2067']
# MIROC-ESM-CHEM
# MIROC-ESM-CHEM_r1i1p1
# 2018
# 2034
# NA
# NA
# 2022
# 2036
# 2073
# NA
# 2018
# 2030
# 2050
# 2067
# ['MIROC-ESM_r1i1p1', '2021', '2040', 'NA', 'NA', '2020', '2033', '2068', 'NA', '2020', '2030', '2052', '2069']
# MIROC-ESM
# MIROC-ESM_r1i1p1
# 2021
# 2040
# NA
# NA
# 2020
# 2033
# 2068
# NA
# 2020
# 2030
# 2052
# 2069
# ['MIROC5_r1i1p1', '2046', 'NA', 'NA', 'NA', '2039', '2071', 'NA', 'NA', '2033', '2048', '2071', 'NA']
# MIROC5
# MIROC5_r1i1p1
# 2046
# NA
# NA
# NA
# 2039
# 2071
# NA
# NA
# 2033
# 2048
# 2071
# NA
# ['MPI-ESM-LR_r1i1p1', '2022', 'NA', 'NA', 'NA', '2022', '2042', 'NA', 'NA', '2017', '2036', '2061', '2081']
# MPI-ESM-LR
# MPI-ESM-LR_r1i1p1
# 2022
# NA
# NA
# NA
# 2022
# 2042
# NA
# NA
# 2017
# 2036
# 2061
# 2081
# ['MPI-ESM-MR_r1i1p1', '2023', 'NA', 'NA', 'NA', '2023', '2045', 'NA', 'NA', '2019', '2038', '2060', '2082']
# MPI-ESM-MR
# MPI-ESM-MR_r1i1p1
# 2023
# NA
# NA
# NA
# 2023
# 2045
# NA
# NA
# 2019
# 2038
# 2060
# 2082
# ['MRI-CGCM3_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2053', '2084', 'NA', 'NA', '2041', '2052', '2076', 'NA']
# MRI-CGCM3
# MRI-CGCM3_r1i1p1
# NA
# NA
# NA
# NA
# 2053
# 2084
# NA
# NA
# 2041
# 2052
# 2076
# NA
# ['NorESM1-M_r1i1p1', 'NA', 'NA', 'NA', 'NA', '2039', '2072', 'NA', 'NA', '2032', '2048', '2072', 'NA']
# NorESM1-M
# NorESM1-M_r1i1p1
# NA
# NA
# NA
# NA
# 2039
# 2072
# NA
# NA
# 2032
# 2048
# 2072
# NA
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# We have :  NOAA-GFDL-GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MIROC-MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/20/c68dcb8602136e8304cac00ddee16ba50a97047404c03c3785650c.nc
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  NOAA-GFDL-GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/9e/5d60a73f3837379e55d8c3e50439b90ccd7210514f030538346cd2.nc
# /data/jservon/climafcache/b3/78870f38bc35353388f38477b391ed5ac4f5359d9d0f13088e832b.nc
# /data/jservon/climafcache/3f/fa836124de5fc29ba2e489628bb51e35832dfc51f3c91e10d5d492.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26
r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/7f/9f733009d235c77f4104e7d3ab0c4d41542e745f1682ec418d05ef.nc
# /data/jservon/climafcache/f0/b008eac2c842adf7ddf75bfa4b0962789f831cb43a3f2566587d5c.nc
# /data/jservon/climafcache/66/42c386cfbcc4a384388b2a19fb5379e54f5070d3510479b7e71f1a.nc
# We have :  NOAA-GFDL-GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/33/7f8239a26db8bad27e00385b44edb8b8bc520ac6704b2292992455.nc
# /data/jservon/climafcache/53/4c5e16e8e06d8960117503dd05dbafe2b87a85fbd1dcafebaa1b60.nc
# /data/jservon/climafcache/43/11f2ae22664b34a08438b84403cef099072b497d0b364560fb6ea9.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# We have :  MIROC-MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/5e/18f8192c0afd4653caad7c9b55963b5f850bb1da2b24cab019b122.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  CCCma-CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/9f/f73d2276da202e0694dad7ff2575e512e3a96963ad86bfc92af72a.nc
# /data/jservon/climafcache/a5/5c804ea685fe9fc540c5a77588645d4b0bc929c7544a6592dbb719.nc
# /data/jservon/climafcache/45/8827323a14beceee9caf2b2748483198daec8615dbe8b5ceb20d12.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/ac/8a089a3ddad72685de60a8777a236942b05d759d736f1df0504747.nc
# /data/jservon/climafcache/17/71e8b1353e5f5184239263d693fe95095299e2d71bdbc8ef2aed64.nc
# /data/jservon/climafcache/38/2555b5f747fb2387eba2f8f4b3c00f01461019ebdd5eb52531d063.nc
# We have :  CSIRO-QCCCE-CSIRO-Mk3-6-0
# {'4_rcp45': 'NA', '1.5_rcp26': '2035', '2_rcp85': '2044', '2_rcp45': '2047', '1.5_rcp85': '2034', '3_rcp85': '2064', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2034', '3_rcp26': 'NA', 'model_run': 'CSIRO-Mk3-6-0_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/1a/a479879fed47168b5c4315c0f6e724c26548383387c8528b5fa06c.nc
# /data/jservon/climafcache/c6/34f5da0a5011e4b1b847b1076b295f0fd8ffb182b6ed49a42a8a3d.nc
# /data/jservon/climafcache/a4/9b57cef8dc4b8133067055f059d5e4d1561647982519e0a925c8e3.nc
# /data/jservon/climafcache/cd/b25589f8ad1bf80cfb86f379bef71575711da728a8a7cb2b85b33f.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '
r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/aa/e6bb32b65c5fcabc018e4ded1bdc4cfc90c18f1fb4a275e4249b40.nc
# /data/jservon/climafcache/81/68db0a73d75274ce41c44b08e1fb2cbbdd62ac966796df6339f4b6.nc
# /data/jservon/climafcache/e5/0b29b97e0df9fd2202ee4d184edd6528339995026e1f03b4a24525.nc
# We have :  MIROC-MIROC5
# {'4_rcp45': 'NA', '1.5_rcp26': '2046', '2_rcp85': '2048', '2_rcp45': '2071', '1.5_rcp85': '2033', '3_rcp85': '2071', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'MIROC5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/f8/b44fd5dcc1d9a04ca26c505c6ee5aab84351f57135181985169394.nc
# /data/jservon/climafcache/79/b6e7fdf494b7e5566ac77c4513cd4b31b4a7fe54e93fc8d6476542.nc
# /data/jservon/climafcache/89/80c5be0f51699bd4ad66a95046e0fc303fde335d93d12833be341c.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/61/a774f82298ea7f918a0932583153ca2e8fd16e52f7a41dab201b6d.nc
# /data/jservon/climafcache/d2/3ad0e7362df167d1dfe4d74a2b3493e2df0af05616732f8cea36f2.nc
# /data/jservon/climafcache/55/fe8144ac7678498a226d20d9b9983c00cf09df5331689fdf0f0472.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/f4/eb3e5dd1036d8ca38e95fb1bf51c7c3c45279e6d06a66cb918521c.nc
# /data/jservon/climafcache/f6/ad2012d2d67348e980421e25b49fa553f4f079919f2d90cc3085d1.nc
# /data/jservon/climafcache/ce/2e6d9eec7af1a54598f2b1de7545c79281b6d4c1279a02b6a7706e.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/eb/99a2c2407b42573046dda741d645e89c50bb8975be1b964704e777.nc
# /data/jservon/climafcache/cf/ced4d75e250445f80717a55b8d0aada2089baee161016e6e78fe5b.nc
# /data/jservon/climafcache/4a/cea517cb70e152919ed02c246178dce26891a5e363a75fdd48cf39.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/37/e2456aa8f0ad21a4554044f053365a0907a7eeeca3e95e683fb589.nc
# /data/jservon/climafcache/2d/b7dcee32ede4168227d8a82771a0ab3a24c9bebf7becc69623d13a.nc
# /data/jservon/climafcache/cb/d11edd6a75ff45aceed3fe342baea8743e8e0bee1009494324dc9d.nc
# We have :  CCCma-CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
# /data/jservon/climafcache/f8/4a83a8995bccb5ec45cf003716901b05231c97aacb5f027dd91718.nc
# /data/jservon/climafcache/86/964cb0abf400714ed5974145e16a7cf8a319fecbb165a4152d7c24.nc
# /data/jservon/climafcache/cb/b2202de3ddd0d01c8554343b734fc45809b7f139457e83aa49b470.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/7e/778fa6392d13ab265f0975e9a51bf275abec028b6dd2c5d37917f9.nc
# /data/jservon/climafcache/03/75ce19ba77243a5e63438d4063bcd3a87e00fe043a078cc83bc8ac.nc
# /data/jservon/climafcache/43/dcea1455dcd6ad108b5a71c0b47cf5bd8bde783f8ef1053bcfd27c.nc
# We have :  NOAA-GFDL-GFDL-ESM2M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2051', '2_rcp45': 'NA', '1.5_rcp85': '2036', '3_rcp85': '2081', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2046', '3_rcp26': 'NA', 'model_run': 'GFDL-ESM2M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/cf/e7a12dd06ed7ed574861430aaea3bd36f5422b110d13c63e213432.nc
# /data/jservon/climafcache/f3/6e35c73e6ae64d63c1fa6f00f18fcb977c3f4fd315d235475eefb9.nc
# /data/jservon/climafcache/c0/7a17b708c0c77a07a32fb50784f0f4b1a79cc1ef2cc5723f01e39d.nc
# We have :  CCCma-CanESM2
# {'4_rcp45': 'NA', '1.5_rcp26': '2013', '2_rcp85': '2026', '2_rcp45': '2031', '1.5_rcp85': '2012', '3_rcp85': '2049', '4_rcp85': '2068', '3_rcp45': '2075', '4_rcp26': 'NA', '1.5_rcp45': '2017', '3_rcp26': 'NA', 'model_run': 'CanESM2_r1i1p1', '2_rcp26': '2032'}
r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/9e/b8b537bface6a05e1e1e01f53de363435fd26da2178d07f0490d60.nc
# /data/jservon/climafcache/8a/ef09f2d2974d53d3a357fc85ac9d2ff7c75d4f48197161e6e2b9f7.nc
# /data/jservon/climafcache/8f/d07867d24c512c3b8169f6f1dc2b1555900df68ebdd0884e265157.nc
# We have :  MPI-M-MPI-ESM-MR
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2038', '2_rcp45': '2045', '1.5_rcp85': '2019', '3_rcp85': '2060', '4_rcp85': '2082', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2023', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-MR_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# We have :  CSIRO-BOM-ACCESS1-0
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2041', '2_rcp45': '2053', '1.5_rcp85': '2028', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26
r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/df/5972681acd6d988043d2799d7fbe4606ff59d1c238eda1bd8f06c6.nc
# /data/jservon/climafcache/9f/e9795aa359be3447ec01ec3d2ebf528908a7e7a8be97e201eafb56.nc
# /data/jservon/climafcache/90/48bbd1a1962c0bfdbf752ee2957a6d56069fcec0704ac3baf38ab2.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/a5/308f158530df32153600e596f9b532fe4d8e340be88159b65d8376.nc
# /data/jservon/climafcache/d4/7df3d53ffd37de8d898139a028c557c3bfa3d7b9c325fd6757802d.nc
# /data/jservon/climafcache/7e/7223e08a2517c0c115b9e142e4bc54f8a219d90c7e0addfa05d8cb.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/92/c6f9ac0e9d1a6cc3d8c397967d515769a0824b0483a6e27980038d.nc
# /data/jservon/climafcache/01/74fd7a91077ad1a5d87390530c04433c5816c495e58fb99c20a944.nc
# /data/jservon/climafcache/49/ded02477df3f2778be4e461b1cd0c55593f590b77be75a05f45a0e.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/78/810c22dc8520e5a60e206b141ba0116c7633971b8c77a51bf3e4cb.nc
# /data/jservon/climafcache/38/33d0ea216865aa7f7c03c570c6cc553fea56cbc69808773d41c26a.nc
# /data/jservon/climafcache/17/594752321053ee13de5ef5fad27a3f6a87414b4f33e3ffbd5fe9b0.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/f3/aa994eb4f33d0fc12a54aaad241002b9e64aa60671ebd04f561ee1.nc
# /data/jservon/climafcache/5d/a7c7f8e793bc610a9b091655329c62ac6f7d95eef0a42d6029777e.nc
# /data/jservon/climafcache/2c/1b8caa38eae1b3b881aa9af52873e2a1097bd3dc12486f367f35eb.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/a5/a471440f64a99bde49dac82c340867f87546f0e92d67a5a146d85b.nc
# /data/jservon/climafcache/54/222982fda922343f8167a83002ea54c23beb05b8cbacd9992cab88.nc
# /data/jservon/climafcache/9e/73689584006682842cd33fb5f005991185bbac79a0fa27949283e1.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/60/362f3df53ef5f7f5e078f7fe000586b325650d39754ebb7ad7117a.nc
# /data/jservon/climafcache/e0/ed4ddd075661f15288b104a501c9fc1e2bf64dc6f3f342c589de46.nc
# /data/jservon/climafcache/37/21f7894e3e800a5e7e6574f818fee796f4e739865e741345364b92.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/85/b8b7dc4e8deb9f5d0ee46c0bd9e4da5a35cc4c4ebb1258aeca9dd3.nc
# /data/jservon/climafcache/fb/2d5a5b89ed29062109bb6fdd43b0beaf8698e1a6fd17281010df1c.nc
# /data/jservon/climafcache/a4/28db967d8b145d3222d64a6d539b5ffed4160d0381604dac520ec0.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/55/e5be6ace34343cae2aa4209e8e1b880c74f1eecfed0623cbb989c7.nc
# /data/jservon/climafcache/dc/fc8528a4ec982cee345ecc747ca75f058587b0076fb7ae849c43ce.nc
# /data/jservon/climafcache/af/e29820fdd50577c8a32987d3dbb77512d756756c47f22a46b54368.nc
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/91/7eaad85c76cda167ec813a08f47ea9ed12e9592248764869417585.nc
# /data/jservon/climafcache/e3/6565f4edb9d8235182e147431bed646c7c558d91ddb9c6c545547a.nc
# /data/jservon/climafcache/54/f09fc7a45e5c6942ce36b78d58cbe5835e0b3c54ccb02d76f7a6b2.nc
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/a7/e508b851bf562197736c72942c84e85f799b90b74254bc38fdc505.nc
# /data/jservon/climafcache/b2/ec2905ca2f6669447c12055823ae861c233d77765ff4fbaee0483b.nc
# /data/jservon/climafcache/6d/64a05f5d8fbf0e84feb0332c6a7b440f8430c172442738914df3cd.nc
# We have :  MOHC-HadGEM2-ES
# {'4_rcp45': 'NA', '1.5_rcp26': '2023', '2_rcp85': '2035', '2_rcp45': '2043', '1.5_rcp85': '2023', '3_rcp85': '2054', '4_rcp85': '2071', '3_rcp45': '2078', '4_rcp26': 'NA', '1.5_rcp45': '2028', '3_rcp26': 'NA', 'model_run': 'HadGEM2-ES_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/ce/303ac05abb121b7a1186b207cd6e716377a189f470318ae5435f11.nc
# /data/jservon/climafcache/61/d8f249bc0d48c2baacb04f2beaf169e61fba299f22b9767389f67b.nc
# /data/jservon/climafcache/a0/7e968b07df635a7a1a7e7bf6c5215d6407865e7b5e21027cf3369c.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/5d/bf1109d9539fa901877cb1c29a694f69978011fa9542d748a4d184.nc
# /data/jservon/climafcache/a2/e21c820d4a751adf8608752615f5b6207b61b7a32d5ec994e62dd1.nc
# /data/jservon/climafcache/43/129ff9d318acaf048860c0e23af86bf1865a50622e2fcd8cc0f9e5.nc
# We have :  CNRM-CERFACS-CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/90/06e932f96433e7c0ed66b40e4981a43eaa10d4a7c3345d4ec261cf.nc
# /data/jservon/climafcache/12/fc95c9c9495d64674db038d1296b684f5bf6ebfe395766f432ee4b.nc
# /data/jservon/climafcache/0d/114a0e3f4b8fa6755fcc6cb0517b23761379a548b04ac74999a247.nc
# /data/jservon/climafcache/ef/78ed560ae47b5ca666f80b35a3e7a5b0cf94da30c6b37ec54189f7.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/c6/d1e539190902ea540616a3e7344c0c2657618de3b89fa9d9eac89c.nc
# /data/jservon/climafcache/40/0db047351192309d65c8f45fd126acae1b72c5ed7e1db5bb4e56d4.nc
# /data/jservon/climafcache/19/bae392c26049abe255b663689614ab462c001d3ac5b98a6fb5682e.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/3d/5d912666db30de7def6a361877109c0c21a2227ba49c4a688df6b6.nc
# /data/jservon/climafcache/4b/e15318b7d6dfacf097f4532b7f5e6bf66ef86b9a5de22c88731d6a.nc
# /data/jservon/climafcache/a2/b6fe00aab5ffb7face06963d8d48a8d5b35392b955e392ee46bb3c.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/b5/73a02d76d20cd64d04eaf4546babac313b8e38c5beeaf0a01d0aff.nc
# /data/jservon/climafcache/5d/ea0d4959a98b1ada6c49fec16824911f4edc3b3dc5570229dca9bc.nc
# /data/jservon/climafcache/bf/72a4ac1d792b937a9937acfb1bd01bef2380d97f9cc42723a383a8.nc
# We have :  MPI-M-MPI-ESM-LR
# {'4_rcp45': 'NA', '1.5_rcp26': '2022', '2_rcp85': '2036', '2_rcp45': '2042', '1.5_rcp85': '2017', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2022', '3_rcp26': 'NA', 'model_run': 'MPI-ESM-LR_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/99/aabc97d0ca4b64f5bec7548baa22ee82bb2f1e6e58c46e52eaa790.nc
# /data/jservon/climafcache/b8/fb60cf6bca0029b139c63a0199e436fa98246d3331d7595b5b68fe.nc
# /data/jservon/climafcache/85/2b22617e931d8808c1af1fd29b6e43fcd561c8aa772424dd76b190.nc
# We have :  NCC-NorESM1-M
# {'4_rcp45': 'NA', '1.5_rcp26': 'NA', '2_rcp85': '2048', '2_rcp45': '2072', '1.5_rcp85': '2032', '3_rcp85': '2072', '4_rcp85': 'NA', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2039', '3_rcp26': 'NA', 'model_run': 'NorESM1-M_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/60/c59ef9343067902965ab8f3d40d3c8f0f5f94cddb0311f199b40a8.nc
# /data/jservon/climafcache/08/cc41b9d307cc6ac44aa420d49d9c96e3608fefee3bd74b9f035c1a.nc
# /data/jservon/climafcache/24/e0edba72978fc64a95b0235783202e6dcbbefe38e1d38cc48b9f4c.nc
# We have :  CNRM-CERFACS-CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/26/bb5b11e2981dfc21f2c51c49139f6b41ed0e56ebcf909ec884aaa2.nc
# /data/jservon/climafcache/ef/2726c71b38a96251840fad848f01fcf57e20d3eb3de141546f8e89.nc
# /data/jservon/climafcache/bf/b53ffcae8e988889850ca5ad6d254d1db694b95f066d00962a65da.nc
# /data/jservon/climafcache/7a/035d74573f51019ff60e622f98579ecd9eb2fa28bdb04299a4e27f.nc
# We have :  CNRM-CERFACS-CNRM-CM5
# {'4_rcp45': 'NA', '1.5_rcp26': '2042', '2_rcp85': '2044', '2_rcp45': '2057', '1.5_rcp85': '2030', '3_rcp85': '2067', '4_rcp85': '2087', '3_rcp45': 'NA', '4_rcp26': 'NA', '1.5_rcp45': '2036', '3_rcp26': 'NA', 'model_run': 'CNRM-CM5_r1i1p1', '2_rcp26': 'NA'}
# /data/jservon/climafcache/7d/2dd1f2958ad3d4bb80ede1ffe4948d988c2e5735a019cc4dc0113c.nc
# /data/jservon/climafcache/b6/8cef3e3f1b33bd324acd7eb8a107a6c1a66329ae96805c29e2ac96.nc
# /data/jservon/climafcache/77/ac47c5f08a6a820b73c63c044e57eec8a23f92f6011ecd17f381d5.nc
# /data/jservon/climafcache/77/f951003b9bbf6c63b0a5aabf89bf876ed431e2a62d91485cc8de6b.nc
# We have :  ICHEC-EC-EARTH
# {'4_rcp45': 'NA', '1.5_rcp26': '9999', '2_rcp85': '2038', '2_rcp45': '2044', '1.5_rcp85': '2020', '3_rcp85': '2061', '4_rcp85': '2081', '3_rcp45': 'NA', '4_rcp26': '9999', '1.5_rcp45': '2022', '3_rcp26': '9999', 'model_run': 'EC-EARTH_r3i1p1', '2_rcp26': '9999'}
# /data/jservon/climafcache/8e/414befd409174ad624259fa2919f279c5f613ea4fdd04d712bd2fd.nc
# /data/jservon/climafcache/7f/c5a740de7e45daf6c7164bb621ae2384f9ece915a27dc8626fcea9.nc
# /data/jservon/climafcache/b7/fb8d163ef367fb334b7eeef23f5b0d3b3418c97b7c45f7f625df75.nc

# %%
def weighted_mean(da, weights, dim):
    """Reduce da by a weighted mean along some dimension(s).

    Parameters
    ----------
    da : DataArray
        Object over which the weighted reduction operation is applied.    
    weights : DataArray
        An array of weights associated with the values in this Dataset.
    dim : str or sequence of str, optional
        Dimension(s) over which to apply the weighted `mean`.
        
    Returns
    -------
    weighted_mean : DataArray
        New DataArray with weighted mean applied to its data and
        the indicated dimension(s) removed.
    """

    weighted_sum = (da * weights).sum(dim=dim, skipna=True)
    # need to mask weights where data is not valid
    masked_weights = weights.where(da.notnull())
    sum_of_weights = masked_weights.sum(dim=dim, skipna=True)
    valid_weights = sum_of_weights != 0
    sum_of_weights = sum_of_weights.where(valid_weights)

    return weighted_sum / sum_of_weights

#
def average_over_AR6_region(filename, variable, region_name):

    # -- AR6 regions
    #ar6_all = regionmask.defined_regions.ar6.all
    # -- Get the regions
    ar6_land = regionmask.defined_regions.ar6.land

    #ax = ar6_all.plot()
    # -- Get land/sea mask (generic)
    land_110 = regionmask.defined_regions.natural_earth.land_110

    # -- Get data
    ds = xr.open_dataset(filename, decode_times=False)
    dat = ds[variable]
    dat.values = np.array(dat.values, dtype=np.float32)

    # -- Mask the data
    mask_3D = ar6_land.mask_3D(dat) # AR6 mask
    land_mask = land_110.mask_3D(dat) # Land sea mask
    mask_lsm = mask_3D * land_mask.squeeze(drop=True) # Combine the two
    
    # -- Compute weights
    if dat.lat.shape == dat.shape or region_name=='all':
        weights = np.cos(np.deg2rad(dat.lat))
        tmp = weighted_mean(dat, mask_lsm * weights, ("lon", "lat"))
        tmp['abbrevs'] = mask_3D.abbrevs
        return tmp
    else:
        # -- Case dat is has time dim
        if 'time' in dat.dims:
            matlat = np.mean(dat.values, axis=dat.dims.index('time')) * 0
        else:
            matlat = dat.values * 0

        if dat.dims.index('lat')<dat.dims.index('lon'):
            for i in range(0,dat.shape[dat.dims.index('lon')]):
                matlat[:,i] = dat.lat
        else:
            for i in range(0,dat.shape[dat.dims.index('lon')]):
                matlat[i,:] = dat.lat
    
        weights = np.cos(np.deg2rad(matlat))
    
        if isinstance(region_name, list):
            res = list()
            for region in region_name:
                region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region))
                dat_region = dat.where(region_mask)
                weights_region = np.where(region_mask, weights, float("nan"))
                #weights_region = weights.where(region_mask)
                res.append( weighted_mean(dat_region, region_mask*weights_region, ("lon","lat")) )
            return res
        else:
            region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region_name))
            dat_region = dat.where(region_mask)
            weights_region = np.where(region_mask, weights, float("nan"))
            #weights_region = weights.where(region_mask)            
            return weighted_mean(dat_region, region_mask*weights_region, ("lon","lat"))
#


def regions_contained(lon, lat, regions):

    # determine if the longitude needs to be wrapped
    regions_is_180 = regions.lon_180
    grid_is_180 = regionmask.core.utils._is_180(lon.min(), lon.max())

    wrap_lon = not regions_is_180 == grid_is_180

    lon_orig = lon.copy()
    if wrap_lon:
        lon = regionmask.core.utils._wrapAngle(lon, wrap_lon)

    lon = np.asarray(lon).squeeze()
    lat = np.asarray(lat).squeeze()

    if lon.ndim == 1 and lat.ndim == 1:
        poly = shapely.geometry.box(lon.min(), lat.min(), lon.max(), lat.max())

    # convex_hull is not really what we need
    # https://gist.github.com/dwyerk/10561690
    #     elif lon.ndim == 2 and lat.ndim == 2:
    #         # get the convex hull from all points
    #         lonlat = np.stack([lon.ravel(), lat.ravel()], axis=1)
    #         multipoint = shapely.geometry.MultiPoint(lonlat)
    #         poly = multipoint.convex_hull
    else:
        raise ValueError("Cannot currently handle 2D coordinates")

    fully_contained = list()
    for region_poly in regions.polygons:
        res = poly.contains(region_poly)

        fully_contained.append(res)

    return xr.DataArray(
        fully_contained, dims=["region"], coords=dict(region=regions.numbers)
    )

#


regional_averages = dict()
errors = []
for CORDEX_domain in CORDEX_domains:
    
    #regional_averages[CORDEX_domain] = dict()
    
    for ens_CORDEX in [all_CORDEX_domains_ens_exp_dict[CORDEX_domain],
                       all_CORDEX_domains_ens_dict_per_GWL[CORDEX_domain]]:
        
        # -- Loop on experiments / horizons
        for clim_period in ens_CORDEX:
            print clim_period
            if clim_period not in regional_averages:
                regional_averages[clim_period] = dict()
            
            # -- Loop on the members of each ensemble
            for mem in ens_CORDEX[clim_period]:
                #if 'CCCma-CanESM2--UCAN-WRF341I' not in mem:
                print mem
                # -- Compute the averages for each AR6 region thanks to regionmask
                # --> We regrid on a 0.25° grid with conservative regridding
                try:
                    tmp = average_over_AR6_region(
                                cfile(regridn(ens_CORDEX[clim_period][mem], cdogrid='r1440x720', option='remapbil')),
                                'tx35isimip', 'all')
                    region_names = tmp.abbrevs
                    for region_name in AR6regions_by_CORDEX_domain[CORDEX_domain]:
                        print region_name
                        region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
                        if region_name not in regional_averages[clim_period]:
                            regional_averages[clim_period][region_name] = [region_value]
                        else:
                            regional_averages[clim_period][region_name].append(region_value)
                except:
                    print 'An error occured for ',ens_CORDEX[clim_period][mem]
                    errors.append(ens_CORDEX[clim_period][mem])




quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        wdat = dat[~np.isnan(dat)]
        if len(wdat)>=5:
            q10 = np.quantile(wdat, 0.1)
            q50 = np.quantile(wdat, 0.5)
            q90 = np.quantile(wdat, 0.9)
            quantiles_dict[clim_period][region_name] = [q10, q50, q90]
        else:
            quantiles_dict[clim_period][region_name] = [-99999, -99999, -99999]

import json

ensemble = 'CORDEX'
outfilename = '/home/jservon/Chapter12_IPCC/data/Figure_S12.1/'+ensemble+'_tx35isimip_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)
# Out:
# rcp85_mid
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1
# NSA
# SCA
# CAR
# rcp26_mid
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# rcp85_far
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1
# NSA
# SCA
# CAR
# rcp26_far
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# baseline
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-3_v4
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1
# NSA
# SCA
# CAR
# 1.5
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_OURANOS-CRCM5_v1_85
# NSA
# SCA
# CAR
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1_26
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ICTP-RegCM4-7_v0_85
# NSA
# SCA
# CAR
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# 3
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0_85
# NSA
# SCA
# CAR
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NSA
# SCA
# CAR
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1_85
# NSA
# SCA
# CAR
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp85_far
# CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp26_far
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# baseline
# CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 1.5
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3_26
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 3
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 2
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# 4
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_UCAN-WRF341I_v2_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-7_v0_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v3_85
# NWS
# NSA
# SAM
# NES
# SWS
# SES
# SSA
# rcp85_mid
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-MR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_OURANOS-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UA-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# rcp26_mid
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# rcp85_far
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-MR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_OURANOS-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UA-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# rcp26_far
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# baseline
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-MR_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_OURANOS-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_NCAR-WRF_v3-5-1
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# 1.5
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# 3
# MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_OURANOS-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_NCAR-WRF_v3-5-1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_NCAR-WRF_v3-5-1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-MR_r1i1p1_UQAM-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_CCCma-CanRCM4_r2_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_UA-WRF_v3-5-1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_ISU-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# 2
# MPI-M-MPI-ESM-LR_r1i1p1_UQAM-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# CCCma-CanESM2_r1i1p1_UQAM-CRCM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM-LR_r1i1p1_NCAR-RegCM4_v4-4-rc8_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1_85
# NWN
# NEN
# WNA
# CNA
# ENA
# NCA
# MPI-M-MPI-ESM
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-4_v0_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# NCC-NorESM1-M_r1i1p1_ICTP-RegCM4-4_v0_85
# TIB
# ECA
# EAS
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-4_v0_85
# TIB
# ECA
# EAS
# 4
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v1_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-4_v0_85
# TIB
# ECA
# EAS
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM5-0-2_v1_85
# TIB
# ECA
# EAS
# MPI-M-MPI-ESM-MR_r1i1p1_ICTP-RegCM4-4_v0_85
# TIB
# ECA
# EAS
# rcp85_mid
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# rcp26_mid
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# rcp85_far
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# rcp26_far
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# baseline
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1
# ARP
# SAS
# WCA
# 1.5
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0_26
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2_26
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# 3
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# 2
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# MIROC-MIROC5_r1i1p1_ORNL-RegCM4-7_v0_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# NOAA-GFDL-GFDL-ESM2M_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# 4
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# CSIRO-QCCCE-CSIRO-Mk3-6-0_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1_85
# ARP
# SAS
# WCA
# IPSL-IPSL-CM5A-LR_r1i1p1_IITM-RegCM4-4_v5_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MOHC-HadGEM2-ES_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-LR_r1i1p1_GERICS-REMO2015_v1_85
# ARP
# SAS
# WCA
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# ARP
# SAS
# WCA
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# CCCma-CanESM2_r1i1p1_SMHI-RCA4_v2_85
# ARP
# SAS
# WCA
# MPI-M-MPI-ESM-MR_r1i1p1_ORNL-RegCM4-7_v0_85
# ...
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# rcp26_mid
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-LR_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# NOAA-GFDL-GFDL-ESM2G_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# rcp85_far
# CNRM-CERFACS-CNRM-CM5_r1i1p1_DMI-HIRHAM5_v2
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_CNRM-ALADIN63_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_CNRM-ALADIN63_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# rcp26_far
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-LR_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# NOAA-GFDL-GFDL-ESM2G_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_DMI-HIRHAM5_v2
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# baseline
# MPI-M-MPI-ESM-LR_r1i1p1_SMHI-RCA4_v1a
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2
# An error occured for  time_average(ccdo2(regrid(ds('tx_individual_models_cordex_ch12%%tx35isimip%1995-2005%global%EUR%historical%ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2'),option='remapnn'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%ICHEC-EC-EARTH_r3i1p1_DMI-HIRHAM5_v2'),operator='cat'))
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2
# An error occured for  time_average(ccdo2(regrid(ds('tx_individual_models_cordex_ch12%%tx35isimip%1995-2005%global%EUR%historical%CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2'),option='remapnn'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2'),operator='cat'))
# MOHC-HadGEM2-ES_r1i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_CNRM-ALADIN63_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MPI-CSC-REMO2009_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r3i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r2i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-CCLM4-8-17_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_DMI-HIRHAM5_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_IPSL-WRF381P_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_ICTP-RegCM4-6_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_MOHC-HadREM3-GA7-05_v1
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2
# An error occured for  time_average(ccdo2(regrid(ds('tx_individual_models_cordex_ch12%%tx35isimip%1995-2005%global%EUR%historical%CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2'),option='remapnn'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2'),operator='cat'))
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1
# An error occured for  time_average(ccdo2(regrid(ds('tx_individual_models_cordex_ch12%%tx35isimip%1995-2005%global%EUR%historical%ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1'),option='remapnn'),ds('tx_individual_models_cordex_ch12%%tx35isimip%2006-2014%global%EUR%rcp85%ICHEC-EC-EARTH_r12i1p1_SMHI-RCA4_v1'),operator='cat'))
# 1.5
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_KNMI-RACMO22E_v1_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2_26
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_GERICS-REMO2015_v1_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_KNMI-RACMO22E_v2_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN53_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_SMHI-RCA4_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_SMHI-RCA4_v1_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_DMI-HIRHAM5_v2_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CNRM-ALADIN63_v2_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_IPSL-WRF381P_v2_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_CLMcom-CCLM4-8-17_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_DMI-HIRHAM5_v3_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_MOHC-HadREM3-GA7-05_v1_85
# MED
# WCE
# NEU
# CNRM-CERFACS-CNRM-CM5_r1i1p1_GERICS-REMO2015_v2_26
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1_85
# MED
# WCE
# NEU
# 3
# NCC-NorESM1-M_r1i1p1_IPSL-WRF381P_v1_85
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_IPSL-WRF381P_v1_85
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_SMHI-RCA4_v1_85
# MED
# WCE
# NEU
# IPSL-IPSL-CM5A-MR_r1i1p1_KNMI-RACMO22E_v1_85
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_SMHI-RCA4_v1_85
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_ICTP-RegCM4-6_v1_85
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1_KNMI-RACMO22E_v2_85
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_CLMcom-CCLM4-8-17_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CLMcom-ETH-COSMO-crCLIM-v1-1_v1_85
# MED
# WCE
# NEU
# ICHEC-EC-EARTH_r12i1p1_IPSL-WRF381P_v1_85
# MED
# WCE
# NEU
# MPI-M-MPI-ESM-LR_r1i1p1_MOHC-HadREM3-GA7-05_v1_85
# MED
# WCE
# NEU
# NCC-NorESM1-M_r1i1p1_CNRM-ALADIN63_v1_85
# MED
# WCE
# NEU
# MOHC-HadGEM2-ES_r1i1p1