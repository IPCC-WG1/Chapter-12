# %% [markdown]
# # Compute WBGT regional averages for the satellite plots

# %%
import regionmask
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import json
import glob

# %% [markdown]
# ### Import the CliMAF library to do the pretreatments (https://climaf.readthedocs.io/en/master/)

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7_v2/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /usr/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %% [markdown]
# ### Declare CliMAF project to get the data

# %%
#/data/ciles/IPCC/FGD/snow/final/cmip6/time_periods/GFDL-CM4_85_snw100seas_1995_2014_MEAN.1deg.nc
#/data/ciles/IPCC/FGD/snow/final/cmip6/GWLs/GFDL-CM4_85_3.nc
pattern = '/data/ciles/IPCC/FGD/snow/final/cmip6/time_periods/${model}_${experiment}_snw100seas_${clim_period}_MEAN.1deg.nc'
cproject('snw_cmip6_ch12','experiment',('period','fx'), 'model', 'clim_period', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_cmip6_ch12', url=pattern)
pattern_gwl = '/data/ciles/IPCC/FGD/snow/final/cmip6/GWLs/${model}_${GWL}.nc'
cproject('snw_cmip6_GWL_ch12','model',('period','fx'),'GWL',('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_cmip6_GWL_ch12', url=pattern_gwl)
# Out:
# <climaf.dataloc.dataloc instance at 0x2aaf2bd54ab8>

# %%
# -- CMIP5
pattern = '/data/ciles/IPCC/FGD/snow/final/cmip5/time_periods/${model}_${experiment}_snw100seas_${clim_period}_MEAN.2deg.nc'
cproject('snw_cmip5_ch12','experiment',('period','fx'), 'model', 'clim_period', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_cmip5_ch12', url=pattern)
pattern_gwl = '/data/ciles/IPCC/FGD/snow/final/cmip5/GWLs/${model}_${GWL}.nc'
cproject('snw_cmip5_GWL_ch12','model',('period','fx'),'GWL',('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_cmip5_GWL_ch12', url=pattern_gwl)
# Out:
# <climaf.dataloc.dataloc instance at 0x2aaf2d14f878>

# %%
# -- CORDEX
pattern = '/data/ciles/IPCC/FGD/snow/final/NA_CORDEX/time_periods/NAM-22_${model}_${experiment}_snw100seas_${clim_period}_remo22grid.nc'
cproject('snw_NAM-22_cordex_ch12','experiment',('period','fx'),'clim_period','model','thres', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_NAM-22_cordex_ch12', url=pattern) 
pattern_gwl = '/data/ciles/IPCC/FGD/snow/final/NA_CORDEX/GWLs/NAM-22_${model}_GWL${GWL}_snw100seas_remo22grid.nc'
cproject('snw_NAM-22_cordex_GWL_ch12',('period','fx'),'model','GWL', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_NAM-22_cordex_GWL_ch12', url=pattern_gwl)
# Out:
# <climaf.dataloc.dataloc instance at 0x2b4ea5812950>

# %%
def weighted_mean(da, weights, dim):
    """Reduce da by a weighted mean along some dimension(s).

    Parameters
    ----------
    da : DataArray
        Object over which the weighted reduction operation is applied.    
    weights : DataArray
        An array of weights associated with the values in this Dataset.
    dim : str or sequence of str, optional
        Dimension(s) over which to apply the weighted `mean`.
        
    Returns
    -------
    weighted_mean : DataArray
        New DataArray with weighted mean applied to its data and
        the indicated dimension(s) removed.
    """

    weighted_sum = (da * weights).sum(dim=dim, skipna=True)
    # need to mask weights where data is not valid
    masked_weights = weights.where(da.notnull())
    sum_of_weights = masked_weights.sum(dim=dim, skipna=True)
    valid_weights = sum_of_weights != 0
    sum_of_weights = sum_of_weights.where(valid_weights)

    return weighted_sum / sum_of_weights

def average_over_AR6_region(filename, mask_sup30, variable, region_name):

    # -- AR6 regions
    #ar6_all = regionmask.defined_regions.ar6.all
    # -- Get the regions
    ar6_land = regionmask.defined_regions.ar6.land

    #ax = ar6_all.plot()
    # -- Get land/sea mask (generic)
    land_110 = regionmask.defined_regions.natural_earth.land_110

    # -- Get data
    ds = xr.open_dataset(filename, decode_times=False)
    dat = ds[variable]
    dat.values = np.array(dat.values, dtype=np.float32)

    # -- Get the mask of values > 30
    mask_ds = xr.open_dataset(mask_sup30, decode_times=False)
    mask = mask_ds[variable]
    mask.values = np.array(mask.values, dtype=np.float32)
    #
    # -- Mask the data
    dat.values = dat.values * mask.values

    # -- Mask the data
    mask_3D = ar6_land.mask_3D(dat) # AR6 mask
    land_mask = land_110.mask_3D(dat) # Land sea mask
    mask_lsm = mask_3D * land_mask.squeeze(drop=True) # Combine the two

    weights = np.cos(np.deg2rad(dat.lat))
    
    if region_name=='all':
        return weighted_mean(dat, mask_3D * weights, ("lon", "lat"))
    else:
        if isinstance(region_name, list):
            res = list()
            for region in region_name:
                region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region))
                dat_region = dat.where(region_mask)
                weights_region = weights.where(region_mask)
                res.append( weighted_mean(dat_region, region_mask*weights_region, ("lon","lat")) )
                #region_mask_sup30 = region_mask.where(dat_region>30)
                #dat_region_sup30 = dat_region.where(dat_region>30)
                #weights_region_sup30 = weights_region.where(dat_region>30)
                #res.append( weighted_mean(dat_region_sup30, region_mask_sup30*weights_region_sup30, ("lon","lat")) )
            return res
        else:
            region_mask = mask_lsm.isel(region=list(mask_3D.abbrevs).index(region_name))
            dat_region = dat.where(region_mask)
            weights_region = weights.where(region_mask) 
            return weighted_mean(dat_region, region_mask*weights_region, ("lon","lat"))
            #region_mask_sup30 = region_mask.where(dat_region>30)
            #dat_region_sup30 = dat_region.where(dat_region>30)
            #weights_region_sup30 = weights_region.where(dat_region>30)
            #return weighted_mean(dat_region_sup30, region_mask_sup30*weights_region_sup30, ("lon","lat"))
    
def regions_contained(lon, lat, regions):

    # determine if the longitude needs to be wrapped
    regions_is_180 = regions.lon_180
    grid_is_180 = regionmask.core.utils._is_180(lon.min(), lon.max())

    wrap_lon = not regions_is_180 == grid_is_180

    lon_orig = lon.copy()
    if wrap_lon:
        lon = regionmask.core.utils._wrapAngle(lon, wrap_lon)

    lon = np.asarray(lon).squeeze()
    lat = np.asarray(lat).squeeze()

    if lon.ndim == 1 and lat.ndim == 1:
        poly = shapely.geometry.box(lon.min(), lat.min(), lon.max(), lat.max())

    # convex_hull is not really what we need
    # https://gist.github.com/dwyerk/10561690
    #     elif lon.ndim == 2 and lat.ndim == 2:
    #         # get the convex hull from all points
    #         lonlat = np.stack([lon.ravel(), lat.ravel()], axis=1)
    #         multipoint = shapely.geometry.MultiPoint(lonlat)
    #         poly = multipoint.convex_hull
    else:
        raise ValueError("Cannot currently handle 2D coordinates")

    fully_contained = list()
    for region_poly in regions.polygons:
        res = poly.contains(region_poly)

        fully_contained.append(res)

    return xr.DataArray(
        fully_contained, dims=["region"], coords=dict(region=regions.numbers)
    )

if None:
    region_name = "all"
    variable = 'tx35'
    filename = "/data/jservon/IPCC/tx35/individual_models/CMIP6_ssp585_tx35_2100_NorESM2-LM_r1i1p1f1.nc"

    tmp = average_over_AR6_region(filename, variable, region_name)
    tmp

# %% [markdown]
# ### Start with baseline, mid-term, late-term, ssp126 and ssp585

# %%
# -- Faire un mask baseline avec seulement les valeurs >30
# -- appliquer le mask

# %%
exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='85',
         clim_period = '1995_2014'),    
    # -- Mid term
    dict(experiment='85',
         clim_period = '2041_2060'),
    dict(experiment='26',
         clim_period = '2041_2060'),
    # -- Late term
    dict(experiment='85',
         clim_period = '2081_2099'),
    dict(experiment='26',
         clim_period = '2081_2099'),
]

# -- Loop on the scenarios
ens_exp_dict = dict()
for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    clim_period = exp['clim_period']
    
    # -- Create ensemble object for the scenario
    req_exp = ds(project='snw_cmip6_ch12',
                 experiment = experiment,
                 clim_period = clim_period,
                 model = '*',
                )
    ens_exp = req_exp.explore('ensemble')
    
    # -- Climatologies
    ens_exp_dict[experiment+'_'+clim_period] = clim_average(ens_exp, 'ANM')

# %%
# -- Make a mask with baseline to keep only the grid points with more than 30 days
mask_dict = dict()
for mem in ens_exp_dict['85_1995_2014']:
    mask_dict[mem] = ccdo(ens_exp_dict['85_1995_2014'][mem], operator='setctomiss,0 -gtc,30')

# %% [markdown]
# ### Then GWLs (mix ssp126 and ssp585)

# %%
# -- Loop on the scenarios
ens_GWL_dict = dict()
for GWL in ['1.5','2','3','4']:
    #
    req_GWL = ds(project='snw_cmip6_GWL_ch12',
                 GWL = GWL,
                 model = '*',
                )
    GWL_ens = req_GWL.explore('ensemble')
    # -- Climatologies
    ens_GWL_dict[GWL] = GWL_ens

# %%
ens_GWL_dict['1.5'].keys()
# Out:
# ['CanESM5_85',
#  'BCC-CSM2-MR_85',
#  'GFDL-CM4_85',
#  'GFDL-ESM4_85',
#  'HadGEM3-GC31-LL_85',
#  'AWI-CM-1-1-MR_85',
#  'IPSL-CM6A-LR_26',
#  'MIROC6_26',
#  'INM-CM4-8_26',
#  'MIROC-ES2L_85',
#  'IPSL-CM6A-LR_85',
#  'UKESM1-0-LL_26',
#  'MRI-ESM2-0_85',
#  'INM-CM5-0_26',
#  'EC-Earth3_26',
#  'MRI-ESM2-0_26',
#  'NESM3_85',
#  'UKESM1-0-LL_85',
#  'AWI-CM-1-1-MR_26',
#  'CanESM5_26',
#  'INM-CM5-0_85',
#  'EC-Earth3_85',
#  'MIROC-ES2L_26',
#  'MIROC6_85',
#  'NESM3_26',
#  'BCC-CSM2-MR_26',
#  'HadGEM3-GC31-LL_26',
#  'MPI-ESM1-2-LR_85',
#  'MPI-ESM1-2-LR_26',
#  'INM-CM4-8_85']

# %%
ens_exp_dict.keys()
# Out:
# ['85_1995_2014',
#  '26_2081_2099',
#  '85_2081_2099',
#  '85_2041_2060',
#  '26_2041_2060']

# %%
regional_averages = dict()

#NAM_regions = ['NWN','NEN','WNA','CNA','ENA','NCA','CAR']

# -- Loop on experiments / horizons
for ens_exp in ens_exp_dict:
    print ens_exp
    regional_averages[ens_exp] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_exp_dict[ens_exp]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[ens_exp]:
                regional_averages[ens_exp][region_name] = [region_value]
            else:
                regional_averages[ens_exp][region_name].append(region_value)
# Out:
# 85_1995_2014
# MPI-ESM1-2-HR
# GIC
# 52.8858058625
# NWN
# 67.3285404605
# NEN
# 55.1941290922
# WNA
# 49.9043563428
# CNA
# nan
# ENA
# 35.7017013487
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 48.8781656266
# WCE
# 45.2900695801
# EEU
# 49.4056370151
# MED
# 40.0818634033
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 64.2169542348
# WSB
# 62.0150301434
# ESB
# 64.1146286581
# RFE
# 72.5811650239
# WCA
# 62.6009180039
# ECA
# 53.1387890629
# TIB
# 63.4551260565
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM5-0
# GIC
# 108.131693994
# NWN
# 64.6545831941
# NEN
# 59.569179083
# WNA
# 45.9546633172
# CNA
# nan
# ENA
# 52.5980180991
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 69.2221288463
# WCE
# 48.8589639273
# EEU
# 66.8151474507
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 63.2651786309
# WSB
# 57.5331614041
# ESB
# 50.2663456968
# RFE
# 75.6316390505
# WCA
# 57.1985633839
# ECA
# nan
# TIB
# 54.6183218042
# EAS
# 58.5161566075
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# GFDL-CM4
# GIC
# 116.07590913
# NWN
# 74.3537817393
# NEN
# 62.466250186
# WNA
# 67.4825636912
# CNA
# nan
# ENA
# 50.8186749986
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 56.0012792115
# WCE
# 47.8923227711
# EEU
# 51.0673625737
# MED
# 56.8473699347
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 66.207965815
# WSB
# 61.8643669348
# ESB
# 65.9367339225
# RFE
# 75.9821983743
# WCA
# 82.7409860156
# ECA
# nan
# TIB
# 90.3775194295
# EAS
# 41.6223509877
# ARP
# nan
# SAS
# 34.90625
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.97056681
# WAN
# 144.468531951
# EC-Earth3
# GIC
# 142.383973528
# NWN
# 93.7217665459
# NEN
# 69.4753019729
# WNA
# 70.1434940138
# CNA
# 32.3027744293
# ENA
# 51.58829903
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 70.9767105116
# WCE
# 59.4766120909
# EEU
# 60.3956033248
# MED
# 52.4725435509
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 78.3160352932
# WSB
# 65.0994121584
# ESB
# 67.8657262896
# RFE
# 82.8575622341
# WCA
# 70.4243364879
# ECA
# nan
# TIB
# 63.5275176957
# EAS
# 42.1385375783
# ARP
# nan
# SAS
# 32.9591217041
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 148.046701119
# WAN
# 145.22009535
# BCC-CSM2-MR
# GIC
# 143.513922901
# NWN
# 84.9200159847
# NEN
# 80.3065948018
# WNA
# 64.0068966403
# CNA
# 36.9182178425
# ENA
# 48.4273897461
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 69.607682379
# WCE
# 42.9251274019
# EEU
# 59.0919332358
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 81.1235050398
# WSB
# 67.1682218651
# ESB
# 69.6994472776
# RFE
# 86.2895673438
# WCA
# 73.7950080444
# ECA
# nan
# TIB
# 83.1916077667
# EAS
# 42.3417213108
# ARP
# nan
# SAS
# 36.9482156353
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 151.0
# WAN
# 148.060132975
# CanESM5
# GIC
# 75.9700070417
# NWN
# 78.5991033803
# NEN
# 68.4206638135
# WNA
# 52.5829799743
# CNA
# nan
# ENA
# 41.4422745411
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 57.6500705991
# WCE
# 38.7734783421
# EEU
# 54.6023240666
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.7168300047
# WSB
# 64.9000546512
# ESB
# 62.6925770398
# RFE
# 76.3926703733
# WCA
# 68.8318149983
# ECA
# 59.1451406708
# TIB
# 83.2450929636
# EAS
# nan
# ARP
# nan
# SAS
# 60.0499992371
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 41.7870110737
# WAN
# 33.9703162815
# MIROC6
# GIC
# 113.771509358
# NWN
# 66.3033212304
# NEN
# 59.4412408416
# WNA
# 51.1166885992
# CNA
# nan
# ENA
# 45.7094772438
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 57.3482590747
# WCE
# 39.1393247
# EEU
# 58.1416002238
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
#
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 19.8264580813
# WCE
# 6.45544175638
# EEU
# 16.3465447812
# MED
# 22.2675643183
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.5730287448
# WSB
# 28.7569162744
# ESB
# nan
# RFE
# 52.7418318795
# WCA
# 22.502251519
# ECA
# nan
# TIB
# 16.3669537818
# EAS
# 10.6158444881
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.894770565
# WAN
# 150.0
# HadGEM3-GC31-LL
# GIC
# 124.030304508
# NWN
# 57.1454719568
# NEN
# 62.6019918095
# WNA
# 19.1843113669
# CNA
# nan
# ENA
# 19.7476412434
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 36.1984452978
# WCE
# 23.5696133727
# EEU
# 31.0829793292
# MED
# 24.9605261485
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.3210656109
# WSB
# 53.1548129841
# ESB
# 53.1008205905
# RFE
# 75.1464669195
# WCA
# 28.1586191568
# ECA
# nan
# TIB
# 41.0986843109
# EAS
# 11.6263742436
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.0
# WAN
# 148.305015701
# HadGEM3-GC31-MM
# GIC
# 130.331544124
# NWN
# 62.2829916058
# NEN
# 73.8186546868
# WNA
# 36.4406438773
# CNA
# nan
# ENA
# 8.76148212879
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# 13.91198136
# NEU
# 53.1817292336
# WCE
# 18.241881576
# EEU
# 20.3237003198
# MED
# 36.2929744105
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 74.8792912701
# WSB
# 51.5277753191
# ESB
# 70.9824058
# RFE
# 72.9367331693
# WCA
# 45.2206073409
# ECA
# nan
# TIB
# 48.3953048374
# EAS
# 47.7247603708
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 148.111865267
# WAN
# 147.153612002
# MPI-ESM1-2-LR
# GIC
# 59.7734788887
# NWN
# 58.8827927485
# NEN
# 47.728151123
# WNA
# 34.4915873894
# CNA
# nan
# ENA
# 34.5596941088
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 31.8262500942
# WCE
# 11.0526313782
# EEU
# 40.4135636948
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 67.7626709798
# WSB
# 52.9162552009
# ESB
# 67.5350770396
# RFE
# 70.9278403898
# WCA
# 44.5233066238
# ECA
# nan
# TIB
# 54.1845811094
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# MRI-ESM2-0
# GIC
# 129.245464883
# NWN
# 68.1431718382
# NEN
# 67.236948774
# WNA
# 41.6448238827
# CNA
# 36.3775007514
# ENA
# 43.6683264091
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 61.2055000212
# WCE
# 41.9076670571
# EEU
# 55.6455530937
# MED
# 38.8607400258
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 73.514405676
# WSB
# 63.3574897553
# ESB
# 69.1889891346
# RFE
# 76.4238967782
# WCA
# 61.0171900769
# ECA
# 44.9316091408
# TIB
# 71.5291673708
# EAS
# 39.2193960714
# ARP
# nan
# SAS
# 45.600440979
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 151.210525513
# WAN
# 151.210525513
# IPSL-CM6A-LR
# GIC
# 113.70628835
# NWN
# 73.5468025901
# NEN
# 72.3204930757
# WNA
# 54.1305587004
# CNA
# 25.6062452339
# ENA
# 38.4133093902
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 60.7555956657
# WCE
# 27.6050576699
# EEU
# 47.3714473273
# MED
# 39.5207242987
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 73.4263959335
# WSB
# 50.0113955018
# ESB
# 70.7086081019
# RFE
# 74.2799450714
# WCA
# 70.3905424141
# ECA
# 59.8649179076
# TIB
# 105.355287494
# EAS
# 42.7710920356
# ARP
# nan
# SAS
# 27.778459549
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM5-0
# GIC
# 102.739944408
# NWN
# 65.6718646201
# NEN
# 55.435792815
# WNA
# 23.621481701
# CNA
# nan
# ENA
# 42.2571954877
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 52.3671682971
# WCE
# 38.2925157212
# EEU
# 60.3103963325
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 62.5830309528
# WSB
# 59.3808970682
# ESB
# 52.5829872966
# RFE
# 70.7358145305
# WCA
# 49.916068281
# ECA
# nan
# TIB
# 43.8677451631
# EAS
# 32.8193700638
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# EC-Earth3
# GIC
# 137.786707629
# NWN
# 79.0288145039
# NEN
# 67.9793067955
# WNA
# 45.8563251194
# CNA
# 21.8640009562
# ENA
# 37.1072099562
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 57.7528987158
# WCE
# 45.1458227939
# EEU
# 38.4850003788
# MED
# 40.318613053
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 78.1906378147
# WSB
# 61.9386021268
# ESB
# 68.3638273305
# RFE
# 81.3345355245
# WCA
# 57.3042024909
# ECA
# nan
# TIB
# 57.6555869192
# EAS
# 35.2724158808
# ARP
# nan
# SAS
# 25.564786911
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 147.416166084
# WAN
# 141.412153245
# BCC-CSM2-MR
# GIC
# 142.580045573
# NWN
# 69.5395301482
# NEN
# 69.9762680292
# WNA
# 30.3200999925
# CNA
# 31.7862398633
# ENA
# 49.5835080281
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 56.24198243
# WCE
# 38.738616554
# EEU
# 56.9062922688
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 85.8553805165
# WSB
# 60.9613221839
# ESB
# 73.6334330784
# RFE
# 79.8508932645
# WCA
# 67.0783437849
# ECA
# nan
# TIB
# 73.6605131511
# EAS
# 29.0289460004
# ARP
# nan
# SAS
# 25.6618551781
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.977846916
# WAN
# 144.916102571
# CanESM5
# GIC
# 66.6943829209
# NWN
# 62.4629210162
# NEN
# 62.9191466406
# WNA
# 21.0923292674
# CNA
# nan
# ENA
# 17.3758545125
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 26.6723640058
# WCE
# 13.3013589701
# EEU
# 35.5678831609
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 63.8296633762
# WSB
# 50.938935502
# ESB
# 55.3375649766
# RFE
# 60.7200020666
# WCA
# 50.0047809654
# ECA
# 54.1137530254
# TIB
# 38.9980285838
# EAS
# nan
# ARP
# nan
# SAS
# 24.7894744873
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 40.1818316952
# WAN
# 32.9376092682
# MIROC6
# GIC
# 112.233831989
# NWN
# 56.4141165964
# NEN
# 56.5510558427
# WNA
# 26.3974355213
# CNA
# nan
# ENA
# 27.606285254
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 37.9938923281
# WCE
# 31.811715968
# EEU
# 50.7753220118
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 61.286098201
# WSB
# 55.6921843955
# ESB
# 53.8895534992
# RFE
# 68.2956123098
# WCA
# 69.7529313071
# ECA
# 26.2779801398
# TIB
# 53.6296389365
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 132.222047582
# WAN
# 103.597366661
# NESM3
# GIC
# nan
# NWN
# 27.8890337387
# NEN
# nan
# WNA
# 8.32565808296
# CNA
# nan
# ENA
# nan
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# nan
# WCE
# nan
# EEU
# nan
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# nan
# WSB
# nan
# ESB
# nan
# RFE
# nan
# WCA
# nan
# ECA
# nan
# TIB
# 42.7883859735
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM4-8
# GIC
# 98.0202349704
# NWN
# 67.7760100238
# NEN
# 56.9516654383
# WNA
# 23.9146358645
# CNA
# nan
# ENA
# 39.2622494155
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 60.9165394996
# WCE
# 42.1250776435
# EEU
# 66.5402307024
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 65.3413820548
# WSB
# 55.6373454638
# ESB
# 49.6749671308
# RFE
# 64.891895762
# WCA
# 44.8397091519
# ECA
# nan
# TIB
# 43.7444277075
# EAS
# 45.0145333094
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# GFDL-ESM4
# GIC
# 118.9844951
# NWN
# 69.4043242553
# NEN
# 59.6783680493
# WNA
# 36.8054627951
# CNA
# nan
# ENA
# 31.7679747164
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 52.4178699802
# WCE
# 23.4933795966
# EEU
# 40.9183509759
# MED
# 49.023928534
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 63.2229386684
# WSB
# 49.5274758482
# ESB
# 65.4218458042
# RFE
# 63.4964801176
# WCA
# 71.8626846625
# ECA
# 33.1578941345
# TIB
# 68.8570714374
# EAS
# 24.8295744639
# ARP
# nan
# SAS
# 9.80921077728
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.642582468
# WAN
# 146.811036611
# AWI-CM-1-1-MR
# GIC
# 46.5421546565
# NWN
# 51.3956031515
# NEN
# 42.7040102293
# WNA
# 38.4607871331
# CNA
# nan
# ENA
# 25.0316735556
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 38.4397661192
# WCE
# nan
# EEU
# 33.9522668737
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 66.158913205
# WSB
# 44.6769204924
# ESB
# 65.6689036004
# RFE
# 69.0457498122
# WCA
# 53.0111873846
# ECA
# 37.3808260848
# TIB
# 61.8300793714
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 70.9833052355
# WAN
# 117.21311174
# MIROC-ES2L
# GIC
# 118.614585494
# NWN
# 44.4915111192
# NEN
# 50.0150870636
# WNA
# nan
# CNA
# nan
# ENA
# 26.6091694832
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 36.3046014189
# WCE
# 38.2926050706
# EEU
# 58.11368118
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 55.8011552767
# WSB
# 64.4047351817
# ESB
# 41.8999288175
# RFE
# 51.9168288105
# WCA
# 42.7495702771
# ECA
# 44.4210510254
# TIB
# 38.0521554633
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 116.956217578
# WAN
# 73.7752917303
# 85_2081_2099
# MPI-ESM1-2-HR
# GIC
# 33.1884419882
# NWN
# 45.3868772696
# NEN
# 33.8775160637
# WNA
# 10.9626609143
# CNA
# nan
# ENA
# 15.4366413091
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 18.2975147098
# WCE
# 5.02380990982
# EEU
# 12.5928690838
# MED
# 9.76765632629
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 59.6404722977
# WSB
# 28.4876063927
# ESB
# 62.9659667411
# RFE
# 55.0243277374
# WCA
# 44.4140546925
# ECA
# 21.1184419377
# TIB
# 48.7264923712
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# UKESM1-0-LL
# GIC
# 128.073918634
# NWN
# 28.6570140549
# NEN
# 52.369162192
# WNA
# 0.210106042071
# CNA
# nan
# ENA
# nan
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 0.923749969849
# WCE
# 0.275699524184
# EEU
# 0.998309738585
# MED
# 3.95511500106
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 49.0485220851
# WSB
# 4.27805851036
# ESB
# nan
# RFE
# 32.9873880567
# WCA
# 8.43327543747
# ECA
# nan
# TIB
# 8.23111144902
# EAS
# 0.0
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.926782793
# WAN
# 150.0
# HadGEM3-GC31-LL
# GIC
# 116.26468028
# NWN
# 39.2311498725
# NEN
# 49.9071549915
# WNA
# 0.272823256829
# CNA
# nan
# ENA
# 0.0
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 12.6205214835
# WCE
# 2.76351404429
# EEU
# 3.13621374617
# MED
# 1.14035089811
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
#
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 72.2235858511
# WSB
# 44.1276689356
# ESB
# 57.5947828319
# RFE
# 72.7040330916
# WCA
# 28.8080762331
# ECA
# nan
# TIB
# 53.0406246185
# EAS
# 10.9680858515
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.0
# WAN
# 148.252601878
# HadGEM3-GC31-MM
# GIC
# 131.622665137
# NWN
# 61.9551141341
# NEN
# 69.5389881318
# WNA
# 32.9556819519
# CNA
# nan
# ENA
# 10.0070551331
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# 15.1040956258
# NEU
# 47.9926622847
# WCE
# 12.5227445463
# EEU
# 19.6136210626
# MED
# 31.6270083923
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 74.7422084859
# WSB
# 52.959714262
# ESB
# 73.9783022902
# RFE
# 72.6467080637
# WCA
# 40.700894508
# ECA
# nan
# TIB
# 44.1826622874
# EAS
# 36.5585429472
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 148.855985376
# WAN
# 147.437252367
# MPI-ESM1-2-LR
# GIC
# 64.552553209
# NWN
# 53.8766515509
# NEN
# 45.4567858853
# WNA
# 21.7899320804
# CNA
# nan
# ENA
# 24.8262465751
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 22.3979226435
# WCE
# 21.3999996185
# EEU
# 32.2636246389
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.6610792677
# WSB
# 48.0415741764
# ESB
# 67.1844365695
# RFE
# 67.2545539439
# WCA
# 45.5430415789
# ECA
# nan
# TIB
# 52.1795364383
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# MRI-ESM2-0
# GIC
# 118.199466383
# NWN
# 59.1274213008
# NEN
# 57.3408264205
# WNA
# 33.160222411
# CNA
# 16.8204053276
# ENA
# 27.7194209112
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.4698114532
# WCE
# 10.7556713724
# EEU
# 43.0507838863
# MED
# 18.9862470142
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.1124584067
# WSB
# 60.5565752268
# ESB
# 70.453515443
# RFE
# 72.3069556168
# WCA
# 56.920167214
# ECA
# 48.8249412296
# TIB
# 68.3139010543
# EAS
# 15.8968433488
# ARP
# nan
# SAS
# 30.7278696696
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 151.25
# WAN
# 151.25
# IPSL-CM6A-LR
# GIC
# 113.809072119
# NWN
# 67.6788692462
# NEN
# 71.5052870269
# WNA
# 34.6007344364
# CNA
# 27.2671750779
# ENA
# 31.3173585666
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 51.3478781684
# WCE
# 22.4391692986
# EEU
# 39.6049177823
# MED
# 28.0420559408
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 71.2257286299
# WSB
# 54.209440399
# ESB
# 69.2486393585
# RFE
# 70.045477167
# WCA
# 65.1777222191
# ECA
# 59.7334588437
# TIB
# 103.589983826
# EAS
# 32.5302648898
# ARP
# nan
# SAS
# 25.7944908142
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM5-0
# GIC
# 102.898384821
# NWN
# 59.2616286866
# NEN
# 54.6353278267
# WNA
# 9.50512679617
# CNA
# nan
# ENA
# 27.0002907758
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 47.5995803895
# WCE
# 28.6123661286
# EEU
# 53.6184686468
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 66.306281528
# WSB
# 56.7475218897
# ESB
# 55.2267990536
# RFE
# 67.8644468502
# WCA
# 52.2508684376
# ECA
# nan
# TIB
# 40.9320027284
# EAS
# 35.4116646902
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# GFDL-CM4
# GIC
# 111.883110765
# NWN
# 61.2781330327
# NEN
# 50.8041473641
# WNA
# 34.2502500515
# CNA
# nan
# ENA
# 14.3775590679
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 36.7861659814
# WCE
# 12.2797098791
# EEU
# 35.8619888252
# MED
# 22.9808019842
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
#
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 73.5130546559
# WSB
# 54.9574971786
# ESB
# 51.7035691428
# RFE
# 65.6520951217
# WCA
# 40.55414327
# ECA
# nan
# TIB
# 50.6085326762
# EAS
# 28.4721713621
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# GFDL-ESM4
# GIC
# 117.69367434
# NWN
# 71.8016699884
# NEN
# 54.4474155812
# WNA
# 48.1473919465
# CNA
# nan
# ENA
# 17.4647417278
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 42.3499172975
# WCE
# 15.0451617213
# EEU
# 35.6381093081
# MED
# 40.3863216821
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 58.0343629612
# WSB
# 61.1626714637
# ESB
# 68.6609479008
# RFE
# 62.0558963028
# WCA
# 67.4971227597
# ECA
# 45.3499984741
# TIB
# 65.4872405866
# EAS
# 19.1348652544
# ARP
# nan
# SAS
# 3.20000004768
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.642198713
# WAN
# 145.265651675
# AWI-CM-1-1-MR
# GIC
# 45.096465091
# NWN
# 54.7855654106
# NEN
# 41.9853886488
# WNA
# 26.7540204318
# CNA
# nan
# ENA
# 12.7082612584
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.4151982181
# WCE
# nan
# EEU
# 26.224141456
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 64.9919312821
# WSB
# 43.4458902443
# ESB
# 63.6072964451
# RFE
# 65.3033418064
# WCA
# 43.8864445491
# ECA
# 34.8648302179
# TIB
# 44.9931031933
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 69.7875867217
# WAN
# 117.243710369
# MIROC-ES2L
# GIC
# 116.077865203
# NWN
# 50.1202733422
# NEN
# 47.2105573567
# WNA
# nan
# CNA
# nan
# ENA
# 20.5626945496
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 21.2504776847
# WCE
# 14.8316493979
# EEU
# 44.0010648777
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 49.0093894028
# WSB
# 55.7017536767
# ESB
# 40.3048687213
# RFE
# 41.3478290628
# WCA
# 44.0866096312
# ECA
# 47.0
# TIB
# 38.9732854816
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 116.443510856
# WAN
# 72.3909609148
# 26_2041_2060
# MPI-ESM1-2-HR
# GIC
# 51.3121481837
# NWN
# 60.5630888544
# NEN
# 50.5026234991
# WNA
# 41.0608266518
# CNA
# nan
# ENA
# 30.2453486404
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 37.2468121448
# WCE
# 21.4039564133
# EEU
# 31.491977592
# MED
# 40.4692687988
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 60.6060255288
# WSB
# 45.869126376
# ESB
# 65.8023873808
# RFE
# 70.6164302581
# WCA
# 63.3863082713
# ECA
# 44.3680947636
# TIB
# 66.6237193173
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# UKESM1-0-LL
# GIC
# 134.884544267
# NWN
# 59.7397180606
# NEN
# 65.3259552392
# WNA
# 17.7160622484
# CNA
# nan
# ENA
# nan
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.2719574402
# WCE
# 15.5685072942
# EEU
# 25.9476817023
# MED
# 36.3428964267
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 79.3211036219
# WSB
# 29.8632453461
# ESB
# nan
# RFE
# 63.9297349548
# WCA
# 32.9931403364
# ECA
# nan
# TIB
# 30.627593894
# EAS
# 17.2886610031
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.949749753
# WAN
# 150.0
# HadGEM3-GC31-LL
# GIC
# 130.454353274
# NWN
# 67.9494824827
# NEN
# 68.8565195521
# WNA
# 21.6157893937
# CNA
# nan
# ENA
# 27.6352645135
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 55.1099832434
# WCE
# 23.1333312987
# EEU
# 21.9702463844
# MED
# 16.825000445
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 74.7325260623
# WSB
# 42.4727276024
# ESB
# 48.3407654158
# RFE
# 74.373644935
# WCA
# 29.9548062319
# ECA
# nan
# TIB
# 55.734375
# EAS
# 23.194526499
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
#
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.641218908
# WAN
# 146.673368781
# AWI-CM-1-1-MR
# GIC
# 55.5538065081
# NWN
# 60.4340435709
# NEN
# 44.1963284277
# WNA
# 30.0242019359
# CNA
# nan
# ENA
# 18.5579342275
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 34.3560498337
# WCE
# nan
# EEU
# 27.7385465014
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 56.3226724003
# WSB
# 50.5991745093
# ESB
# 66.3233047922
# RFE
# 66.3970814921
# WCA
# 47.2079703577
# ECA
# 36.4358263238
# TIB
# 61.3683143259
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 73.6790094822
# WAN
# 117.243710369
# MIROC-ES2L
# GIC
# 118.60440093
# NWN
# 45.734349051
# NEN
# 50.900237545
# WNA
# nan
# CNA
# nan
# ENA
# 29.2470705509
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 31.9137588468
# WCE
# 29.7989256964
# EEU
# 52.8409938172
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 54.5791233435
# WSB
# 55.4518195566
# ESB
# 38.2991956074
# RFE
# 44.9233975908
# WCA
# 44.6919109208
# ECA
# 41.4500007629
# TIB
# 36.4068131155
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 117.325780006
# WAN
# 74.8698501655

# %%
# -- Loop on experiments / horizons
for GWL in ens_GWL_dict :
    print GWL
    regional_averages[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        #if mem in mask_dict:
        tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), cfile(mask_dict[mem.replace('_85','').replace('_26','')]), 'snw', 'all')
        region_names = tmp.abbrevs
        for tmp_region_name in region_names:
            region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[GWL]:
                regional_averages[GWL][region_name] = [region_value]
            else:
                regional_averages[GWL][region_name].append(region_value)
# Out:
# 1.5
# CanESM5_85
# GIC
# 73.1141304247
# NWN
# 76.6025414475
# NEN
# 67.0952585113
# WNA
# 52.02424633
# CNA
# nan
# ENA
# 33.4993585652
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 53.0536064362
# WCE
# 35.2057738548
# EEU
# 55.7350430391
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 70.5438339793
# WSB
# 66.382101809
# ESB
# 67.6079057706
# RFE
# 77.9426722712
# WCA
# 63.8476999787
# ECA
# 58.3976424197
# TIB
# 59.2173034374
# EAS
# nan
# ARP
# nan
# SAS
# 49.9500007629
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 41.1915404847
# WAN
# 34.4228768092
# BCC-CSM2-MR_85
# GIC
# 143.138572562
# NWN
# 72.4503426291
# NEN
# 74.7925877354
# WNA
# 46.3114464357
# CNA
# 19.2443171823
# ENA
# 39.7375728645
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 58.0395886347
# WCE
# 41.9276273263
# EEU
# 64.3447159429
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 86.4421275972
# WSB
# 66.780077934
# ESB
# 69.4465388751
# RFE
# 78.5224114531
# WCA
# 67.0137596009
# ECA
# nan
# TIB
# 70.8823126978
# EAS
# 22.8661051903
# ARP
# nan
# SAS
# 23.0350873501
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.901729708
# WAN
# 144.64970851
# GFDL-CM4_85
# GIC
# 114.318932389
# NWN
# 66.694170191
# NEN
# 58.3416318949
# WNA
# 45.9287561238
# CNA
# nan
# ENA
# 30.9937811398
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
#
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 80.3027048555
# WSB
# 48.8249373396
# ESB
# 50.2955212436
# RFE
# 79.1208164265
# WCA
# 32.7081904119
# ECA
# nan
# TIB
# 53.90625
# EAS
# 35.6727748149
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.0
# WAN
# 148.438590175
# MPI-ESM1-2-LR_85
# GIC
# 58.6090180832
# NWN
# 59.844500111
# NEN
# 47.3790682735
# WNA
# 31.3425977137
# CNA
# nan
# ENA
# 26.1530070674
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 26.9984409049
# WCE
# 22.75
# EEU
# 45.2549337352
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 69.7543248657
# WSB
# 52.473986615
# ESB
# 67.3951364952
# RFE
# 72.3027503432
# WCA
# 39.6352769435
# ECA
# nan
# TIB
# 44.6921354763
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# MPI-ESM1-2-LR_26
# GIC
# 62.8792062457
# NWN
# 63.5870571271
# NEN
# 44.7018388663
# WNA
# 37.688538378
# CNA
# nan
# ENA
# 36.7331520923
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 28.0640194037
# WCE
# 14.4499998093
# EEU
# 45.2703757409
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 71.7934028043
# WSB
# 52.9440390297
# ESB
# 64.9346747337
# RFE
# 69.437514582
# WCA
# 49.8286801586
# ECA
# nan
# TIB
# 54.7443386133
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM4-8_85
# GIC
# 102.973650521
# NWN
# 71.381496777
# NEN
# 59.7762115595
# WNA
# 35.8192959238
# CNA
# nan
# ENA
# 37.1395032184
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 72.5824139744
# WCE
# 47.7933886681
# EEU
# 66.778437587
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 70.7352223913
# WSB
# 57.4863223821
# ESB
# 59.3345584832
# RFE
# 64.7147047479
# WCA
# 44.0988007343
# ECA
# nan
# TIB
# 47.7618838422
# EAS
# 45.8798931334
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# 3
# CanESM5_85
# GIC
# 68.1007605097
# NWN
# 67.0892866826
# NEN
# 65.6900663353
# WNA
# 17.8053399793
# CNA
# nan
# ENA
# 20.6096212236
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.9777934951
# WCE
# 15.8721739078
# EEU
# 28.7247790484
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 65.3251018036
# WSB
# 47.1658955992
# ESB
# 58.074960141
# RFE
# 65.7943213936
# WCA
# 48.1894912317
# ECA
# 46.7899520561
# TIB
# 35.0355602737
# EAS
# nan
# ARP
# nan
# SAS
# 25.0
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 38.6771759808
# WAN
# 31.1075733451
# BCC-CSM2-MR_85
# GIC
# 140.298150917
# NWN
# 48.4703058341
# NEN
# 61.3528739297
# WNA
# 9.27395712523
# CNA
# 14.5377574803
# ENA
# 26.0857616278
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 36.7614598884
# WCE
# 11.3004709074
# EEU
# 36.8874674901
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 84.9922669177
# WSB
# 57.8661686931
# ESB
# 71.7914434873
# RFE
# 64.1776162243
# WCA
# 47.7974468626
# ECA
# nan
# TIB
# 62.5196684924
# EAS
# 4.7946151344
# ARP
# nan
# SAS
# 14.6526310029
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.811632682
# WAN
# 141.901349987
# GFDL-CM4_85
# GIC
# 110.009378443
# NWN
# 57.8552198346
# NEN
# 47.926710862
# WNA
# 26.5179666811
# CNA
# nan
# ENA
# 9.10208578976
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.0831728415
# WCE
# 7.04943428417
# EEU
# 25.8041281541
# MED
# 16.6556552685
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
#
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 64.9435312978
# WSB
# 56.8135444905
# ESB
# 69.5261498547
# RFE
# 69.4443109021
# WCA
# 49.3647804145
# ECA
# 41.1841746621
# TIB
# 65.8307667602
# EAS
# 14.1804677252
# ARP
# nan
# SAS
# 32.3095823924
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 151.25
# WAN
# 151.25
# MIROC-ES2L_85
# GIC
# 114.110087045
# NWN
# 37.6143233408
# NEN
# 40.5138260716
# WNA
# nan
# CNA
# nan
# ENA
# 14.6693357229
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 19.0404747165
# WCE
# 19.0335983634
# EEU
# 44.5007637069
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 50.2587022785
# WSB
# 48.9755255355
# ESB
# 45.687146385
# RFE
# 40.359334421
# WCA
# 32.3342095903
# ECA
# 35.8499984741
# TIB
# 31.1114894559
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 111.542226481
# WAN
# 69.0478122709
# UKESM1-0-LL_85
# GIC
# 135.165616719
# NWN
# 57.245782979
# NEN
# 68.7549681822
# WNA
# 16.7582804134
# CNA
# nan
# ENA
# nan
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 25.0415836287
# WCE
# 6.55189980817
# EEU
# 20.859829166
# MED
# 22.5668050516
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 76.6591551525
# WSB
# 31.3214648058
# ESB
# nan
# RFE
# 55.2253361881
# WCA
# 27.2307275753
# ECA
# nan
# TIB
# 18.1199131608
# EAS
# 12.1156601906
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.945977075
# WAN
# 150.0
# MPI-ESM1-2-LR_85
# GIC
# 51.3267254391
# NWN
# 52.4480550714
# NEN
# 37.8779990721
# WNA
# 12.1799260373
# CNA
# nan
# ENA
# 21.3791928818
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 7.27591691096
# WCE
# 4.40000009537
# EEU
# 29.0439391724
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 64.8359027935
# WSB
# 47.7764907347
# ESB
# 69.5735297706
# RFE
# 60.0184384569
# WCA
# 37.7340306181
# ECA
# nan
# TIB
# 42.7061730382
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM5-0_85
# GIC
# 104.653287412
# NWN
# 57.0971318031
# NEN
# 54.3865351595
# WNA
# 8.46349777801
# CNA
# nan
# ENA
# 26.588749501
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 37.4887006657
# WCE
# 27.8446681694
# EEU
# 50.2607574031
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 68.7953856252
# WSB
# 51.5373623885
# ESB
# 60.5962028164
# RFE
# 62.2203178158
# WCA
# 49.0748817476
# ECA
# nan
# TIB
# 42.3575823384
# EAS
# 17.0712139332
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# EC-Earth3_85
# GIC
# 137.295769411
# NWN
# 75.4135851358
# NEN
# 60.6884988727
# WNA
# 36.0873621641
# CNA
# 10.9341702461
# ENA
# 26.1951636642
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 44.3674797448
# WCE
# 30.4829730182
# EEU
# 26.2504252403
# MED
# 22.0927790916
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 77.0728781581
# WSB
# 58.2072627731
# ESB
# 70.8069424652
# RFE
# 82.8946981883
# WCA
# 49.2374528241
# ECA
# nan
# TIB
# 44.3623742153
# EAS
# 32.0832972045
# ARP
# nan
# SAS
# 16.8363380432
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 147.529584317
# WAN
# 140.93185384
# MIROC6_85
# GIC
# 108.317377992
# NWN
# 40.592533268
# NEN
# 42.5435128393
# WNA
# 5.36220785579
# CNA
# nan
# ENA
# 9.55732547326
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 17.7529704248
# WCE
# 5.11392007463
# EEU
# 29.139073007
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 50.3458901056
# WSB
# 45.0363640217
# ESB
# 60.4067038656
# RFE
# 55.5831802004
# WCA
# 57.7960570854
# ECA
# 24.3290494411
# TIB
# 47.1003528148
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
#
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 67.8595329085
# WSB
# 54.2240518345
# ESB
# 60.0549306025
# RFE
# 68.8385705711
# WCA
# 59.1534275767
# ECA
# nan
# TIB
# 39.6720099329
# EAS
# 36.4101022769
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# EC-Earth3_85
# GIC
# 139.312585231
# NWN
# 84.6664282895
# NEN
# 67.7668976569
# WNA
# 45.9641473043
# CNA
# 22.6653620402
# ENA
# 28.9355614453
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 47.5495851285
# WCE
# 40.0797362882
# EEU
# 37.0066866006
# MED
# 36.2069639103
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 74.3738039161
# WSB
# 62.1313426483
# ESB
# 67.9969892176
# RFE
# 80.8931871081
# WCA
# 57.9869029931
# ECA
# nan
# TIB
# 59.1891687832
# EAS
# 28.4733329107
# ARP
# nan
# SAS
# 26.8056907654
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 147.903513237
# WAN
# 143.866630559
# MIROC6_85
# GIC
# 110.181165152
# NWN
# 54.6109949001
# NEN
# 56.5623256735
# WNA
# 15.8691103794
# CNA
# nan
# ENA
# 23.3334297666
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 41.5352998597
# WCE
# 24.49349536
# EEU
# 49.0269674681
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 55.4834023666
# WSB
# 60.7704586151
# ESB
# 60.0063119228
# RFE
# 66.0299673653
# WCA
# 61.8721852748
# ECA
# 23.4150142517
# TIB
# 44.4010463259
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 129.374626939
# WAN
# 98.0372179793
# NESM3_26
# GIC
# nan
# NWN
# 37.1384041132
# NEN
# nan
# WNA
# 12.1328125
# CNA
# nan
# ENA
# nan
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# nan
# WCE
# nan
# EEU
# nan
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# nan
# WSB
# nan
# ESB
# nan
# RFE
# nan
# WCA
# nan
# ECA
# nan
# TIB
# 34.1433504847
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# HadGEM3-GC31-LL_26
# GIC
# 130.582022869
# NWN
# 62.5335675
# NEN
# 70.9931638499
# WNA
# 23.6462657177
# CNA
# nan
# ENA
# 30.673522332
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 60.6853686811
# WCE
# 22.0311624406
# EEU
# 27.8004227422
# MED
# 34.5312506358
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 79.0744506221
# WSB
# 46.3955419263
# ESB
# 54.5297362788
# RFE
# 74.881587296
# WCA
# 37.7530300726
# ECA
# nan
# TIB
# 50.953125
# EAS
# 25.6061171947
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 150.0
# WAN
# 148.320056541
# MPI-ESM1-2-LR_85
# GIC
# 62.760429354
# NWN
# 55.8307852501
# NEN
# 46.6056116151
# WNA
# 23.9927310747
# CNA
# nan
# ENA
# 22.3935071972
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 23.5462715414
# WCE
# 19.6000003815
# EEU
# 37.5115405538
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 68.413706921
# WSB
# 51.4971841132
# ESB
# 67.1461151733
# RFE
# 68.824892871
# WCA
# 43.9867983043
# ECA
# nan
# TIB
# 50.0588330444
# EAS
# nan
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# INM-CM4-8_85
# GIC
# 101.697181303
# NWN
# 66.3999959861
# NEN
# 61.1887445455
# WNA
# 22.2121395435
# CNA
# nan
# ENA
# 30.6114315924
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 68.9201943118
# WCE
# 45.1233035679
# EEU
# 68.9023144484
# MED
# nan
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 72.0551414926
# WSB
# 55.4873891421
# ESB
# 56.11477464
# RFE
# 67.5372534542
# WCA
# 43.3886691707
# ECA
# nan
# TIB
# 48.730304133
# EAS
# 29.2775372949
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# 4
# CanESM5_85
# GIC
# 64.4894596606
# NWN
# 54.2197584006
# NEN
# 58.0345164967
# WNA
# 8.66236513324
# CNA
# nan
# ENA
# 10.9691638682
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
#
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 40.5278441809
# WCE
# 13.8193361416
# EEU
# 30.1712970425
# MED
# 19.2723043869
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 68.0634161986
# WSB
# 47.3454490218
# ESB
# 70.9112720772
# RFE
# 60.0194644709
# WCA
# 56.7053539292
# ECA
# 48.414452026
# TIB
# 93.6344669672
# EAS
# 22.9064301286
# ARP
# nan
# SAS
# 17.3550291061
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# nan
# WAN
# nan
# HadGEM3-GC31-LL_85
# GIC
# 124.832451479
# NWN
# 56.1704265793
# NEN
# 64.1051425476
# WNA
# 8.60554798823
# CNA
# nan
# ENA
# 13.4906863702
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 29.2389443782
# WCE
# 4.00216904646
# EEU
# 13.7227003042
# MED
# 16.1291666031
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 62.0913694836
# WSB
# 38.0473841299
# ESB
# 56.5495844408
# RFE
# 63.8113452194
# WCA
# 29.2150713064
# ECA
# nan
# TIB
# 58.6875
# EAS
# 7.45790749626
# ARP
# nan
# SAS
# nan
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 149.846479826
# WAN
# 148.13686854
# MRI-ESM2-0_85
# GIC
# 115.422259902
# NWN
# 50.9281085171
# NEN
# 53.0732973291
# WNA
# 15.5694078391
# CNA
# 7.83554805044
# ENA
# 10.6326339348
# NCA
# nan
# SCA
# nan
# CAR
# nan
# NWS
# nan
# NSA
# nan
# NES
# nan
# SAM
# nan
# SWS
# nan
# SES
# nan
# SSA
# nan
# NEU
# 19.5710615391
# WCE
# 6.53939274089
# EEU
# 33.9076351705
# MED
# 8.5803063006
# SAH
# nan
# WAF
# nan
# CAF
# nan
# NEAF
# nan
# SEAF
# nan
# WSAF
# nan
# ESAF
# nan
# MDG
# nan
# RAR
# 62.6713847191
# WSB
# 51.9914889132
# ESB
# 66.307459227
# RFE
# 60.3659292398
# WCA
# 44.8837809483
# ECA
# 42.9402498701
# TIB
# 65.4182933165
# EAS
# 4.69371910408
# ARP
# nan
# SAS
# 23.6798617045
# SEA
# nan
# NAU
# nan
# CAU
# nan
# EAU
# nan
# SAU
# nan
# NZ
# nan
# EAN
# 151.25
# WAN
# 150.69283474

# %% [markdown]
# ### Compute the ensemble statistics

# %%
import numpy
quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        print [q10, q50, q90]
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# 1.5 NEN
# [nan, nan, nan]
# 1.5 NCA
# [nan, nan, nan]
# 1.5 WAN
# [nan, nan, nan]
# 1.5 EEU
# [nan, nan, nan]
# 1.5 CAR
# [nan, nan, nan]
# 1.5 WSAF
# [nan, nan, nan]
# 1.5 CAU
# [nan, nan, nan]
# 1.5 WSB
# [nan, nan, nan]
# 1.5 NAU
# [nan, nan, nan]
# 1.5 SWS
# [nan, nan, nan]
# 1.5 NEU
# [nan, nan, nan]
# 1.5 NES
# [nan, nan, nan]
# 1.5 TIB
# [40.02397492537323, 51.46518321318183, 77.07161442555878]
# 1.5 WNA
# [nan, nan, nan]
# 1.5 SES
# [nan, nan, nan]
# 1.5 SAM
# [nan, nan, nan]
# 1.5 NWS
# [nan, nan, nan]
# 1.5 NSA
# [nan, nan, nan]
# 1.5 SCA
# [nan, nan, nan]
# 1.5 MDG
# [nan, nan, nan]
# 1.5 CAF
# [nan, nan, nan]
# 1.5 SEAF
# [nan, nan, nan]
# 1.5 NZ
# [nan, nan, nan]
# 1.5 RAR
# [nan, nan, nan]
# 1.5 SEA
# [nan, nan, nan]
# 1.5 SAS
# [nan, nan, nan]
# 1.5 NWN
# [55.21039250480631, 68.73823175975085, 77.45477060781398]
# 1.5 EAU
# [nan, nan, nan]
# 1.5 SAU
# [nan, nan, nan]
# 1.5 ENA
# [nan, nan, nan]
# 1.5 WAF
# [nan, nan, nan]
# 1.5 WCA
# [nan, nan, nan]
# 1.5 SAH
# [nan, nan, nan]
# 1.5 GIC
# [nan, nan, nan]
# 1.5 ESB
# [nan, nan, nan]
# 1.5 RFE
# [nan, nan, nan]
# 1.5 CNA
# [nan, nan, nan]
# 1.5 EAS
# [nan, nan, nan]
# 1.5 ARP
# [nan, nan, nan]
# 1.5 MED
# [nan, nan, nan]
# 1.5 ECA
# [nan, nan, nan]
# 1.5 NEAF
# [nan, nan, nan]
# 1.5 EAN
# [nan, nan, nan]
# 1.5 WCE
# [nan, nan, nan]
# 1.5 SSA
# [nan, nan, nan]
# 1.5 ESAF
# [nan, nan, nan]
# 85_1995_2014 NEN
# [nan, nan, nan]
# 85_1995_2014 NCA
# [nan, nan, nan]
# 85_1995_2014 WAN
# [nan, nan, nan]
# 85_1995_2014 EEU
# [nan, nan, nan]
# 85_1995_2014 CAR
# [nan, nan, nan]
# 85_1995_2014 WSAF
# [nan, nan, nan]
# 85_1995_2014 CAU
# [nan, nan, nan]
# 85_1995_2014 WSB
# [nan, nan, nan]
# 85_1995_2014 NAU
# [nan, nan, nan]
# 85_1995_2014 SWS
# [nan, nan, nan]
# 85_1995_2014 NEU
# [nan, nan, nan]
# 85_1995_2014 NES
# [nan, nan, nan]
# 85_1995_2014 TIB
# [46.06191965692112, 62.180074479080275, 91.39569702714209]
# 85_1995_2014 WNA
# [nan, nan, nan]
# 85_1995_2014 SES
# [nan, nan, nan]
# 85_1995_2014 SAM
# [nan, nan, nan]
# 85_1995_2014 NWS
# [nan, nan, nan]
# 85_1995_2014 NSA
# [nan, nan, nan]
# 85_1995_2014 SCA
# [nan, nan, nan]
# 85_1995_2014 MDG
# [nan, nan, nan]
# 85_1995_2014 CAF
# [nan, nan, nan]
# 85_1995_2014 SEAF
# [nan, nan, nan]
# 85_1995_2014 NZ
# [nan, nan, nan]
# 85_1995_2014 RAR
# [nan, nan, nan]
# 85_1995_2014 SEA
# [nan, nan, nan]
# 85_1995_2014 SAS
# [nan, nan, nan]
# 85_1995_2014 NWN
# [62.71734961176895, 71.69211421852108, 83.2865757908703]
# 85_1995_2014 EAU
# [nan, nan, nan]
# 85_1995_2014 SAU
# [nan, nan, nan]
# 85_1995_2014 ENA
# [nan, nan, nan]
# 85_1995_2014 WAF
# [nan, nan, nan]
# 85_1995_2014 WCA
# [nan, nan, nan]
# 85_1995_2014 SAH
# [nan, nan, nan]
# 85_1995_2014 GIC
# [nan, nan, nan]
# 85_1995_2014 ESB
# [nan, nan, nan]
# 85_1995_2014 RFE
# [nan, nan, nan]
# 85_1995_2014 CNA
# [nan, nan, nan]
# 85_1995_2014 EAS
# [nan, nan, nan]
# 85_1995_2014 ARP
# [nan, nan, nan]
# 85_1995_2014 MED
# [nan, nan, nan]
# 85_1995_2014 ECA
# [nan, nan, nan]
# 85_1995_2014 NEAF
# [nan, nan, nan]
# 85_1995_2014 EAN
# [nan, nan, nan]
# 85_1995_2014 WCE
# [nan, nan, nan]
# 85_1995_2014 SSA
# [nan, nan, nan]
# 85_1995_2014 ESAF
# [nan, nan, nan]
# 26_2041_2060 NEN
# [nan, nan, nan]
# 26_2041_2060 NCA
# [nan, nan, nan]
# 26_2041_2060 WAN
# [nan, nan, nan]
# 26_2041_2060 EEU
# [nan, nan, nan]
# 26_2041_2060 CAR
# [nan, nan, nan]
# 26_2041_2060 WSAF
# [nan, nan, nan]
# 26_2041_2060 CAU
# [nan, nan, nan]
# 26_2041_2060 WSB
# [nan, nan, nan]
# 26_2041_2060 NAU
# [nan, nan, nan]
# 26_2041_2060 SWS
# [nan, nan, nan]
# 26_2041_2060 NEU
# [nan, nan, nan]
# 26_2041_2060 NES
# [nan, nan, nan]
# 26_2041_2060 TIB
# [37.383915875639445, 55.18950040187956, 76.54571830980686]
# 26_2041_2060 WNA
# [nan, nan, nan]
# 26_2041_2060 SES
# [nan, nan, nan]
# 26_2041_2060 SAM
# [nan, nan, nan]
# 26_2041_2060 NWS
# [nan, nan, nan]
# 26_2041_2060 NSA
# [nan, nan, nan]
# 26_2041_2060 SCA
# [nan, nan, nan]
# 26_2041_2060 MDG
# [nan, nan, nan]
# 26_2041_2060 CAF
# [nan, nan, nan]
# 26_2041_2060 SEAF
# [nan, nan, nan]
# 26_2041_2060 NZ
# [nan, nan, nan]
# 26_2041_2060 RAR
# [nan, nan, nan]
# 26_2041_2060 SEA
# [nan, nan, nan]
# 26_2041_2060 SAS
# [nan, nan, nan]
# 26_2041_2060 NWN
# [53.53801828957077, 66.82556256851741, 71.91627139024021]
# 26_2041_2060 EAU
# [nan, nan, nan]
# 26_2041_2060 SAU
# [nan, nan, nan]
# 26_2041_2060 ENA
# [nan, nan, nan]
# 26_2041_2060 WAF
# [nan, nan, nan]
# 26_2041_2060 WCA
# [nan, nan, nan]
# 26_2041_2060 SAH
# [nan, nan, nan]
# 26_2041_2060 GIC
# [nan, nan, nan]
# 26_2041_2060 ESB
# [nan, nan, nan]
# 26_2041_2060 RFE
# [nan, nan, nan]
# 26_2041_2060 CNA
# [nan, nan, nan]
# 26_2041_2060 EAS
# [nan, nan, nan]
# 26_2041_2060 ARP
# [nan, nan, nan]
# 26_2041_2060 MED
# [nan, nan, nan]
# 26_2041_2060 ECA
# [nan, nan, nan]
# 26_2041_2060 NEAF
# [nan, nan, nan]
# 26_2041_2060 EAN
# [nan, nan, nan]
# 26_2041_2060 WCE
# [nan, nan, nan]
# 26_2041_2060 SSA
# [nan, nan, nan]
# 26_2041_2060 ESAF
# [nan, nan, nan]
# 3 NEN
# [nan, nan, nan]
# 3 NCA
# [nan, nan, nan]
# 3 WAN
# [nan, nan, nan]
# 3 EEU
# [nan, nan, nan]
# 3 CAR
# [nan, nan, nan]
# 3 WSAF
# [nan, nan, nan]
# 3 CAU
# [nan, nan, nan]
# 3 WSB
# [nan, nan, nan]
# 3 NAU
# [nan, nan, nan]
# 3 SWS
# [nan, nan, nan]
# 3 NEU
# [nan, nan, nan]
# 3 NES
# [nan, nan, nan]
# 3 TIB
# [33.03149136196319, 45.26572843568826, 64.17521762629765]
# 3 WNA
# [nan, nan, nan]
# 3 SES
# [nan, nan, nan]
# 3 SAM
# [nan, nan, nan]
# 3 NWS
# [nan, nan, nan]
# 3 NSA
# [nan, nan, nan]
# 3 SCA
# [nan, nan, nan]
# 3 MDG
# [nan, nan, nan]
# 3 CAF
# [nan, nan, nan]
# 3 SEAF
# [nan, nan, nan]
# 3 NZ
# [nan, nan, nan]
# 3 RAR
# [nan, nan, nan]
# 3 SEA
# [nan, nan, nan]
# 3 SAS
# [nan, nan, nan]
# 3 NWN
# [39.10342830441219, 57.171457391059576, 69.50546186789997]
# 3 EAU
# [nan, nan, nan]
# 3 SAU
# [nan, nan, nan]
# 3 ENA
# [nan, nan, nan]
# 3 WAF
# [nan, nan, nan]
# 3 WCA
# [nan, nan, nan]
# 3 SAH
# [nan, nan, nan]
# 3 GIC
# [nan, nan, nan]
# 3 ESB
# [nan, nan, nan]
# 3 RFE
# [nan, nan, nan]
# 3 CNA
# [nan, nan, nan]
# 3 EAS
# [nan, nan, nan]
# 3 ARP
# [nan, nan, nan]
# 3 MED
# [nan, nan, nan]
# 3 ECA
# [nan, nan, nan]
# 3 NEAF
# [nan, nan, nan]
# 3 EAN
# [nan, nan, nan]
# 3 WCE
# [nan, nan, nan]
# 3 SSA
# [nan, nan, nan]
# 3 ESAF
# [nan, nan, nan]
# 26_2081_2099 NEN
# [nan, nan, nan]
# 26_2081_2099 NCA
# [nan, nan, nan]
# 26_2081_2099 WAN
# [nan, nan, nan]
# 26_2081_2099 EEU
# [nan, nan, nan]
# 26_2081_2099 CAR
# [nan, nan, nan]
# 26_2081_2099 WSAF
# [nan, nan, nan]
# 26_2081_2099 CAU
# [nan, nan, nan]
# 26_2081_2099 WSB
# [nan, nan, nan]
# 26_2081_2099 NAU
# [nan, nan, nan]
# 26_2081_2099 SWS
# [nan, nan, nan]
# 26_2081_2099 NEU
# [nan, nan, nan]
# 26_2081_2099 NES
# [nan, nan, nan]
# 26_2081_2099 TIB
# [38.61967933556713, 53.62963893652973, 72.38170568294065]
# 26_2081_2099 WNA
# [nan, nan, nan]
# 26_2081_2099 SES
# [nan, nan, nan]
# 26_2081_2099 SAM
# [nan, nan, nan]
# 26_2081_2099 NWS
# [nan, nan, nan]
# 26_2081_2099 NSA
# [nan, nan, nan]
# 26_2081_2099 SCA
# [nan, nan, nan]
# 26_2081_2099 MDG
# [nan, nan, nan]
# 26_2081_2099 CAF
# [nan, nan, nan]
# 26_2081_2099 SEAF
# [nan, nan, nan]
# 26_2081_2099 NZ
# [nan, nan, nan]
# 26_2081_2099 RAR
# [nan, nan, nan]
# 26_2081_2099 SEA
# [nan, nan, nan]
# 26_2081_2099 SAS
# [nan, nan, nan]
# 26_2081_2099 NWN
# [48.63396633861258, 62.282991605776516, 71.14243912499671]
# 26_2081_2099 EAU
# [nan, nan, nan]
# 26_2081_2099 SAU
# [nan, nan, nan]
# 26_2081_2099 ENA
# [nan, nan, nan]
# 26_2081_2099 WAF
# [nan, nan, nan]
# 26_2081_2099 WCA
# [nan, nan, nan]
# 26_2081_2099 SAH
# [nan, nan, nan]
# 26_2081_2099 GIC
# [nan, nan, nan]
# 26_2081_2099 ESB
# [nan, nan, nan]
# 26_2081_2099 RFE
# [nan, nan, nan]
# 26_2081_2099 CNA
# [nan, nan, nan]
# 26_2081_2099 EAS
# [nan, nan, nan]
# 26_2081_2099 ARP
# [nan, nan, nan]
# 26_2081_2099 MED
# [nan, nan, nan]
# 26_2081_2099 ECA
# [nan, nan, nan]
# 26_2081_2099 NEAF
# [nan, nan, nan]
# 26_2081_2099 EAN
# [nan, nan, nan]
# 26_2081_2099 WCE
# [nan, nan, nan]
# 26_2081_2099 SSA
# [nan, nan, nan]
# 26_2081_2099 ESAF
# [nan, nan, nan]
# 4 NEN
# [nan, nan, nan]
# 4 NCA
# [nan, nan, nan]
# 4 WAN
# [nan, nan, nan]
# 4 EEU
# [nan, nan, nan]
# 4 CAR
# [nan, nan, nan]
# 4 WSAF
# [nan, nan, nan]
# 4 CAU
# [nan, nan, nan]
# 4 WSB
# [nan, nan, nan]
# 4 NAU
# [nan, nan, nan]
# 4 SWS
# [nan, nan, nan]
# 4 NEU
# [nan, nan, nan]
# 4 NES
# [nan, nan, nan]
# 4 TIB
# [28.185115479459334, 44.806970386429356, 71.06152804660547]
# 4 WNA
# [6.884438390585085, 10.507014528430515, 25.49394248519076]
# 4 SES
# [nan, nan, nan]
# 4 SAM
# [nan, nan, nan]
# 4 NWS
# [nan, nan, nan]
# 4 NSA
# [nan, nan, nan]
# 4 SCA
# [nan, nan, nan]
# 4 MDG
# [nan, nan, nan]
# 4 CAF
# [nan, nan, nan]
# 4 SEAF
# [nan, nan, nan]
# 4 NZ
# [nan, nan, nan]
# 4 RAR
# [nan, nan, nan]
# 4 SEA
# [nan, nan, nan]
# 4 SAS
# [nan, nan, nan]
# 4 NWN
# [33.39500562448252, 53.457543031075765, 58.824122935102764]
# 4 EAU
# [nan, nan, nan]
# 4 SAU
# [nan, nan, nan]
# 4 ENA
# [nan, nan, nan]
# 4 WAF
# [nan, nan, nan]
# 4 WCA
# [nan, nan, nan]
# 4 SAH
# [nan, nan, nan]
# 4 GIC
# [nan, nan, nan]
# 4 ESB
# [nan, nan, nan]
# 4 RFE
# [nan, nan, nan]
# 4 CNA
# [nan, nan, nan]
# 4 EAS
# [nan, nan, nan]
# 4 ARP
# [nan, nan, nan]
# 4 MED
# [nan, nan, nan]
# 4 ECA
# [nan, nan, nan]
# 4 NEAF
# [nan, nan, nan]
# 4 EAN
# [nan, nan, nan]
# 4 WCE
# [nan, nan, nan]
# 4 SSA
# [nan, nan, nan]
# 4 ESAF
# [nan, nan, nan]
# 85_2041_2060 NEN
# [nan, nan, nan]
# 85_2041_2060 NCA
# [nan, nan, nan]
# 85_2041_2060 WAN
# [nan, nan, nan]
# 85_2041_2060 EEU
# [nan, nan, nan]
# 85_2041_2060 CAR
# [nan, nan, nan]
# 85_2041_2060 WSAF
# [nan, nan, nan]
# 85_2041_2060 CAU
# [nan, nan, nan]
# 85_2041_2060 WSB
# [nan, nan, nan]
# 85_2041_2060 NAU
# [nan, nan, nan]
# 85_2041_2060 SWS
# [nan, nan, nan]
# 85_2041_2060 NEU
# [nan, nan, nan]
# 85_2041_2060 NES
# [nan, nan, nan]
# 85_2041_2060 TIB
# [31.90694619575409, 50.0545062246924, 69.92105876713686]
# 85_2041_2060 WNA
# [nan, nan, nan]
# 85_2041_2060 SES
# [nan, nan, nan]
# 85_2041_2060 SAM
# [nan, nan, nan]
# 85_2041_2060 NWS
# [nan, nan, nan]
# 85_2041_2060 NSA
# [nan, nan, nan]
# 85_2041_2060 SCA
# [nan, nan, nan]
# 85_2041_2060 MDG
# [nan, nan, nan]
# 85_2041_2060 CAF
# [nan, nan, nan]
# 85_2041_2060 SEAF
# [nan, nan, nan]
# 85_2041_2060 NZ
# [nan, nan, nan]
# 85_2041_2060 RAR
# [nan, nan, nan]
# 85_2041_2060 SEA
# [nan, nan, nan]
# 85_2041_2060 SAS
# [nan, nan, nan]
# 85_2041_2060 NWN
# [52.74973808833467, 59.00017811074446, 69.59335282055827]
# 85_2041_2060 EAU
# [nan, nan, nan]
# 85_2041_2060 SAU
# [nan, nan, nan]
# 85_2041_2060 ENA
# [nan, nan, nan]
# 85_2041_2060 WAF
# [nan, nan, nan]
# 85_2041_2060 WCA
# [nan, nan, nan]
# 85_2041_2060 SAH
# [nan, nan, nan]
# 85_2041_2060 GIC
# [nan, nan, nan]
# 85_2041_2060 ESB
# [nan, nan, nan]
# 85_2041_2060 RFE
# [nan, nan, nan]
# 85_2041_2060 CNA
# [nan, nan, nan]
# 85_2041_2060 EAS
# [nan, nan, nan]
# 85_2041_2060 ARP
# [nan, nan, nan]
# 85_2041_2060 MED
# [nan, nan, nan]
# 85_2041_2060 ECA
# [nan, nan, nan]
# 85_2041_2060 NEAF
# [nan, nan, nan]
# 85_2041_2060 EAN
# [nan, nan, nan]
# 85_2041_2060 WCE
# [nan, nan, nan]
# 85_2041_2060 SSA
# [nan, nan, nan]
# 85_2041_2060 ESAF
# [nan, nan, nan]
# 2 NEN
# [nan, nan, nan]
# 2 NCA
# [nan, nan, nan]
# 2 WAN
# [nan, nan, nan]
# 2 EEU
# [nan, nan, nan]
# 2 CAR
# [nan, nan, nan]
# 2 WSAF
# [nan, nan, nan]
# 2 CAU
# [nan, nan, nan]
# 2 WSB
# [nan, nan, nan]
# 2 NAU
# [nan, nan, nan]
# 2 SWS
# [nan, nan, nan]
# 2 NEU
# [nan, nan, nan]
# 2 NES
# [nan, nan, nan]
# 2 TIB
# [32.34429801833415, 50.05883304441272, 76.48480907716328]
# 2 WNA
# [nan, nan, nan]
# 2 SES
# [nan, nan, nan]
# 2 SAM
# [nan, nan, nan]
# 2 NWS
# [nan, nan, nan]
# 2 NSA
# [nan, nan, nan]
# 2 SCA
# [nan, nan, nan]
# 2 MDG
# [nan, nan, nan]
# 2 CAF
# [nan, nan, nan]
# 2 SEAF
# [nan, nan, nan]
# 2 NZ
# [nan, nan, nan]
# 2 RAR
# [nan, nan, nan]
# 2 SEA
# [nan, nan, nan]
# 2 SAS
# [nan, nan, nan]
# 2 NWN
# [53.09319727370095, 64.04206159300102, 75.97983148745854]
# 2 EAU
# [nan, nan, nan]
# 2 SAU
# [nan, nan, nan]
# 2 ENA
# [nan, nan, nan]
# 2 WAF
# [nan, nan, nan]
# 2 WCA
# [nan, nan, nan]
# 2 SAH
# [nan, nan, nan]
# 2 GIC
# [nan, nan, nan]
# 2 ESB
# [nan, nan, nan]
# 2 RFE
# [nan, nan, nan]
# 2 CNA
# [nan, nan, nan]
# 2 EAS
# [nan, nan, nan]
# 2 ARP
# [nan, nan, nan]
# 2 MED
# [nan, nan, nan]
# 2 ECA
# [nan, nan, nan]
# 2 NEAF
# [nan, nan, nan]
# 2 EAN
# [nan, nan, nan]
# 2 WCE
# [nan, nan, nan]
# 2 SSA
# [nan, nan, nan]
# 2 ESAF
# [nan, nan, nan]
# 85_2081_2099 NEN
# [nan, nan, nan]
# 85_2081_2099 NCA
# [nan, nan, nan]
# 85_2081_2099 WAN
# [nan, nan, nan]
# 85_2081_2099 EEU
# [nan, nan, nan]
# 85_2081_2099 CAR
# [nan, nan, nan]
# 85_2081_2099 WSAF
# [nan, nan, nan]
# 85_2081_2099 CAU
# [nan, nan, nan]
# 85_2081_2099 WSB
# [nan, nan, nan]
# 85_2081_2099 NAU
# [nan, nan, nan]
# 85_2081_2099 SWS
# [nan, nan, nan]
# 85_2081_2099 NEU
# [nan, nan, nan]
# 85_2081_2099 NES
# [nan, nan, nan]
# 85_2081_2099 TIB
# [21.59686920335502, 39.5404626143189, 62.17528121262816]
# 85_2081_2099 WNA
# [nan, nan, nan]
# 85_2081_2099 SES
# [nan, nan, nan]
# 85_2081_2099 SAM
# [nan, nan, nan]
# 85_2081_2099 NWS
# [nan, nan, nan]
# 85_2081_2099 NSA
# [nan, nan, nan]
# 85_2081_2099 SCA
# [nan, nan, nan]
# 85_2081_2099 MDG
# [nan, nan, nan]
# 85_2081_2099 CAF
# [nan, nan, nan]
# 85_2081_2099 SEAF
# [nan, nan, nan]
# 85_2081_2099 NZ
# [nan, nan, nan]
# 85_2081_2099 RAR
# [nan, nan, nan]
# 85_2081_2099 SEA
# [nan, nan, nan]
# 85_2081_2099 SAS
# [nan, nan, nan]
# 85_2081_2099 NWN
# [24.8485388693965, 40.82196316595143, 53.24084169379596]
# 85_2081_2099 EAU
# [nan, nan, nan]
# 85_2081_2099 SAU
# [nan, nan, nan]
# 85_2081_2099 ENA
# [nan, nan, nan]
# 85_2081_2099 WAF
# [nan, nan, nan]
# 85_2081_2099 WCA
# [nan, nan, nan]
# 85_2081_2099 SAH
# [nan, nan, nan]
# 85_2081_2099 GIC
# [nan, nan, nan]
# 85_2081_2099 ESB
# [nan, nan, nan]
# 85_2081_2099 RFE
# [nan, nan, nan]
# 85_2081_2099 CNA
# [nan, nan, nan]
# 85_2081_2099 EAS
# [nan, nan, nan]
# 85_2081_2099 ARP
# [nan, nan, nan]
# 85_2081_2099 MED
# [nan, nan, nan]
# 85_2081_2099 ECA
# [nan, nan, nan]
# 85_2081_2099 NEAF
# [nan, nan, nan]
# 85_2081_2099 EAN
# [nan, nan, nan]
# 85_2081_2099 WCE
# [nan, nan, nan]
# 85_2081_2099 SSA
# [nan, nan, nan]
# 85_2081_2099 ESAF
# [nan, nan, nan]

# %% [markdown]
# ### Save in a json file

# %%
# !mkdir -p /home/jservon/Chapter12_IPCC/data/snw/

# %%
import json
ensemble = 'CMIP6'
outfilename = '/home/jservon/Chapter12_IPCC/data/snw/'+ensemble+'_SWE100_AR6_regional_averages.json'
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %% [markdown]
# ## CMIP5

# %%
NAM_regions = ['NWN','NEN','WNA','CNA','ENA','NCA','CAR']


exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='85',
         clim_period = '1995_2014'),    
    # -- Mid term
    dict(experiment='85',
         clim_period = '2041_2060'),
    dict(experiment='26',
         clim_period = '2041_2060'),
    # -- Late term
    dict(experiment='85',
         clim_period = '2081_2099'),
    dict(experiment='26',
         clim_period = '2081_2099'),
]

# -- Loop on the scenarios
ens_exp_dict = dict()
for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    clim_period = exp['clim_period']
    
    # -- Create ensemble object for the scenario
    req_exp = ds(project='snw_cmip5_ch12',
                 experiment = experiment,
                 clim_period = clim_period,
                 model = '*'
                )
    ens_exp = req_exp.explore('ensemble')
    
    # -- Climatologies
    ens_exp_dict[experiment+'_'+clim_period] = clim_average(ens_exp, 'ANM')

ens_GWL_dict = dict()
for GWL in ['1.5','2','3','4']:
    #
    req_GWL = ds(project='snw_cmip5_GWL_ch12',
                 GWL = GWL,
                 model = '*'
                )
    GWL_ens = req_GWL.explore('ensemble')
    # -- Climatologies
    ens_GWL_dict[GWL] = GWL_ens

# %%
# -- Make a mask with baseline to keep only the grid points with more than 30 days
mask_dict = dict()
for mem in ens_exp_dict['85_1995_2014']:
    mask_dict[mem] = ccdo(ens_exp_dict['85_1995_2014'][mem], operator='setctomiss,0 -gtc,30')

# %%
regional_averages = dict()

NAM_regions = ['NWN','NEN','WNA','CNA','ENA','NCA','CAR']

# -- Loop on experiments / horizons
for ens_exp in ens_exp_dict:
    print ens_exp
    regional_averages[ens_exp] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_exp_dict[ens_exp]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', 'all')
        region_names = tmp.abbrevs
        for region_name in NAM_regions:
            #tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', region_name)
            #region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[ens_exp]:
                regional_averages[ens_exp][region_name] = [region_value]
            else:
                regional_averages[ens_exp][region_name].append(region_value)
# Out:
# 85_1995_2014
# inmcm4
# NWN
# 77.5870930181
# NEN
# 74.1847872966
# WNA
# 40.6906102507
# CNA
# nan
# ENA
# 36.4672775269
# NCA
# nan
# CAR
# nan
# BNU-ESM
# NWN
# 73.4059002526
# NEN
# 63.3137267306
# WNA
# 46.5450041045
# CNA
# nan
# ENA
# 44.3131071621
# NCA
# nan
# CAR
# nan
# FGOALS-g2
# NWN
# 79.4840384875
# NEN
# 75.9615130307
# WNA
# 54.8773239579
# CNA
# 34.498629522
# ENA
# 48.2478412933
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G
# NWN
# 75.8499808103
# NEN
# 58.508430758
# WNA
# 59.9764125366
# CNA
# 30.8037471771
# ENA
# 43.1916809574
# NCA
# nan
# CAR
# nan
# MRI-CGCM3
# NWN
# 75.5637777474
# NEN
# 72.875955162
# WNA
# 64.2649461004
# CNA
# 47.3474578857
# ENA
# 60.6068333323
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M
# NWN
# 69.9978240309
# NEN
# 60.1381413688
# WNA
# 54.7372366595
# CNA
# nan
# ENA
# 41.7533895118
# NCA
# nan
# CAR
# nan
# NorESM1-M
# NWN
# 82.4301220526
# NEN
# 85.2143104813
# WNA
# 52.3366520096
# CNA
# nan
# ENA
# 54.8820021493
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0
# NWN
# 75.4380393884
# NEN
# 60.2001721144
# WNA
# 30.1809921265
# CNA
# nan
# ENA
# 43.2205833435
# NCA
# nan
# CAR
# nan
# GFDL-CM3
# NWN
# 70.6544268272
# NEN
# 80.8315497687
# WNA
# 56.7562665233
# CNA
# nan
# ENA
# 46.4749992916
# NCA
# nan
# CAR
# nan
# MIROC-ESM
# NWN
# 69.082461618
# NEN
# 60.2702895516
# WNA
# 46.8299879626
# CNA
# 39.4933586121
# ENA
# 51.5828589855
# NCA
# nan
# CAR
# nan
# CNRM-CM5
# NWN
# 77.4950669962
# NEN
# 68.6042185762
# WNA
# 65.7408925182
# CNA
# nan
# ENA
# 59.0299134184
# NCA
# nan
# CAR
# nan
# HadGEM2-ES
# NWN
# 77.2402028038
# NEN
# 65.3993145426
# WNA
# 59.6072636406
# CNA
# nan
# ENA
# 51.6930493378
# NCA
# nan
# CAR
# nan
# CanESM2
# NWN
# 68.4464761879
# NEN
# 57.7056585179
# WNA
# 41.00786502
# CNA
# nan
# ENA
# 40.2328635784
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM
# NWN
# 65.2105793949
# NEN
# 59.672829154
# WNA
# 45.837501222
# CNA
# 46.6421890259
# ENA
# 46.5984761503
# NCA
# nan
# CAR
# nan
# bcc-csm1-1
# NWN
# 79.4276424034
# NEN
# 61.8148003269
# WNA
# 41.5753753924
# CNA
# nan
# ENA
# 51.036207537
# NCA
# nan
# CAR
# nan
# MIROC5
# NWN
# 59.5374115517
# NEN
# 58.1758554271
# WNA
# 44.5914309026
# CNA
# nan
# ENA
# 45.791626166
# NCA
# nan
# CAR
# nan
# HadGEM2-CC
# NWN
# 77.4848033684
# NEN
# 59.4196299834
# WNA
# 58.2814968746
# CNA
# nan
# ENA
# 55.7002307345
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR
# NWN
# 65.2326985149
# NEN
# 50.6005330484
# WNA
# 42.5731568614
# CNA
# nan
# ENA
# 35.6775566101
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m
# NWN
# 82.5640932314
# NEN
# 76.7495864982
# WNA
# 50.7069255354
# CNA
# 31.3668937683
# ENA
# 43.4801210867
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR
# NWN
# 65.6250396627
# NEN
# 51.1297692056
# WNA
# 43.3606727633
# CNA
# nan
# ENA
# 35.2597878774
# NCA
# nan
# CAR
# nan
# MRI-ESM1
# NWN
# 73.6329266033
# NEN
# 70.02132308
# WNA
# 66.0520772993
# CNA
# 42.658372879
# ENA
# 61.9035066566
# NCA
# nan
# CAR
# nan
# 26_2081_2099
# BNU-ESM
# NWN
# 64.4835451977
# NEN
# 62.2901896814
# WNA
# 23.5760012616
# CNA
# nan
# ENA
# 33.7846476956
# NCA
# nan
# CAR
# nan
# FGOALS-g2
# NWN
# 79.1934831158
# NEN
# 76.9869887086
# WNA
# 39.528538401
# CNA
# 43.1033624587
# ENA
# 46.0873053121
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G
# NWN
# 67.3971128663
# NEN
# 50.3125766056
# WNA
# 58.7427314543
# CNA
# 21.1990509033
# ENA
# 39.7869620854
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m
# NWN
# 74.1572359324
# NEN
# 77.4926484796
# WNA
# 31.1194849968
# CNA
# 26.1311969757
# ENA
# 33.7586423224
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M
# NWN
# 59.8523626263
# NEN
# 54.6660453836
# WNA
# 40.5680230882
# CNA
# nan
# ENA
# 42.4359393834
# NCA
# nan
# CAR
# nan
# NorESM1-M
# NWN
# 70.7748975028
# 69.4114308691
# WNA
# 19.8718769698
# CNA
# 21.8842582703
# ENA
# 32.7936591027
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M
# NWN
# 48.6367746802
# NEN
# 52.5578851274
# WNA
# 13.727506927
# CNA
# nan
# ENA
# 12.4221341405
# NCA
# nan
# CAR
# nan
# NorESM1-M
# NWN
# 55.6332587465
# NEN
# 71.1782255457
# WNA
# 6.49340841823
# CNA
# nan
# ENA
# 17.2336554527
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0
# NWN
# 40.0412622477
# NEN
# 39.6515107838
# WNA
# 0.0
# CNA
# nan
# ENA
# 8.86446332932
# NCA
# nan
# CAR
# nan
# GFDL-CM3
# NWN
# 22.5016939711
# NEN
# 34.4982490591
# WNA
# 4.01247796317
# CNA
# nan
# ENA
# 1.56015033381
# NCA
# nan
# CAR
# nan
# MIROC-ESM
# NWN
# 34.0577297274
# NEN
# 22.5019101154
# WNA
# 0.0
# CNA
# 0.203536182642
# ENA
# 0.119990929001
# NCA
# nan
# CAR
# nan
# CNRM-CM5
# NWN
# 61.3394384188
# NEN
# 54.6796341162
# WNA
# 25.8842242666
# CNA
# nan
# ENA
# 15.6546584513
# NCA
# nan
# CAR
# nan
# HadGEM2-ES
# NWN
# 37.6686706815
# NEN
# 47.5505842513
# WNA
# 0.79128922974
# CNA
# nan
# ENA
# 10.4600578953
# NCA
# nan
# CAR
# nan
# CanESM2
# NWN
# 34.6608502095
# NEN
# 36.4271444028
# WNA
# 0.119639614945
# CNA
# nan
# ENA
# 1.15226980515
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM
# NWN
# 28.8816527373
# NEN
# 21.8957411326
# WNA
# 0.0
# CNA
# 0.31455591321
# ENA
# 0.47857740085
# NCA
# nan
# CAR
# nan
# bcc-csm1-1
# NWN
# 35.6330945364
# NEN
# 50.0270768801
# WNA
# 1.38117790487
# CNA
# nan
# ENA
# 13.8375370903
# NCA
# nan
# CAR
# nan
# MIROC5
# NWN
# 36.2389062512
# NEN
# 40.6915930238
# WNA
# 1.35417021697
# CNA
# nan
# ENA
# 8.81230418847
# NCA
# nan
# CAR
# nan
# HadGEM2-CC
# NWN
# 46.3677614455
# NEN
# 46.2328244361
# WNA
# 8.40974228135
# CNA
# nan
# ENA
# 11.2187986682
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR
# NWN
# 29.2940806667
# NEN
# 32.0172733671
# WNA
# 7.63916704088
# CNA
# nan
# ENA
# 9.5788444519
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m
# NWN
# 47.7927424336
# NEN
# 64.3988235986
# WNA
# 3.55572621366
# CNA
# 5.82888889313
# ENA
# 23.1899718962
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR
# NWN
# 32.5983333251
# NEN
# 35.0822270169
# WNA
# 3.46888035806
# CNA
# nan
# ENA
# 8.59072399139
# NCA
# nan
# CAR
# nan
# MRI-ESM1
# NWN
# 54.15882199
# NEN
# 66.5904133333
# WNA
# CNA
# nan
# ENA
# 28.0258749966
# NCA
# nan
# CAR
# nan
# HadGEM2-CC
# NWN
# 64.5515348555
# NEN
# 60.1116836256
# WNA
# 31.9248243835
# CNA
# nan
# ENA
# 35.0609784055
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR
# NWN
# 50.5399745864
# NEN
# 45.5377990742
# WNA
# 13.7676918747
# CNA
# nan
# ENA
# 17.426294899
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m
# NWN
# 66.4138305254
# NEN
# 72.3375573014
# WNA
# 20.4497145794
# CNA
# 26.2742290497
# ENA
# 41.4621657288
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR
# NWN
# 53.5791629176
# NEN
# 49.0795975971
# WNA
# 11.759305113
# CNA
# nan
# ENA
# 26.9902114868
# NCA
# nan
# CAR
# nan
# MRI-ESM1
# NWN
# 62.6781301111
# NEN
# 68.5662685753
# WNA
# 51.5724954157
# CNA
# 20.6425352097
# ENA
# 44.5722804428
# NCA
# nan
# CAR
# nan
# 26_2041_2060
# BNU-ESM
# NWN
# 67.4715836484
# NEN
# 60.1152878611
# WNA
# 25.7843555502
# CNA
# nan
# ENA
# 43.1571778946
# NCA
# nan
# CAR
# nan
# FGOALS-g2
# NWN
# 75.5233682098
# NEN
# 74.9561856655
# WNA
# 30.5191579529
# CNA
# 28.6693205522
# ENA
# 46.2026571721
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G
# NWN
# 68.2385380244
# NEN
# 60.2760771513
# WNA
# 49.7318535958
# CNA
# 20.7720317841
# ENA
# 43.3782136183
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m
# NWN
# 77.430167876
# NEN
# 74.199178021
# WNA
# 29.6782593715
# CNA
# 21.3394870758
# ENA
# 37.8859045495
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M
# NWN
# 58.3650291705
# NEN
# 52.352342358
# WNA
# 42.9339576939
# CNA
# nan
# ENA
# 41.9189650006
# NCA
# nan
# CAR
# nan
# NorESM1-M
# NWN
# 75.9247674464
# NEN
# 85.5150703929
# WNA
# 29.1990340624
# CNA
# nan
# ENA
# 37.4941904885
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0
# NWN
# 71.6319773413
# NEN
# 52.2868636329
# WNA
# 8.07524013519
# CNA
# nan
# ENA
# 30.9666400909
# NCA
# nan
# CAR
# nan
# MIROC-ESM
# NWN
# 55.1379097871
# NEN
# 53.5483953924
# WNA
# 4.88943231427
# CNA
# 22.1937494278
# ENA
# 20.7945066474
# NCA
# nan
# CAR
# nan
# CNRM-CM5
# NWN
# 76.8707081856
# NEN
# 65.3235667864
# WNA
# 46.9685363992
# CNA
# nan
# ENA
# 44.1424238016
# NCA
# nan
# CAR
# nan
# HadGEM2-ES
# NWN
# 71.1921666126
# NEN
# 64.7902792206
# WNA
# 49.3306930617
# CNA
# nan
# ENA
# 41.2659251202
# NCA
# nan
# CAR
# nan
# CanESM2
# NWN
# 64.3346622008
# NEN
# 51.2379788679
# WNA
# 12.8355685155
# CNA
# nan
# ENA
# 18.3589197781
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM
# NWN
# 62.046567473
# NEN
# 54.6330752044
# WNA
# 6.04857794183
# CNA
# 16.5480465889
# ENA
# 25.5759629357
# NCA
# nan
# CAR
# nan
# MIROC5
# NWN
# 54.6665731754
# NEN
# 60.0160119077
# WNA
# 25.6607948541
# CNA
# nan
# ENA
# 40.6840911714
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR
# NWN
# 57.5353118924
# NEN
# 43.518326618
# WNA
# 33.145995781
# CNA
# nan
# ENA
# 22.6665885925
# NCA
# nan
# CAR
# nan
# MRI-CGCM3
# NWN
# 69.366263299
# NEN
# 76.0017858974
# WNA
# 49.7236070315
# CNA
# 38.5368270874
# ENA
# 57.0435918606
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR
# NWN
# 62.908257769
# NEN
# 51.6892222597
# WNA
# 33.15757923
# CNA
# nan
# ENA
# 26.0180781682
# NCA
# nan
# CAR
# nan
# bcc-csm1-1
# NWN
# 74.0131971592
# NEN
# 64.9192508658
# WNA
# 21.679420762
# CNA
# nan
# ENA
# 35.790949037
# NCA
# nan
# CAR
# nan

# %%
# -- Loop on experiments / horizons
for GWL in ens_GWL_dict :
    print GWL
    regional_averages[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        #if mem in mask_dict:
        tmp = average_over_AR6_region(cfile(ens_GWL_dict[GWL][mem]), cfile(mask_dict[mem.replace('_85','').replace('_26','')]), 'snw', 'all')
        region_names = tmp.abbrevs
        for region_name in NAM_regions:
            #tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', region_name)
            #region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[GWL]:
                regional_averages[GWL][region_name] = [region_value]
            else:
                regional_averages[GWL][region_name].append(region_value)
# Out:
# 1.5
# MPI-ESM-MR_26
# NWN
# 66.2196359303
# NEN
# 46.7356215422
# WNA
# 32.3889908857
# CNA
# nan
# ENA
# 18.3711544037
# NCA
# nan
# CAR
# nan
# MIROC-ESM_85
# NWN
# 63.4696603161
# NEN
# 56.7500224882
# WNA
# 27.6336500623
# CNA
# 31.4964838028
# ENA
# 40.9404566807
# NCA
# nan
# CAR
# nan
# MIROC5_26
# NWN
# 55.4903721432
# NEN
# 59.1368074292
# WNA
# 29.4317006128
# CNA
# nan
# ENA
# 41.2902271896
# NCA
# nan
# CAR
# nan
# MRI-CGCM3_85
# NWN
# 68.9574484766
# NEN
# 76.0655981023
# WNA
# 45.504669775
# CNA
# 55.4960899353
# ENA
# 48.1727568814
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_85
# NWN
# 58.8129443223
# NEN
# 50.8765234451
# WNA
# 29.6813766048
# CNA
# nan
# ENA
# 19.8670004209
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G_85
# NWN
# 70.9080454963
# NEN
# 57.223531716
# WNA
# 49.8991319479
# CNA
# 6.95314598083
# ENA
# 31.5111014096
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR_85
# NWN
# 58.9895778327
# NEN
# 44.9691648412
# WNA
# 34.2957443658
# CNA
# nan
# ENA
# 31.0544330597
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_85
# NWN
# 80.4615926014
# NEN
# 76.776653663
# WNA
# 49.540448414
# CNA
# 34.1601753235
# ENA
# 42.7021485417
# NCA
# nan
# CAR
# nan
# MIROC-ESM_26
# NWN
# 61.6429085827
# NEN
# 55.1020055254
# WNA
# 22.2559012315
# CNA
# 29.2507820129
# ENA
# 48.1336885289
# NCA
# nan
# CAR
# nan
# HadGEM2-CC_85
# NWN
# 72.6614097224
# NEN
# 60.1381234903
# WNA
# 49.8373774027
# CNA
# nan
# ENA
# 39.917924502
# NCA
# nan
# CAR
# nan
# CanESM2_85
# NWN
# 66.0140641554
# NEN
# 56.4003965342
# WNA
# 37.5791143786
# CNA
# nan
# ENA
# 37.5585656647
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0_26
# NWN
# 72.4236251403
# NEN
# 51.1503894775
# WNA
# 8.19413566589
# CNA
# nan
# ENA
# 31.3582248688
# NCA
# nan
# CAR
# nan
# GFDL-CM3_85
# NWN
# 64.2132931671
# NEN
# 65.933154741
# WNA
# 37.9042823069
# CNA
# nan
# ENA
# 36.5410714831
# NCA
# nan
# CAR
# nan
# CNRM-CM5_26
# NWN
# 76.4752243355
# NEN
# 65.1021626971
# WNA
# 50.1483247004
# CNA
# nan
# ENA
# 43.930517555
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_26
# NWN
# 81.3695675341
# NEN
# 79.5299168832
# WNA
# 41.4138190952
# CNA
# 27.4988117218
# ENA
# 45.6108833905
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_85
# NWN
# 61.7962372344
# NEN
# 55.3922792071
# WNA
# 33.536336254
# CNA
# 37.6031255722
# ENA
# 38.3446746025
# NCA
# nan
# CAR
# nan
# inmcm4_85
# NWN
# 67.8111272754
# NEN
# 69.3813358931
# WNA
# 12.6955642819
# CNA
# nan
# ENA
# 25.1454825401
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_85
# NWN
# 62.5309839913
# NEN
# 57.392689481
# WNA
# 42.8099629432
# CNA
# nan
# ENA
# 33.2835636353
# NCA
# nan
# CAR
# nan
# CNRM-CM5_85
# NWN
# 78.9551614198
# NEN
# 63.5670363793
# WNA
# 55.7628230346
# CNA
# nan
# ENA
# 50.9314428207
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_26
# NWN
# 65.2110690301
# NEN
# 56.7418301278
# WNA
# 28.7040129103
# CNA
# 32.8550786972
# ENA
# 39.6245322647
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_85
# NWN
# 73.5401325434
# NEN
# 57.2138473396
# WNA
# 54.0013797488
# CNA
# nan
# ENA
# 45.1093174529
# NCA
# nan
# CAR
# nan
# bcc-csm1-1_26
# NWN
# 80.4649322458
# NEN
# 65.3056191879
# WNA
# 29.8889779045
# CNA
# nan
# ENA
# 39.489772628
# NCA
# nan
# CAR
# nan
# CanESM2_26
# NWN
# 69.5035090118
# NEN
# 58.2943832173
# WNA
# 42.2779275537
# CNA
# nan
# ENA
# 36.858002018
# NCA
# nan
# CAR
# nan
# NorESM1-M_85
# NWN
# 72.2319792155
# NEN
# 80.7985673406
# WNA
# 33.4233552299
# CNA
# nan
# ENA
# 52.2791246687
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_26
# NWN
# 72.3702620289
# NEN
# 62.7762475444
# WNA
# 44.2441259966
# CNA
# nan
# ENA
# 33.4405458776
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0_85
# NWN
# 74.6534392782
# NEN
# 58.0027911029
# WNA
# 11.7587928772
# CNA
# nan
# ENA
# 32.4200866699
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_26
# NWN
# 63.3394613464
# NEN
# 50.15372212
# WNA
# 25.5670805438
# CNA
# nan
# ENA
# 26.6221049627
# NCA
# nan
# CAR
# nan
# bcc-csm1-1_85
# NWN
# 74.6196544851
# NEN
# 63.7426714818
# WNA
# 27.470473629
# CNA
# nan
# ENA
# 41.5098436093
# NCA
# nan
# CAR
# nan
# MIROC5_85
# NWN
# 55.6023170569
# NEN
# 58.0522065292
# WNA
# 27.9013144766
# CNA
# nan
# ENA
# 37.7019899065
# NCA
# nan
# CAR
# nan
# 3
# MIROC-ESM_85
# NWN
# 55.4650647169
# NEN
# 43.377179045
# WNA
# 0.392282263235
# CNA
# 4.08710947633
# ENA
# 8.74051902405
# NCA
# nan
# CAR
# nan
# MRI-CGCM3_85
# NWN
# 60.7922640665
# NEN
# 67.6375611661
# WNA
# 26.7882402606
# CNA
# 36.7032241821
# ENA
# 37.9376688644
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G_85
# NWN
# 55.8018296965
# NEN
# 51.3901574855
# WNA
# 18.9300191485
# CNA
# 3.38716602325
# ENA
# 20.930253139
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR_85
# NWN
# 50.2417787323
# NEN
# 42.7299294421
# WNA
# 11.0321459107
# CNA
# nan
# ENA
# 10.9630867004
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_85
# NWN
# 62.4983431388
# NEN
# 72.926911246
# WNA
# 13.9618536937
# CNA
# 16.2613697052
# ENA
# 31.1215345269
# NCA
# nan
# CAR
# nan
# HadGEM2-CC_85
# NWN
# 58.1111540349
# NEN
# 59.1231616828
# WNA
# 23.2166032906
# CNA
# nan
# ENA
# 31.746933849
# NCA
# nan
# CAR
# nan
# CanESM2_85
# NWN
# 57.993907154
# NEN
# 48.8896647169
# WNA
# 5.81783765292
# CNA
# nan
# ENA
# 17.8577382124
# NCA
# nan
# CAR
# nan
# GFDL-CM3_85
# NWN
# 42.2270293592
# NEN
# 52.0684149168
# WNA
# 12.0518269437
# CNA
# nan
# ENA
# 26.6660709381
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_85
# NWN
# 54.6690180215
# NEN
# 49.4775204517
# WNA
# 1.32640869237
# CNA
# 6.171875
# ENA
# 13.3058219935
# NCA
# nan
# CAR
# nan
# inmcm4_85
# NWN
# 47.3857613482
# NEN
# 59.4978277423
# WNA
# 1.54821412164
# CNA
# nan
# ENA
# 11.6976071596
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_85
# NWN
# 53.4075022454
# NEN
# 50.1487260693
# WNA
# 18.8659948266
# CNA
# nan
# ENA
# 15.2591301478
# NCA
# nan
# CAR
# nan
# CNRM-CM5_85
# NWN
# 73.0853471784
# NEN
# 58.7107688732
# WNA
# 35.6879604564
# CNA
# nan
# ENA
# 36.4764361753
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_85
# NWN
# 51.3271827056
# NEN
# 46.1874304879
# WNA
# 9.97177256589
# CNA
# nan
# ENA
# 16.0621053378
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_85
# NWN
# 62.6518445621
# NEN
# 58.3125324712
# WNA
# 20.0065280655
# CNA
# nan
# ENA
# 25.5481490915
# NCA
# nan
# CAR
# nan
# NorESM1-M_85
# NWN
# 59.283377539
# NEN
# 73.4159097475
# WNA
# 15.8182346306
# CNA
# nan
# ENA
# 27.1415143694
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0_85
# NWN
# 52.2696544133
# NEN
# 54.9630342342
# WNA
# 0.105186417699
# CNA
# nan
# ENA
# 24.8384429932
# NCA
# nan
# CAR
# nan
# bcc-csm1-1_85
# NWN
# 55.550125771
# NEN
# 62.0782280338
# WNA
# 7.18546411091
# CNA
# nan
# ENA
# 28.2923103806
# NCA
# nan
# CAR
# nan
# MIROC5_85
# NWN
# 49.0935100182
# NEN
# 51.2653861005
# WNA
# 11.2068481869
# CNA
# nan
# ENA
# 16.0261854114
# NCA
# nan
# CAR
# nan
# 2
# MIROC-ESM_85
# NWN
# 60.741644754
# NEN
# 53.4205586841
# WNA
# 12.2678969171
# CNA
# 22.2183589935
# ENA
# 29.1399276528
# NCA
# nan
# CAR
# nan
# MRI-CGCM3_85
# NWN
# 64.6177465703
# NEN
# 71.1881161361
# WNA
# 43.5401800102
# CNA
# 49.8721580505
# ENA
# 46.9838039542
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_85
# NWN
# 60.3063872376
# NEN
# 51.1554162823
# WNA
# 26.4820304449
# CNA
# nan
# ENA
# 25.9131428401
# NCA
# nan
# CAR
# nan
# GFDL-ESM2G_85
# NWN
# 60.3311433005
# NEN
# 47.6845119095
# WNA
# 44.5235141148
# CNA
# 12.011136055
# ENA
# 39.2995404
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR_85
# NWN
# 58.9444937529
# NEN
# 44.0982678613
# WNA
# 30.8800311926
# CNA
# nan
# ENA
# 26.1281486511
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_85
# NWN
# 81.4975500774
# NEN
# 78.4193988372
# WNA
# 36.7528572798
# CNA
# 24.237487793
# ENA
# 37.1165314756
# NCA
# nan
# CAR
# nan
# MIROC-ESM_26
# NWN
# 56.2595993732
# NEN
# 53.1828722673
# WNA
# 7.12319204547
# CNA
# 14.7898440361
# ENA
# 21.8897287677
# NCA
# nan
# CAR
# nan
# HadGEM2-CC_85
# NWN
# 67.7538804487
# NEN
# 60.233127542
# WNA
# 35.1484978435
# CNA
# nan
# ENA
# 33.0631742427
# NCA
# nan
# CAR
# nan
# CanESM2_85
# NWN
# 64.8818781187
# NEN
# 55.3012098392
# WNA
# 27.6640217146
# CNA
# nan
# ENA
# 24.3417356452
# NCA
# nan
# CAR
# nan
# GFDL-CM3_85
# NWN
# 61.1215365599
# NEN
# 62.3515619019
# WNA
# 36.8368941524
# CNA
# nan
# ENA
# 30.7678571429
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_85
# NWN
# 58.4786848036
# NEN
# 51.8041794917
# WNA
# 14.7414072939
# CNA
# 23.7957034111
# ENA
# 31.6459571971
# NCA
# nan
# CAR
# nan
# inmcm4_85
# NWN
# 60.2866425959
# NEN
# 66.5093627933
# WNA
# 6.97222321495
# CNA
# nan
# ENA
# 23.6877651215
# NCA
# nan
# CAR
# nan
# NorESM1-M_85
# NWN
# 69.6986600727
# NEN
# 76.1389757005
# WNA
# 30.6134969962
# CNA
# nan
# ENA
# 50.4123208182
# NCA
# nan
# CAR
# nan
# CNRM-CM5_85
# NWN
# 76.0137204404
# NEN
# 62.0957256684
# WNA
# 53.1065737633
# CNA
# nan
# ENA
# 37.672795826
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_26
# NWN
# 61.0964138474
# NEN
# 57.515750316
# WNA
# 11.3511609377
# CNA
# 24.1214847565
# ENA
# 27.8712169676
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_85
# NWN
# 65.8182107185
# NEN
# 60.1564578553
# WNA
# 42.6282809644
# CNA
# nan
# ENA
# 34.6915170375
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_26
# NWN
# 80.584942774
# NEN
# 77.104322689
# WNA
# 31.8205186821
# CNA
# 24.0982265472
# ENA
# 36.7621060838
# NCA
# nan
# CAR
# nan
# CanESM2_26
# NWN
# 61.7554856575
# NEN
# 55.9833907359
# WNA
# 28.1515417006
# CNA
# nan
# ENA
# 24.3661930121
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_85
# NWN
# 56.7038958576
# NEN
# 58.0974235849
# WNA
# 32.2250238039
# CNA
# nan
# ENA
# 28.1327791148
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0_85
# NWN
# 60.7773045897
# NEN
# 58.6506808757
# WNA
# 3.16611123085
# CNA
# nan
# ENA
# 36.668107605
# NCA
# nan
# CAR
# nan
# bcc-csm1-1_85
# NWN
# 71.7711823434
# NEN
# 66.5608739069
# WNA
# 18.9256228361
# CNA
# nan
# ENA
# 36.5325077099
# NCA
# nan
# CAR
# nan
# MIROC5_85
# NWN
# 56.2714716718
# NEN
# 58.2645817161
# WNA
# 21.2182870877
# CNA
# nan
# ENA
# 27.3464824254
# NCA
# nan
# CAR
# nan
# 4
# MIROC-ESM_85
# NWN
# 42.2229038486
# NEN
# 35.5989871601
# WNA
# 0.0170812175548
# CNA
# 1.21015622653
# ENA
# 4.10566670469
# NCA
# nan
# CAR
# nan
# CNRM-CM5_85
# NWN
# 62.7103402844
# NEN
# 54.458611394
# WNA
# 27.7096846525
# CNA
# nan
# ENA
# 17.0698373031
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_85
# NWN
# 39.3359944855
# NEN
# 40.2603020343
# WNA
# 6.80922829953
# CNA
# nan
# ENA
# 9.44000506401
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_85
# NWN
# 51.0489732979
# NEN
# 51.4331676232
# WNA
# 9.44147217997
# CNA
# nan
# ENA
# 13.2615407065
# NCA
# nan
# CAR
# nan
# MPI-ESM-MR_85
# NWN
# 32.7062323792
# NEN
# 34.7164205059
# WNA
# 7.2865653514
# CNA
# nan
# ENA
# 8.82960233688
# NCA
# nan
# CAR
# nan
# bcc-csm1-1-m_85
# NWN
# 49.4278004785
# NEN
# 66.447410312
# WNA
# 5.47234760368
# CNA
# 10.041560173
# ENA
# 22.6835891782
# NCA
# nan
# CAR
# nan
# HadGEM2-CC_85
# NWN
# 51.5636086076
# NEN
# 52.4617864118
# WNA
# 9.05522724294
# CNA
# nan
# ENA
# 19.8595130251
# NCA
# nan
# CAR
# nan
# CanESM2_85
# NWN
# 47.6624745789
# NEN
# 45.0381897076
# WNA
# 4.32534321317
# CNA
# nan
# ENA
# 5.27134565162
# NCA
# nan
# CAR
# nan
# CSIRO-Mk3-6-0_85
# NWN
# 48.5327738586
# NEN
# 46.6898058344
# WNA
# 0.377502381802
# CNA
# nan
# ENA
# 17.6721544266
# NCA
# nan
# CAR
# nan
# GFDL-CM3_85
# NWN
# 32.5072978264
# NEN
# 45.8663527959
# WNA
# 4.06449574424
# CNA
# nan
# ENA
# 4.68035713264
# NCA
# nan
# CAR
# nan
# bcc-csm1-1_85
# NWN
# 41.7652066714
# NEN
# 54.5764497114
# WNA
# 0.984794582884
# CNA
# nan
# ENA
# 19.4004507098
# NCA
# nan
# CAR
# nan
# MIROC-ESM-CHEM_85
# NWN
# 41.777109323
# NEN
# 37.0080057527
# WNA
# 0.0
# CNA
# 3.68437492847
# ENA
# 7.56252468346
# NCA
# nan
# CAR
# nan

# %%
import numpy
quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# 1.5 NEN
# 1.5 ENA
# 1.5 WNA
# 1.5 CAR
# 1.5 CNA
# 1.5 NCA
# 1.5 NWN
# 85_1995_2014 NEN
# 85_1995_2014 ENA
# 85_1995_2014 WNA
# 85_1995_2014 CAR
# 85_1995_2014 CNA
# 85_1995_2014 NCA
# 85_1995_2014 NWN
# 26_2041_2060 NEN
# 26_2041_2060 ENA
# 26_2041_2060 WNA
# 26_2041_2060 CAR
# 26_2041_2060 CNA
# 26_2041_2060 NCA
# 26_2041_2060 NWN
# 3 NEN
# 3 ENA
# 3 WNA
# 3 CAR
# 3 CNA
# 3 NCA
# 3 NWN
# 26_2081_2099 NEN
# 26_2081_2099 ENA
# 26_2081_2099 WNA
# 26_2081_2099 CAR
# 26_2081_2099 CNA
# 26_2081_2099 NCA
# 26_2081_2099 NWN
# 4 NEN
# 4 ENA
# 4 WNA
# 4 CAR
# 4 CNA
# 4 NCA
# 4 NWN
# 85_2041_2060 NEN
# 85_2041_2060 ENA
# 85_2041_2060 WNA
# 85_2041_2060 CAR
# 85_2041_2060 CNA
# 85_2041_2060 NCA
# 85_2041_2060 NWN
# 2 NEN
# 2 ENA
# 2 WNA
# 2 CAR
# 2 CNA
# 2 NCA
# 2 NWN
# 85_2081_2099 NEN
# 85_2081_2099 ENA
# 85_2081_2099 WNA
# 85_2081_2099 CAR
# 85_2081_2099 CNA
# 85_2081_2099 NCA
# 85_2081_2099 NWN

# %%
import json
ensemble = 'CMIP5'
outfilename = '/home/jservon/Chapter12_IPCC/data/snw/'+ensemble+'_NORTH-AMERICA_snw_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %% [markdown]
# ## CORDEX, all domains

# %%
# -- CORDEX
pattern = '/data/ciles/IPCC/FGD/snow/final/NA_CORDEX/time_periods/NAM-22_${model}_${experiment}_snw100seas_${clim_period}_remo22grid.nc'
cproject('snw_NAM-22_cordex_ch12','experiment',('period','fx'),'clim_period','model','thres', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_NAM-22_cordex_ch12', url=pattern) 
pattern_gwl = '/data/ciles/IPCC/FGD/snow/final/NA_CORDEX/GWLs/NAM-22_${model}_GWL${GWL}_snw100seas_remo22grid.nc'
cproject('snw_NAM-22_cordex_GWL_ch12',('period','fx'),'model','GWL', ('variable','snw'), ensemble=['model'], separator='%')
dataloc(project='snw_NAM-22_cordex_GWL_ch12', url=pattern_gwl)

clog('critical')

exp_list = [
    # -- Baseline (ssp126 and ssp585 are the same files)
    dict(experiment='85',
         clim_period = '1995_2014'),    
    # -- Mid term
    dict(experiment='85',
         clim_period = '2041_2060'),
    dict(experiment='26',
         clim_period = '2041_2060'),
    # -- Late term
    dict(experiment='85',
         clim_period = '2081_209*'),
    dict(experiment='26',
         clim_period = '2081_209*'),
]

ens_exp_dict = dict()
ens_GWL_dict = dict()

for exp in exp_list:
    #
    # -- Experiment and period
    experiment = exp['experiment']
    clim_period = exp['clim_period']

    # -- Create ensemble object for the scenario
    req_dict = dict(project='snw_NAM-22_cordex_ch12',
                  experiment = experiment,
                  clim_period = clim_period,
                 )
    #
    req_exp = ds(model = '*', **req_dict)
    lom = req_exp.explore('choices')['model']

    ens_dict = dict()
    for model in lom:
        ens_dict[model] = ds(model=model, **req_dict).explore('resolve')
    ens = cens(ens_dict)
    
    ens_exp_dict[experiment+'_'+clim_period] = ens
    

ens_GWL_dict = dict()
for GWL in ['1.5','2','3','4']:
    #
    req_GWL = ds(project='snw_NAM-22_cordex_GWL_ch12',
                 GWL = GWL,
                 model = '*',
                )
    GWL_ens = req_GWL.explore('ensemble')
    # -- Climatologies
    ens_GWL_dict[GWL] = GWL_ens

# %%
# -- Make a mask with baseline to keep only the grid points with more than 30 days
mask_dict = dict()
for mem in ens_exp_dict['85_1995_2014']:
    mask_dict[mem] = ccdo(ens_exp_dict['85_1995_2014'][mem], operator='setctomiss,0 -gtc,30')

# %%
regional_averages = dict()

NAM_regions = ['NWN','NEN','WNA','CNA','ENA','NCA','CAR']

# -- Loop on experiments / horizons
for ens_exp in ens_exp_dict:
    print ens_exp
    regional_averages[ens_exp] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_exp_dict[ens_exp]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        tmp = average_over_AR6_region(cfile(regridn(ens_exp_dict[ens_exp][mem], cdogrid='r1440x720')),
                                      cfile(regridn(mask_dict[mem.replace('_85','').replace('_26','')], cdogrid='r1440x720', option='remapnn')),
                                      'snw', 'all')
        region_names = tmp.abbrevs
        for region_name in NAM_regions:
            #tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', region_name)
            #region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[ens_exp]:
                regional_averages[ens_exp][region_name] = [region_value]
            else:
                regional_averages[ens_exp][region_name].append(region_value)
# Out:
# 26_2081_209*
# MOHC_HadGEM2-ES_r1i1p1_GERICS-REMO2015
# NWN
# 57.59484927
# NEN
# 61.1441613979
# WNA
# 50.5676226781
# CNA
# nan
# ENA
# 28.000532438
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_GERICS-REMO2015
# NWN
# 72.1118990531
# NEN
# 65.2929861347
# WNA
# 55.2910340696
# CNA
# 33.9361989704
# ENA
# 51.8346923983
# NCA
# nan
# CAR
# nan
# NCC_NorESM1-M_r1i1p1_GERICS-REMO2015
# NWN
# 60.455721035
# NEN
# 64.2124420006
# WNA
# 52.3136262519
# CNA
# nan
# ENA
# 38.4566986074
# NCA
# nan
# CAR
# nan
# 85_2081_209*
# MOHC_HadGEM2-ES_r1i1p1_GERICS-REMO2015
# NWN
# 34.2864371449
# NEN
# 40.1461484514
# WNA
# 12.3627024118
# CNA
# nan
# ENA
# 2.77613996074
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_GERICS-REMO2015
# NWN
# 46.5912623728
# NEN
# 47.6623193082
# WNA
# 25.845362888
# CNA
# 11.3324986094
# ENA
# 18.1866265132
# NCA
# nan
# CAR
# nan
# NCC_NorESM1-M_r1i1p1_GERICS-REMO2015
# NWN
# 49.1924621039
# NEN
# 52.8139728814
# WNA
# 25.6273889178
# CNA
# nan
# ENA
# 8.18513059176
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 90.6976061537
# NEN
# 82.9859549601
# WNA
# 58.9987903844
# CNA
# 27.1902262325
# ENA
# 49.5394617257
# NCA
# 3.30851535551
# CAR
# nan
# NOAA_GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 100.672957219
# NEN
# 91.6298665351
# WNA
# 68.4381298078
# CNA
# 37.1635189189
# ENA
# 54.2204710329
# NCA
# 7.58313839358
# CAR
# nan
# MOHC_HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 79.9945033043
# NEN
# 81.2357842902
# WNA
# 43.497786776
# CNA
# 34.5342726109
# ENA
# 47.959778192
# NCA
# 2.05631971359
# CAR
# nan
# 85_1995_2014
# MOHC_HadGEM2-ES_r1i1p1_GERICS-REMO2015
# NWN
# 64.4540269931
# NEN
# 61.5492806668
# WNA
# 59.4513702552
# CNA
# nan
# ENA
# 44.2376636013
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_GERICS-REMO2015
# NWN
# 73.7370020084
# NEN
# 71.8610367197
# WNA
# 72.1726848534
# CNA
# 43.1846420422
# ENA
# 53.0254900011
# NCA
# nan
# CAR
# nan
# NCC_NorESM1-M_r1i1p1_GERICS-REMO2015
# NWN
# 69.0248464093
# NEN
# 65.5419359255
# WNA
# 65.3780969446
# CNA
# nan
# ENA
# 48.4499560576
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 99.6008292998
# NEN
# 92.7756060752
# WNA
# 90.9056253679
# CNA
# 52.5051820644
# ENA
# 75.7517380512
# NCA
# 42.0392621564
# CAR
# nan
# NOAA_GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 99.0484091549
# NEN
# 92.2040566434
# WNA
# 92.2640921867
# CNA
# 42.4328892875
# ENA
# 76.4921234299
# NCA
# 55.5442486444
# CAR
# nan
# MOHC_HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 92.1557880874
# NEN
# 88.282161568
# WNA
# 89.3257362302
# CNA
# 46.2188274603
# ENA
# 76.6868305438
# NCA
# 30.1818790436
# CAR
# nan
# 85_2041_2060
# MOHC_HadGEM2-ES_r1i1p1_GERICS-REMO2015
# NWN
# 49.1928105406
# NEN
# 56.7061945337
# WNA
# 32.8955491486
# CNA
# nan
# ENA
# 21.0837973986
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_GERICS-REMO2015
# NWN
# 65.6721237626
# NEN
# 64.892887981
# WNA
# 45.9784815129
# CNA
# 27.2510475245
# ENA
# 42.4685884974
# NCA
# nan
# CAR
# nan
# NCC_NorESM1-M_r1i1p1_GERICS-REMO2015
# NWN
# 59.1997623096
# NEN
# 58.3870544325
# WNA
# 47.4054515377
# CNA
# nan
# ENA
# 31.7006239958
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 101.706704486
# NEN
# 97.8304884431
# WNA
# 74.4895995539
# CNA
# 56.1397506208
# ENA
# 74.8113217557
# NCA
# 13.7851773254
# CAR
# nan
# NOAA_GFDL-GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 101.143929125
# NEN
# 94.5270310072
# WNA
# 80.7915321083
# CNA
# 42.3180556062
# ENA
# 65.519145917
# NCA
# 21.2175414907
# CAR
# nan
# MOHC_HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4
# NWN
# 87.4649431041
# NEN
# 87.0402844863
# WNA
# 67.3825640865
# CNA
# 34.6346622592
# ENA
# 64.8212084466
# NCA
# 14.7696475983
# CAR
# nan
# 26_2041_2060
# MOHC_HadGEM2-ES_r1i1p1_GERICS-REMO2015
# NWN
# 56.4663939791
# NEN
# 61.5504125579
# WNA
# 57.6407414003
# CNA
# nan
# ENA
# 29.0210542515
# NCA
# nan
# CAR
# nan
# MPI-M_MPI-ESM-LR_r1i1p1_GERICS-REMO2015
# NWN
# 73.1808170847
# NEN
# 67.445304989
# WNA
# 65.5778415378
# CNA
# 41.7093463029
# ENA
# 37.8885842667
# NCA
# nan
# CAR
# nan
# NCC_NorESM1-M_r1i1p1_GERICS-REMO2015
# NWN
# 63.2682874267
# NEN
# 65.042127694
# WNA
# 46.3157756693
# CNA
# nan
# ENA
# 26.4717084499
# NCA
# nan
# CAR
# nan

# %%
wmask_dict = dict()
for elt in mask_dict:
    wmask_dict[elt.replace('MOHC_','').replace('MPI-M_','').replace('NOAA_GFDL-','').replace('NCC_','')] = mask_dict[elt]

# -- Loop on experiments / horizons
for GWL in ens_GWL_dict :
    print GWL
    regional_averages[GWL] = dict()
    # -- Loop on the members of each ensemble
    for mem in ens_GWL_dict[GWL]:
        print mem
        # -- Compute the averages for each AR6 region thanks to regionmask
        #if mem in mask_dict:
        tmp = average_over_AR6_region(cfile(regridn(ens_GWL_dict[GWL][mem], cdogrid='r1440x720')),
                                      cfile(regridn(wmask_dict[mem.replace('_85','').replace('_26','')], cdogrid='r1440x720', option='remapnn')),
                                      'snw', 'all')
        region_names = tmp.abbrevs
        for region_name in NAM_regions:
            #tmp = average_over_AR6_region(cfile(ens_exp_dict[ens_exp][mem]), cfile(mask_dict[mem]), 'snw', region_name)
            #region_name = str(tmp_region_name.values)
            print region_name
            #region_value = float(tmp.values)
            region_value = float(tmp.sel(region=list(tmp.abbrevs).index(region_name))[0].values)
            print region_value
            if region_name not in regional_averages[GWL]:
                regional_averages[GWL][region_name] = [region_value]
            else:
                regional_averages[GWL][region_name].append(region_value)
# Out:
# 1.5
# HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 92.4405848043
# NEN
# 87.2590944957
# WNA
# 85.2258164638
# CNA
# 36.5588944428
# ENA
# 74.7595207179
# NCA
# 18.1990566254
# CAR
# nan
# MPI-ESM-LR_r1i1p1_GERICS-REMO2015_85
# NWN
# 67.0214348548
# NEN
# 67.3272948824
# WNA
# 58.1995269864
# CNA
# 33.4331582265
# ENA
# 39.5774409147
# NCA
# nan
# CAR
# nan
# HadGEM2-ES_r1i1p1_GERICS-REMO2015_85
# NWN
# 62.1449948907
# NEN
# 59.2439237544
# WNA
# 55.9787752436
# CNA
# nan
# ENA
# 29.5302836625
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 101.125359155
# NEN
# 93.4166439127
# WNA
# 83.1142107146
# CNA
# 40.8816239542
# ENA
# 69.2530709367
# NCA
# 31.3978056747
# CAR
# nan
# HadGEM2-ES_r1i1p1_GERICS-REMO2015_26
# NWN
# 60.0134931525
# NEN
# 62.7693401625
# WNA
# 43.7027973884
# CNA
# nan
# ENA
# 23.1075958536
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_r1i1p1_GERICS-REMO2015_26
# NWN
# 73.7745122181
# NEN
# 67.6758782647
# WNA
# 58.6318684033
# CNA
# 37.4812194229
# ENA
# 49.7569749961
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 99.3435656341
# NEN
# 93.2726388744
# WNA
# 86.9310517187
# CNA
# 43.5181067085
# ENA
# 75.0898854201
# NCA
# 33.0947602118
# CAR
# nan
# NorESM1-M_r1i1p1_GERICS-REMO2015_85
# NWN
# 60.0371026352
# NEN
# 60.8607474807
# WNA
# 54.2263396248
# CNA
# nan
# ENA
# 38.8479796846
# NCA
# nan
# CAR
# nan
# 3
# HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 88.6683102944
# NEN
# 88.5531354701
# WNA
# 62.8504640916
# CNA
# 37.1017507442
# ENA
# 63.89548546
# NCA
# 9.4458990097
# CAR
# nan
# MPI-ESM-LR_r1i1p1_GERICS-REMO2015_85
# NWN
# 63.7239093254
# NEN
# 62.4021799288
# WNA
# 38.3651614451
# CNA
# 23.0203241338
# ENA
# 37.1502958015
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 100.581077535
# NEN
# 91.583448964
# WNA
# 70.7005527202
# CNA
# 41.3365383213
# ENA
# 69.9067147031
# NCA
# 14.185985922
# CAR
# nan
# HadGEM2-ES_r1i1p1_GERICS-REMO2015_85
# NWN
# 50.0011037602
# NEN
# 55.6918252506
# WNA
# 27.4801141405
# CNA
# nan
# ENA
# 16.6231398437
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 101.31314843
# NEN
# 95.3105216217
# WNA
# 73.9379335898
# CNA
# 39.2986213791
# ENA
# 56.3646108822
# NCA
# 7.58223495457
# CAR
# nan
# NorESM1-M_r1i1p1_GERICS-REMO2015_85
# NWN
# 52.8984589774
# NEN
# 55.9320085894
# WNA
# 34.4365464894
# CNA
# nan
# ENA
# 16.4930228989
# NCA
# nan
# CAR
# nan
# 2
# HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 91.8299776419
# NEN
# 88.337989269
# WNA
# 85.8128175889
# CNA
# 33.0704107548
# ENA
# 72.9691434525
# NCA
# 25.2747154236
# CAR
# nan
# MPI-ESM-LR_r1i1p1_GERICS-REMO2015_85
# NWN
# 69.6903559244
# NEN
# 68.2308041115
# WNA
# 61.8951470954
# CNA
# 39.1295230616
# ENA
# 48.0657481784
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 100.923818298
# NEN
# 98.2874176339
# WNA
# 82.3886319339
# CNA
# 53.0270291642
# ENA
# 79.1061249287
# NCA
# 15.7103859556
# CAR
# nan
# HadGEM2-ES_r1i1p1_GERICS-REMO2015_85
# NWN
# 56.4561947741
# NEN
# 60.5579284094
# WNA
# 50.060567596
# CNA
# nan
# ENA
# 24.8069773768
# NCA
# nan
# CAR
# nan
# GFDL-ESM2M_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 101.265987296
# NEN
# 94.7005384477
# WNA
# 80.6894559585
# CNA
# 41.3958820666
# ENA
# 64.1602837884
# NCA
# 22.9284345479
# CAR
# nan
# NorESM1-M_r1i1p1_GERICS-REMO2015_85
# NWN
# 58.6899712567
# NEN
# 57.7707806285
# WNA
# 46.4714444232
# CNA
# nan
# ENA
# 31.8491825731
# NCA
# nan
# CAR
# nan
# 4
# HadGEM2-ES_r1i1p1_GERICS-REMO2015_85
# NWN
# 43.2389647429
# NEN
# 46.9700069686
# WNA
# 19.5091849126
# CNA
# nan
# ENA
# 6.80164375057
# NCA
# nan
# CAR
# nan
# MPI-ESM-LR_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 94.0396359313
# NEN
# 86.309437204
# WNA
# 60.5534705762
# CNA
# 24.8163933676
# ENA
# 57.5987831815
# NCA
# 3.44840891174
# CAR
# nan
# HadGEM2-ES_r1i1p1_ISU-RegCM4-v4.4_85
# NWN
# 85.5393267471
# NEN
# 86.3005420999
# WNA
# 56.0103849394
# CNA
# 29.1282098561
# ENA
# 55.6899485279
# NCA
# 1.77795863152
# CAR
# nan
# MPI-ESM-LR_r1i1p1_GERICS-REMO2015_85
# NWN
# 52.5639844528
# NEN
# 54.7645333451
# WNA
# 30.7064442581
# CNA
# 9.64904370137
# ENA
# 20.7029707748
# NCA
# nan
# CAR
# nan

# %%
import numpy
quantiles_dict = dict()
for clim_period in regional_averages:
    quantiles_dict[clim_period] = dict()
    for region_name in regional_averages[clim_period]:
        print clim_period, region_name
        quantiles_dict[clim_period][region_name] = dict()
        dat = np.array(regional_averages[clim_period][region_name])
        q10 = np.quantile(dat, 0.1)
        q50 = np.quantile(dat, 0.5)
        q90 = np.quantile(dat, 0.9)
        quantiles_dict[clim_period][region_name] = [q10, q50, q90]
# Out:
# 26_2081_209* NEN
# 26_2081_209* ENA
# 26_2081_209* WNA
# 26_2081_209* CAR
# 26_2081_209* CNA
# 26_2081_209* NCA
# 26_2081_209* NWN
# 1.5 NEN
# 1.5 ENA
# 1.5 WNA
# 1.5 CAR
# 1.5 CNA
# 1.5 NCA
# 1.5 NWN
# 85_1995_2014 NEN
# 85_1995_2014 ENA
# 85_1995_2014 WNA
# 85_1995_2014 CAR
# 85_1995_2014 CNA
# 85_1995_2014 NCA
# 85_1995_2014 NWN
# 26_2041_2060 NEN
# 26_2041_2060 ENA
# 26_2041_2060 WNA
# 26_2041_2060 CAR
# 26_2041_2060 CNA
# 26_2041_2060 NCA
# 26_2041_2060 NWN
# 85_2081_209* NEN
# 85_2081_209* ENA
# 85_2081_209* WNA
# 85_2081_209* CAR
# 85_2081_209* CNA
# 85_2081_209* NCA
# 85_2081_209* NWN
# 3 NEN
# 3 ENA
# 3 WNA
# 3 CAR
# 3 CNA
# 3 NCA
# 3 NWN
# 2 NEN
# 2 ENA
# 2 WNA
# 2 CAR
# 2 CNA
# 2 NCA
# 2 NWN
# 4 NEN
# 4 ENA
# 4 WNA
# 4 CAR
# 4 CNA
# 4 NCA
# 4 NWN
# 85_2041_2060 NEN
# 85_2041_2060 ENA
# 85_2041_2060 WNA
# 85_2041_2060 CAR
# 85_2041_2060 CNA
# 85_2041_2060 NCA
# 85_2041_2060 NWN

# %%
import json
ensemble = 'NAM-22_CORDEX'
outfilename = '/home/jservon/Chapter12_IPCC/data/snw/'+ensemble+'_NORTH-AMERICA_snw_AR6_regional_averages.json'
#print outfilename
with open(outfilename, 'w') as fp:
    json.dump(quantiles_dict, fp, sort_keys=True, indent=4)

# %%
# Creer une grille lon/lat pour chaque CORDEX domain
# regriller sur cette grille
# missing values outside the domain
#   => ok to retrieve the regions
#   => not ok to check if the region is completely covered
#   => check by hand?
#   => if CORDEX_domain = ... ; then subregions = [...]
#   => if partially covered => No!
# AFR, 3 domains for America, Aus = ok, 3 domains over Asia, 1 over Europe =
#   8 domains = feasable
# AFR, et Asia = ok; need Europe, and the Americas

# %%
# Prendre un champ de chaque domain, faire un plot avec toutes les regions
# Selectionner a la main

# Si on prend les regions partiellement couvertes:
#  - on regrille CMIP6 et CMIP5 sur tous les domains CORDEX
#  - en multipliant par un mask pour mettre des missing

# %%
ncdump(ens_CORDEX[short_CORDEX_domain][ens_exp][mem])
# Out:
# netcdf \074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67 {
# dimensions:
# 	time = UNLIMITED ; // (1 currently)
# 	bnds = 2 ;
# 	x = 477 ;
# 	y = 497 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 2045-12-30" ;
# 		time:calendar = "360_day" ;
# 		time:axis = "T" ;
# 	double time_bnds(time, bnds) ;
# 	double lon(y, x) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "Longitude on Cross Points" ;
# 		lon:units = "degrees_east" ;
# 		lon:_CoordinateAxisType = "Lon" ;
# 	double lat(y, x) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "Latitude on Cross Points" ;
# 		lat:units = "degrees_north" ;
# 		lat:_CoordinateAxisType = "Lat" ;
# 	double x(x) ;
# 		x:standard_name = "projection_x_coordinate" ;
# 		x:long_name = "x-coordinate in Cartesian system" ;
# 		x:units = "m" ;
# 		x:axis = "X" ;
# 	double y(y) ;
# 		y:standard_name = "projection_y_coordinate" ;
# 		y:long_name = "y-coordinate in Cartesian system" ;
# 		y:units = "m" ;
# 		y:axis = "Y" ;
# 	float WBGTindoor(time, y, x) ;
# 		WBGTindoor:long_name = "Number of days per year with wet-bulb temperature above Exceed33 degC" ;
# 		WBGTindoor:units = "days" ;
# 		WBGTindoor:coordinates = "lat lon" ;
# 		WBGTindoor:_FillValue = 1.e+20f ;
# 		WBGTindoor:missing_value = 1.e+20f ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Wed Feb 03 16:41:26 2021: cdo -O -timmean -selname,WBGTindoor /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc /data/jservon/climafcache/17/074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67_34809.nc\nWed Feb  3 15:47:08 2021: ncatted -O -a coordinates,WBGTindoor,o,c,time lat lon -a units,WBGTindoor,o,c,days -a long_name,WBGTindoor,o,c,Number of days per year with wet-bulb temperature above Exceed33 degC /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc\nWed Feb 03 15:47:07 2021: cdo -b 32 setmissval,1e+20 -copy /data/ciles/IPCC/FGD/WBGT_FGD/CORDEX-AFR-22_share/MOHC-HadGEM2-ES_ICTP-RegCM4-7/WBGT_Exceed33_MOHC-HadGEM2-ES_ICTP-RegCM4-7_rcp85_r1i1p1_3.0K_QDM_HI.nc /data/jservon/IPCC/WBGT/CORDEX/AFR-22/MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1_Exceed33_rcp85_3.0K.nc" ;
# 		:Conventions = "CF-1.6" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "time_average(ds(\'wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp85%3.0K%AFR-22%MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1%Exceed33\'))" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.13 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/jservon/climafcache/17/074711fb002bc1317c7f5f1c4061cc2ab06afbc9ecb09c9df8dd67.nc
# ncdump(time_average(ds('wbgt_cordex_ch12_test%%WBGTindoor%fx%global%rcp85%3.0K%AFR-22%MOHC-HadGEM2-ES--ICTP-RegCM4-7_r1i1p1%Exceed33')))

# %%
# If region is not entireley covered => 0
# Do the map with regions on top and hatching
# Start the barplot:
# - retrieve values from json file
# - do the plot for one region
# Start to build the multiplot
#

# %% [markdown]
# #
# #
# #

# %%
regionmask.defined_regions.ar6.all.abbrevs.index('CAR')
# Out:
# 8

# %%
ar6_land = regionmask.defined_regions.ar6.land
ar6_land
# Out:
# <regionmask.Regions>
# Name:     AR6 reference regions (land only)
# Source:   Iturbide et al., 2020 (Earth Syst. Sci. Data)
#
# Regions:
#   0  GIC  Greenland/Iceland
#   1  NWN  N.W.North-America
#   2  NEN  N.E.North-America
#   3  WNA    W.North-America
#   4  CNA    C.North-America
# ..   ...                ...
#  41  EAU        E.Australia
#  42  SAU        S.Australia
#  43   NZ        New-Zealand
#  44  EAN       E.Antarctica
#  45  WAN       W.Antarctica
#
# [46 regions]

# %%
ar6_land.abbrevs
# Out:
# [u'GIC',
#  u'NWN',
#  u'NEN',
#  u'WNA',
#  u'CNA',
#  u'ENA',
#  u'NCA',
#  u'SCA',
#  u'CAR',
#  u'NWS',
#  u'NSA',
#  u'NES',
#  u'SAM',
#  u'SWS',
#  u'SES',
#  u'SSA',
#  u'NEU',
#  u'WCE',
#  u'EEU',
#  u'MED',
#  u'SAH',
#  u'WAF',
#  u'CAF',
#  u'NEAF',
#  u'SEAF',
#  u'WSAF',
#  u'ESAF',
#  u'MDG',
#  u'RAR',
#  u'WSB',
#  u'ESB',
#  u'RFE',
#  u'WCA',
#  u'ECA',
#  u'TIB',
#  u'EAS',
#  u'ARP',
#  u'SAS',
#  u'SEA',
#  u'NAU',
#  u'CAU',
#  u'EAU',
#  u'SAU',
#  u'NZ',
#  u'EAN',
#  u'WAN']

# %%
ar6_land.names
# Out:
# [u'Greenland/Iceland',
#  u'N.W.North-America',
#  u'N.E.North-America',
#  u'W.North-America',
#  u'C.North-America',
#  u'E.North-America',
#  u'N.Central-America',
#  u'S.Central-America',
#  u'Caribbean',
#  u'N.W.South-America',
#  u'N.South-America',
#  u'N.E.South-America',
#  u'South-American-Monsoon',
#  u'S.W.South-America',
#  u'S.E.South-America',
#  u'S.South-America',
#  u'N.Europe',
#  u'West&Central-Europe',
#  u'E.Europe',
#  u'Mediterranean',
#  u'Sahara',
#  u'Western-Africa',
#  u'Central-Africa',
#  u'N.Eastern-Africa',
#  u'S.Eastern-Africa',
#  u'W.Southern-Africa',
#  u'E.Southern-Africa',
#  u'Madagascar',
#  u'Russian-Arctic',
#  u'W.Siberia',
#  u'E.Siberia',
#  u'Russian-Far-East',
#  u'W.C.Asia',
#  u'E.C.Asia',
#  u'Tibetan-Plateau',
#  u'E.Asia',
#  u'Arabian-Peninsula',
#  u'S.Asia',
#  u'S.E.Asia',
#  u'N.Australia',
#  u'C.Australia',
#  u'E.Australia',
#  u'S.Australia',
#  u'New-Zealand',
#  u'E.Antarctica',
#  u'W.Antarctica']
