# %% [markdown]
# ## Get the data

# %%
import os

for CORDEX_domain in ['SEA']:
    #['WAS','EAS','SEA']:
    rootdir='/data/jservon/IPCC/Q100/CORDEX-core/'+CORDEX_domain+'/'
    Q100_baseline = rootdir+'Q100_rcp85_1995-2014.nc'
    Q100_85late = rootdir+'Q100_rcp85_2080-2099.nc'

    # -- Function to split a multi-member file in individual files
    # -- Uses Xarray
    def split_Q100_ensemble_file(ensemble_file, output_pattern, variable):
        if not os.path.isdir(os.path.dirname(output_pattern)):
            os.makedirs(os.path.dirname(output_pattern))
        import xarray as xr
        dat = xr.open_dataset(ensemble_file)[variable]
        for i in range(0,len(dat.RP)):
            #print dat[i,:,:].shape    for member in dat.member:
            #member_name = str(member.values)
            #print member_name
            outfilename = output_pattern+'_model'+str(i)+'.nc'
            if not os.path.isfile(outfilename):
                print 'Save '+outfilename
                member_dat = dat[i,:,:]
                member_dat.to_netcdf(outfilename)
            else:
                print outfilename+' already exists'
    #
    # -- Select Q100
    for wfile in [Q100_baseline, Q100_85late]:
        filename = os.path.basename(wfile)
        output_dir = wfile.replace('.nc','/')
        #is not os.path.isdir(output_dir):
        #    os.makedirs(output_dir)
        output_pattern = output_dir + filename.replace('.nc','')
        split_Q100_ensemble_file(wfile,output_pattern, 'QRP')
# Out:
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model0.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model1.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model2.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model3.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model4.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_1995-2014/Q100_rcp85_1995-2014_model5.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model0.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model1.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model2.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model3.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model4.nc
# Save /data/jservon/IPCC/Q100/CORDEX-core/SEA/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model5.nc

# %%
from climaf.api import *
# Out:
# CliMAF version = 1.2.13
# CliMAF install => /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post
# python => /modfs/modtools/miniconda2/envs/analyse_2.7/bin/python
# ---
# Required softwares to run CliMAF => you are using the following versions/installations:
# ncl 6.6.2 => /modfs/modtools/miniconda2/envs/analyse_2.7/bin/ncl
# cdo 1.9.6 => /opt/nco/1.9/bin/cdo
# nco (ncks) 4.5.2 => /opt/nco-4.5.2/bin/ncks
# ncdump fichier => /modfs/modtools/miniconda2/envs/analyse_2.7/bin/ncdump
# Check stamping requirements
# nco (ncatted) found -> /opt/nco-4.5.2/bin/ncatted
# convert found -> /modfs/modtools/miniconda2/envs/analyse_2.7/bin/convert
# pdftk found -> /usr/bin/pdftk
# exiv2 found -> /ciclad-home/jservon/Evaluation/CliMAF/climaf_installs/climaf_V1.2.13_post/bin/exiv2
# ---
# Cache directory set to : /data/jservon/climafcache (use $CLIMAF_CACHE if set)
# Cache directory for remote data set to : /data/jservon/climafcache/remote_data (use $CLIMAF_REMOTE_CACHE if set)
# warning  : When defining temp_penalty : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# warning  : When defining cquantile : duplicate declaration for input #0
# Available macros read from ~/.climaf.macros are : []

# %%
pattern = '/data/jservon/IPCC/Q100/CORDEX-core/${CORDEX_domain}/Q100_rcp85_${clim_period}/Q100_rcp85_${clim_period}_${model}.nc'
cproject('Q100_CORDEX-CORE','CORDEX_domain','clim_period',('period','fx'),'model', ('variable','Q100'), ensemble=['model'], separator='%')
dataloc(project='Q100_CORDEX-CORE', url=pattern)
calias('Q100_CORDEX-CORE','Q100','QRP')

# %%
for CORDEX_domain in ['WAS','EAS','SEA']:
    #:
    req_late = ds(project='Q100_CORDEX-CORE',
                  CORDEX_domain=CORDEX_domain,
                  clim_period='2080-2099',
                  model='*'
                 )
    late_ensemble = req_late.explore('ensemble')

    req_baseline = ds(project='Q100_CORDEX-CORE',
                      CORDEX_domain=CORDEX_domain,
                      clim_period='1995-2014',
                      model='*'
                     )
    baseline_ensemble = req_baseline.explore('ensemble')

    change_baseline_late = fsub(late_ensemble, baseline_ensemble)

    ensmedian_change = ccdo_ens(change_baseline_late, operator='enspctl,50')
    print CORDEX_domain
    print cfile(ensmedian_change)
# Out:
# WAS
# /data/jservon/climafcache/01/c3e25089e9fa76e80c2596872377bffbe4edf2ce52039dff1cffe2.nc
# EAS
# /data/jservon/climafcache/b6/678b1166bce235d041987b5b45c0f8616b68bd02042b75d93feb36.nc
# SEA
# /data/jservon/climafcache/05/e5a0919afd971c8a22039691995595b92f5008fc533727dc7f7be7.nc

# %%
#           signif90_dict[wfuture],
#           shade_above = -0.99999,
#           focus='land',
#           proj='Robinson',
#           shading_options='gsnShadeHigh=3|gsnShadeFillScales=0.3'

fld = regridn(ensmedian_change, cdogrid='r360x180', option='remapcon')
mask = ccdo(fld, operator='gtc,0')
iplot(plot(fld,
           mask,
           shade_above = 0.9,
           min=-100,max=100, delta=10,
           color='MPL_BrBG',
           options='cnFillMode=RasterFill|cnRasterSmoothingOn=False',
           shading_options='gsnShadeHigh=3'#|gsnShadeFillScales=0.9'
          )
     )

# %%
ncdump(fld)
# Out:
# netcdf \0990e18ec08512a5018dfd937bc75c61dd8d38769261da4f775dd1 {
# dimensions:
# 	lon = 360 ;
# 	lat = 180 ;
# variables:
# 	double lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	double lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	float Q100(lat, lon) ;
# 		Q100:_FillValue = 1.e+20f ;
# 		Q100:missing_value = 1.e+20f ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.9.6 (http://mpimet.mpg.de/cdi)" ;
# 		:history = "Thu Jan 21 16:57:10 2021: cdo remapcon,r360x180 /data/jservon/climafcache/92/ed9d29785b60901846e62246d3b317b1bce46db336321048b5f8e9.nc /data/jservon/climafcache/c4/0990e18ec08512a5018dfd937bc75c61dd8d38769261da4f775dd1_15440.nc\nThu Jan 21 14:44:07 2021: cdo enspctl,50 /data/jservon/climafcache/69/1d682d90b3a42be7af4f71c3fbc1a8df9e7223490b4deba3eb8b99.nc /data/jservon/climafcache/cc/5deccdc24cffe7d2a6e6c9e95c5734e25f140f67f7fd1d58931b8e.nc /data/jservon/climafcache/92/2c49e880635d81b439a332424e6dc92e8417b9a37e08c40235181d.nc /data/jservon/climafcache/53/5b208b4dfe5479c1118ee9fa3817f303a3ff185b094f1e050eb76d.nc /data/jservon/climafcache/d2/524f1c81e4782474ee2a6ad4ae0a0439cc473b530ad02b46faf290.nc /data/jservon/climafcache/27/895e0f881985b87b476d32fb64649d9c72b98a00c000feef947b03.nc /data/jservon/climafcache/92/ed9d29785b60901846e62246d3b317b1bce46db336321048b5f8e9_63788.nc\nThu Jan 21 14:44:00 2021: cdo sub /data/jservon/climafcache/3e/b74749bbaf08b718e84792e4ecbc1c247779d7eb9b1c9bc229011b.nc /data/jservon/climafcache/63/c8994c03452de8fbe5c77d7b1ebe6c037c66609cc44157cb3cc0a0.nc /data/jservon/climafcache/69/1d682d90b3a42be7af4f71c3fbc1a8df9e7223490b4deba3eb8b99_63788.nc\nThu Jan 21 14:43:59 2021: cdo -O -copy -selname,Q100 -expr,Q100=QRP*1+0 /data/jservon/IPCC/Q100/CORDEX-core/AFR/Q100_rcp85_2080-2099/Q100_rcp85_2080-2099_model0.nc /data/jservon/climafcache/3e/b74749bbaf08b718e84792e4ecbc1c247779d7eb9b1c9bc229011b_63788.nc" ;
# 		:Conventions = "CF-1.6" ;
# 		:CDO = "Climate Data Operators version 1.9.6 (http://mpimet.mpg.de/cdo)" ;
# 		:CRS_def = "regridn(ccdo_ens(cens({\'model0\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model0\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model0\')),\'model1\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model1\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model1\')),\'model2\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model2\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model2\')),\'model3\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model3\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model3\')),\'model4\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model4\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model4\')),\'model5\':minus(ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model5\'),ds(\'Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model5\'))}),operator=\'enspctl,50\'),cdogrid=\'r360x180\',option=\'remapcon\')" ;
# 		:CliMAF = "CLImate Model Assessment Framework version 1.2.13 (http://climaf.rtfd.org)" ;
# }
#
#
# stdout and stderr of script call :
# 	 ncdump -h /data/jservon/climafcache/c4/0990e18ec08512a5018dfd937bc75c61dd8d38769261da4f775dd1.nc
# ncdump(regridn(ccdo_ens(cens({'model0':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model0'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model0')),'model1':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model1'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model1')),'model2':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model2'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model2')),'model3':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model3'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model3')),'model4':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model4'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model4')),'model5':minus(ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%2080-2099%model5'),ds('Q100_CORDEX-CORE%%Q100%fx%global%AFR%1995-2014%model5'))}),operator='enspctl,50'),cdogrid='r360x180',option='remapcon'))

# %%
ncfile = cfile(ensmedian_change)
ncfile
# Out:
# '/data/jservon/climafcache/92/ed9d29785b60901846e62246d3b317b1bce46db336321048b5f8e9.nc'

# %%
fld = llbox(regridn(ensmedian_change, cdogrid='r720x360', option='remapcon'),
                  lonmin= region_dict['lonmin'],
                  lonmax= region_dict['lonmax'],
                  latmin= region_dict['latmin'],
                  latmax= region_dict['latmax'])
mask = ccdo(fld, operator='gtc,0')
#mask_file = cfile(mask)
#mask_file
cfile(mask)
# Out:
# '/data/jservon/climafcache/39/dc7a83cfcf10113cad1f29305494174fd0222bc0e1227a2ae55bcb.nc'

# %%
mask_NA = ccdo(mask, operator='setctomiss,0')
cfile(mask_NA)
# Out:
# '/data/jservon/climafcache/0e/a88dee508ad9f21b76992506a38e4ad5f63fbfe3a12894c3e45f10.nc'

# %%
implot(mask)

# %%
dir(Ngl)
# Out:
# ['PlotIds',
#  'Resources',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__version__',
#  '_ngl_all',
#  'add_annotation',
#  'add_cyclic',
#  'add_lat_90',
#  'add_new_coord_limits',
#  'add_polygon',
#  'add_polyline',
#  'add_polymarker',
#  'add_text',
#  'asciiread',
#  'betainc',
#  'blank_plot',
#  'change_workstation',
#  'chiinv',
#  'clear_workstation',
#  'contour',
#  'contour_map',
#  'datatondc',
#  'define_colormap',
#  'delete_wks',
#  'destroy',
#  'dim_gbits',
#  'draw',
#  'draw_color_palette',
#  'draw_colormap',
#  'draw_ndc_grid',
#  'end',
#  'frame',
#  'free_color',
#  'fspan',
#  'ftcurv',
#  'ftcurvp',
#  'ftcurvpi',
#  'gaus',
#  'gc_convert',
#  'gc_dist',
#  'gc_inout',
#  'gc_interp',
#  'gc_qarea',
#  'gc_tarea',
#  'generate_2d_array',
#  'get_MDfloat_array',
#  'get_MDinteger_array',
#  'get_bounding_box',
#  'get_float',
#  'get_float_array',
#  'get_integer',
#  'get_integer_array',
#  'get_named_color_index',
#  'get_string',
#  'get_string_array',
#  'get_workspace_id',
#  'hlsrgb',
#  'hsvrgb',
#  'ind',
#  'int2p',
#  'labelbar_ndc',
#  'legend_ndc',
#  'linmsg',
#  'map',
#  'maximize_plot',
#  'merge_colormaps',
#  'natgrid',
#  'ndctodata',
#  'nearlyequal',
#  'new_color',
#  'new_dash_pattern',
#  'new_marker',
#  'nice_cntr_levels',
#  'nngetp',
#  'nnsetp',
#  'normalize_angle',
#  'open_wks',
#  'overlay',
#  'panel',
#  'polygon',
#  'polygon_ndc',
#  'polyline',
#  'polyline_ndc',
#  'polymarker',
#  'polymarker_ndc',
#  'pynglpath',
#  'read_colormap_file',
#  'regline',
#  'remove_annotation',
#  'remove_overlay',
#  'retrieve_colormap',
#  'rgbhls',
#  'rgbhsv',
#  'rgbyiq',
#  'set_color',
#  'set_values',
#  'skewt_bkg',
#  'skewt_plt',
#  'streamline',
#  'streamline_map',
#  'streamline_scalar',
#  'streamline_scalar_map',
#  'taylor_diagram',
#  'text',
#  'text_ndc',
#  'update_workstation',
#  'vector',
#  'vector_map',
#  'vector_scalar',
#  'vector_scalar_map',
#  'vinth2p',
#  'wmbarb',
#  'wmbarbmap',
#  'wmgetp',
#  'wmsetp',
#  'wmstnm',
#  'wrf_avo',
#  'wrf_dbz',
#  'wrf_ij_to_ll',
#  'wrf_ll_to_ij',
#  'wrf_map_resources',
#  'wrf_pvo',
#  'wrf_rh',
#  'wrf_slp',
#  'wrf_td',
#  'wrf_tk',
#  'xy',
#  'y',
#  'yiqrgb']

# %%
import Ngl, Nio
import os, numpy, csv, json
from IPython.display import Image
from shapely.geometry import Polygon, Point
import geopandas

#CORDEX_domain = 'WAS'
#ncfile = '/data/jservon/climafcache/01/c3e25089e9fa76e80c2596872377bffbe4edf2ce52039dff1cffe2.nc'
#CORDEX_domain = 'EAS'
#ncfile = '/data/jservon/climafcache/b6/678b1166bce235d041987b5b45c0f8616b68bd02042b75d93feb36.nc'
CORDEX_domain = 'SEA'
ncfile = '/data/jservon/climafcache/05/e5a0919afd971c8a22039691995595b92f5008fc533727dc7f7be7.nc'

#ncfile = '/data/jservon/climafcache/92/ed9d29785b60901846e62246d3b317b1bce46db336321048b5f8e9.nc'

#mask_file = '/data/jservon/climafcache/39/dc7a83cfcf10113cad1f29305494174fd0222bc0e1227a2ae55bcb.nc'
#----------------------------------------------------------------------
#  Add the trajectory lines.
#----------------------------------------------------------------------
def retrieve_AR6regions_for_region(region_name):

    regions_filename='/home/jservon/Chapter12_IPCC/scripts/ATLAS/reference-regions/IPCC-WGI-reference-regions-v4_coordinates.csv'

    # -- Store the informations by region in the 'regions' dictionary
    regions = dict()
    with open(regions_filename) as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',')#, quotechar='|')
        for row in spamreader:
            #if row[0]==region_name:
            if region_name in row[0]:
                region_dict = dict()
                lats_vect = []
                lons_vect = []
                tmp_polygon_vertices = []
                for vertice in row[4:-1]:
                    if vertice:
                        dum = vertice.split('|')
                        lons_vect.append(float(dum[0]))
                        lats_vect.append(float(dum[1]))
                        tmp_polygon_vertices.append( (float(dum[0]), float(dum[1])) )
                region_dict['polygon'] = Polygon(tmp_polygon_vertices)
                region_dict['lons_vect'] = lons_vect
                region_dict['lats_vect'] = lats_vect
                #
                regions[row[3]] = region_dict
    #
    return regions


#
def add_AR6regions(wks, base_map, regions):
    #
    txres                       = Ngl.Resources()  
    txres.txFontHeightF         = 0.018
    
    gsres                   = Ngl.Resources()
    # Polyline resources.
    gsres.gsLineColor       = "Black"
    gsres.gsLineThicknessF  = 3.0      # thrice thickness

    for subregion in regions:
        #if subregion not in ['RAR','WSB','TIB','ECA', 'ESB']:
        #if regions[subregion]['region']==region_name:
        lons_vect = regions[subregion]['lons_vect']
        lats_vect = regions[subregion]['lats_vect']
        # Draw a text string labeling the marker
        Ngl.add_text(wks,base_map, subregion, numpy.mean(lons_vect), numpy.mean(lats_vect), txres)

        # -- Close the polygon
        lons_vect.append(lons_vect[0])
        lats_vect.append(lats_vect[0])
        poly1 = Ngl.add_polyline(wks,base_map,lons_vect,lats_vect,gsres)

    return


def create_Q100_map(wks, ncfile, region_dict, title):
    
    f    = Nio.open_file(ncfile)
    dat  = f.variables["Q100"][:,:]
    lat  = f.variables["lat"][:]
    lon  = f.variables["lon"][:]

    cnres                 = Ngl.Resources()
    cnres.nglDraw  = False
    cnres.nglFrame = False
    cnres.nglMaximize = False

    # Contour resources
    cnres.cnFillOn        = True
    cnres.cnLevelSelectionMode = "ManualLevels"
    cnres.cnLevelSpacingF      = 10
    cnres.cnMinLevelValF       = -100
    cnres.cnMaxLevelValF       = 100

    cnres.cnFillPalette   = "MPL_BrBG"      # New in PyNGL 1.5.0
    cnres.cnLinesOn       = False
    cnres.cnLineLabelsOn  = False
    cnres.cnFillMode             = "RasterFill"
    cnres.cnRasterSmoothingOn = False
    #cnres.cnLevels = inc

    # Labelbar resource
    cnres.lbOrientation   = "horizontal"
    cnres.lbBoxEndCapStyle= "TriangleBothEnds"
    cnres.lbLabelFontHeightF = 0.018
    cnres.pmLabelBarOrthogonalPosF = 0.02
    cnres.pmLabelBarWidthF = 0.6
    cnres.pmLabelBarHeightF = 0.1
    #pmLabelBarWidthF
    

    # Scalar field resources
    cnres.sfXArray        = lon
    cnres.sfYArray        = lat

    # Map resources
    cnres.mpFillOn               = True
    cnres.mpFillDrawOrder        = "PostDraw"
    cnres.mpLandFillColor        = "Transparent"
    cnres.mpOceanFillColor       = "Gray"
    cnres.mpInlandWaterFillColor = "Transparent"
    cnres.mpGridAndLimbOn      =  False                  #-- don't draw grid lines
    cnres.mpLimitMode = "LatLon"
    #res.mpGridLineColor = -1
    cnres.mpMaxLatF   = region_dict['latmax']           # select subregion
    cnres.mpMinLatF   = region_dict['latmin']
    cnres.mpMinLonF   = region_dict['lonmin']
    cnres.mpMaxLonF   = region_dict['lonmax']
    # Remove box around plot
    #cnres.pmTickMarkDisplayMode = "Never"
    cnres.lbLabelBarOn = True

    # Remove Lon/lat ticks
    cnres.tmXBOn = False
    cnres.tmYLOn = False
    cnres.tmXTOn = False
    cnres.tmYROn = False
    #cnres.gsnPanelBottom = 0.2
    #cnres.gsnPanelYWhiteSpacePercent = 20

    # Titles
    cnres.tiMainString = title
    
    return Ngl.contour_map(wks,dat,cnres), cnres, dat


def create_shading_layer(wks, mask_file, region_dict, title):
    
    f    = Nio.open_file(mask_file)
    dat  = f.variables["Q100"][:,:]
    lat  = f.variables["lat"][:]
    lon  = f.variables["lon"][:]

    cnres                 = Ngl.Resources()
    cnres.nglDraw  = False
    cnres.nglFrame = False
    cnres.nglMaximize = False
    #
    cnres.gsnShadeFillType = "pattern"
    cnres.gsnShadeHigh     = 1

    # Contour resources
    cnres.cnFillOn        = True
    #cnres.cnMonoFillPattern = True
    #cnres.cnFillPattern = 3
    #cnres.cnMinLevelValF = 0.9
    cnres.cnMonoFillPattern = False
    cnres.cnFillPatterns = [-1,10]
    cnres.cnMinLevelValF = 0.9
    cnres.cnMaxLevelValF = 0.9
    cnres.cnLinesOn       = False
    cnres.cnLineLabelsOn  = False
    cnres.cnFillColors      = [ 1, 1]
    #cnres.cnFillMode             = "RasterFill"
    #cnres.cnRasterSmoothingOn = False

    # Scalar field resources
    cnres.sfXArray        = lon
    cnres.sfYArray        = lat

    # Map resources
    cnres.mpFillOn               = False
    #cnres.mpFillDrawOrder        = "PostDraw"
    #cnres.mpLandFillColor        = "Transparent"
    #cnres.mpOceanFillColor       = "Gray"
    #cnres.mpInlandWaterFillColor = "Transparent"
    cnres.mpGridAndLimbOn      =  False                  #-- don't draw grid lines
    
    cnres.mpLimitMode = "LatLon"
    #res.mpGridLineColor = -1
    cnres.mpMaxLatF   = region_dict['latmax']           # select subregion
    cnres.mpMinLatF   = region_dict['latmin']
    cnres.mpMinLonF   = region_dict['lonmin']
    cnres.mpMaxLonF   = region_dict['lonmax']
    # Remove box around plot
    cnres.pmTickMarkDisplayMode = "Never"
    cnres.lbLabelBarOn = False

    # Remove Lon/lat ticks
    cnres.tmXBOn = False
    cnres.tmYLOn = False
    cnres.tmXTOn = False
    cnres.tmYROn = False
    #cnres.gsnPanelBottom = 0.2
    #cnres.gsnPanelYWhiteSpacePercent = 20

    # Titles
    cnres.tiMainString = title
    
    #plot(1) = gsn_contour_shade(plot(1), 0, 15.5, cnres)
    return Ngl.contour_map(wks,dat,cnres)
    #Ngl.contour_shade(wks, dat, 


def layer_AR6_regions(wks, cnres):
    cnres2                 = cnres
    # Contour resources
    cnres2.cnFillOn        = False

    # Map resources
    cnres2.mpFillOn               = False
    return Ngl.map(wks,cnres2)
    #return Ngl.contour_map(wks, dat, cnres2)
    


inc = [-100, -80, -60, -40, -20, -10, 0, 10, 20, 40, 60, 80, 100]


title = 'Q100 discharge'
scenario = 'RCP85'
horizon = '2100'
region_dict = dict(name='ASIA',
                    lonmin = 20,
                    lonmax = 180,
                    latmin = -20,
                    latmax = 80
                   )

outfilename='Q100_test_'+CORDEX_domain+'_'+region_dict['name']

ncfile='/home/jservon/Chapter12_IPCC/data/ASIA_map_fig_Q100/EAS_WAS_SEA_ensmedian_test.nc'
#ncfile='/home/jservon/Chapter12_IPCC/scripts/dev_tests/ASIA_Q100_composite.nc'

#do_map = True
#do_colorbar = True
wks_type = "png"

#if do_map:
wks = Ngl.open_wks(wks_type, outfilename)

wmap, cnres, dat = create_Q100_map(wks, ncfile, region_dict, ' ')
#shading_map = create_shading_layer(wks, mask_file, region_dict, ' ')

wmap_empty = layer_AR6_regions(wks, cnres)
# -- Add the AR6 regions
# -- Extract the subregions of the region
regions = retrieve_AR6regions_for_region(region_dict['name'])

add_AR6regions(wks, wmap_empty, regions)
#add_AR6regions(wks, shading_map, regions)

#Ngl.overlay(wmap, shading_map)#, wmap_empty) 
Ngl.overlay(wmap, wmap_empty) 

Ngl.draw(wmap)
#Ngl.draw(shading_map)
Ngl.draw(wmap_empty)

txres                       = Ngl.Resources()  
txres.txFontHeightF         = 0.025

# Draw a text string labeling the marker
if ncfile=='/home/jservon/Chapter12_IPCC/scripts/dev_tests/ASIA_Q100_composite.nc':
    Ngl.text_ndc(wks,'Q100 composite - RCP85 2100',0.5,0.72,txres)
if ncfile=='/home/jservon/Chapter12_IPCC/data/ASIA_map_fig_Q100/EAS_WAS_SEA_ensmedian_test.nc':
    Ngl.text_ndc(wks,'Q100 regrid + ens median - RCP85 2100',0.5,0.72,txres)
#Ngl.text_ndc(wks,'',0.5,0.83,txres)
Ngl.text_ndc(wks,"(a)",0.22,0.72,txres)




Ngl.frame(wks)

Ngl.end()
print outfilename+'.png'
Image(outfilename+'.png')
# Out:
# Q100_test_SEA_ASIA.png

# %%
os.system('python Q100_test.py')
Image(outfilename+'.png')
# Out:
# 0

# %% [markdown]
# #
# #
# #

# %%
Image(outfilename+'.png')

# %%
cnres                 = Ngl.Resources()
cnres()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-361a93661cca> in <module>()
#       1 cnres                 = Ngl.Resources()
# ----> 2 cnres()
#
# AttributeError: Resources instance has no __call__ method

# %%
# -- Trim the figure and extract the colorbar
# -----------------------------------------------
from PIL import Image as PILImage

def extract_plot(figure_file,trim_figure) :
    im = PILImage.open(figure_file)
    #box=(left, upper, right, lower).
    im_crop = im.crop((200, 150, 820, 915))
    im_crop.save(trim_figure, quality=95)


# -- color bar file
variable = 'CoastalRecession'
trim_figure = '/home/jservon/Chapter12_IPCC/figs/AFRICA_regional_figure/Q100_map_RCP85_2100.png'
# -- Extract the colorbar
extract_plot(outfilename+'.png',trim_figure)
Image(trim_figure)

# %%
# !ls -ltr
# Out:
# total 40824
# -rw-r--r-- 1 jservon ciclad     2676 21 déc.  09:31 Browse_CMIP6_data.ipynb
# -rw-r--r-- 1 jservon ciclad  4031699  5 janv. 09:43 Figure_1_multipanel.ipynb
# -rw-r--r-- 1 jservon ciclad   202499  7 janv. 14:17 pyNGL_firsttest.ipynb
# -rw-r--r-- 1 jservon ciclad   371834  8 janv. 00:20 plot_ipcc_climaf.ipynb
# -rw-r--r-- 1 jservon ciclad    84485  9 janv. 13:30 satellite2.png
# -rw-r--r-- 1 jservon ciclad    80831  9 janv. 14:43 Rplot001.png
# -rw-r--r-- 1 jservon ciclad    39759  9 janv. 15:20 satellite_coastal.png
# -rw-r--r-- 1 jservon ciclad   127721 11 janv. 21:48 satellite.png
# -rw-r--r-- 1 jservon ciclad    91381 13 janv. 18:40 Reference_Regions_R.ipynb
# -rw-r--r-- 1 jservon ciclad    12614 14 janv. 23:25 Average_over_AR6_region.ipynb
# -rw-r--r-- 1 jservon ciclad   186820 15 janv. 16:36 test.png
# -rw-r--r-- 1 jservon ciclad 32981035 15 janv. 17:03 Coastal_data_and_AR6_regions.ipynb
# -rw-r--r-- 1 jservon ciclad   168353 16 janv. 19:27 pyNGL_AR6regions.ipynb
# -rw-r--r-- 1 jservon ciclad   247181 19 janv. 17:45 CoastalRecession_map_AR6regions-Copy1.ipynb
# -rw-r--r-- 1 jservon ciclad   135312 19 janv. 21:20 test_2050_85.png
# -rw-r--r-- 1 jservon ciclad    70350 20 janv. 00:16 Untitled.ipynb
# -rw-r--r-- 1 jservon ciclad   128841 20 janv. 15:04 Coastal_Recession_2100_RCP85.png
# -rw-r--r-- 1 jservon ciclad   346899 20 janv. 15:44 CoastalRecession_map_AR6regions.ipynb
# -rw-r--r-- 1 jservon ciclad    96938 20 janv. 15:45 Split_CoastalRecession_csv_file_per_continent_json_files.ipynb
# -rw-r--r-- 1 jservon ciclad    52011 20 janv. 17:04 AFRICA_satellite_coastal.png
# -rw-r--r-- 1 jservon ciclad    54367 20 janv. 17:05 ASIA_satellite_coastal.png
# -rw-r--r-- 1 jservon ciclad   432158 20 janv. 18:49 Quantile_plot_region.ipynb
# -rw-r--r-- 1 jservon ciclad    12949 21 janv. 12:01 Average_over_AR6_region-Copy1.ipynb
# -rw-r--r-- 1 jservon ciclad      219 21 janv. 14:52 climaf.log
# -rw-r--r-- 1 jservon ciclad      761 21 janv. 14:53 last.out
# -rw-r--r-- 1 jservon ciclad   753236 21 janv. 16:00 Q100_test.png
# -rw-r--r-- 1 jservon ciclad  1020756 21 janv. 16:03 pyNGL_AR6regions_Q100.ipynb
